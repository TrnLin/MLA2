# %% [markdown]
# # Task 3 — Usage E8 with 687 added images
#
# **This follows the current main EDA's saved teacher folds.** The dataset keeps the earlier 120 additions and adds 567 more images. All earlier IDs and folds stay fixed.
#
# **Run All trains five fresh models, one per fold, for 30 epochs each.** The model recipe stays the same as E8. This tests the effect of adding data.
#
# | Control | Fixed value |
# |---|---|
# | Target | Usage; the original nine classes, including NA |
# | Input | RGB, 60 pixels wide × 80 pixels high |
# | Model | SmallCNN; widths 32, 64, 128, 256; average pooling |
# | Epochs / batch size | 30 / 128 |
# | Optimizer | AdamW; learning rate 0.001; weight decay 0.0001 |
# | Schedule | Cosine; final learning rate 0.00001 |
# | Loss | Weighted cross-entropy; effective-number beta 0.999, cap 5 |
# | Augmentation | Image shifts of up to 2 pixels, with probability 0.5 |
# | Seed / precision | 2753 / FP32 |
# | Checkpoint | Final epoch; fresh weights; no early stopping |
#
# The main comparison uses the **same teacher validation images** for three models: original E8, E8 with 120 added images, and this version with 687. Added-source scores are shown separately.

# %% [markdown]
# ## 1. Start in Colab
#
# 1. Select a **GPU** in **Runtime → Change runtime type**.
# 2. Put `teacher_plus_rare_usage_v2_training.zip` in `MyDrive/MLA2/data/`.
# 3. Keep the existing `task3-data.zip` in that same folder.
# 4. Choose **Run All**.
#
# The new training ZIP includes the code, splits, all 687 added images and both saved references. You do not need the separate dataset-only ZIP. Results go to `MyDrive/MLA2/task3_usage_expanded_v2_e8/`.
#
# After a disconnect, use Run All again. Complete folds are checked and reused. An unfinished fold starts again with fresh weights.

# %%
from pathlib import Path
import hashlib
import json
import os
import shutil
import sys
import tempfile
import zipfile

from google.colab import drive

DRIVE_MOUNT = Path("/content/drive")
drive.mount(str(DRIVE_MOUNT), force_remount=False)
DRIVE_PROJECT = DRIVE_MOUNT / "MyDrive/MLA2"
BUNDLE_ZIP = DRIVE_PROJECT / "data/teacher_plus_rare_usage_v2_training.zip"
TEACHER_ZIP = DRIVE_PROJECT / "data/task3-data.zip"
DRIVE_TASK_DIR = DRIVE_PROJECT / "task3_usage_expanded_v2_e8"


def sha256_file(path):
    with Path(path).open("rb") as handle:
        return hashlib.file_digest(handle, "sha256").hexdigest()


def safe_members(archive, prefix=None):
    members = archive.infolist()
    names = [member.filename for member in members]
    if len(names) != len(set(names)):
        raise ValueError("Archive contains duplicate file names.")
    for member in members:
        name = member.filename
        if Path(name).is_absolute() or ".." in Path(name).parts or "\\" in name:
            raise ValueError(f"Unsafe archive path: {name}")
        if (member.external_attr >> 16) & 0o170000 == 0o120000:
            raise ValueError(f"Archive symlink is not allowed: {name}")
    return [m for m in members if prefix is None or m.filename.startswith(prefix)]


if not BUNDLE_ZIP.is_file():
    raise FileNotFoundError(f"Upload the new training ZIP here first: {BUNDLE_ZIP}")
bundle_digest = sha256_file(BUNDLE_ZIP)
LOCAL_BUNDLE = Path("/content") / f"usage-v2-training-{bundle_digest[:12]}.zip"
if not LOCAL_BUNDLE.is_file() or sha256_file(LOCAL_BUNDLE) != bundle_digest:
    partial = LOCAL_BUNDLE.with_suffix(".zip.partial")
    shutil.copyfile(BUNDLE_ZIP, partial)
    if sha256_file(partial) != bundle_digest:
        raise RuntimeError("Training ZIP copy is incomplete. Run this cell again.")
    partial.replace(LOCAL_BUNDLE)
REPO_DIR = Path("/content") / f"MLA2-usage-expanded-v2-{bundle_digest[:12]}"
with zipfile.ZipFile(LOCAL_BUNDLE) as archive:
    members = safe_members(archive)
    manifest = json.loads(archive.read("training_bundle_manifest.json"))
    if manifest["dataset"]["name"] != "teacher_plus_rare_usage_v2_20260906":
        raise ValueError("This notebook requires the new v2 training bundle.")
    expected = manifest["files"]
    actual = {m.filename for m in members if not m.is_dir()}
    if actual != set(expected) | {"training_bundle_manifest.json"}:
        raise ValueError("The training archive inventory differs from its manifest.")
    for name, digest in expected.items():
        if hashlib.sha256(archive.read(name)).hexdigest() != digest:
            raise ValueError(f"Training archive file changed: {name}")
    if not REPO_DIR.exists():
        with tempfile.TemporaryDirectory(prefix="usage-v2-unpack-", dir="/content") as temporary:
            staging = Path(temporary) / "project"
            staging.mkdir()
            archive.extractall(staging)
            for name, digest in expected.items():
                if sha256_file(staging / name) != digest:
                    raise RuntimeError(f"Extracted bundle file differs: {name}")
            staging.rename(REPO_DIR)
for name, digest in expected.items():
    if not (REPO_DIR / name).is_file() or sha256_file(REPO_DIR / name) != digest:
        raise RuntimeError(f"Local bundle file differs: {name}. Use a fresh runtime.")

# The verified archive stays intact. Current code comes from GitHub.
BUNDLE_ROOT = REPO_DIR
import subprocess
import tempfile

REPOSITORY = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
with tempfile.TemporaryDirectory(prefix="usage-current-code-", dir="/content") as temporary:
    checkout = Path(temporary) / "project"
    subprocess.run(["git", "clone", "--quiet", "--depth=1", "--branch", BRANCH,
                    REPOSITORY, str(checkout)], check=True)
    CODE_COMMIT = subprocess.check_output(
        ["git", "-C", str(checkout), "rev-parse", "HEAD"], text=True).strip()
    CHECKOUT_DIR = Path(str(BUNDLE_ROOT) + "-code-" + CODE_COMMIT[:12])
    if CHECKOUT_DIR.exists():
        subprocess.run(["git", "-C", str(CHECKOUT_DIR), "diff", "--quiet", "HEAD", "--", "src", "core/src"],
                       check=True)
    else:
        checkout.rename(CHECKOUT_DIR)
REPO_DIR = CHECKOUT_DIR / "core" if (CHECKOUT_DIR / "core/src/fashion").is_dir() else CHECKOUT_DIR
print("Current code commit:", CODE_COMMIT)

if "fashion.config" in sys.modules:
    loaded_root = Path(sys.modules["fashion.config"].ROOT)
    if loaded_root != REPO_DIR:
        raise RuntimeError("Another notebook is loaded. Restart the session, then Run All.")
os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
if str(REPO_DIR / "src") not in sys.path:
    sys.path.insert(0, str(REPO_DIR / "src"))
from fashion.train.task3_bundle_inputs import install_bundle_inputs
print("Reused data/reference files:", install_bundle_inputs(BUNDLE_ROOT, REPO_DIR))
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"
REFERENCE_ROOT = REPO_DIR / "reference/usage_expanded_v2"
print("New Usage code and data ready:", REPO_DIR)
print("Bundle SHA-256:", bundle_digest)
# Out:
# Mounted at /content/drive
# New Usage code and data ready: /content/MLA2-usage-expanded-v2-646c4ede60b6
# Bundle SHA-256: 646c4ede60b69d830772c9a24d030f41e7791e74c5cbfcf06acec8ad80127ea9

# %% [markdown]
# ## 2. Load the teacher images
#
# The dataset contains **39,299 rows**: 38,612 teacher rows plus 687 additions. Training and validation use **33,459 rows with Usage labels**. The other rows are the saved holdout, quarantined rows, and one teacher row without a Usage label.
#
# The five folds use the same main-EDA teacher assignments. New images stay with their related product groups. This notebook uses development data only.

# %%
if not TEACHER_ZIP.is_file():
    raise FileNotFoundError(f"Existing teacher archive is missing: {TEACHER_ZIP}")
LOCAL_TEACHER_ZIP = Path("/content/task3-data.zip")
if (
    not LOCAL_TEACHER_ZIP.is_file()
    or LOCAL_TEACHER_ZIP.stat().st_size != TEACHER_ZIP.stat().st_size
):
    partial = LOCAL_TEACHER_ZIP.with_suffix(".zip.partial")
    shutil.copyfile(TEACHER_ZIP, partial)
    if partial.stat().st_size != TEACHER_ZIP.stat().st_size:
        raise RuntimeError("Teacher ZIP copy is incomplete. Run this cell again.")
    partial.replace(LOCAL_TEACHER_ZIP)
with zipfile.ZipFile(LOCAL_TEACHER_ZIP) as archive:
    members = safe_members(archive, prefix="data/raw/teacher/")
    if not members:
        raise ValueError("Teacher archive must contain data/raw/teacher/.")
    for member in members:
        destination = REPO_DIR / member.filename
        if member.is_dir():
            destination.mkdir(parents=True, exist_ok=True)
        elif not destination.is_file() or destination.stat().st_size != member.file_size:
            archive.extract(member, REPO_DIR)
print("Teacher images are on local disk.")
# Out:
# Teacher images are on local disk.

# %% [markdown]
# ## 3. Check the selected dataset
#
# This checks the new split, class map, earlier fold assignments and source-border geometry. Training checks every image it uses before the first fold.
#
# Channel means, channel spreads and class weights are calculated from each fold's **training images only**. The saved borders exclude added white padding from channel statistics.
#
# Use the normal Colab GPU runtime. The trainer records the actual library versions.

# %%
import pandas as pd
import torch
from IPython.display import Image as DisplayImage, display
from fashion.train.task3_usage_expanded_v2 import (
    expanded_usage_spec,
    run_expanded_usage_v2,
    save_learning_curves,
    usage_registry_path,
    validate_dataset,
)

if not torch.cuda.is_available():
    raise RuntimeError("Choose a GPU runtime, then Run All.")
splits, contract = validate_dataset(root=REPO_DIR, check_images=False)
DRIVE_REGISTRY = usage_registry_path(DRIVE_TASK_DIR)
E8_DIR = REFERENCE_ROOT / "teacher_e8"
SOURCE_REGISTRY = REFERENCE_ROOT / "teacher_e8_runs.csv"
PREVIOUS_DIR = REFERENCE_ROOT / "previous_expansion"
PREVIOUS_REGISTRY = REFERENCE_ROOT / "previous_expansion_runs.csv"

print("Dataset:", contract["name"])
print("Usage development images:", contract["usage_development_rows"])
print("GPU:", torch.cuda.get_device_name(0))
print("Results:", DRIVE_TASK_DIR)
print("Run log:", DRIVE_REGISTRY)
counts = pd.DataFrame(contract["folds"])
display(counts[[
    "fold", "training_rows", "validation_rows",
    "new_added_training_rows", "new_added_validation_rows",
]].rename(columns={
    "fold": "Fold", "training_rows": "Train", "validation_rows": "Validation",
    "new_added_training_rows": "New in train",
    "new_added_validation_rows": "New in validation",
}))
print("Recipe:", expanded_usage_spec().name)
# Out:
# Dataset: teacher_plus_rare_usage_v2_20260906
# Usage development images: 33459
# GPU: NVIDIA L4
# Results: /content/drive/MyDrive/MLA2/task3_usage_expanded_v2_e8
# Run log: /content/drive/MyDrive/MLA2/task3_usage_expanded_v2_e8/experiments/t3_usage_expanded_v2_e8/usage/results/runs.csv
#    Fold  Train  Validation  New in train  New in validation
# 0     0  26751        6708           436                131
# 1     1  26771        6688           458                109
# 2     2  26771        6688           457                110
# 3     3  26772        6687           456                111
# 4     4  26771        6688           461                106
# Recipe: usage_expanded_v2_e8

# %% [markdown]
# ## 4. Train all five folds
#
# Each fold starts from scratch and runs 30 epochs. The saved E8 and first-expansion models are read only to verify reference results. Their weights are never copied into the new models.
#
# Each run is logged before its first training step. The notebook saves checkpoints, epoch histories, clean training predictions, validation predictions, source-specific scores and corruption checks. A separate v2 run log keeps these results apart from the earlier runs.
#
# Keep all five folds for the full comparison. A smaller fold list is saved as a partial result and is compared only against the matching reference folds.

# %%
FOLDS = (0, 1, 2, 3, 4)
result = run_expanded_usage_v2(
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=(LOCAL_REGISTRY,),
    e8_directory=E8_DIR,
    source_registry_path=SOURCE_REGISTRY,
    previous_directory=PREVIOUS_DIR,
    previous_registry_path=PREVIOUS_REGISTRY,
    folds=FOLDS,
    resume=True,
)
print("Saved teacher-only comparison:", result["comparison_path"])
# Out:
# [task3] preparing target=usage fold=0: train=26,751 (before selection=26,751), validation=6,708
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_expanded_v2_e8_usage_smallcnn_f0_s2753_3c4369c6ce6e_20260906T141147Zfb606e; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=1.0784 train_macro_f1=0.2868 validation_loss=0.9425 validation_macro_f1=0.3697
# [task3] target=usage fold=0 epoch=2/30 train_loss=0.8042 train_macro_f1=0.4783 validation_loss=0.8869 validation_macro_f1=0.3703
# [task3] target=usage fold=0 epoch=3/30 train_loss=0.6946 train_macro_f1=0.5559 validation_loss=0.8059 validation_macro_f1=0.4776
# [task3] target=usage fold=0 epoch=4/30 train_loss=0.6210 train_macro_f1=0.6100 validation_loss=0.7190 validation_macro_f1=0.5540
# [task3] target=usage fold=0 epoch=5/30 train_loss=0.5780 train_macro_f1=0.6359 validation_loss=0.6586 validation_macro_f1=0.6275
# [task3] target=usage fold=0 epoch=6/30 train_loss=0.5432 train_macro_f1=0.6591 validation_loss=0.6065 validation_macro_f1=0.5802
# [task3] target=usage fold=0 epoch=7/30 train_loss=0.5109 train_macro_f1=0.6775 validation_loss=0.5648 validation_macro_f1=0.6659
# [task3] target=usage fold=0 epoch=8/30 train_loss=0.4790 train_macro_f1=0.6861 validation_loss=0.6811 validation_macro_f1=0.6117
# [task3] target=usage fold=0 epoch=9/30 train_loss=0.4642 train_macro_f1=0.6946 validation_loss=0.9009 validation_macro_f1=0.5265
# [task3] target=usage fold=0 epoch=10/30 train_loss=0.4341 train_macro_f1=0.7126 validation_loss=0.6515 validation_macro_f1=0.6253
# [task3] target=usage fold=0 epoch=11/30 train_loss=0.4160 train_macro_f1=0.7248 validation_loss=1.0205 validation_macro_f1=0.4632
# [task3] target=usage fold=0 epoch=12/30 train_loss=0.3813 train_macro_f1=0.7452 validation_loss=0.6309 validation_macro_f1=0.6911
# [task3] target=usage fold=0 epoch=13/30 train_loss=0.3676 train_macro_f1=0.7596 validation_loss=0.6768 validation_macro_f1=0.6768
# [task3] target=usage fold=0 epoch=14/30 train_loss=0.3553 train_macro_f1=0.7631 validation_loss=1.4676 validation_macro_f1=0.3033
# [task3] target=usage fold=0 epoch=15/30 train_loss=0.3287 train_macro_f1=0.7821 validation_loss=0.4765 validation_macro_f1=0.7318
# [task3] target=usage fold=0 epoch=16/30 train_loss=0.3191 train_macro_f1=0.7941 validation_loss=0.8877 validation_macro_f1=0.6265
# [task3] target=usage fold=0 epoch=17/30 train_loss=0.2992 train_macro_f1=0.8111 validation_loss=0.6920 validation_macro_f1=0.4936
# [task3] target=usage fold=0 epoch=18/30 train_loss=0.2827 train_macro_f1=0.8209 validation_loss=0.6106 validation_macro_f1=0.5244
# [task3] target=usage fold=0 epoch=19/30 train_loss=0.2691 train_macro_f1=0.8406 validation_loss=0.5994 validation_macro_f1=0.6911
# [task3] target=usage fold=0 epoch=20/30 train_loss=0.2592 train_macro_f1=0.8341 validation_loss=0.4942 validation_macro_f1=0.7386
# [task3] target=usage fold=0 epoch=21/30 train_loss=0.2450 train_macro_f1=0.8552 validation_loss=0.4684 validation_macro_f1=0.7351
# [task3] target=usage fold=0 epoch=22/30 train_loss=0.2444 train_macro_f1=0.8470 validation_loss=0.4717 validation_macro_f1=0.7507
# [task3] target=usage fold=0 epoch=23/30 train_loss=0.2354 train_macro_f1=0.8619 validation_loss=0.4879 validation_macro_f1=0.7487
# [task3] target=usage fold=0 epoch=24/30 train_loss=0.2245 train_macro_f1=0.8750 validation_loss=0.4893 validation_macro_f1=0.7056
# [task3] target=usage fold=0 epoch=25/30 train_loss=0.2156 train_macro_f1=0.8877 validation_loss=0.4792 validation_macro_f1=0.7675
# [task3] target=usage fold=0 epoch=26/30 train_loss=0.2096 train_macro_f1=0.8955 validation_loss=0.4506 validation_macro_f1=0.7543
# [task3] target=usage fold=0 epoch=27/30 train_loss=0.2057 train_macro_f1=0.8970 validation_loss=0.4399 validation_macro_f1=0.7584
# [task3] target=usage fold=0 epoch=28/30 train_loss=0.2022 train_macro_f1=0.8893 validation_loss=0.4441 validation_macro_f1=0.7623
# [task3] target=usage fold=0 epoch=29/30 train_loss=0.2002 train_macro_f1=0.8949 validation_loss=0.4403 validation_macro_f1=0.7620
# [task3] target=usage fold=0 epoch=30/30 train_loss=0.1970 train_macro_f1=0.8960 validation_loss=0.4516 validation_macro_f1=0.7639
# [task3] completed target=usage fold=0: t3_usage_expanded_v2_e8_usage_smallcnn_f0_s2753_3c4369c6ce6e_20260906T141147Zfb606e
# [task3] preparing target=usage fold=1: train=26,771 (before selection=26,771), validation=6,688
# [task3] fitting fold-training RGB statistics for target=usage fold=1
# [task3] RGB statistics ready for target=usage fold=1
# [task3] registered t3_usage_expanded_v2_e8_usage_smallcnn_f1_s2753_3c4369c6ce6e_20260906T142131Zb5daae; the first optimiser step may now run
# [task3] target=usage fold=1 epoch=1/30 train_loss=1.0941 train_macro_f1=0.2586 validation_loss=1.5260 validation_macro_f1=0.3034
# [task3] target=usage fold=1 epoch=2/30 train_loss=0.7886 train_macro_f1=0.4898 validation_loss=0.8371 validation_macro_f1=0.4985
# [task3] target=usage fold=1 epoch=3/30 train_loss=0.6767 train_macro_f1=0.5825 validation_loss=0.9811 validation_macro_f1=0.5118
# [task3] target=usage fold=1 epoch=4/30 train_loss=0.6169 train_macro_f1=0.6160 validation_loss=0.7344 validation_macro_f1=0.5906
# [task3] target=usage fold=1 epoch=5/30 train_loss=0.5742 train_macro_f1=0.6435 validation_loss=0.8182 validation_macro_f1=0.5263
# [task3] target=usage fold=1 epoch=6/30 train_loss=0.5335 train_macro_f1=0.6644 validation_loss=0.6258 validation_macro_f1=0.6519
# [task3] target=usage fold=1 epoch=7/30 train_loss=0.5144 train_macro_f1=0.6679 validation_loss=0.6301 validation_macro_f1=0.6404
# [task3] target=usage fold=1 epoch=8/30 train_loss=0.4727 train_macro_f1=0.6982 validation_loss=1.0047 validation_macro_f1=0.5312
# [task3] target=usage fold=1 epoch=9/30 train_loss=0.4491 train_macro_f1=0.7037 validation_loss=0.5619 validation_macro_f1=0.7030
# [task3] target=usage fold=1 epoch=10/30 train_loss=0.4110 train_macro_f1=0.7257 validation_loss=0.6525 validation_macro_f1=0.6316
# [task3] target=usage fold=1 epoch=11/30 train_loss=0.4055 train_macro_f1=0.7344 validation_loss=0.9252 validation_macro_f1=0.5937
# [task3] target=usage fold=1 epoch=12/30 train_loss=0.3797 train_macro_f1=0.7461 validation_loss=0.5856 validation_macro_f1=0.7304
# [task3] target=usage fold=1 epoch=13/30 train_loss=0.3512 train_macro_f1=0.7624 validation_loss=0.4991 validation_macro_f1=0.6570
# [task3] target=usage fold=1 epoch=14/30 train_loss=0.3282 train_macro_f1=0.7901 validation_loss=0.6229 validation_macro_f1=0.7185
# [task3] target=usage fold=1 epoch=15/30 train_loss=0.3238 train_macro_f1=0.7841 validation_loss=0.6664 validation_macro_f1=0.7354
# [task3] target=usage fold=1 epoch=16/30 train_loss=0.3117 train_macro_f1=0.7896 validation_loss=0.5878 validation_macro_f1=0.6395
# [task3] target=usage fold=1 epoch=17/30 train_loss=0.2932 train_macro_f1=0.8095 validation_loss=0.5032 validation_macro_f1=0.6286
# [task3] target=usage fold=1 epoch=18/30 train_loss=0.2839 train_macro_f1=0.8175 validation_loss=0.6218 validation_macro_f1=0.7099
# [task3] target=usage fold=1 epoch=19/30 train_loss=0.2591 train_macro_f1=0.8477 validation_loss=0.4544 validation_macro_f1=0.7382
# [task3] target=usage fold=1 epoch=20/30 train_loss=0.2561 train_macro_f1=0.8383 validation_loss=0.5235 validation_macro_f1=0.7601
# [task3] target=usage fold=1 epoch=21/30 train_loss=0.2453 train_macro_f1=0.8488 validation_loss=0.4805 validation_macro_f1=0.6603
# [task3] target=usage fold=1 epoch=22/30 train_loss=0.2344 train_macro_f1=0.8537 validation_loss=0.5341 validation_macro_f1=0.7489
# [task3] target=usage fold=1 epoch=23/30 train_loss=0.2174 train_macro_f1=0.8811 validation_loss=0.4918 validation_macro_f1=0.7435
# [task3] target=usage fold=1 epoch=24/30 train_loss=0.2115 train_macro_f1=0.8920 validation_loss=0.4893 validation_macro_f1=0.7470
# [task3] target=usage fold=1 epoch=25/30 train_loss=0.2058 train_macro_f1=0.8914 validation_loss=0.4766 validation_macro_f1=0.7624
# [task3] target=usage fold=1 epoch=26/30 train_loss=0.2006 train_macro_f1=0.8941 validation_loss=0.4668 validation_macro_f1=0.7472
# [task3] target=usage fold=1 epoch=27/30 train_loss=0.1993 train_macro_f1=0.8955 validation_loss=0.4724 validation_macro_f1=0.7703
# [task3] target=usage fold=1 epoch=28/30 train_loss=0.1956 train_macro_f1=0.8985 validation_loss=0.4558 validation_macro_f1=0.7672
# [task3] target=usage fold=1 epoch=29/30 train_loss=0.1903 train_macro_f1=0.9018 validation_loss=0.4521 validation_macro_f1=0.7759
# [task3] target=usage fold=1 epoch=30/30 train_loss=0.1891 train_macro_f1=0.9053 validation_loss=0.4640 validation_macro_f1=0.7812
# [task3] completed target=usage fold=1: t3_usage_expanded_v2_e8_usage_smallcnn_f1_s2753_3c4369c6ce6e_20260906T142131Zb5daae
# [task3] preparing target=usage fold=2: train=26,771 (before selection=26,771), validation=6,688
# [task3] fitting fold-training RGB statistics for target=usage fold=2
# [task3] RGB statistics ready for target=usage fold=2
# [task3] registered t3_usage_expanded_v2_e8_usage_smallcnn_f2_s2753_3c4369c6ce6e_20260906T143118Zfb9b48; the first optimiser step may now run
# [task3] target=usage fold=2 epoch=1/30 train_loss=1.0688 train_macro_f1=0.2727 validation_loss=1.1232 validation_macro_f1=0.3662
# [task3] target=usage fold=2 epoch=2/30 train_loss=0.7816 train_macro_f1=0.5047 validation_loss=1.1477 validation_macro_f1=0.3825
# [task3] target=usage fold=2 epoch=3/30 train_loss=0.6742 train_macro_f1=0.5697 validation_loss=0.8713 validation_macro_f1=0.4629
# [task3] target=usage fold=2 epoch=4/30 train_loss=0.6009 train_macro_f1=0.6250 validation_loss=0.8739 validation_macro_f1=0.5041
# [task3] target=usage fold=2 epoch=5/30 train_loss=0.5658 train_macro_f1=0.6403 validation_loss=1.0610 validation_macro_f1=0.4495
# [task3] target=usage fold=2 epoch=6/30 train_loss=0.5197 train_macro_f1=0.6799 validation_loss=0.8452 validation_macro_f1=0.5689
# [task3] target=usage fold=2 epoch=7/30 train_loss=0.4992 train_macro_f1=0.6811 validation_loss=0.7838 validation_macro_f1=0.5173
# [task3] target=usage fold=2 epoch=8/30 train_loss=0.4668 train_macro_f1=0.6959 validation_loss=1.1039 validation_macro_f1=0.4017
# [task3] target=usage fold=2 epoch=9/30 train_loss=0.4410 train_macro_f1=0.7045 validation_loss=0.6444 validation_macro_f1=0.5926
# [task3] target=usage fold=2 epoch=10/30 train_loss=0.4057 train_macro_f1=0.7249 validation_loss=0.6293 validation_macro_f1=0.6117
# [task3] target=usage fold=2 epoch=11/30 train_loss=0.3923 train_macro_f1=0.7374 validation_loss=0.6877 validation_macro_f1=0.5728
# [task3] target=usage fold=2 epoch=12/30 train_loss=0.3738 train_macro_f1=0.7416 validation_loss=0.9729 validation_macro_f1=0.5387
# [task3] target=usage fold=2 epoch=13/30 train_loss=0.3522 train_macro_f1=0.7623 validation_loss=0.9186 validation_macro_f1=0.6247
# [task3] target=usage fold=2 epoch=14/30 train_loss=0.3361 train_macro_f1=0.7778 validation_loss=0.9863 validation_macro_f1=0.5764
# [task3] target=usage fold=2 epoch=15/30 train_loss=0.3343 train_macro_f1=0.7670 validation_loss=0.5791 validation_macro_f1=0.6169
# [task3] target=usage fold=2 epoch=16/30 train_loss=0.2951 train_macro_f1=0.8094 validation_loss=0.5789 validation_macro_f1=0.5963
# [task3] target=usage fold=2 epoch=17/30 train_loss=0.2845 train_macro_f1=0.8175 validation_loss=0.5447 validation_macro_f1=0.6186
# [task3] target=usage fold=2 epoch=18/30 train_loss=0.2839 train_macro_f1=0.8240 validation_loss=0.5514 validation_macro_f1=0.5855
# [task3] target=usage fold=2 epoch=19/30 train_loss=0.2630 train_macro_f1=0.8288 validation_loss=0.7281 validation_macro_f1=0.6105
# [task3] target=usage fold=2 epoch=20/30 train_loss=0.2435 train_macro_f1=0.8607 validation_loss=0.6092 validation_macro_f1=0.7325
# [task3] target=usage fold=2 epoch=21/30 train_loss=0.2425 train_macro_f1=0.8393 validation_loss=0.8347 validation_macro_f1=0.6388
# [task3] target=usage fold=2 epoch=22/30 train_loss=0.2275 train_macro_f1=0.8625 validation_loss=0.5089 validation_macro_f1=0.7298
# [task3] target=usage fold=2 epoch=23/30 train_loss=0.2205 train_macro_f1=0.8633 validation_loss=0.5263 validation_macro_f1=0.7319
# [task3] target=usage fold=2 epoch=24/30 train_loss=0.2198 train_macro_f1=0.8719 validation_loss=0.4875 validation_macro_f1=0.7288
# [task3] target=usage fold=2 epoch=25/30 train_loss=0.2112 train_macro_f1=0.8807 validation_loss=0.5110 validation_macro_f1=0.7453
# [task3] target=usage fold=2 epoch=26/30 train_loss=0.2004 train_macro_f1=0.8871 validation_loss=0.4883 validation_macro_f1=0.7311
# [task3] target=usage fold=2 epoch=27/30 train_loss=0.1994 train_macro_f1=0.8890 validation_loss=0.5101 validation_macro_f1=0.7435
# [task3] target=usage fold=2 epoch=28/30 train_loss=0.1959 train_macro_f1=0.8844 validation_loss=0.5175 validation_macro_f1=0.7382
# [task3] target=usage fold=2 epoch=29/30 train_loss=0.1965 train_macro_f1=0.8890 validation_loss=0.5128 validation_macro_f1=0.7415
# [task3] target=usage fold=2 epoch=30/30 train_loss=0.1930 train_macro_f1=0.8994 validation_loss=0.5093 validation_macro_f1=0.7441
# [task3] completed target=usage fold=2: t3_usage_expanded_v2_e8_usage_smallcnn_f2_s2753_3c4369c6ce6e_20260906T143118Zfb9b48
# [task3] preparing target=usage fold=3: train=26,772 (before selection=26,772), validation=6,687
# [task3] fitting fold-training RGB statistics for target=usage fold=3
# [task3] RGB statistics ready for target=usage fold=3
# [task3] registered t3_usage_expanded_v2_e8_usage_smallcnn_f3_s2753_3c4369c6ce6e_20260906T144112Z005070; the first optimiser step may now run
# [task3] target=usage fold=3 epoch=1/30 train_loss=1.0515 train_macro_f1=0.2939 validation_loss=0.9071 validation_macro_f1=0.4350
# [task3] target=usage fold=3 epoch=2/30 train_loss=0.7636 train_macro_f1=0.5247 validation_loss=0.7514 validation_macro_f1=0.4850
# [task3] target=usage fold=3 epoch=3/30 train_loss=0.6588 train_macro_f1=0.5918 validation_loss=0.9370 validation_macro_f1=0.4307
# [task3] target=usage fold=3 epoch=4/30 train_loss=0.6037 train_macro_f1=0.6195 validation_loss=0.8143 validation_macro_f1=0.4955
# [task3] target=usage fold=3 epoch=5/30 train_loss=0.5660 train_macro_f1=0.6486 validation_loss=1.0111 validation_macro_f1=0.4468
# [task3] target=usage fold=3 epoch=6/30 train_loss=0.5387 train_macro_f1=0.6505 validation_loss=0.7852 validation_macro_f1=0.4711
# [task3] target=usage fold=3 epoch=7/30 train_loss=0.5053 train_macro_f1=0.6788 validation_loss=0.6709 validation_macro_f1=0.6167
# [task3] target=usage fold=3 epoch=8/30 train_loss=0.4823 train_macro_f1=0.6949 validation_loss=0.8417 validation_macro_f1=0.5736
# [task3] target=usage fold=3 epoch=9/30 train_loss=0.4442 train_macro_f1=0.7025 validation_loss=0.7366 validation_macro_f1=0.6552
# [task3] target=usage fold=3 epoch=10/30 train_loss=0.4214 train_macro_f1=0.7177 validation_loss=0.7884 validation_macro_f1=0.5965
# [task3] target=usage fold=3 epoch=11/30 train_loss=0.4093 train_macro_f1=0.7223 validation_loss=0.9305 validation_macro_f1=0.6169
# [task3] target=usage fold=3 epoch=12/30 train_loss=0.3870 train_macro_f1=0.7381 validation_loss=0.7095 validation_macro_f1=0.6628
# [task3] target=usage fold=3 epoch=13/30 train_loss=0.3669 train_macro_f1=0.7611 validation_loss=0.7573 validation_macro_f1=0.5759
# [task3] target=usage fold=3 epoch=14/30 train_loss=0.3426 train_macro_f1=0.7695 validation_loss=0.7863 validation_macro_f1=0.6601
# [task3] target=usage fold=3 epoch=15/30 train_loss=0.3310 train_macro_f1=0.7743 validation_loss=1.6495 validation_macro_f1=0.5214
# [task3] target=usage fold=3 epoch=16/30 train_loss=0.3097 train_macro_f1=0.7959 validation_loss=0.7672 validation_macro_f1=0.6115
# [task3] target=usage fold=3 epoch=17/30 train_loss=0.3020 train_macro_f1=0.7965 validation_loss=0.6574 validation_macro_f1=0.6673
# [task3] target=usage fold=3 epoch=18/30 train_loss=0.2840 train_macro_f1=0.8122 validation_loss=0.6103 validation_macro_f1=0.7183
# [task3] target=usage fold=3 epoch=19/30 train_loss=0.2707 train_macro_f1=0.8184 validation_loss=0.5146 validation_macro_f1=0.7350
# [task3] target=usage fold=3 epoch=20/30 train_loss=0.2569 train_macro_f1=0.8368 validation_loss=0.5727 validation_macro_f1=0.6760
# [task3] target=usage fold=3 epoch=21/30 train_loss=0.2397 train_macro_f1=0.8553 validation_loss=0.5541 validation_macro_f1=0.7245
# [task3] target=usage fold=3 epoch=22/30 train_loss=0.2381 train_macro_f1=0.8633 validation_loss=0.5317 validation_macro_f1=0.7326
# [task3] target=usage fold=3 epoch=23/30 train_loss=0.2251 train_macro_f1=0.8722 validation_loss=0.6503 validation_macro_f1=0.7476
# [task3] target=usage fold=3 epoch=24/30 train_loss=0.2189 train_macro_f1=0.8778 validation_loss=0.5406 validation_macro_f1=0.7397
# [task3] target=usage fold=3 epoch=25/30 train_loss=0.2104 train_macro_f1=0.8950 validation_loss=0.5517 validation_macro_f1=0.7510
# [task3] target=usage fold=3 epoch=26/30 train_loss=0.2084 train_macro_f1=0.8877 validation_loss=0.4670 validation_macro_f1=0.7136
# [task3] target=usage fold=3 epoch=27/30 train_loss=0.1985 train_macro_f1=0.8975 validation_loss=0.5155 validation_macro_f1=0.7425
# [task3] target=usage fold=3 epoch=28/30 train_loss=0.1980 train_macro_f1=0.8974 validation_loss=0.5117 validation_macro_f1=0.7408
# [task3] target=usage fold=3 epoch=29/30 train_loss=0.1976 train_macro_f1=0.9001 validation_loss=0.5316 validation_macro_f1=0.7475
# [task3] target=usage fold=3 epoch=30/30 train_loss=0.1939 train_macro_f1=0.8991 validation_loss=0.5129 validation_macro_f1=0.7546
# [task3] completed target=usage fold=3: t3_usage_expanded_v2_e8_usage_smallcnn_f3_s2753_3c4369c6ce6e_20260906T144112Z005070
# [task3] preparing target=usage fold=4: train=26,771 (before selection=26,771), validation=6,688
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_expanded_v2_e8_usage_smallcnn_f4_s2753_3c4369c6ce6e_20260906T145103Z229e7e; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=1.0626 train_macro_f1=0.2744 validation_loss=0.8957 validation_macro_f1=0.4525
# [task3] target=usage fold=4 epoch=2/30 train_loss=0.7745 train_macro_f1=0.4969 validation_loss=1.4900 validation_macro_f1=0.3742
# [task3] target=usage fold=4 epoch=3/30 train_loss=0.6700 train_macro_f1=0.5876 validation_loss=0.7934 validation_macro_f1=0.5352
# [task3] target=usage fold=4 epoch=4/30 train_loss=0.5944 train_macro_f1=0.6369 validation_loss=0.8973 validation_macro_f1=0.5254
# [task3] target=usage fold=4 epoch=5/30 train_loss=0.5537 train_macro_f1=0.6548 validation_loss=0.6985 validation_macro_f1=0.6025
# [task3] target=usage fold=4 epoch=6/30 train_loss=0.5238 train_macro_f1=0.6683 validation_loss=0.9419 validation_macro_f1=0.5159
# [task3] target=usage fold=4 epoch=7/30 train_loss=0.4850 train_macro_f1=0.6792 validation_loss=0.6264 validation_macro_f1=0.6260
# [task3] target=usage fold=4 epoch=8/30 train_loss=0.4615 train_macro_f1=0.6950 validation_loss=0.7182 validation_macro_f1=0.5813
# [task3] target=usage fold=4 epoch=9/30 train_loss=0.4441 train_macro_f1=0.7059 validation_loss=0.8775 validation_macro_f1=0.4652
# [task3] target=usage fold=4 epoch=10/30 train_loss=0.4270 train_macro_f1=0.7161 validation_loss=0.6304 validation_macro_f1=0.6072
# [task3] target=usage fold=4 epoch=11/30 train_loss=0.3951 train_macro_f1=0.7346 validation_loss=0.7224 validation_macro_f1=0.6470
# [task3] target=usage fold=4 epoch=12/30 train_loss=0.3783 train_macro_f1=0.7355 validation_loss=1.0455 validation_macro_f1=0.5221
# [task3] target=usage fold=4 epoch=13/30 train_loss=0.3564 train_macro_f1=0.7685 validation_loss=0.6015 validation_macro_f1=0.6890
# [task3] target=usage fold=4 epoch=14/30 train_loss=0.3305 train_macro_f1=0.7884 validation_loss=0.5624 validation_macro_f1=0.6956
# [task3] target=usage fold=4 epoch=15/30 train_loss=0.3149 train_macro_f1=0.8021 validation_loss=0.6514 validation_macro_f1=0.6624
# [task3] target=usage fold=4 epoch=16/30 train_loss=0.3011 train_macro_f1=0.8063 validation_loss=0.6123 validation_macro_f1=0.6040
# [task3] target=usage fold=4 epoch=17/30 train_loss=0.2841 train_macro_f1=0.8111 validation_loss=0.5838 validation_macro_f1=0.7100
# [task3] target=usage fold=4 epoch=18/30 train_loss=0.2816 train_macro_f1=0.8161 validation_loss=0.7268 validation_macro_f1=0.5934
# [task3] target=usage fold=4 epoch=19/30 train_loss=0.3054 train_macro_f1=0.7860 validation_loss=0.5925 validation_macro_f1=0.5558
# [task3] target=usage fold=4 epoch=20/30 train_loss=0.2571 train_macro_f1=0.8402 validation_loss=0.6423 validation_macro_f1=0.6911
# [task3] target=usage fold=4 epoch=21/30 train_loss=0.2417 train_macro_f1=0.8521 validation_loss=0.4756 validation_macro_f1=0.6702
# [task3] target=usage fold=4 epoch=22/30 train_loss=0.2353 train_macro_f1=0.8537 validation_loss=0.4755 validation_macro_f1=0.7301
# [task3] target=usage fold=4 epoch=23/30 train_loss=0.2260 train_macro_f1=0.8727 validation_loss=0.5006 validation_macro_f1=0.7186
# [task3] target=usage fold=4 epoch=24/30 train_loss=0.2135 train_macro_f1=0.8777 validation_loss=0.5128 validation_macro_f1=0.7291
# [task3] target=usage fold=4 epoch=25/30 train_loss=0.2106 train_macro_f1=0.8794 validation_loss=0.4654 validation_macro_f1=0.7309
# [task3] target=usage fold=4 epoch=26/30 train_loss=0.2042 train_macro_f1=0.8899 validation_loss=0.4800 validation_macro_f1=0.7314
# [task3] target=usage fold=4 epoch=27/30 train_loss=0.1980 train_macro_f1=0.8988 validation_loss=0.4971 validation_macro_f1=0.7378
# [task3] target=usage fold=4 epoch=28/30 train_loss=0.1986 train_macro_f1=0.8915 validation_loss=0.4729 validation_macro_f1=0.7313
# [task3] target=usage fold=4 epoch=29/30 train_loss=0.1939 train_macro_f1=0.8949 validation_loss=0.4815 validation_macro_f1=0.7407
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.1949 train_macro_f1=0.8927 validation_loss=0.4750 validation_macro_f1=0.7339
# [task3] completed target=usage fold=4: t3_usage_expanded_v2_e8_usage_smallcnn_f4_s2753_3c4369c6ce6e_20260906T145103Z229e7e
# Saved teacher-only comparison: /content/drive/MyDrive/MLA2/task3_usage_expanded_v2_e8/experiments/t3_usage_expanded_v2_e8/usage/aggregate/teacher_comparison.json

# %% [markdown]
# ## 5. Read the results
#
# **Use the teacher-only comparison to judge whether this data helps the assignment task.** All three models are scored on the same teacher images with the same nine-class map.
#
# The combined and added-source scores help explain what the model learned. Their class mix is different, so a higher combined score alone does not show better teacher-test performance.
#
# There are 136 added Home, 224 Party, 162 Smart Casual and 165 Travel images across the two intakes. No NA images were added. The new labels come from product text or retailer collections. A 49-image Smart Casual family makes the new fold sizes uneven.
#
# Earlier holdout and teacher-test evaluations already exist. This notebook keeps fitting and comparison within development data.

# %%
summary = result["comparison"]
teacher = summary["sources"]["teacher"]["metrics"]
reference_names = {
    "teacher_e8": "Original E8",
    "previous_expansion": "E8 + 120 added images",
}
scores = [
    {"Model": reference_names[name], "Teacher macro-F1": metrics["macro_f1"]}
    for name, metrics in summary["teacher_references"].items()
]
scores.append({"Model": "E8 + 687 added images", "Teacher macro-F1": teacher["macro_f1"]})
display(pd.DataFrame(scores))
print("Same teacher images in each comparison:", summary["sources"]["teacher"]["rows"])
display(pd.DataFrame(summary["teacher_per_class"]))
display(pd.DataFrame([
    {"Source": name, "Images": scope["rows"],
     "Macro-F1": scope["metrics"]["macro_f1"] if scope["metrics"] else None}
    for name, scope in summary["sources"].items()
]))
display(pd.DataFrame([
    {
        "Fold": run["metrics"]["validation_fold"],
        "Teacher train F1": run["metrics"]["source_metrics"]["clean_training"]["teacher"]["metrics"]["macro_f1"],
        "Teacher validation F1": run["metrics"]["source_metrics"]["validation"]["teacher"]["metrics"]["macro_f1"],
    }
    for run in result["fold_results"]
]))
print("Result files:", Path(result["comparison_path"]).parent)
print("Run registry:", result["registry_path"])
# Out:
#                    Model  Teacher macro-F1
# 0            Original E8          0.419393
# 1  E8 + 120 added images          0.408634
# 2  E8 + 687 added images          0.409277
# Same teacher images in each comparison: 32772
#      class_name  support     v2_f1  teacher_e8_f1  change_from_teacher_e8  \
# 0        Casual    25151  0.933918       0.930523                0.003396
# 1        Ethnic     2183  0.862373       0.847377                0.014995
# 2        Formal     1949  0.799148       0.777070                0.022078
# 3          Home        1  0.000000       0.000000                0.000000
# 4            NA       61  0.236220       0.169014                0.067206
# 5         Party       12  0.000000       0.076923               -0.076923
# 6  Smart Casual       47  0.000000       0.103448               -0.103448
# 7        Sports     3346  0.690546       0.666102                0.024444
# 8        Travel       22  0.161290       0.204082               -0.042791
#
#    previous_expansion_f1  change_from_previous_expansion
# 0               0.929725                        0.004193
# 1               0.850199                        0.012174
# 2               0.769765                        0.029383
# 3               0.000000                        0.000000
# 4               0.222222                        0.013998
# 5               0.000000                        0.000000
# 6               0.038462                       -0.038462
# 7               0.663253                        0.027293
# 8               0.204082                       -0.042791
#            Source  Images  Macro-F1
# 0        combined   33459  0.756713
# 1         teacher   32772  0.409277
# 2  previous_added     120  0.173200
# 3       new_added     567  0.426877
# 4           added     687  0.409066
#    Fold  Teacher train F1  Teacher validation F1
# 0     0          0.865061               0.402356
# 1     1          0.836242               0.406464
# 2     2          0.883864               0.420295
# 3     3          0.830979               0.412852
# 4     4          0.771428               0.399614
# Result files: /content/drive/MyDrive/MLA2/task3_usage_expanded_v2_e8/experiments/t3_usage_expanded_v2_e8/usage/aggregate
# Run registry: /content/drive/MyDrive/MLA2/task3_usage_expanded_v2_e8/experiments/t3_usage_expanded_v2_e8/usage/results/runs.csv

# %% [markdown]
# ## 6. Check learning across epochs
#
# These curves show validation on the combined teacher and external data. The teacher-only table above remains the main comparison. The model uses epoch 30; these curves do not select a different checkpoint.

# %%
curve_path = save_learning_curves(
    result,
    path=DRIVE_TASK_DIR / "results/figures/task3/usage_expanded_v2_e8_learning_curves.png",
)
display(DisplayImage(filename=str(curve_path)))
print("Saved curves:", curve_path)
# Out:
# Saved curves: /content/drive/MyDrive/MLA2/task3_usage_expanded_v2_e8/results/figures/task3/usage_expanded_v2_e8_learning_curves.png
