# %% [markdown]
# # Task 3 — Scratch Micro-Swin Clean-Slate Screen 2
#
# This is a separate GPU experiment. It does not continue the E1–E10 CNN chain and it does not retrain Clean-Slate Screen 1. **Run All starts four fits:** Usage folds 0 and 4, then Gender folds 0 and 4. Completed matching folds are reused after a Colab disconnect.

# %% [markdown]
# ## 1. Mount Drive and load the Task 3 branch
#
# Drive stores the teacher ZIP, the historical anchors, the persistent run registry, and every new model artifact.

# %%
from pathlib import Path
import os
import subprocess
import sys
import time
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
CHECKOUT_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
LOCAL_DATA_ZIP = Path("/content/task3-data.zip")
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"

def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

# %%
try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab GPU runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)
if (CHECKOUT_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=CHECKOUT_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{CHECKOUT_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=CHECKOUT_DIR)
    run_checked(["git", "switch", BRANCH], cwd=CHECKOUT_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=CHECKOUT_DIR)
elif CHECKOUT_DIR.exists():
    raise RuntimeError(f"{CHECKOUT_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, CHECKOUT_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=CHECKOUT_DIR, text=True).strip()
REPO_DIR = CHECKOUT_DIR / "core" if (CHECKOUT_DIR / "core/src/fashion").is_dir() else CHECKOUT_DIR
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"
print("Repository ready:", REPO_DIR)
print("Branch:", BRANCH)
print("Commit:", commit)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# $ git fetch origin task-3-gender-usage-classification
# $ git switch task-3-gender-usage-classification
# $ git merge --ff-only origin/task-3-gender-usage-classification
# Repository ready: /content/MLA2
# Branch: task-3-gender-usage-classification
# Commit: aed3551b8fb32a6ad0f8d5e5a014493f349f99cb

# %% [markdown]
# ## 2. Restore the teacher dataset on the Colab disk
#
# Only the teacher dataset is extracted. Task 3 does not use the high-resolution dataset.

# %%
def copy_teacher_zip_to_local_disk():
    if LOCAL_DATA_ZIP.is_file():
        try:
            with zipfile.ZipFile(LOCAL_DATA_ZIP) as existing:
                existing.infolist()
            print("Using the existing local ZIP copy:", LOCAL_DATA_ZIP)
            return
        except zipfile.BadZipFile:
            LOCAL_DATA_ZIP.unlink()

    partial = LOCAL_DATA_ZIP.with_suffix(".zip.partial")
    for attempt in range(1, 4):
        partial.unlink(missing_ok=True)
        try:
            if not DATA_ZIP.is_file():
                raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")
            expected_bytes = DATA_ZIP.stat().st_size
            print(
                f"Copying {expected_bytes / 1024**3:.2f} GiB from Drive to Colab "
                f"(attempt {attempt}/3)...",
                flush=True,
            )
            copied = 0
            next_report = 256 * 1024**2
            with DATA_ZIP.open("rb") as source, partial.open("wb") as target:
                while chunk := source.read(8 * 1024**2):
                    target.write(chunk)
                    copied += len(chunk)
                    if copied >= next_report:
                        print(f"  copied {copied / 1024**2:.0f} MiB", flush=True)
                        next_report += 256 * 1024**2
            if copied != expected_bytes:
                raise OSError(f"ZIP copy is incomplete: {copied} of {expected_bytes} bytes")
            partial.replace(LOCAL_DATA_ZIP)
            print("Local ZIP copy ready:", LOCAL_DATA_ZIP)
            return
        except (OSError, FileNotFoundError) as error:
            partial.unlink(missing_ok=True)
            if attempt == 3:
                raise RuntimeError(
                    "Google Drive disconnected three times while copying the teacher ZIP. "
                    "Reconnect Drive, then rerun this cell."
                ) from error
            print(f"Drive read failed: {error}. Remounting Drive...", flush=True)
            try:
                drive.flush_and_unmount()
            except Exception as unmount_error:
                print("Drive unmount warning:", unmount_error)
            drive.mount(str(DRIVE_MOUNT), force_remount=True)
            time.sleep(2)


copy_teacher_zip_to_local_disk()

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_suffixes = {".jpg", ".jpeg"}
image_dirs = (teacher_dir / "train/images_train", teacher_dir / "test/images_test")

with zipfile.ZipFile(LOCAL_DATA_ZIP) as archive:
    names = archive.namelist()
    unsafe = [name for name in names if Path(name).is_absolute() or ".." in Path(name).parts]
    if unsafe:
        raise RuntimeError("The dataset archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/") and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    if expected_images == 0:
        raise RuntimeError("The archive has no teacher images in data/raw/teacher.")
    current_images = sum(
        path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
    )
    if current_images != expected_images or not all(path.is_file() for path in required_files):
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found {actual_images:,}; "
        f"missing files: {missing_files}"
    )
print(f"Teacher data ready: {actual_images:,} images")

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print("Drive output root:", DRIVE_TASK_DIR)
# Out:
# Using the existing local ZIP copy: /content/task3-data.zip
# Teacher data is already extracted; skipping.
# Teacher data ready: 44,441 images
# Drive output root: /content/drive/MyDrive/MLA2/task3

# %% [markdown]
# ## 3. Verify the GPU screen without training
#
# This builds both random-weight models and checks their output shapes, class order, teacher files, family-safe folds, runtime, and 7 GiB GPU limit. It creates no optimizer and takes no training step.

# %%
from fashion.train.task3_micro_swin import check_micro_swin_screen_setup

screen_check = check_micro_swin_screen_setup(root=REPO_DIR, device_name="cuda")
if screen_check["optimizer_steps"] != 0 or screen_check["pretrained_weights_loaded"]:
    raise RuntimeError("The preflight unexpectedly trained or loaded weights.")
print("GPU:", screen_check["environment"]["gpu"])
print("Screen folds:", screen_check["screen_folds"])
for target, details in screen_check["targets"].items():
    print(target, details["input_view"], f'{details["parameter_count"]:,} parameters')
# Out:
# GPU: NVIDIA A100-SXM4-40GB
# Screen folds: [0, 4]
# gender foreground_masked 2,267,377 parameters
# usage full 2,268,405 parameters

# %% [markdown]
# ## 4. Frozen hypotheses and fair stopping rule
#
# **Why this model is new.** Every learned E1–E10 candidate used convolution blocks. This model converts each 4×4 image patch with a linear layer, then mixes patches through local and shifted-window attention. It starts from random weights and contains no convolution layer or pretrained component.
#
# **Gender hypothesis.** The foreground EDA showed that foreground-masked HOG was stronger than full-canvas HOG. A foreground-masked micro-Swin may combine child/adult, silhouette, colour, and accessory cues without relying as heavily on the catalogue background. It must still be rejected if the train–validation gap remains large or its matched score/classes fail the frozen screen gate.
#
# **Usage hypothesis.** The EDA showed full-image HOG was stronger than foreground-only HOG for usage. A full-image micro-Swin may combine product parts and wider context that a flat CNN or the type-only rule misses. The literal `NA` and `Home` output classes remain present. Report both all-nine and without-`Home` macro-F1.
#
# **Screen rule.** Run only canonical folds 0 and 4 with seed 2753. Keep the fixed final epoch; do not select a checkpoint from these outer validation folds. Advance only after reviewing score, per-class change, overfitting, robustness, runtime, and memory.

# %% [markdown]
# ## 5. Train Usage scratch micro-Swin
#
# This trains folds 0 and 4 only. Fold-only class weights are kept because Usage is extremely imbalanced. Artifacts are written directly to Drive after every epoch and completed fold.

# %%
from fashion.train.task3_micro_swin import run_micro_swin_screen

usage_anchor = (
    DRIVE_TASK_DIR
    / "experiments/t3_usage_e8_translation/usage/aggregate/oof_predictions.csv"
)
if not usage_anchor.is_file():
    raise FileNotFoundError(f"Usage E8 anchor is missing: {usage_anchor}")
usage_micro_swin = run_micro_swin_screen(
    "usage",
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
    anchor_prediction_path=usage_anchor,
    reuse_completed=True,
)
{
    "metrics_path": usage_micro_swin["metrics_path"],
    "macro_f1": usage_micro_swin["metrics"]["macro_f1"],
    "macro_f1_without_home": usage_micro_swin["metrics"]["macro_f1_without_home"],
    "screen_gate": usage_micro_swin["metrics"]["screen_gate"],
}
# Out:
# [task3-micro-swin] reusing completed target=usage fold=0: t3_cs2_micro_swin_usage_f0_s2753_a221b6c184a8_20260902T150141Z97d6bd
# [task3-micro-swin] reusing completed target=usage fold=4: t3_cs2_micro_swin_usage_f4_s2753_2819a04bffe4_20260902T151806Z713ccf
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/task3_clean_slate_micro_swin_screen_2/usage/aggregate_folds_0_4/metrics.json',
#  'macro_f1': 0.39729804145581515,
#  'macro_f1_without_home': 0.44696029663779197,
#  'screen_gate': {'status': 'fail',
#   'training_scope_integrity': True,
#   'resource_limit_pass': True,
#   'probability_integrity': True,
#   'candidate_macro_f1': 0.39729804145581515,
#   'matched_anchor_macro_f1': 0.42427162439534893,
#   'macro_f1_delta': -0.02697358293953378,
#   'score_noninferiority_pass': False,
#   'supported_class_noninferiority_pass': False,
#   'anchor_label_integrity': 'canonical_index_verified',
#   'anchor_literal_na_label_repairs': 22}}

# %% [markdown]
# ## 6. Train Gender scratch micro-Swin
#
# This trains the same frozen transformer family on the foreground-masked Gender input for folds 0 and 4. It is an independent model with its own head, normalization, checkpoint, and registry rows.

# %%
gender_anchor = (
    DRIVE_TASK_DIR
    / "experiments/t3_gender_e9_semantic_filter/gender/aggregate/oof_predictions.csv"
)
if not gender_anchor.is_file():
    raise FileNotFoundError(f"Gender E9 anchor is missing: {gender_anchor}")
gender_micro_swin = run_micro_swin_screen(
    "gender",
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
    anchor_prediction_path=gender_anchor,
    reuse_completed=True,
)
{
    "metrics_path": gender_micro_swin["metrics_path"],
    "macro_f1": gender_micro_swin["metrics"]["macro_f1"],
    "screen_gate": gender_micro_swin["metrics"]["screen_gate"],
}
# Out:
# [task3-micro-swin] target=gender fold=0: fitting foreground_masked RGB statistics
# [task3-micro-swin] normalisation view=foreground_masked: 1/26,220 images
# [task3-micro-swin] normalisation view=foreground_masked: 5,000/26,220 images
# [task3-micro-swin] normalisation view=foreground_masked: 10,000/26,220 images
# [task3-micro-swin] normalisation view=foreground_masked: 15,000/26,220 images
# [task3-micro-swin] normalisation view=foreground_masked: 20,000/26,220 images
# [task3-micro-swin] normalisation view=foreground_masked: 25,000/26,220 images
# [task3-micro-swin] normalisation view=foreground_masked: 26,220/26,220 images
# [task3-micro-swin] registered t3_cs2_micro_swin_gender_f0_s2753_2636e3521046_20260902T154822Z2cc20a; first optimiser step may now run on NVIDIA A100-SXM4-40GB
# [task3-micro-swin] target=gender fold=0 epoch=1/60 train_macro_f1=0.2702 validation_macro_f1=0.3169
# [task3-micro-swin] target=gender fold=0 epoch=2/60 train_macro_f1=0.4572 validation_macro_f1=0.5645
# [task3-micro-swin] target=gender fold=0 epoch=3/60 train_macro_f1=0.5732 validation_macro_f1=0.6153
# [task3-micro-swin] target=gender fold=0 epoch=4/60 train_macro_f1=0.6096 validation_macro_f1=0.6255
# [task3-micro-swin] target=gender fold=0 epoch=5/60 train_macro_f1=0.6410 validation_macro_f1=0.6513
# [task3-micro-swin] target=gender fold=0 epoch=6/60 train_macro_f1=0.6592 validation_macro_f1=0.6333
# [task3-micro-swin] target=gender fold=0 epoch=7/60 train_macro_f1=0.6762 validation_macro_f1=0.6534
# [task3-micro-swin] target=gender fold=0 epoch=8/60 train_macro_f1=0.7026 validation_macro_f1=0.6599
# [task3-micro-swin] target=gender fold=0 epoch=9/60 train_macro_f1=0.7167 validation_macro_f1=0.6910
# [task3-micro-swin] target=gender fold=0 epoch=10/60 train_macro_f1=0.7344 validation_macro_f1=0.6837
# [task3-micro-swin] target=gender fold=0 epoch=11/60 train_macro_f1=0.7488 validation_macro_f1=0.6608
# [task3-micro-swin] target=gender fold=0 epoch=12/60 train_macro_f1=0.7540 validation_macro_f1=0.6768
# [task3-micro-swin] target=gender fold=0 epoch=13/60 train_macro_f1=0.7764 validation_macro_f1=0.6802
# [task3-micro-swin] target=gender fold=0 epoch=14/60 train_macro_f1=0.7851 validation_macro_f1=0.6253
# [task3-micro-swin] target=gender fold=0 epoch=15/60 train_macro_f1=0.7979 validation_macro_f1=0.6426
# [task3-micro-swin] target=gender fold=0 epoch=16/60 train_macro_f1=0.7992 validation_macro_f1=0.6587
# [task3-micro-swin] target=gender fold=0 epoch=17/60 train_macro_f1=0.8159 validation_macro_f1=0.6513
# [task3-micro-swin] target=gender fold=0 epoch=18/60 train_macro_f1=0.8284 validation_macro_f1=0.6798
# [task3-micro-swin] target=gender fold=0 epoch=19/60 train_macro_f1=0.8360 validation_macro_f1=0.6756
# [task3-micro-swin] target=gender fold=0 epoch=20/60 train_macro_f1=0.8452 validation_macro_f1=0.6827
# [task3-micro-swin] target=gender fold=0 epoch=21/60 train_macro_f1=0.8607 validation_macro_f1=0.6737
# [task3-micro-swin] target=gender fold=0 epoch=22/60 train_macro_f1=0.8590 validation_macro_f1=0.6774
# [task3-micro-swin] target=gender fold=0 epoch=23/60 train_macro_f1=0.8789 validation_macro_f1=0.6791
# [task3-micro-swin] target=gender fold=0 epoch=24/60 train_macro_f1=0.8788 validation_macro_f1=0.6733
# [task3-micro-swin] target=gender fold=0 epoch=25/60 train_macro_f1=0.8878 validation_macro_f1=0.6547
# [task3-micro-swin] target=gender fold=0 epoch=26/60 train_macro_f1=0.8978 validation_macro_f1=0.6876
# [task3-micro-swin] target=gender fold=0 epoch=27/60 train_macro_f1=0.9008 validation_macro_f1=0.6779
# [task3-micro-swin] target=gender fold=0 epoch=28/60 train_macro_f1=0.9116 validation_macro_f1=0.6720
# [task3-micro-swin] target=gender fold=0 epoch=29/60 train_macro_f1=0.9153 validation_macro_f1=0.6923
# [task3-micro-swin] target=gender fold=0 epoch=30/60 train_macro_f1=0.9216 validation_macro_f1=0.6752
# [task3-micro-swin] target=gender fold=0 epoch=31/60 train_macro_f1=0.9261 validation_macro_f1=0.6957
# [task3-micro-swin] target=gender fold=0 epoch=32/60 train_macro_f1=0.9297 validation_macro_f1=0.6909
# [task3-micro-swin] target=gender fold=0 epoch=33/60 train_macro_f1=0.9349 validation_macro_f1=0.7020
# [task3-micro-swin] target=gender fold=0 epoch=34/60 train_macro_f1=0.9414 validation_macro_f1=0.6835
# [task3-micro-swin] target=gender fold=0 epoch=35/60 train_macro_f1=0.9472 validation_macro_f1=0.6921
# [task3-micro-swin] target=gender fold=0 epoch=36/60 train_macro_f1=0.9526 validation_macro_f1=0.6667
# [task3-micro-swin] target=gender fold=0 epoch=37/60 train_macro_f1=0.9527 validation_macro_f1=0.6747
# [task3-micro-swin] target=gender fold=0 epoch=38/60 train_macro_f1=0.9565 validation_macro_f1=0.6663
# [task3-micro-swin] target=gender fold=0 epoch=39/60 train_macro_f1=0.9598 validation_macro_f1=0.6889
# [task3-micro-swin] target=gender fold=0 epoch=40/60 train_macro_f1=0.9674 validation_macro_f1=0.6877
# [task3-micro-swin] target=gender fold=0 epoch=41/60 train_macro_f1=0.9643 validation_macro_f1=0.6969
# [task3-micro-swin] target=gender fold=0 epoch=42/60 train_macro_f1=0.9632 validation_macro_f1=0.6883
# [task3-micro-swin] target=gender fold=0 epoch=43/60 train_macro_f1=0.9683 validation_macro_f1=0.6779
# [task3-micro-swin] target=gender fold=0 epoch=44/60 train_macro_f1=0.9704 validation_macro_f1=0.6920
# [task3-micro-swin] target=gender fold=0 epoch=45/60 train_macro_f1=0.9720 validation_macro_f1=0.6759
# [task3-micro-swin] target=gender fold=0 epoch=46/60 train_macro_f1=0.9751 validation_macro_f1=0.6895
# [task3-micro-swin] target=gender fold=0 epoch=47/60 train_macro_f1=0.9755 validation_macro_f1=0.7016
# [task3-micro-swin] target=gender fold=0 epoch=48/60 train_macro_f1=0.9769 validation_macro_f1=0.6968
# [task3-micro-swin] target=gender fold=0 epoch=49/60 train_macro_f1=0.9789 validation_macro_f1=0.6879
# [task3-micro-swin] target=gender fold=0 epoch=50/60 train_macro_f1=0.9770 validation_macro_f1=0.6875
# [task3-micro-swin] target=gender fold=0 epoch=51/60 train_macro_f1=0.9808 validation_macro_f1=0.6943
# [task3-micro-swin] target=gender fold=0 epoch=52/60 train_macro_f1=0.9834 validation_macro_f1=0.6850
# [task3-micro-swin] target=gender fold=0 epoch=53/60 train_macro_f1=0.9834 validation_macro_f1=0.6942
# [task3-micro-swin] target=gender fold=0 epoch=54/60 train_macro_f1=0.9833 validation_macro_f1=0.6887
# [task3-micro-swin] target=gender fold=0 epoch=55/60 train_macro_f1=0.9841 validation_macro_f1=0.6864
# [task3-micro-swin] target=gender fold=0 epoch=56/60 train_macro_f1=0.9847 validation_macro_f1=0.6977
# [task3-micro-swin] target=gender fold=0 epoch=57/60 train_macro_f1=0.9821 validation_macro_f1=0.6929
# [task3-micro-swin] target=gender fold=0 epoch=58/60 train_macro_f1=0.9831 validation_macro_f1=0.6930
# [task3-micro-swin] target=gender fold=0 epoch=59/60 train_macro_f1=0.9845 validation_macro_f1=0.6941
# [task3-micro-swin] target=gender fold=0 epoch=60/60 train_macro_f1=0.9857 validation_macro_f1=0.6913
# [task3-micro-swin] complete target=gender fold=0: macro_f1=0.6913
# [task3-micro-swin] target=gender fold=4: fitting foreground_masked RGB statistics
# [task3-micro-swin] normalisation view=foreground_masked: 1/26,216 images
# [task3-micro-swin] normalisation view=foreground_masked: 5,000/26,216 images
# [task3-micro-swin] normalisation view=foreground_masked: 10,000/26,216 images
# [task3-micro-swin] normalisation view=foreground_masked: 15,000/26,216 images
# [task3-micro-swin] normalisation view=foreground_masked: 20,000/26,216 images
# [task3-micro-swin] normalisation view=foreground_masked: 25,000/26,216 images
# [task3-micro-swin] normalisation view=foreground_masked: 26,216/26,216 images
# [task3-micro-swin] registered t3_cs2_micro_swin_gender_f4_s2753_bee406bd99e4_20260902T162150Z70bb81; first optimiser step may now run on NVIDIA A100-SXM4-40GB
# [task3-micro-swin] target=gender fold=4 epoch=1/60 train_macro_f1=0.2687 validation_macro_f1=0.3009
# [task3-micro-swin] target=gender fold=4 epoch=2/60 train_macro_f1=0.4601 validation_macro_f1=0.5841
# [task3-micro-swin] target=gender fold=4 epoch=3/60 train_macro_f1=0.5755 validation_macro_f1=0.6065
# [task3-micro-swin] target=gender fold=4 epoch=4/60 train_macro_f1=0.6072 validation_macro_f1=0.6327
# [task3-micro-swin] target=gender fold=4 epoch=5/60 train_macro_f1=0.6322 validation_macro_f1=0.6577
# [task3-micro-swin] target=gender fold=4 epoch=6/60 train_macro_f1=0.6666 validation_macro_f1=0.6679
# [task3-micro-swin] target=gender fold=4 epoch=7/60 train_macro_f1=0.6823 validation_macro_f1=0.6685
# [task3-micro-swin] target=gender fold=4 epoch=8/60 train_macro_f1=0.6984 validation_macro_f1=0.6534
# [task3-micro-swin] target=gender fold=4 epoch=9/60 train_macro_f1=0.7154 validation_macro_f1=0.6843
# [task3-micro-swin] target=gender fold=4 epoch=10/60 train_macro_f1=0.7276 validation_macro_f1=0.6795
# [task3-micro-swin] target=gender fold=4 epoch=11/60 train_macro_f1=0.7411 validation_macro_f1=0.6578
# [task3-micro-swin] target=gender fold=4 epoch=12/60 train_macro_f1=0.7514 validation_macro_f1=0.6619
# [task3-micro-swin] target=gender fold=4 epoch=13/60 train_macro_f1=0.7661 validation_macro_f1=0.6830
# [task3-micro-swin] target=gender fold=4 epoch=14/60 train_macro_f1=0.7682 validation_macro_f1=0.6697
# [task3-micro-swin] target=gender fold=4 epoch=15/60 train_macro_f1=0.7854 validation_macro_f1=0.6862
# [task3-micro-swin] target=gender fold=4 epoch=16/60 train_macro_f1=0.7972 validation_macro_f1=0.6820
# [task3-micro-swin] target=gender fold=4 epoch=17/60 train_macro_f1=0.8061 validation_macro_f1=0.6930
# [task3-micro-swin] target=gender fold=4 epoch=18/60 train_macro_f1=0.8195 validation_macro_f1=0.6882
# [task3-micro-swin] target=gender fold=4 epoch=19/60 train_macro_f1=0.8330 validation_macro_f1=0.6698
# [task3-micro-swin] target=gender fold=4 epoch=20/60 train_macro_f1=0.8479 validation_macro_f1=0.6693
# [task3-micro-swin] target=gender fold=4 epoch=21/60 train_macro_f1=0.8533 validation_macro_f1=0.6703
# [task3-micro-swin] target=gender fold=4 epoch=22/60 train_macro_f1=0.8638 validation_macro_f1=0.7045
# [task3-micro-swin] target=gender fold=4 epoch=23/60 train_macro_f1=0.8574 validation_macro_f1=0.6805
# [task3-micro-swin] target=gender fold=4 epoch=24/60 train_macro_f1=0.8814 validation_macro_f1=0.6900
# [task3-micro-swin] target=gender fold=4 epoch=25/60 train_macro_f1=0.8776 validation_macro_f1=0.6790
# [task3-micro-swin] target=gender fold=4 epoch=26/60 train_macro_f1=0.8928 validation_macro_f1=0.6725
# [task3-micro-swin] target=gender fold=4 epoch=27/60 train_macro_f1=0.8998 validation_macro_f1=0.6790
# [task3-micro-swin] target=gender fold=4 epoch=28/60 train_macro_f1=0.9078 validation_macro_f1=0.6519
# [task3-micro-swin] target=gender fold=4 epoch=29/60 train_macro_f1=0.9120 validation_macro_f1=0.6974
# [task3-micro-swin] target=gender fold=4 epoch=30/60 train_macro_f1=0.9189 validation_macro_f1=0.6786
# [task3-micro-swin] target=gender fold=4 epoch=31/60 train_macro_f1=0.9252 validation_macro_f1=0.6779
# [task3-micro-swin] target=gender fold=4 epoch=32/60 train_macro_f1=0.9317 validation_macro_f1=0.6784
# [task3-micro-swin] target=gender fold=4 epoch=33/60 train_macro_f1=0.9351 validation_macro_f1=0.6877
# [task3-micro-swin] target=gender fold=4 epoch=34/60 train_macro_f1=0.9410 validation_macro_f1=0.6807
# [task3-micro-swin] target=gender fold=4 epoch=35/60 train_macro_f1=0.9488 validation_macro_f1=0.6629
# [task3-micro-swin] target=gender fold=4 epoch=36/60 train_macro_f1=0.9488 validation_macro_f1=0.6778
# [task3-micro-swin] target=gender fold=4 epoch=37/60 train_macro_f1=0.9537 validation_macro_f1=0.6745
# [task3-micro-swin] target=gender fold=4 epoch=38/60 train_macro_f1=0.9553 validation_macro_f1=0.6677
# [task3-micro-swin] target=gender fold=4 epoch=39/60 train_macro_f1=0.9599 validation_macro_f1=0.6832
# [task3-micro-swin] target=gender fold=4 epoch=40/60 train_macro_f1=0.9644 validation_macro_f1=0.6953
# [task3-micro-swin] target=gender fold=4 epoch=41/60 train_macro_f1=0.9682 validation_macro_f1=0.6675
# [task3-micro-swin] target=gender fold=4 epoch=42/60 train_macro_f1=0.9682 validation_macro_f1=0.6535
# [task3-micro-swin] target=gender fold=4 epoch=43/60 train_macro_f1=0.9719 validation_macro_f1=0.6813
# [task3-micro-swin] target=gender fold=4 epoch=44/60 train_macro_f1=0.9726 validation_macro_f1=0.6706
# [task3-micro-swin] target=gender fold=4 epoch=45/60 train_macro_f1=0.9760 validation_macro_f1=0.6836
# [task3-micro-swin] target=gender fold=4 epoch=46/60 train_macro_f1=0.9747 validation_macro_f1=0.6803
# [task3-micro-swin] target=gender fold=4 epoch=47/60 train_macro_f1=0.9766 validation_macro_f1=0.6757
# [task3-micro-swin] target=gender fold=4 epoch=48/60 train_macro_f1=0.9778 validation_macro_f1=0.6727
# [task3-micro-swin] target=gender fold=4 epoch=49/60 train_macro_f1=0.9838 validation_macro_f1=0.6787
# [task3-micro-swin] target=gender fold=4 epoch=50/60 train_macro_f1=0.9851 validation_macro_f1=0.6732
# [task3-micro-swin] target=gender fold=4 epoch=51/60 train_macro_f1=0.9839 validation_macro_f1=0.6811
# [task3-micro-swin] target=gender fold=4 epoch=52/60 train_macro_f1=0.9808 validation_macro_f1=0.6789
# [task3-micro-swin] target=gender fold=4 epoch=53/60 train_macro_f1=0.9832 validation_macro_f1=0.6815
# [task3-micro-swin] target=gender fold=4 epoch=54/60 train_macro_f1=0.9847 validation_macro_f1=0.6708
# [task3-micro-swin] target=gender fold=4 epoch=55/60 train_macro_f1=0.9842 validation_macro_f1=0.6709
# [task3-micro-swin] target=gender fold=4 epoch=56/60 train_macro_f1=0.9841 validation_macro_f1=0.6749
# [task3-micro-swin] target=gender fold=4 epoch=57/60 train_macro_f1=0.9857 validation_macro_f1=0.6744
# [task3-micro-swin] target=gender fold=4 epoch=58/60 train_macro_f1=0.9836 validation_macro_f1=0.6767
# [task3-micro-swin] target=gender fold=4 epoch=59/60 train_macro_f1=0.9831 validation_macro_f1=0.6792
# [task3-micro-swin] target=gender fold=4 epoch=60/60 train_macro_f1=0.9853 validation_macro_f1=0.6783
# [task3-micro-swin] complete target=gender fold=4: macro_f1=0.6783
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/task3_clean_slate_micro_swin_screen_2/gender/aggregate_folds_0_4/metrics.json',
#  'macro_f1': 0.6846634219949939,
#  'screen_gate': {'status': 'fail',
#   'training_scope_integrity': True,
#   'resource_limit_pass': True,
#   'probability_integrity': True,
#   'candidate_macro_f1': 0.6846634219949939,
#   'matched_anchor_macro_f1': 0.7392855486858143,
#   'macro_f1_delta': -0.05462212669082045,
#   'score_noninferiority_pass': False,
#   'supported_class_noninferiority_pass': False,
#   'anchor_label_integrity': 'canonical_index_verified',
#   'anchor_literal_na_label_repairs': 0}}

# %% [markdown]
# ## 7. Confirm the saved screen evidence
#
# This only summarizes the two completed screen aggregates. It does not promote either model or start five-fold training.

# %%
import pandas as pd

summary = pd.DataFrame(
    [
        {
            "target": target,
            "model_family": result["metrics"]["model_family"],
            "folds": result["metrics"]["validation_folds"],
            "macro_f1": result["metrics"]["macro_f1"],
            "fold_sd": result["metrics"]["fold_macro_f1_sample_sd"],
            "gate": result["metrics"]["screen_gate"]["status"],
            "metrics_path": result["metrics_path"],
        }
        for target, result in (
            ("usage", usage_micro_swin),
            ("gender", gender_micro_swin),
        )
    ]
)
display(summary)
print("Stop here. Review Screen 1 and Screen 2 before any five-fold promotion.")
# Out:
#    target                   model_family   folds  macro_f1   fold_sd  gate  \
# 0   usage  scratch_pure_patch_micro_swin  [0, 4]  0.397298  0.035133  fail
# 1  gender  scratch_pure_patch_micro_swin  [0, 4]  0.684663  0.009169  fail
#
#                                         metrics_path
# 0  /content/drive/MyDrive/MLA2/task3/experiments/...
# 1  /content/drive/MyDrive/MLA2/task3/experiments/...
# Stop here. Review Screen 1 and Screen 2 before any five-fold promotion.
