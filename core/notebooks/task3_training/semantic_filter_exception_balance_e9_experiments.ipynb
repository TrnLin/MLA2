# %% [markdown]
# # Task 3 — Semantic Filter and Exception Balance E9 Experiments
#
# This Colab runner trains only the two predeclared E9 children. Usage runs first from the exact E2 parents. Gender then uses the exact E6 parents after the deterministic 305-row filter contract is reproduced. No human-rating gate is used. It never trains E1–E8.

# %% [markdown]
# ## 1. Safe Colab setup
#
# Run on a GPU runtime. The repository update stops on local changes. Training data is extracted into Colab-local storage; evidence and the registry stay in Drive.

# %%
from pathlib import Path
import os
import subprocess
import sys
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
CHECKOUT_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"


def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command))
    return subprocess.run(command, cwd=cwd, check=True)

# %%
try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("This runner must run in Google Colab.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)

if (CHECKOUT_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=CHECKOUT_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{CHECKOUT_DIR} belongs to a different repository: {remote_url}")
    dirty = subprocess.check_output(
        ["git", "status", "--porcelain"], cwd=CHECKOUT_DIR, text=True
    ).strip()
    if dirty:
        raise RuntimeError(
            "The Colab clone has local changes. Save them first; no switch or merge was attempted."
        )
    run_checked(["git", "fetch", "origin", BRANCH], cwd=CHECKOUT_DIR)
    run_checked(["git", "switch", BRANCH], cwd=CHECKOUT_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=CHECKOUT_DIR)
elif CHECKOUT_DIR.exists():
    raise RuntimeError(f"{CHECKOUT_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, CHECKOUT_DIR])

REPO_DIR = CHECKOUT_DIR / "core" if (CHECKOUT_DIR / "core/src/fashion").is_dir() else CHECKOUT_DIR
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"
print(f"Repository ready: {REPO_DIR} ({BRANCH})")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# $ git fetch origin task-3-gender-usage-classification
# $ git switch task-3-gender-usage-classification
# $ git merge --ff-only origin/task-3-gender-usage-classification
# Repository ready: /content/MLA2 (task-3-gender-usage-classification)

# %%
if not DATA_ZIP.is_file():
    raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_suffixes = {".jpg", ".jpeg"}
image_dirs = (
    teacher_dir / "train/images_train",
    teacher_dir / "test/images_test",
)

with zipfile.ZipFile(DATA_ZIP) as archive:
    names = archive.namelist()
    unsafe_names = [
        name for name in names if Path(name).is_absolute() or ".." in Path(name).parts
    ]
    if unsafe_names:
        raise RuntimeError("The dataset archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/")
        and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    if expected_images == 0:
        raise RuntimeError("The archive has no teacher images in the expected folder.")
    current_images = sum(
        path.suffix.lower() in image_suffixes
        for image_dir in image_dirs
        for path in image_dir.glob("*")
    )
    needs_extract = current_images != expected_images or not all(
        path.is_file() for path in required_files
    )
    if needs_extract:
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes
    for image_dir in image_dirs
    for path in image_dir.glob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found "
        f"{actual_images:,}; missing files: {missing_files}"
    )
print(f"Teacher data ready: {actual_images:,} images")

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)
DRIVE_TASK_DIR.mkdir(parents=True, exist_ok=True)
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print("Output folders are ready.")
# Out:
# Extracting 44,441 teacher images...
# Teacher data ready: 44,441 images
# Output folders are ready.

# %% [markdown]
# ## 2. Exact parents and zero-step preflight
#
# The IDs below are the validated completed parent folds. The resolver must return the same tuple. Preflight builds the child shape and contract but creates no optimizer step.

# %%
from fashion.train.task3_experiments import (
    audit_completed_registry_rows,
    check_task3_child_setup,
    latest_completed_gender_e6_parent_run_ids,
    latest_completed_usage_e2_parent_run_ids,
    run_task3_child_cv,
)
from fashion.train.task3_e9 import write_task3_e9_prerun_evidence

GENDER_E6_PARENT_RUN_IDS = ('t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f', 't3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5', 't3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677', 't3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a', 't3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd')
USAGE_E2_PARENT_RUN_IDS = ('t3_usage_e2_class_balanced_ce_usage_smallcnn_f0_s2753_5461e048c3b3_20260830T115815Z356f6d', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f1_s2753_5461e048c3b3_20260830T120645Z6d08cd', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f2_s2753_5461e048c3b3_20260830T121514Zd58aa0', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f3_s2753_5461e048c3b3_20260830T122347Z2cb06e', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f4_s2753_5461e048c3b3_20260830T123218Z94db47')

resolved_gender = latest_completed_gender_e6_parent_run_ids(output_root=DRIVE_TASK_DIR)
resolved_usage = latest_completed_usage_e2_parent_run_ids(output_root=DRIVE_TASK_DIR)
if resolved_gender != GENDER_E6_PARENT_RUN_IDS:
    raise RuntimeError("Resolved Gender E6 parents differ from the frozen tuple.")
if resolved_usage != USAGE_E2_PARENT_RUN_IDS:
    raise RuntimeError("Resolved Usage E2 parents differ from the frozen tuple.")

usage_check = check_task3_child_setup(
    "usage_exception_balance",
    parent_run_ids=USAGE_E2_PARENT_RUN_IDS,
    root=REPO_DIR,
    device_name="cuda",
)
gender_check = check_task3_child_setup(
    "gender_semantic_filter",
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    root=REPO_DIR,
    device_name="cuda",
)
if usage_check["optimizer_steps"] != 0 or gender_check["optimizer_steps"] != 0:
    raise RuntimeError("Preflight unexpectedly reported an optimizer step.")
print("Both E9 contracts passed zero-step preflight.")
print("Gender deterministic audit required:", gender_check["gender_deterministic_audit_required"])
print("Gender human gate required:", gender_check["gender_human_rating_gate_required"])
# Out:
# Both E9 contracts passed zero-step preflight.
# Gender deterministic audit required: True
# Gender human gate required: False

# %%
USAGE_E2_OOF = (
    DRIVE_TASK_DIR
    / "experiments/t3_usage_e2_class_balanced_ce/usage/aggregate/oof_predictions.csv"
)
missing_audit_inputs = [
    str(path) for path in (USAGE_E2_OOF,)
    if not path.is_file()
]
if missing_audit_inputs:
    raise FileNotFoundError(f"Missing saved audit inputs: {missing_audit_inputs}")

e9_prerun = write_task3_e9_prerun_evidence(
    splits_path=REPO_DIR / "data/processed/splits.csv",
    usage_prediction_path=USAGE_E2_OOF,
    output_dir=DRIVE_TASK_DIR / "e9_prerun",
)
if e9_prerun["optimizer_steps"] != 0:
    raise RuntimeError("The audit pack unexpectedly reported an optimizer step.")
gender_contract = e9_prerun["gender_deterministic_contract"]
if not gender_contract["verified"] or not all(gender_contract["checks"].values()):
    raise RuntimeError("The deterministic Gender contract did not verify.")
if gender_contract["human_rating_gate_required"]:
    raise RuntimeError("E9G must not depend on a human-rating gate.")
print("Gender conflict rows:", gender_contract["conflict_rows"])
print("Gender fold-training removals:", gender_contract["training_removals"])
print("Gender excluded-ID hash:", gender_contract["conflict_ids_hash"])
print("Deterministic E9 evidence ready in Drive; optimizer steps: 0")
# Out:
# Gender conflict rows: 305
# Gender fold-training removals: {'0': 242, '1': 224, '2': 259, '3': 263, '4': 232}
# Gender excluded-ID hash: 42faeef3794267065daa3e1aa61aeb5bbc62364f9bcb405013d96d29e96ccdb6
# Deterministic E9 evidence ready in Drive; optimizer steps: 0

# %% [markdown]
# ## 3. Usage E9U — run first
#
# This first training call keeps every row and changes only fold-training usual/exception weights on top of the exact E2 class weights. ArticleType remains training metadata only.

# %%
usage_e9 = run_task3_child_cv(
    "usage_exception_balance",
    parent_run_ids=USAGE_E2_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    folds=range(5),
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
)
usage_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, usage_e9["fold_run_ids"]
)
print("Usage E9 complete:", usage_e9["metrics_path"])
print(usage_registry_audit)
# Out:
# [task3] starting five-fold experiment=t3_usage_exception_balance_smallcnn for target=usage
# [task3] preparing target=usage fold=0: train=26,219 (before selection=26,219), validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_e9_exception_balance_usage_smallcnn_f0_s2753_d22930bc1285_20260902T004030Zed2d5a; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=1.9079 train_macro_f1=0.1435 validation_loss=1.4704 validation_macro_f1=0.1344
# [task3] target=usage fold=0 epoch=2/30 train_loss=1.7049 train_macro_f1=0.1780 validation_loss=1.4216 validation_macro_f1=0.1452
# [task3] target=usage fold=0 epoch=3/30 train_loss=1.4701 train_macro_f1=0.2268 validation_loss=1.2717 validation_macro_f1=0.2267
# [task3] target=usage fold=0 epoch=4/30 train_loss=1.3100 train_macro_f1=0.2552 validation_loss=1.1717 validation_macro_f1=0.2310
# [task3] target=usage fold=0 epoch=5/30 train_loss=1.2022 train_macro_f1=0.2754 validation_loss=1.2013 validation_macro_f1=0.2199
# [task3] target=usage fold=0 epoch=6/30 train_loss=1.0746 train_macro_f1=0.2796 validation_loss=1.1377 validation_macro_f1=0.2668
# [task3] target=usage fold=0 epoch=7/30 train_loss=0.9531 train_macro_f1=0.2910 validation_loss=1.4352 validation_macro_f1=0.2134
# [task3] target=usage fold=0 epoch=8/30 train_loss=0.9139 train_macro_f1=0.2974 validation_loss=1.1058 validation_macro_f1=0.2768
# [task3] target=usage fold=0 epoch=9/30 train_loss=0.8043 train_macro_f1=0.3159 validation_loss=0.9769 validation_macro_f1=0.2833
# [task3] target=usage fold=0 epoch=10/30 train_loss=0.7074 train_macro_f1=0.3181 validation_loss=1.7810 validation_macro_f1=0.2102
# [task3] target=usage fold=0 epoch=11/30 train_loss=0.6945 train_macro_f1=0.3994 validation_loss=1.1572 validation_macro_f1=0.2699
# [task3] target=usage fold=0 epoch=12/30 train_loss=0.5663 train_macro_f1=0.3434 validation_loss=1.0494 validation_macro_f1=0.2856
# [task3] target=usage fold=0 epoch=13/30 train_loss=0.5227 train_macro_f1=0.4716 validation_loss=0.9284 validation_macro_f1=0.3132
# [task3] target=usage fold=0 epoch=14/30 train_loss=0.4392 train_macro_f1=0.4997 validation_loss=0.8943 validation_macro_f1=0.3148
# [task3] target=usage fold=0 epoch=15/30 train_loss=0.3856 train_macro_f1=0.5292 validation_loss=1.0125 validation_macro_f1=0.3147
# [task3] target=usage fold=0 epoch=16/30 train_loss=0.3543 train_macro_f1=0.5498 validation_loss=1.3648 validation_macro_f1=0.2727
# [task3] target=usage fold=0 epoch=17/30 train_loss=0.3260 train_macro_f1=0.5812 validation_loss=1.0957 validation_macro_f1=0.3308
# [task3] target=usage fold=0 epoch=18/30 train_loss=0.2998 train_macro_f1=0.6160 validation_loss=1.0375 validation_macro_f1=0.3459
# [task3] target=usage fold=0 epoch=19/30 train_loss=0.2767 train_macro_f1=0.6234 validation_loss=0.9868 validation_macro_f1=0.3817
# [task3] target=usage fold=0 epoch=20/30 train_loss=0.2543 train_macro_f1=0.6647 validation_loss=1.0752 validation_macro_f1=0.3394
# [task3] target=usage fold=0 epoch=21/30 train_loss=0.2407 train_macro_f1=0.7063 validation_loss=1.2142 validation_macro_f1=0.3502
# [task3] target=usage fold=0 epoch=22/30 train_loss=0.2271 train_macro_f1=0.7019 validation_loss=1.2346 validation_macro_f1=0.3473
# [task3] target=usage fold=0 epoch=23/30 train_loss=0.2125 train_macro_f1=0.7118 validation_loss=1.4114 validation_macro_f1=0.3297
# [task3] target=usage fold=0 epoch=24/30 train_loss=0.1990 train_macro_f1=0.7393 validation_loss=1.0839 validation_macro_f1=0.3855
# [task3] target=usage fold=0 epoch=25/30 train_loss=0.1894 train_macro_f1=0.7548 validation_loss=1.0958 validation_macro_f1=0.3783
# [task3] target=usage fold=0 epoch=26/30 train_loss=0.1840 train_macro_f1=0.7778 validation_loss=1.0596 validation_macro_f1=0.3765
# [task3] target=usage fold=0 epoch=27/30 train_loss=0.1762 train_macro_f1=0.7684 validation_loss=1.1446 validation_macro_f1=0.3860
# [task3] target=usage fold=0 epoch=28/30 train_loss=0.1732 train_macro_f1=0.7855 validation_loss=1.1239 validation_macro_f1=0.3815
# [task3] target=usage fold=0 epoch=29/30 train_loss=0.1690 train_macro_f1=0.7896 validation_loss=1.1115 validation_macro_f1=0.3911
# [task3] target=usage fold=0 epoch=30/30 train_loss=0.1679 train_macro_f1=0.8004 validation_loss=1.1154 validation_macro_f1=0.3942
# [task3] completed target=usage fold=0: t3_usage_e9_exception_balance_usage_smallcnn_f0_s2753_d22930bc1285_20260902T004030Zed2d5a
# [task3] preparing target=usage fold=1: train=26,216 (before selection=26,216), validation=6,556
# [task3] fitting fold-training RGB statistics for target=usage fold=1
# [task3] RGB statistics ready for target=usage fold=1
# [task3] registered t3_usage_e9_exception_balance_usage_smallcnn_f1_s2753_d22930bc1285_20260902T004910Z10b181; the first optimiser step may now run
# [task3] target=usage fold=1 epoch=1/30 train_loss=2.0782 train_macro_f1=0.1319 validation_loss=1.4024 validation_macro_f1=0.1596
# [task3] target=usage fold=1 epoch=2/30 train_loss=1.6642 train_macro_f1=0.1697 validation_loss=1.2473 validation_macro_f1=0.1641
# [task3] target=usage fold=1 epoch=3/30 train_loss=1.5264 train_macro_f1=0.2181 validation_loss=1.3046 validation_macro_f1=0.2085
# [task3] target=usage fold=1 epoch=4/30 train_loss=1.4613 train_macro_f1=0.2316 validation_loss=1.4976 validation_macro_f1=0.1566
# [task3] target=usage fold=1 epoch=5/30 train_loss=1.3364 train_macro_f1=0.2494 validation_loss=1.4640 validation_macro_f1=0.1988
# [task3] target=usage fold=1 epoch=6/30 train_loss=1.2140 train_macro_f1=0.2638 validation_loss=3.3492 validation_macro_f1=0.0640
# [task3] target=usage fold=1 epoch=7/30 train_loss=1.1133 train_macro_f1=0.2726 validation_loss=1.2084 validation_macro_f1=0.2538
# [task3] target=usage fold=1 epoch=8/30 train_loss=0.9990 train_macro_f1=0.2864 validation_loss=0.9684 validation_macro_f1=0.2623
# [task3] target=usage fold=1 epoch=9/30 train_loss=0.9217 train_macro_f1=0.2922 validation_loss=1.0273 validation_macro_f1=0.2744
# [task3] target=usage fold=1 epoch=10/30 train_loss=0.7835 train_macro_f1=0.2959 validation_loss=1.3431 validation_macro_f1=0.2184
# [task3] target=usage fold=1 epoch=11/30 train_loss=0.6879 train_macro_f1=0.4278 validation_loss=1.2694 validation_macro_f1=0.2592
# [task3] target=usage fold=1 epoch=12/30 train_loss=0.6236 train_macro_f1=0.4366 validation_loss=0.9799 validation_macro_f1=0.2820
# [task3] target=usage fold=1 epoch=13/30 train_loss=0.5605 train_macro_f1=0.4595 validation_loss=1.0457 validation_macro_f1=0.2791
# [task3] target=usage fold=1 epoch=14/30 train_loss=0.5055 train_macro_f1=0.4897 validation_loss=1.1573 validation_macro_f1=0.2695
# [task3] target=usage fold=1 epoch=15/30 train_loss=0.4447 train_macro_f1=0.4866 validation_loss=0.8509 validation_macro_f1=0.2984
# [task3] target=usage fold=1 epoch=16/30 train_loss=0.4000 train_macro_f1=0.5161 validation_loss=1.0073 validation_macro_f1=0.3052
# [task3] target=usage fold=1 epoch=17/30 train_loss=0.3582 train_macro_f1=0.5683 validation_loss=1.2673 validation_macro_f1=0.2737
# [task3] target=usage fold=1 epoch=18/30 train_loss=0.3341 train_macro_f1=0.5523 validation_loss=1.0703 validation_macro_f1=0.2903
# [task3] target=usage fold=1 epoch=19/30 train_loss=0.3068 train_macro_f1=0.5914 validation_loss=1.0251 validation_macro_f1=0.3057
# [task3] target=usage fold=1 epoch=20/30 train_loss=0.2827 train_macro_f1=0.6370 validation_loss=1.3535 validation_macro_f1=0.2765
# [task3] target=usage fold=1 epoch=21/30 train_loss=0.2635 train_macro_f1=0.6609 validation_loss=0.9592 validation_macro_f1=0.3446
# [task3] target=usage fold=1 epoch=22/30 train_loss=0.2433 train_macro_f1=0.6941 validation_loss=1.0486 validation_macro_f1=0.3271
# [task3] target=usage fold=1 epoch=23/30 train_loss=0.2320 train_macro_f1=0.7246 validation_loss=1.0775 validation_macro_f1=0.3195
# [task3] target=usage fold=1 epoch=24/30 train_loss=0.2182 train_macro_f1=0.7387 validation_loss=1.0435 validation_macro_f1=0.3264
# [task3] target=usage fold=1 epoch=25/30 train_loss=0.2089 train_macro_f1=0.7402 validation_loss=0.9718 validation_macro_f1=0.3556
# [task3] target=usage fold=1 epoch=26/30 train_loss=0.1994 train_macro_f1=0.7887 validation_loss=0.9635 validation_macro_f1=0.3440
# [task3] target=usage fold=1 epoch=27/30 train_loss=0.1942 train_macro_f1=0.7805 validation_loss=1.0248 validation_macro_f1=0.3425
# [task3] target=usage fold=1 epoch=28/30 train_loss=0.1899 train_macro_f1=0.7869 validation_loss=0.9730 validation_macro_f1=0.3376
# [task3] target=usage fold=1 epoch=29/30 train_loss=0.1865 train_macro_f1=0.7956 validation_loss=0.9781 validation_macro_f1=0.3477
# [task3] target=usage fold=1 epoch=30/30 train_loss=0.1837 train_macro_f1=0.7771 validation_loss=0.9755 validation_macro_f1=0.3485
# [task3] completed target=usage fold=1: t3_usage_e9_exception_balance_usage_smallcnn_f1_s2753_d22930bc1285_20260902T004910Z10b181
# [task3] preparing target=usage fold=2: train=26,219 (before selection=26,219), validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=2
# [task3] RGB statistics ready for target=usage fold=2
# [task3] registered t3_usage_e9_exception_balance_usage_smallcnn_f2_s2753_d22930bc1285_20260902T005754Z8e65ce; the first optimiser step may now run
# [task3] target=usage fold=2 epoch=1/30 train_loss=1.9030 train_macro_f1=0.1399 validation_loss=1.3055 validation_macro_f1=0.1655
# [task3] target=usage fold=2 epoch=2/30 train_loss=1.6819 train_macro_f1=0.1820 validation_loss=1.5615 validation_macro_f1=0.1303
# [task3] target=usage fold=2 epoch=3/30 train_loss=1.4512 train_macro_f1=0.2414 validation_loss=1.3851 validation_macro_f1=0.2140
# [task3] target=usage fold=2 epoch=4/30 train_loss=1.3043 train_macro_f1=0.2482 validation_loss=1.2088 validation_macro_f1=0.2372
# [task3] target=usage fold=2 epoch=5/30 train_loss=1.2257 train_macro_f1=0.2582 validation_loss=1.2882 validation_macro_f1=0.2083
# [task3] target=usage fold=2 epoch=6/30 train_loss=1.1471 train_macro_f1=0.2746 validation_loss=1.0658 validation_macro_f1=0.2762
# [task3] target=usage fold=2 epoch=7/30 train_loss=0.9812 train_macro_f1=0.2822 validation_loss=1.4235 validation_macro_f1=0.2168
# [task3] target=usage fold=2 epoch=8/30 train_loss=0.8414 train_macro_f1=0.3003 validation_loss=1.8853 validation_macro_f1=0.1618
# [task3] target=usage fold=2 epoch=9/30 train_loss=0.8322 train_macro_f1=0.3080 validation_loss=1.1529 validation_macro_f1=0.2376
# [task3] target=usage fold=2 epoch=10/30 train_loss=0.6712 train_macro_f1=0.3270 validation_loss=1.3352 validation_macro_f1=0.2433
# [task3] target=usage fold=2 epoch=11/30 train_loss=0.6559 train_macro_f1=0.3299 validation_loss=1.0119 validation_macro_f1=0.2644
# [task3] target=usage fold=2 epoch=12/30 train_loss=0.5510 train_macro_f1=0.3532 validation_loss=1.0990 validation_macro_f1=0.2901
# [task3] target=usage fold=2 epoch=13/30 train_loss=0.5451 train_macro_f1=0.4189 validation_loss=1.5284 validation_macro_f1=0.2442
# [task3] target=usage fold=2 epoch=14/30 train_loss=0.4478 train_macro_f1=0.4833 validation_loss=1.6367 validation_macro_f1=0.2277
# [task3] target=usage fold=2 epoch=15/30 train_loss=0.4175 train_macro_f1=0.4844 validation_loss=1.4672 validation_macro_f1=0.2530
# [task3] target=usage fold=2 epoch=16/30 train_loss=0.3697 train_macro_f1=0.5596 validation_loss=1.3299 validation_macro_f1=0.2777
# [task3] target=usage fold=2 epoch=17/30 train_loss=0.3384 train_macro_f1=0.5743 validation_loss=1.0629 validation_macro_f1=0.3118
# [task3] target=usage fold=2 epoch=18/30 train_loss=0.3002 train_macro_f1=0.5448 validation_loss=1.2598 validation_macro_f1=0.3032
# [task3] target=usage fold=2 epoch=19/30 train_loss=0.2855 train_macro_f1=0.6078 validation_loss=1.0054 validation_macro_f1=0.3102
# [task3] target=usage fold=2 epoch=20/30 train_loss=0.2680 train_macro_f1=0.6077 validation_loss=1.1438 validation_macro_f1=0.3140
# [task3] target=usage fold=2 epoch=21/30 train_loss=0.2427 train_macro_f1=0.6745 validation_loss=1.0783 validation_macro_f1=0.3578
# [task3] target=usage fold=2 epoch=22/30 train_loss=0.2263 train_macro_f1=0.6893 validation_loss=1.0957 validation_macro_f1=0.3560
# [task3] target=usage fold=2 epoch=23/30 train_loss=0.2122 train_macro_f1=0.7228 validation_loss=0.9571 validation_macro_f1=0.3806
# [task3] target=usage fold=2 epoch=24/30 train_loss=0.1997 train_macro_f1=0.7213 validation_loss=0.9570 validation_macro_f1=0.3814
# [task3] target=usage fold=2 epoch=25/30 train_loss=0.1901 train_macro_f1=0.7455 validation_loss=0.9890 validation_macro_f1=0.4015
# [task3] target=usage fold=2 epoch=26/30 train_loss=0.1805 train_macro_f1=0.7633 validation_loss=0.9756 validation_macro_f1=0.4096
# [task3] target=usage fold=2 epoch=27/30 train_loss=0.1744 train_macro_f1=0.7708 validation_loss=1.0174 validation_macro_f1=0.4083
# [task3] target=usage fold=2 epoch=28/30 train_loss=0.1690 train_macro_f1=0.7874 validation_loss=0.9858 validation_macro_f1=0.4205
# [task3] target=usage fold=2 epoch=29/30 train_loss=0.1674 train_macro_f1=0.7519 validation_loss=0.9826 validation_macro_f1=0.4077
# [task3] target=usage fold=2 epoch=30/30 train_loss=0.1659 train_macro_f1=0.7593 validation_loss=0.9600 validation_macro_f1=0.4097
# [task3] completed target=usage fold=2: t3_usage_e9_exception_balance_usage_smallcnn_f2_s2753_d22930bc1285_20260902T005754Z8e65ce
# [task3] preparing target=usage fold=3: train=26,219 (before selection=26,219), validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=3
# [task3] RGB statistics ready for target=usage fold=3
# [task3] registered t3_usage_e9_exception_balance_usage_smallcnn_f3_s2753_d22930bc1285_20260902T010640Z1df42d; the first optimiser step may now run
# [task3] target=usage fold=3 epoch=1/30 train_loss=1.9755 train_macro_f1=0.1430 validation_loss=1.4744 validation_macro_f1=0.1391
# [task3] target=usage fold=3 epoch=2/30 train_loss=1.6147 train_macro_f1=0.1819 validation_loss=1.2915 validation_macro_f1=0.2227
# [task3] target=usage fold=3 epoch=3/30 train_loss=1.5011 train_macro_f1=0.2287 validation_loss=1.4929 validation_macro_f1=0.1894
# [task3] target=usage fold=3 epoch=4/30 train_loss=1.3057 train_macro_f1=0.2445 validation_loss=1.3064 validation_macro_f1=0.2061
# [task3] target=usage fold=3 epoch=5/30 train_loss=1.2129 train_macro_f1=0.2613 validation_loss=1.1688 validation_macro_f1=0.2471
# [task3] target=usage fold=3 epoch=6/30 train_loss=1.0410 train_macro_f1=0.2774 validation_loss=1.3158 validation_macro_f1=0.2695
# [task3] target=usage fold=3 epoch=7/30 train_loss=0.9804 train_macro_f1=0.2855 validation_loss=2.0042 validation_macro_f1=0.1784
# [task3] target=usage fold=3 epoch=8/30 train_loss=0.8482 train_macro_f1=0.2989 validation_loss=1.5111 validation_macro_f1=0.1687
# [task3] target=usage fold=3 epoch=9/30 train_loss=0.7815 train_macro_f1=0.2992 validation_loss=1.1748 validation_macro_f1=0.2443
# [task3] target=usage fold=3 epoch=10/30 train_loss=0.6590 train_macro_f1=0.3257 validation_loss=1.1445 validation_macro_f1=0.2583
# [task3] target=usage fold=3 epoch=11/30 train_loss=0.5893 train_macro_f1=0.3396 validation_loss=1.1488 validation_macro_f1=0.2605
# [task3] target=usage fold=3 epoch=12/30 train_loss=0.5384 train_macro_f1=0.4627 validation_loss=1.1272 validation_macro_f1=0.2848
# [task3] target=usage fold=3 epoch=13/30 train_loss=0.4755 train_macro_f1=0.5028 validation_loss=1.0273 validation_macro_f1=0.2994
# [task3] target=usage fold=3 epoch=14/30 train_loss=0.4154 train_macro_f1=0.5085 validation_loss=0.9516 validation_macro_f1=0.2778
# [task3] target=usage fold=3 epoch=15/30 train_loss=0.4132 train_macro_f1=0.5228 validation_loss=1.4082 validation_macro_f1=0.2471
# [task3] target=usage fold=3 epoch=16/30 train_loss=0.3365 train_macro_f1=0.5673 validation_loss=1.3380 validation_macro_f1=0.2588
# [task3] target=usage fold=3 epoch=17/30 train_loss=0.3088 train_macro_f1=0.5974 validation_loss=0.9854 validation_macro_f1=0.3151
# [task3] target=usage fold=3 epoch=18/30 train_loss=0.2871 train_macro_f1=0.6304 validation_loss=1.4635 validation_macro_f1=0.3029
# [task3] target=usage fold=3 epoch=19/30 train_loss=0.2680 train_macro_f1=0.6305 validation_loss=1.3178 validation_macro_f1=0.3025
# [task3] target=usage fold=3 epoch=20/30 train_loss=0.2468 train_macro_f1=0.6706 validation_loss=1.1723 validation_macro_f1=0.3233
# [task3] target=usage fold=3 epoch=21/30 train_loss=0.2297 train_macro_f1=0.7079 validation_loss=1.0317 validation_macro_f1=0.3334
# [task3] target=usage fold=3 epoch=22/30 train_loss=0.2092 train_macro_f1=0.7400 validation_loss=1.0587 validation_macro_f1=0.3703
# [task3] target=usage fold=3 epoch=23/30 train_loss=0.2017 train_macro_f1=0.7357 validation_loss=1.0893 validation_macro_f1=0.3516
# [task3] target=usage fold=3 epoch=24/30 train_loss=0.1888 train_macro_f1=0.7592 validation_loss=0.9631 validation_macro_f1=0.3744
# [task3] target=usage fold=3 epoch=25/30 train_loss=0.1770 train_macro_f1=0.7795 validation_loss=1.0502 validation_macro_f1=0.3911
# [task3] target=usage fold=3 epoch=26/30 train_loss=0.1697 train_macro_f1=0.7963 validation_loss=1.0176 validation_macro_f1=0.3991
# [task3] target=usage fold=3 epoch=27/30 train_loss=0.1644 train_macro_f1=0.8124 validation_loss=1.0066 validation_macro_f1=0.3939
# [task3] target=usage fold=3 epoch=28/30 train_loss=0.1599 train_macro_f1=0.8034 validation_loss=1.0086 validation_macro_f1=0.3932
# [task3] target=usage fold=3 epoch=29/30 train_loss=0.1560 train_macro_f1=0.8134 validation_loss=1.0082 validation_macro_f1=0.4029
# [task3] target=usage fold=3 epoch=30/30 train_loss=0.1554 train_macro_f1=0.8189 validation_loss=1.0070 validation_macro_f1=0.4045
# [task3] completed target=usage fold=3: t3_usage_e9_exception_balance_usage_smallcnn_f3_s2753_d22930bc1285_20260902T010640Z1df42d
# [task3] preparing target=usage fold=4: train=26,215 (before selection=26,215), validation=6,557
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_e9_exception_balance_usage_smallcnn_f4_s2753_d22930bc1285_20260902T011529Z920677; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=1.8955 train_macro_f1=0.1433 validation_loss=1.4727 validation_macro_f1=0.1465
# [task3] target=usage fold=4 epoch=2/30 train_loss=1.6699 train_macro_f1=0.1753 validation_loss=2.1020 validation_macro_f1=0.0928
# [task3] target=usage fold=4 epoch=3/30 train_loss=1.5254 train_macro_f1=0.2186 validation_loss=1.5449 validation_macro_f1=0.1656
# [task3] target=usage fold=4 epoch=4/30 train_loss=1.4007 train_macro_f1=0.2463 validation_loss=1.5659 validation_macro_f1=0.1664
# [task3] target=usage fold=4 epoch=5/30 train_loss=1.2357 train_macro_f1=0.2570 validation_loss=1.0233 validation_macro_f1=0.2608
# [task3] target=usage fold=4 epoch=6/30 train_loss=1.1647 train_macro_f1=0.2664 validation_loss=1.0756 validation_macro_f1=0.2446
# [task3] target=usage fold=4 epoch=7/30 train_loss=1.0127 train_macro_f1=0.2818 validation_loss=1.2259 validation_macro_f1=0.2208
# [task3] target=usage fold=4 epoch=8/30 train_loss=0.9387 train_macro_f1=0.2932 validation_loss=2.4515 validation_macro_f1=0.1221
# [task3] target=usage fold=4 epoch=9/30 train_loss=0.8525 train_macro_f1=0.2967 validation_loss=0.9910 validation_macro_f1=0.2762
# [task3] target=usage fold=4 epoch=10/30 train_loss=0.7332 train_macro_f1=0.3164 validation_loss=1.2799 validation_macro_f1=0.2979
# [task3] target=usage fold=4 epoch=11/30 train_loss=0.6426 train_macro_f1=0.3288 validation_loss=1.4142 validation_macro_f1=0.2374
# [task3] target=usage fold=4 epoch=12/30 train_loss=0.5965 train_macro_f1=0.3436 validation_loss=1.1827 validation_macro_f1=0.3096
# [task3] target=usage fold=4 epoch=13/30 train_loss=0.5065 train_macro_f1=0.3628 validation_loss=0.9102 validation_macro_f1=0.2991
# [task3] target=usage fold=4 epoch=14/30 train_loss=0.4372 train_macro_f1=0.3949 validation_loss=1.0328 validation_macro_f1=0.3296
# [task3] target=usage fold=4 epoch=15/30 train_loss=0.4018 train_macro_f1=0.4277 validation_loss=0.9645 validation_macro_f1=0.2989
# [task3] target=usage fold=4 epoch=16/30 train_loss=0.3645 train_macro_f1=0.4551 validation_loss=0.9844 validation_macro_f1=0.2757
# [task3] target=usage fold=4 epoch=17/30 train_loss=0.3282 train_macro_f1=0.4796 validation_loss=0.9806 validation_macro_f1=0.3549
# [task3] target=usage fold=4 epoch=18/30 train_loss=0.2947 train_macro_f1=0.5232 validation_loss=0.8804 validation_macro_f1=0.3710
# [task3] target=usage fold=4 epoch=19/30 train_loss=0.2777 train_macro_f1=0.5378 validation_loss=0.9690 validation_macro_f1=0.3544
# [task3] target=usage fold=4 epoch=20/30 train_loss=0.2553 train_macro_f1=0.5680 validation_loss=1.0316 validation_macro_f1=0.3240
# [task3] target=usage fold=4 epoch=21/30 train_loss=0.2409 train_macro_f1=0.5958 validation_loss=0.8857 validation_macro_f1=0.3804
# [task3] target=usage fold=4 epoch=22/30 train_loss=0.2248 train_macro_f1=0.5918 validation_loss=1.3126 validation_macro_f1=0.2599
# [task3] target=usage fold=4 epoch=23/30 train_loss=0.2097 train_macro_f1=0.6400 validation_loss=1.0544 validation_macro_f1=0.3513
# [task3] target=usage fold=4 epoch=24/30 train_loss=0.1974 train_macro_f1=0.6399 validation_loss=1.0044 validation_macro_f1=0.3337
# [task3] target=usage fold=4 epoch=25/30 train_loss=0.1859 train_macro_f1=0.6643 validation_loss=0.9427 validation_macro_f1=0.3979
# [task3] target=usage fold=4 epoch=26/30 train_loss=0.1817 train_macro_f1=0.6771 validation_loss=0.9097 validation_macro_f1=0.4065
# [task3] target=usage fold=4 epoch=27/30 train_loss=0.1742 train_macro_f1=0.6745 validation_loss=0.9180 validation_macro_f1=0.4118
# [task3] target=usage fold=4 epoch=28/30 train_loss=0.1705 train_macro_f1=0.6882 validation_loss=0.9344 validation_macro_f1=0.4040
# [task3] target=usage fold=4 epoch=29/30 train_loss=0.1669 train_macro_f1=0.6867 validation_loss=0.9484 validation_macro_f1=0.4135
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.1651 train_macro_f1=0.6956 validation_loss=0.9460 validation_macro_f1=0.4163
# [task3] completed target=usage fold=4: t3_usage_e9_exception_balance_usage_smallcnn_f4_s2753_d22930bc1285_20260902T011529Z920677
# [task3] completed pooled five-fold OOF experiment=t3_usage_exception_balance_smallcnn target=usage
# Usage E9 complete: /content/drive/MyDrive/MLA2/task3/experiments/t3_usage_e9_exception_balance/usage/aggregate/metrics.json
# {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv', 'run_ids': ['t3_usage_e9_exception_balance_usage_smallcnn_f0_s2753_d22930bc1285_20260902T004030Zed2d5a', 't3_usage_e9_exception_balance_usage_smallcnn_f1_s2753_d22930bc1285_20260902T004910Z10b181', 't3_usage_e9_exception_balance_usage_smallcnn_f2_s2753_d22930bc1285_20260902T005754Z8e65ce', 't3_usage_e9_exception_balance_usage_smallcnn_f3_s2753_d22930bc1285_20260902T010640Z1df42d', 't3_usage_e9_exception_balance_usage_smallcnn_f4_s2753_d22930bc1285_20260902T011529Z920677'], 'completed_rows': 5, 'ready': True}

# %% [markdown]
# ## 4. Deterministic Gender contract
#
# The next cell rechecks the automated evidence created before training. It needs the exact rule version, 305 conflict IDs, frozen ID and distribution hashes, and fold-removal counts.

# %%
expected_gender_removals = {"0": 242, "1": 224, "2": 259, "3": 263, "4": 232}
if gender_contract["conflict_rows"] != 305:
    raise RuntimeError("Gender conflict count changed.")
if gender_contract["training_removals"] != expected_gender_removals:
    raise RuntimeError("Gender fold-removal counts changed.")
if gender_contract["human_rating_gate_required"]:
    raise RuntimeError("A removed human-rating gate was reintroduced.")
print("Deterministic Gender contract verified; no formal ratings are required.")
# Out:
# Deterministic Gender contract verified; no formal ratings are required.

# %% [markdown]
# ## 5. Gender E9G — run after Usage
#
# This call changes only fold-training row selection from the exact E6 GeM parent. It excludes the deterministic conflicts from each training complement, keeps validation untouched, and stores the exact IDs, rule hash, and verification fields with each fold.

# %%
gender_e9 = run_task3_child_cv(
    "gender_semantic_filter",
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    folds=range(5),
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
)
gender_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, gender_e9["fold_run_ids"]
)
print("Gender E9 complete:", gender_e9["metrics_path"])
print(gender_registry_audit)
# Out:
# [task3] starting five-fold experiment=t3_gender_semantic_filter_gem_p3 for target=gender
# [task3] preparing target=gender fold=0: train=25,978 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_e9_semantic_filter_gender_smallcnngem3_f0_s2753_1840d4857b63_20260902T012421Zee4aa5; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.5425 train_macro_f1=0.5180 validation_loss=0.5630 validation_macro_f1=0.5578
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.3912 train_macro_f1=0.6668 validation_loss=0.4513 validation_macro_f1=0.6537
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.3372 train_macro_f1=0.7382 validation_loss=0.3937 validation_macro_f1=0.6709
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.3011 train_macro_f1=0.7691 validation_loss=0.5296 validation_macro_f1=0.6670
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.2626 train_macro_f1=0.7972 validation_loss=0.5108 validation_macro_f1=0.6921
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.2339 train_macro_f1=0.8285 validation_loss=0.3582 validation_macro_f1=0.7141
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.2043 train_macro_f1=0.8562 validation_loss=0.5858 validation_macro_f1=0.6498
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.1732 train_macro_f1=0.8746 validation_loss=0.5112 validation_macro_f1=0.5848
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.1461 train_macro_f1=0.9054 validation_loss=0.4007 validation_macro_f1=0.6966
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.1167 train_macro_f1=0.9253 validation_loss=0.6938 validation_macro_f1=0.6640
# [task3] target=gender fold=0 epoch=11/30 train_loss=0.0957 train_macro_f1=0.9481 validation_loss=0.4041 validation_macro_f1=0.7026
# [task3] target=gender fold=0 epoch=12/30 train_loss=0.0714 train_macro_f1=0.9650 validation_loss=0.3864 validation_macro_f1=0.7289
# [task3] target=gender fold=0 epoch=13/30 train_loss=0.0527 train_macro_f1=0.9767 validation_loss=0.5584 validation_macro_f1=0.6737
# [task3] target=gender fold=0 epoch=14/30 train_loss=0.0395 train_macro_f1=0.9861 validation_loss=0.4454 validation_macro_f1=0.7124
# [task3] target=gender fold=0 epoch=15/30 train_loss=0.0290 train_macro_f1=0.9936 validation_loss=0.3989 validation_macro_f1=0.7381
# [task3] target=gender fold=0 epoch=16/30 train_loss=0.0205 train_macro_f1=0.9965 validation_loss=0.4098 validation_macro_f1=0.7401
# [task3] target=gender fold=0 epoch=17/30 train_loss=0.0151 train_macro_f1=0.9981 validation_loss=0.4166 validation_macro_f1=0.7371
# [task3] target=gender fold=0 epoch=18/30 train_loss=0.0111 train_macro_f1=0.9996 validation_loss=0.4596 validation_macro_f1=0.7154
# [task3] target=gender fold=0 epoch=19/30 train_loss=0.0096 train_macro_f1=0.9994 validation_loss=0.5340 validation_macro_f1=0.6810
# [task3] target=gender fold=0 epoch=20/30 train_loss=0.0078 train_macro_f1=0.9996 validation_loss=0.4837 validation_macro_f1=0.7370
# [task3] target=gender fold=0 epoch=21/30 train_loss=0.0063 train_macro_f1=0.9999 validation_loss=0.4693 validation_macro_f1=0.7437
# [task3] target=gender fold=0 epoch=22/30 train_loss=0.0055 train_macro_f1=0.9998 validation_loss=0.4535 validation_macro_f1=0.7353
# [task3] target=gender fold=0 epoch=23/30 train_loss=0.0049 train_macro_f1=0.9997 validation_loss=0.4599 validation_macro_f1=0.7413
# [task3] target=gender fold=0 epoch=24/30 train_loss=0.0043 train_macro_f1=0.9999 validation_loss=0.4536 validation_macro_f1=0.7415
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.0039 train_macro_f1=0.9998 validation_loss=0.4718 validation_macro_f1=0.7320
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.0035 train_macro_f1=0.9999 validation_loss=0.4568 validation_macro_f1=0.7437
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.0034 train_macro_f1=0.9998 validation_loss=0.4628 validation_macro_f1=0.7417
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.0032 train_macro_f1=0.9999 validation_loss=0.4671 validation_macro_f1=0.7398
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.0030 train_macro_f1=0.9999 validation_loss=0.4642 validation_macro_f1=0.7426
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.0031 train_macro_f1=0.9999 validation_loss=0.4646 validation_macro_f1=0.7418
# [task3] completed target=gender fold=0: t3_gender_e9_semantic_filter_gender_smallcnngem3_f0_s2753_1840d4857b63_20260902T012421Zee4aa5
# [task3] preparing target=gender fold=1: train=25,993 (before selection=26,217), validation=6,556
# [task3] fitting fold-training RGB statistics for target=gender fold=1
# [task3] RGB statistics ready for target=gender fold=1
# [task3] registered t3_gender_e9_semantic_filter_gender_smallcnngem3_f1_s2753_1840d4857b63_20260902T013307Z85f9f6; the first optimiser step may now run
# [task3] target=gender fold=1 epoch=1/30 train_loss=0.5435 train_macro_f1=0.5061 validation_loss=0.5304 validation_macro_f1=0.5466
# [task3] target=gender fold=1 epoch=2/30 train_loss=0.3927 train_macro_f1=0.6833 validation_loss=0.4823 validation_macro_f1=0.6056
# [task3] target=gender fold=1 epoch=3/30 train_loss=0.3391 train_macro_f1=0.7247 validation_loss=0.8533 validation_macro_f1=0.4183
# [task3] target=gender fold=1 epoch=4/30 train_loss=0.3038 train_macro_f1=0.7593 validation_loss=0.3952 validation_macro_f1=0.6070
# [task3] target=gender fold=1 epoch=5/30 train_loss=0.2645 train_macro_f1=0.7981 validation_loss=0.5903 validation_macro_f1=0.6092
# [task3] target=gender fold=1 epoch=6/30 train_loss=0.2445 train_macro_f1=0.8208 validation_loss=0.4040 validation_macro_f1=0.6376
# [task3] target=gender fold=1 epoch=7/30 train_loss=0.2115 train_macro_f1=0.8409 validation_loss=0.3978 validation_macro_f1=0.6708
# [task3] target=gender fold=1 epoch=8/30 train_loss=0.1799 train_macro_f1=0.8689 validation_loss=0.4534 validation_macro_f1=0.6742
# [task3] target=gender fold=1 epoch=9/30 train_loss=0.1567 train_macro_f1=0.8912 validation_loss=0.3752 validation_macro_f1=0.6835
# [task3] target=gender fold=1 epoch=10/30 train_loss=0.1227 train_macro_f1=0.9249 validation_loss=0.3767 validation_macro_f1=0.6706
# [task3] target=gender fold=1 epoch=11/30 train_loss=0.1078 train_macro_f1=0.9341 validation_loss=0.4990 validation_macro_f1=0.6964
# [task3] target=gender fold=1 epoch=12/30 train_loss=0.0861 train_macro_f1=0.9516 validation_loss=0.3611 validation_macro_f1=0.6855
# [task3] target=gender fold=1 epoch=13/30 train_loss=0.0591 train_macro_f1=0.9716 validation_loss=0.3698 validation_macro_f1=0.7086
# [task3] target=gender fold=1 epoch=14/30 train_loss=0.0428 train_macro_f1=0.9845 validation_loss=0.4073 validation_macro_f1=0.7332
# [task3] target=gender fold=1 epoch=15/30 train_loss=0.0344 train_macro_f1=0.9876 validation_loss=0.4004 validation_macro_f1=0.6981
# [task3] target=gender fold=1 epoch=16/30 train_loss=0.0252 train_macro_f1=0.9909 validation_loss=0.4101 validation_macro_f1=0.7300
# [task3] target=gender fold=1 epoch=17/30 train_loss=0.0177 train_macro_f1=0.9971 validation_loss=0.3902 validation_macro_f1=0.7414
# [task3] target=gender fold=1 epoch=18/30 train_loss=0.0136 train_macro_f1=0.9983 validation_loss=0.4947 validation_macro_f1=0.6946
# [task3] target=gender fold=1 epoch=19/30 train_loss=0.0165 train_macro_f1=0.9982 validation_loss=0.4182 validation_macro_f1=0.7282
# [task3] target=gender fold=1 epoch=20/30 train_loss=0.0105 train_macro_f1=0.9992 validation_loss=0.5172 validation_macro_f1=0.6951
# [task3] target=gender fold=1 epoch=21/30 train_loss=0.0079 train_macro_f1=0.9998 validation_loss=0.4236 validation_macro_f1=0.7220
# [task3] target=gender fold=1 epoch=22/30 train_loss=0.0071 train_macro_f1=0.9997 validation_loss=0.5082 validation_macro_f1=0.7335
# [task3] target=gender fold=1 epoch=23/30 train_loss=0.0074 train_macro_f1=0.9997 validation_loss=0.4240 validation_macro_f1=0.7240
# [task3] target=gender fold=1 epoch=24/30 train_loss=0.0053 train_macro_f1=0.9999 validation_loss=0.4601 validation_macro_f1=0.7296
# [task3] target=gender fold=1 epoch=25/30 train_loss=0.0083 train_macro_f1=0.9995 validation_loss=0.4265 validation_macro_f1=0.7411
# [task3] target=gender fold=1 epoch=26/30 train_loss=0.0049 train_macro_f1=0.9999 validation_loss=0.4394 validation_macro_f1=0.7332
# [task3] target=gender fold=1 epoch=27/30 train_loss=0.0044 train_macro_f1=0.9998 validation_loss=0.4314 validation_macro_f1=0.7326
# [task3] target=gender fold=1 epoch=28/30 train_loss=0.0042 train_macro_f1=0.9999 validation_loss=0.4260 validation_macro_f1=0.7407
# [task3] target=gender fold=1 epoch=29/30 train_loss=0.0041 train_macro_f1=0.9999 validation_loss=0.4375 validation_macro_f1=0.7359
# [task3] target=gender fold=1 epoch=30/30 train_loss=0.0040 train_macro_f1=1.0000 validation_loss=0.4359 validation_macro_f1=0.7337
# [task3] completed target=gender fold=1: t3_gender_e9_semantic_filter_gender_smallcnngem3_f1_s2753_1840d4857b63_20260902T013307Z85f9f6
# [task3] preparing target=gender fold=2: train=25,961 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=2
# [task3] RGB statistics ready for target=gender fold=2
# [task3] registered t3_gender_e9_semantic_filter_gender_smallcnngem3_f2_s2753_1840d4857b63_20260902T014151Z301edf; the first optimiser step may now run
# [task3] target=gender fold=2 epoch=1/30 train_loss=0.5515 train_macro_f1=0.4795 validation_loss=0.4516 validation_macro_f1=0.6246
# [task3] target=gender fold=2 epoch=2/30 train_loss=0.3933 train_macro_f1=0.6624 validation_loss=0.4152 validation_macro_f1=0.6578
# [task3] target=gender fold=2 epoch=3/30 train_loss=0.3419 train_macro_f1=0.7194 validation_loss=0.3904 validation_macro_f1=0.6928
# [task3] target=gender fold=2 epoch=4/30 train_loss=0.2986 train_macro_f1=0.7633 validation_loss=0.4392 validation_macro_f1=0.6445
# [task3] target=gender fold=2 epoch=5/30 train_loss=0.2631 train_macro_f1=0.7935 validation_loss=0.4299 validation_macro_f1=0.7074
# [task3] target=gender fold=2 epoch=6/30 train_loss=0.2382 train_macro_f1=0.8214 validation_loss=0.3519 validation_macro_f1=0.6644
# [task3] target=gender fold=2 epoch=7/30 train_loss=0.2080 train_macro_f1=0.8505 validation_loss=0.3276 validation_macro_f1=0.7320
# [task3] target=gender fold=2 epoch=8/30 train_loss=0.1768 train_macro_f1=0.8762 validation_loss=0.4243 validation_macro_f1=0.6967
# [task3] target=gender fold=2 epoch=9/30 train_loss=0.1480 train_macro_f1=0.9015 validation_loss=0.4487 validation_macro_f1=0.7121
# [task3] target=gender fold=2 epoch=10/30 train_loss=0.1236 train_macro_f1=0.9214 validation_loss=0.5696 validation_macro_f1=0.6720
# [task3] target=gender fold=2 epoch=11/30 train_loss=0.0955 train_macro_f1=0.9424 validation_loss=0.3846 validation_macro_f1=0.7205
# [task3] target=gender fold=2 epoch=12/30 train_loss=0.0710 train_macro_f1=0.9647 validation_loss=0.5601 validation_macro_f1=0.6340
# [task3] target=gender fold=2 epoch=13/30 train_loss=0.0549 train_macro_f1=0.9756 validation_loss=1.0122 validation_macro_f1=0.6171
# [task3] target=gender fold=2 epoch=14/30 train_loss=0.0412 train_macro_f1=0.9843 validation_loss=0.4288 validation_macro_f1=0.6651
# [task3] target=gender fold=2 epoch=15/30 train_loss=0.0305 train_macro_f1=0.9924 validation_loss=0.3842 validation_macro_f1=0.7043
# [task3] target=gender fold=2 epoch=16/30 train_loss=0.0208 train_macro_f1=0.9967 validation_loss=0.4148 validation_macro_f1=0.7312
# [task3] target=gender fold=2 epoch=17/30 train_loss=0.0152 train_macro_f1=0.9983 validation_loss=0.3877 validation_macro_f1=0.7593
# [task3] target=gender fold=2 epoch=18/30 train_loss=0.0123 train_macro_f1=0.9992 validation_loss=0.4070 validation_macro_f1=0.7460
# [task3] target=gender fold=2 epoch=19/30 train_loss=0.0096 train_macro_f1=0.9994 validation_loss=0.4200 validation_macro_f1=0.7452
# [task3] target=gender fold=2 epoch=20/30 train_loss=0.0078 train_macro_f1=0.9996 validation_loss=0.3904 validation_macro_f1=0.7475
# [task3] target=gender fold=2 epoch=21/30 train_loss=0.0067 train_macro_f1=0.9999 validation_loss=0.4045 validation_macro_f1=0.7349
# [task3] target=gender fold=2 epoch=22/30 train_loss=0.0058 train_macro_f1=0.9996 validation_loss=0.4139 validation_macro_f1=0.7459
# [task3] target=gender fold=2 epoch=23/30 train_loss=0.0051 train_macro_f1=0.9998 validation_loss=0.4087 validation_macro_f1=0.7409
# [task3] target=gender fold=2 epoch=24/30 train_loss=0.0045 train_macro_f1=0.9998 validation_loss=0.4183 validation_macro_f1=0.7490
# [task3] target=gender fold=2 epoch=25/30 train_loss=0.0040 train_macro_f1=0.9999 validation_loss=0.4244 validation_macro_f1=0.7399
# [task3] target=gender fold=2 epoch=26/30 train_loss=0.0038 train_macro_f1=0.9998 validation_loss=0.4184 validation_macro_f1=0.7356
# [task3] target=gender fold=2 epoch=27/30 train_loss=0.0035 train_macro_f1=0.9998 validation_loss=0.4210 validation_macro_f1=0.7308
# [task3] target=gender fold=2 epoch=28/30 train_loss=0.0033 train_macro_f1=0.9999 validation_loss=0.4243 validation_macro_f1=0.7354
# [task3] target=gender fold=2 epoch=29/30 train_loss=0.0033 train_macro_f1=0.9999 validation_loss=0.4244 validation_macro_f1=0.7285
# [task3] target=gender fold=2 epoch=30/30 train_loss=0.0032 train_macro_f1=0.9998 validation_loss=0.4223 validation_macro_f1=0.7334
# [task3] completed target=gender fold=2: t3_gender_e9_semantic_filter_gender_smallcnngem3_f2_s2753_1840d4857b63_20260902T014151Z301edf
# [task3] preparing target=gender fold=3: train=25,956 (before selection=26,219), validation=6,554
# [task3] fitting fold-training RGB statistics for target=gender fold=3
# [task3] RGB statistics ready for target=gender fold=3
# [task3] registered t3_gender_e9_semantic_filter_gender_smallcnngem3_f3_s2753_1840d4857b63_20260902T015036Z5edcc7; the first optimiser step may now run
# [task3] target=gender fold=3 epoch=1/30 train_loss=0.5507 train_macro_f1=0.4950 validation_loss=0.4717 validation_macro_f1=0.5726
# [task3] target=gender fold=3 epoch=2/30 train_loss=0.3915 train_macro_f1=0.6781 validation_loss=0.5734 validation_macro_f1=0.3967
# [task3] target=gender fold=3 epoch=3/30 train_loss=0.3442 train_macro_f1=0.7202 validation_loss=0.4435 validation_macro_f1=0.6047
# [task3] target=gender fold=3 epoch=4/30 train_loss=0.3027 train_macro_f1=0.7640 validation_loss=0.3581 validation_macro_f1=0.6885
# [task3] target=gender fold=3 epoch=5/30 train_loss=0.2652 train_macro_f1=0.7977 validation_loss=0.3919 validation_macro_f1=0.7206
# [task3] target=gender fold=3 epoch=6/30 train_loss=0.2346 train_macro_f1=0.8235 validation_loss=0.3277 validation_macro_f1=0.7425
# [task3] target=gender fold=3 epoch=7/30 train_loss=0.2017 train_macro_f1=0.8481 validation_loss=0.4044 validation_macro_f1=0.6866
# [task3] target=gender fold=3 epoch=8/30 train_loss=0.1770 train_macro_f1=0.8741 validation_loss=0.5552 validation_macro_f1=0.7183
# [task3] target=gender fold=3 epoch=9/30 train_loss=0.1482 train_macro_f1=0.9018 validation_loss=0.3624 validation_macro_f1=0.7107
# [task3] target=gender fold=3 epoch=10/30 train_loss=0.1197 train_macro_f1=0.9262 validation_loss=0.3366 validation_macro_f1=0.7467
# [task3] target=gender fold=3 epoch=11/30 train_loss=0.0943 train_macro_f1=0.9450 validation_loss=0.4108 validation_macro_f1=0.7115
# [task3] target=gender fold=3 epoch=12/30 train_loss=0.0742 train_macro_f1=0.9596 validation_loss=0.4087 validation_macro_f1=0.7032
# [task3] target=gender fold=3 epoch=13/30 train_loss=0.0576 train_macro_f1=0.9732 validation_loss=0.3453 validation_macro_f1=0.7556
# [task3] target=gender fold=3 epoch=14/30 train_loss=0.0420 train_macro_f1=0.9853 validation_loss=0.4359 validation_macro_f1=0.7601
# [task3] target=gender fold=3 epoch=15/30 train_loss=0.0284 train_macro_f1=0.9910 validation_loss=0.3650 validation_macro_f1=0.7534
# [task3] target=gender fold=3 epoch=16/30 train_loss=0.0212 train_macro_f1=0.9947 validation_loss=0.3749 validation_macro_f1=0.7662
# [task3] target=gender fold=3 epoch=17/30 train_loss=0.0138 train_macro_f1=0.9990 validation_loss=0.3827 validation_macro_f1=0.7702
# [task3] target=gender fold=3 epoch=18/30 train_loss=0.0107 train_macro_f1=0.9992 validation_loss=0.4108 validation_macro_f1=0.7746
# [task3] target=gender fold=3 epoch=19/30 train_loss=0.0089 train_macro_f1=0.9996 validation_loss=0.3984 validation_macro_f1=0.7563
# [task3] target=gender fold=3 epoch=20/30 train_loss=0.0069 train_macro_f1=0.9996 validation_loss=0.3925 validation_macro_f1=0.7701
# [task3] target=gender fold=3 epoch=21/30 train_loss=0.0058 train_macro_f1=1.0000 validation_loss=0.3954 validation_macro_f1=0.7587
# [task3] target=gender fold=3 epoch=22/30 train_loss=0.0050 train_macro_f1=1.0000 validation_loss=0.4074 validation_macro_f1=0.7719
# [task3] target=gender fold=3 epoch=23/30 train_loss=0.0044 train_macro_f1=1.0000 validation_loss=0.4095 validation_macro_f1=0.7669
# [task3] target=gender fold=3 epoch=24/30 train_loss=0.0038 train_macro_f1=1.0000 validation_loss=0.4195 validation_macro_f1=0.7764
# [task3] target=gender fold=3 epoch=25/30 train_loss=0.0036 train_macro_f1=1.0000 validation_loss=0.4164 validation_macro_f1=0.7653
# [task3] target=gender fold=3 epoch=26/30 train_loss=0.0034 train_macro_f1=1.0000 validation_loss=0.4159 validation_macro_f1=0.7732
# [task3] target=gender fold=3 epoch=27/30 train_loss=0.0033 train_macro_f1=1.0000 validation_loss=0.4172 validation_macro_f1=0.7763
# [task3] target=gender fold=3 epoch=28/30 train_loss=0.0031 train_macro_f1=1.0000 validation_loss=0.4188 validation_macro_f1=0.7789
# [task3] target=gender fold=3 epoch=29/30 train_loss=0.0030 train_macro_f1=1.0000 validation_loss=0.4168 validation_macro_f1=0.7783
# [task3] target=gender fold=3 epoch=30/30 train_loss=0.0029 train_macro_f1=1.0000 validation_loss=0.4190 validation_macro_f1=0.7803
# [task3] completed target=gender fold=3: t3_gender_e9_semantic_filter_gender_smallcnngem3_f3_s2753_1840d4857b63_20260902T015036Z5edcc7
# [task3] preparing target=gender fold=4: train=25,984 (before selection=26,216), validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_e9_semantic_filter_gender_smallcnngem3_f4_s2753_1840d4857b63_20260902T015921Z58173c; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.5468 train_macro_f1=0.4915 validation_loss=0.4584 validation_macro_f1=0.6077
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.3934 train_macro_f1=0.6635 validation_loss=0.4024 validation_macro_f1=0.6401
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.3385 train_macro_f1=0.7376 validation_loss=0.6689 validation_macro_f1=0.5387
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.2967 train_macro_f1=0.7692 validation_loss=0.4244 validation_macro_f1=0.6792
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.2627 train_macro_f1=0.7967 validation_loss=0.3519 validation_macro_f1=0.7004
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.2335 train_macro_f1=0.8277 validation_loss=0.3485 validation_macro_f1=0.7263
# [task3] target=gender fold=4 epoch=7/30 train_loss=0.2023 train_macro_f1=0.8596 validation_loss=0.6534 validation_macro_f1=0.6656
# [task3] target=gender fold=4 epoch=8/30 train_loss=0.1769 train_macro_f1=0.8756 validation_loss=0.5105 validation_macro_f1=0.6783
# [task3] target=gender fold=4 epoch=9/30 train_loss=0.1446 train_macro_f1=0.9023 validation_loss=0.3843 validation_macro_f1=0.6935
# [task3] target=gender fold=4 epoch=10/30 train_loss=0.1176 train_macro_f1=0.9234 validation_loss=0.3702 validation_macro_f1=0.7046
# [task3] target=gender fold=4 epoch=11/30 train_loss=0.0878 train_macro_f1=0.9494 validation_loss=1.1513 validation_macro_f1=0.5667
# [task3] target=gender fold=4 epoch=12/30 train_loss=0.0693 train_macro_f1=0.9643 validation_loss=0.5578 validation_macro_f1=0.6779
# [task3] target=gender fold=4 epoch=13/30 train_loss=0.0561 train_macro_f1=0.9747 validation_loss=0.4133 validation_macro_f1=0.7187
# [task3] target=gender fold=4 epoch=14/30 train_loss=0.0379 train_macro_f1=0.9876 validation_loss=0.3728 validation_macro_f1=0.7433
# [task3] target=gender fold=4 epoch=15/30 train_loss=0.0254 train_macro_f1=0.9938 validation_loss=0.4211 validation_macro_f1=0.7231
# [task3] target=gender fold=4 epoch=16/30 train_loss=0.0185 train_macro_f1=0.9972 validation_loss=0.3828 validation_macro_f1=0.7049
# [task3] target=gender fold=4 epoch=17/30 train_loss=0.0138 train_macro_f1=0.9986 validation_loss=0.5960 validation_macro_f1=0.6875
# [task3] target=gender fold=4 epoch=18/30 train_loss=0.0101 train_macro_f1=0.9996 validation_loss=0.4168 validation_macro_f1=0.7456
# [task3] target=gender fold=4 epoch=19/30 train_loss=0.0089 train_macro_f1=0.9995 validation_loss=0.4219 validation_macro_f1=0.7385
# [task3] target=gender fold=4 epoch=20/30 train_loss=0.0071 train_macro_f1=0.9996 validation_loss=0.4283 validation_macro_f1=0.7247
# [task3] target=gender fold=4 epoch=21/30 train_loss=0.0054 train_macro_f1=0.9999 validation_loss=0.4368 validation_macro_f1=0.7334
# [task3] target=gender fold=4 epoch=22/30 train_loss=0.0049 train_macro_f1=0.9999 validation_loss=0.4330 validation_macro_f1=0.7309
# [task3] target=gender fold=4 epoch=23/30 train_loss=0.0044 train_macro_f1=0.9998 validation_loss=0.4467 validation_macro_f1=0.7309
# [task3] target=gender fold=4 epoch=24/30 train_loss=0.0041 train_macro_f1=0.9998 validation_loss=0.5415 validation_macro_f1=0.7168
# [task3] target=gender fold=4 epoch=25/30 train_loss=0.0037 train_macro_f1=0.9999 validation_loss=0.4569 validation_macro_f1=0.7282
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.0034 train_macro_f1=0.9998 validation_loss=0.4598 validation_macro_f1=0.7269
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.0032 train_macro_f1=0.9998 validation_loss=0.4516 validation_macro_f1=0.7304
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.0030 train_macro_f1=0.9999 validation_loss=0.4519 validation_macro_f1=0.7380
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.0029 train_macro_f1=0.9999 validation_loss=0.4578 validation_macro_f1=0.7341
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.0028 train_macro_f1=0.9999 validation_loss=0.4564 validation_macro_f1=0.7364
# [task3] completed target=gender fold=4: t3_gender_e9_semantic_filter_gender_smallcnngem3_f4_s2753_1840d4857b63_20260902T015921Z58173c
# [task3] completed pooled five-fold OOF experiment=t3_gender_semantic_filter_gem_p3 target=gender
# Gender E9 complete: /content/drive/MyDrive/MLA2/task3/experiments/t3_gender_e9_semantic_filter/gender/aggregate/metrics.json
# {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv', 'run_ids': ['t3_gender_e9_semantic_filter_gender_smallcnngem3_f0_s2753_1840d4857b63_20260902T012421Zee4aa5', 't3_gender_e9_semantic_filter_gender_smallcnngem3_f1_s2753_1840d4857b63_20260902T013307Z85f9f6', 't3_gender_e9_semantic_filter_gender_smallcnngem3_f2_s2753_1840d4857b63_20260902T014151Z301edf', 't3_gender_e9_semantic_filter_gender_smallcnngem3_f3_s2753_1840d4857b63_20260902T015036Z5edcc7', 't3_gender_e9_semantic_filter_gender_smallcnngem3_f4_s2753_1840d4857b63_20260902T015921Z58173c'], 'completed_rows': 5, 'ready': True}

# %% [markdown]
# ## 6. Stop and return to the main notebook
#
# Do not run another seed or stack another change here. Return the saved E9 aggregates to Notebook 04, apply the frozen gates, and record accept/reject before any further experiment.
