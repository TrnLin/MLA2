# %% [markdown]
# # Task 3 — Gender G-Drop30 screen
#
# Run All trains only folds 0 and 4 from scratch. Add dropout p=0.30 after GeM pooling in full-width G2. During training this randomly hides pooled features; clean evaluation disables dropout. The aim is a smaller training–validation gap within the agreed score limits. The benefit is unproven.
#
# Use a fresh Colab L4 runtime matching 04w. Publish this notebook and its source changes before running. The completed 04w diagnostic and saved G2/E6 source runs must be on Drive.

# %% [markdown]
# ## 1. Colab GPU and repository

# %%
from pathlib import Path
import os
import shutil
import subprocess
import sys
import time
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
CHECKOUT_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
LOCAL_DATA_ZIP = Path("/content/task3-data.zip")
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"

def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab GPU runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)
if (CHECKOUT_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=CHECKOUT_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{CHECKOUT_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=CHECKOUT_DIR)
    run_checked(["git", "switch", BRANCH], cwd=CHECKOUT_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=CHECKOUT_DIR)
elif CHECKOUT_DIR.exists():
    raise RuntimeError(f"{CHECKOUT_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, CHECKOUT_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=CHECKOUT_DIR, text=True).strip()
REPO_DIR = CHECKOUT_DIR / "core" if (CHECKOUT_DIR / "core/src/fashion").is_dir() else CHECKOUT_DIR
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"
print("Repository ready:", REPO_DIR)
print("Commit:", commit)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# $ git fetch origin task-3-gender-usage-classification
# $ git switch task-3-gender-usage-classification
# $ git merge --ff-only origin/task-3-gender-usage-classification
# Repository ready: /content/MLA2
# Commit: 62a64ce27288a398c2fa5de4c30dde96da2f391f

# %% [markdown]
# ## 2. Teacher data and canonical split

# %%
def copy_teacher_zip_to_local_disk():
    if LOCAL_DATA_ZIP.is_file():
        try:
            with zipfile.ZipFile(LOCAL_DATA_ZIP) as existing:
                existing.infolist()
            return
        except zipfile.BadZipFile:
            LOCAL_DATA_ZIP.unlink()
    partial = LOCAL_DATA_ZIP.with_suffix(".zip.partial")
    for attempt in range(1, 4):
        partial.unlink(missing_ok=True)
        try:
            expected_bytes = DATA_ZIP.stat().st_size
            with DATA_ZIP.open("rb") as source, partial.open("wb") as target:
                shutil.copyfileobj(source, target, length=8 * 1024**2)
            if partial.stat().st_size != expected_bytes:
                raise OSError("The local ZIP copy is incomplete.")
            partial.replace(LOCAL_DATA_ZIP)
            return
        except OSError as error:
            partial.unlink(missing_ok=True)
            if attempt == 3:
                raise RuntimeError("Drive disconnected three times. Remount and retry.") from error
            drive.mount(str(DRIVE_MOUNT), force_remount=True)
            time.sleep(2)

copy_teacher_zip_to_local_disk()
teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_dirs = (teacher_dir / "train/images_train", teacher_dir / "test/images_test")
image_suffixes = {".jpg", ".jpeg"}
with zipfile.ZipFile(LOCAL_DATA_ZIP) as archive:
    names = archive.namelist()
    if any(Path(name).is_absolute() or ".." in Path(name).parts for name in names):
        raise RuntimeError("The teacher archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/") and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    current_images = sum(
        path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
    )
    if current_images != expected_images or not all(path.is_file() for path in required_files):
        archive.extractall(REPO_DIR)

actual_images = sum(
    path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
)
if actual_images != expected_images or not all(path.is_file() for path in required_files):
    raise RuntimeError(f"Teacher data is incomplete: {actual_images:,}/{expected_images:,} images")

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
if str(REPO_DIR / "src") not in sys.path:
    sys.path.insert(0, str(REPO_DIR / "src"))
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print(f"Teacher data ready: {actual_images:,} images")
# Out:
# Teacher data ready: 44,441 images

# %% [markdown]
# ## 3. Frozen change and evidence checks
#
# Keep the full G2 widths `[32, 64, 128, 256]` and **390,181 parameters**. Change only classifier dropout from **0.0 to 0.30**, after GeM pooling and before the linear classifier. Dropout has no trainable parameters and is disabled for validation, clean training evaluation and corruption checks.
#
# Keep G2's full images, fold-training RGB statistics, ±2-pixel translation, fixed GeM p=3, plain cross-entropy, AdamW weight decay 0.0001, learning rate and schedule, batch 128, 30 epochs, seed 2753 and final-epoch checkpoint. Parent checkpoints are comparison evidence; the child starts with new random weights. No pretrained weights, new split, extra augmentation, stronger decay or early stopping.
#
# Keep the runtime-default training precision reproduced in 04w. For the decision, reevaluate both saved G2/E6 and the completed child checkpoints in **full IEEE FP32**, using batch 128 and the same images. These separate snapshots include clean training, validation and all standard corruption predictions. Historical registered scores remain separate. This common evaluation setting is not a second training-factor change.
#
# The source check below does not train. It verifies the completed precision evidence and all ten G2/E6 bundles before the first fit. Reusable IEEE snapshots are bound to source, data, code and runtime hashes.

# %%
from fashion.train.task3_gender_dropout import (
    check_gender_dropout_sources, run_gender_dropout_screen,
)

G2_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_v2_g2_translation/gender"
E6_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_e6_gem_p3/gender"
PRECISION_DIR = DRIVE_TASK_DIR / "diagnostics/gender_precision/20260905T085822668071Z"
sources, classes, spec, evidence = check_gender_dropout_sources(
    g2_directory=G2_DIR, e6_directory=E6_DIR, source_registry_path=DRIVE_REGISTRY,
    precision_directory=PRECISION_DIR, root=REPO_DIR,
)
print("Source runs:", {name: len(runs) for name, runs in sources.items()})
print("Frozen recipe:", spec.to_dict())
print("Output:", DRIVE_TASK_DIR / spec.artifact_dir / "gender")
# Out:
# Source runs: {'G2': 5, 'E6': 5}
# Frozen recipe: {'name': 'gender_dropout_030', 'target': 'gender', 'experiment_id': 't3_gender_dropout_030', 'hypothesis_id': 't3_gender_dropout_030', 'artifact_dir': 'experiments/t3_gender_dropout_030', 'run_prefix': 't3_gender_dropout_030', 'changed_factor': 'post_gem_classifier_dropout_0_to_030', 'parent_artifact_dir': 'experiments/t3_gender_v2_g2_translation', 'parent_run_ids': ['t3_gender_v2_g2_translation_gender_smallcnngem3_f0_s2753_cb072542dbdc_20260904T135102Z6698e6', 't3_gender_v2_g2_translation_gender_smallcnngem3_f1_s2753_cb072542dbdc_20260904T153837Z5db37d', 't3_gender_v2_g2_translation_gender_smallcnngem3_f2_s2753_cb072542dbdc_20260904T154745Z7d81aa', 't3_gender_v2_g2_translation_gender_smallcnngem3_f3_s2753_cb072542dbdc_20260904T155700Zb0abef', 't3_gender_v2_g2_translation_gender_smallcnngem3_f4_s2753_cb072542dbdc_20260904T140011Z2211b1'], 'model_family': 'task3_small_cnn_gem_p3', 'run_model_token': 'smallcnngem3', 'training_augmentation': 'translation_uniform_2px_p05', 'input_view': 'full', 'sample_weight_strategy': 'none', 'loss_name': 'cross_entropy', 'class_weight_beta': None, 'class_weight_cap': None, 'classifier_dropout': 0.3, 'label_smoothing': 0.0, 'focal_gamma': 0.0, 'checkpoint_policy': 'final_epoch', 'early_stopping_min_epoch': 0, 'early_stopping_patience': 0, 'early_stopping_min_delta': 0.0, 'training_selection_strategy': 'all', 'auxiliary_target': 'none', 'primary_loss_weight': 1.0, 'auxiliary_loss_weight': 0.0, 'execution_policy': 'g2_training_defaults_ieee_comparison_under_3gb_v1', 'screen_rule_version': 'gdrop030_loss003_gap005_v1'}
# Output: /content/drive/MyDrive/MLA2/task3/experiments/t3_gender_dropout_030/gender

# %% [markdown]
# ## 4. Agreed screen rules
#
# All rules must pass, using the same full-FP32 evaluation for each model:
#
# - Pooled validation macro-F1 falls by at most **0.030 versus matched G2**. The paired whole-family bootstrap 95% lower bound for the difference must be **at least −0.030**. Neither fold may lose more than 0.030. Use 10,000 draws within folds, seed 2753.
# - The mean clean training–validation F1 gap falls by at least **0.050**. **Both folds' gaps must shrink.** Use clean evaluation-mode training scores from each finished checkpoint, not online augmented training scores.
# - Preserve the existing stricter class guard: no pooled class loses more than **0.020 F1**. Thus the overall 0.030 allowance does not override a class failure. NLL may rise by at most 0.020 and ECE by at most 0.010 versus G2; these measure the quality of model confidence.
# - Preserve corruption guards versus matched E6: the translation-induced F1 change improves by at least 0.030; every other standard corruption, including darkening, worsens by at most 0.020. Each corrupted score is measured relative to that model's clean score.
# - Exactly **390,181 parameters** and peak allocated GPU memory **strictly below 3,000,000,000 bytes**. Training time and latency are reported without speed caps. A memory failure stops before another fold begins.
#
# The thresholds are derived from the new matched IEEE reference scores; do not substitute the rounded historical values. A pass means this screen met the chosen trade-off, not that the model is accepted or more accurate.

# %%
result = run_gender_dropout_screen(
    g2_directory=G2_DIR, e6_directory=E6_DIR, source_registry_path=DRIVE_REGISTRY,
    precision_directory=PRECISION_DIR, output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY, registry_mirrors=(LOCAL_REGISTRY,), root=REPO_DIR,
)
print("Screen:", result["status"])
for row in result.get("folds", []):
    print("Fold", row["fold"], "train F1:", row["candidate_train_f1"],
          "validation F1:", row["candidate_validation_f1"], "gap:", row["candidate_gap"])
for gate in result.get("checks", []):
    if gate["status"] != "pass":
        print(gate)
if "reason" in result:
    print(result["reason"])
# Out:
# IEEE evaluation: t3_gender_v2_g2_translation_gender_smallcnngem3_f0_s2753_cb072542dbdc_20260904T135102Z6698e6
# IEEE evaluation: t3_gender_v2_g2_translation_gender_smallcnngem3_f4_s2753_cb072542dbdc_20260904T140011Z2211b1
# IEEE evaluation: t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f
# IEEE evaluation: t3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd
# [task3] preparing target=gender fold=0: train=26,220 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_dropout_030_gender_smallcnngem3_f0_s2753_2ab5e633206b_20260905T111550Zce42ad; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.6267 train_macro_f1=0.4208 validation_loss=0.5143 validation_macro_f1=0.5161
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.4827 train_macro_f1=0.5704 validation_loss=0.4325 validation_macro_f1=0.5945
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.4318 train_macro_f1=0.6150 validation_loss=0.4017 validation_macro_f1=0.6583
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.4003 train_macro_f1=0.6537 validation_loss=0.4096 validation_macro_f1=0.6282
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.3749 train_macro_f1=0.6803 validation_loss=0.3909 validation_macro_f1=0.7019
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.3504 train_macro_f1=0.7002 validation_loss=0.3614 validation_macro_f1=0.7043
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.3375 train_macro_f1=0.7026 validation_loss=0.3738 validation_macro_f1=0.6862
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.3226 train_macro_f1=0.7232 validation_loss=0.3768 validation_macro_f1=0.6726
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.3039 train_macro_f1=0.7403 validation_loss=0.3239 validation_macro_f1=0.7240
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.2948 train_macro_f1=0.7514 validation_loss=0.3510 validation_macro_f1=0.6857
# [task3] target=gender fold=0 epoch=11/30 train_loss=0.2797 train_macro_f1=0.7673 validation_loss=0.3808 validation_macro_f1=0.6900
# [task3] target=gender fold=0 epoch=12/30 train_loss=0.2719 train_macro_f1=0.7761 validation_loss=0.3653 validation_macro_f1=0.7078
# [task3] target=gender fold=0 epoch=13/30 train_loss=0.2573 train_macro_f1=0.7861 validation_loss=0.3382 validation_macro_f1=0.7277
# [task3] target=gender fold=0 epoch=14/30 train_loss=0.2389 train_macro_f1=0.8082 validation_loss=0.3516 validation_macro_f1=0.7249
# [task3] target=gender fold=0 epoch=15/30 train_loss=0.2315 train_macro_f1=0.8097 validation_loss=0.3377 validation_macro_f1=0.7238
# [task3] target=gender fold=0 epoch=16/30 train_loss=0.2217 train_macro_f1=0.8203 validation_loss=0.3147 validation_macro_f1=0.7215
# [task3] target=gender fold=0 epoch=17/30 train_loss=0.2047 train_macro_f1=0.8351 validation_loss=0.4031 validation_macro_f1=0.7034
# [task3] target=gender fold=0 epoch=18/30 train_loss=0.1994 train_macro_f1=0.8470 validation_loss=0.3864 validation_macro_f1=0.6963
# [task3] target=gender fold=0 epoch=19/30 train_loss=0.1857 train_macro_f1=0.8584 validation_loss=0.3211 validation_macro_f1=0.7441
# [task3] target=gender fold=0 epoch=20/30 train_loss=0.1813 train_macro_f1=0.8610 validation_loss=0.3063 validation_macro_f1=0.7472
# [task3] target=gender fold=0 epoch=21/30 train_loss=0.1670 train_macro_f1=0.8793 validation_loss=0.3024 validation_macro_f1=0.7443
# [task3] target=gender fold=0 epoch=22/30 train_loss=0.1595 train_macro_f1=0.8863 validation_loss=0.3418 validation_macro_f1=0.7191
# [task3] target=gender fold=0 epoch=23/30 train_loss=0.1549 train_macro_f1=0.8855 validation_loss=0.3021 validation_macro_f1=0.7630
# [task3] target=gender fold=0 epoch=24/30 train_loss=0.1472 train_macro_f1=0.8897 validation_loss=0.3060 validation_macro_f1=0.7514
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.1467 train_macro_f1=0.8905 validation_loss=0.3108 validation_macro_f1=0.7536
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.1400 train_macro_f1=0.8983 validation_loss=0.3107 validation_macro_f1=0.7521
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.1384 train_macro_f1=0.9029 validation_loss=0.3006 validation_macro_f1=0.7671
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.1323 train_macro_f1=0.9069 validation_loss=0.3035 validation_macro_f1=0.7614
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.1332 train_macro_f1=0.9064 validation_loss=0.3027 validation_macro_f1=0.7659
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.1296 train_macro_f1=0.9063 validation_loss=0.3047 validation_macro_f1=0.7642
# [task3] completed target=gender fold=0: t3_gender_dropout_030_gender_smallcnngem3_f0_s2753_2ab5e633206b_20260905T111550Zce42ad
# IEEE evaluation: t3_gender_dropout_030_gender_smallcnngem3_f0_s2753_2ab5e633206b_20260905T111550Zce42ad
# [task3] preparing target=gender fold=4: train=26,216 (before selection=26,216), validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_dropout_030_gender_smallcnngem3_f4_s2753_2ab5e633206b_20260905T112541Z8145b5; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.6252 train_macro_f1=0.4021 validation_loss=0.6024 validation_macro_f1=0.3276
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.4814 train_macro_f1=0.5587 validation_loss=0.4291 validation_macro_f1=0.6057
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.4278 train_macro_f1=0.6130 validation_loss=0.4315 validation_macro_f1=0.6171
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.4027 train_macro_f1=0.6466 validation_loss=0.3858 validation_macro_f1=0.6610
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.3800 train_macro_f1=0.6728 validation_loss=0.3656 validation_macro_f1=0.6714
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.3544 train_macro_f1=0.6860 validation_loss=0.5016 validation_macro_f1=0.6569
# [task3] target=gender fold=4 epoch=7/30 train_loss=0.3358 train_macro_f1=0.7038 validation_loss=0.4485 validation_macro_f1=0.6613
# [task3] target=gender fold=4 epoch=8/30 train_loss=0.3171 train_macro_f1=0.7322 validation_loss=0.3244 validation_macro_f1=0.6735
# [task3] target=gender fold=4 epoch=9/30 train_loss=0.3049 train_macro_f1=0.7392 validation_loss=0.3654 validation_macro_f1=0.7186
# [task3] target=gender fold=4 epoch=10/30 train_loss=0.2922 train_macro_f1=0.7527 validation_loss=0.4406 validation_macro_f1=0.6733
# [task3] target=gender fold=4 epoch=11/30 train_loss=0.2792 train_macro_f1=0.7646 validation_loss=0.3317 validation_macro_f1=0.7286
# [task3] target=gender fold=4 epoch=12/30 train_loss=0.2664 train_macro_f1=0.7726 validation_loss=0.3077 validation_macro_f1=0.7194
# [task3] target=gender fold=4 epoch=13/30 train_loss=0.2535 train_macro_f1=0.7922 validation_loss=0.3753 validation_macro_f1=0.6976
# [task3] target=gender fold=4 epoch=14/30 train_loss=0.2453 train_macro_f1=0.8016 validation_loss=0.3088 validation_macro_f1=0.7225
# [task3] target=gender fold=4 epoch=15/30 train_loss=0.2344 train_macro_f1=0.8124 validation_loss=0.3323 validation_macro_f1=0.7052
# [task3] target=gender fold=4 epoch=16/30 train_loss=0.2222 train_macro_f1=0.8254 validation_loss=0.3467 validation_macro_f1=0.6966
# [task3] target=gender fold=4 epoch=17/30 train_loss=0.2120 train_macro_f1=0.8346 validation_loss=0.3336 validation_macro_f1=0.6986
# [task3] target=gender fold=4 epoch=18/30 train_loss=0.2007 train_macro_f1=0.8369 validation_loss=0.3360 validation_macro_f1=0.7154
# [task3] target=gender fold=4 epoch=19/30 train_loss=0.1872 train_macro_f1=0.8537 validation_loss=0.3197 validation_macro_f1=0.7064
# [task3] target=gender fold=4 epoch=20/30 train_loss=0.1816 train_macro_f1=0.8676 validation_loss=0.2921 validation_macro_f1=0.7333
# [task3] target=gender fold=4 epoch=21/30 train_loss=0.1688 train_macro_f1=0.8770 validation_loss=0.3375 validation_macro_f1=0.7242
# [task3] target=gender fold=4 epoch=22/30 train_loss=0.1627 train_macro_f1=0.8805 validation_loss=0.2886 validation_macro_f1=0.7302
# [task3] target=gender fold=4 epoch=23/30 train_loss=0.1565 train_macro_f1=0.8898 validation_loss=0.3058 validation_macro_f1=0.7090
# [task3] target=gender fold=4 epoch=24/30 train_loss=0.1503 train_macro_f1=0.8929 validation_loss=0.2974 validation_macro_f1=0.7297
# [task3] target=gender fold=4 epoch=25/30 train_loss=0.1474 train_macro_f1=0.8902 validation_loss=0.2921 validation_macro_f1=0.7433
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.1386 train_macro_f1=0.9012 validation_loss=0.2996 validation_macro_f1=0.7336
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.1358 train_macro_f1=0.9001 validation_loss=0.2940 validation_macro_f1=0.7345
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.1350 train_macro_f1=0.9063 validation_loss=0.2926 validation_macro_f1=0.7382
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.1337 train_macro_f1=0.9042 validation_loss=0.2925 validation_macro_f1=0.7450
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.1333 train_macro_f1=0.9081 validation_loss=0.2937 validation_macro_f1=0.7439
# [task3] completed target=gender fold=4: t3_gender_dropout_030_gender_smallcnngem3_f4_s2753_2ab5e633206b_20260905T112541Z8145b5
# IEEE evaluation: t3_gender_dropout_030_gender_smallcnngem3_f4_s2753_2ab5e633206b_20260905T112541Z8145b5
# Screen: fail
# Fold 0 train F1: 0.9645413317086675 validation F1: 0.7642496740255693 gap: 0.2002916576830982
# Fold 4 train F1: 0.9684899459857249 validation F1: 0.7439585381718377 gap: 0.22453140781388725
# {'gate': 'mean_gap_reduction', 'value': 0.035973923953303955, 'rule': '>= 0.050', 'status': 'fail'}
# {'gate': 'robustness_vs_e6.brightness_085', 'value': -0.08364929735170695, 'rule': '>= -0.02', 'status': 'fail'}
# {'gate': 'robustness_vs_e6.grayscale', 'value': -0.04310048598157746, 'rule': '>= -0.02', 'status': 'fail'}

# %% [markdown]
# ## 5. Stop and review
#
# Do not auto-run folds 1–3, refit or open the held-out test. Tell me when this finishes so the saved result can be checked. Each training run appends a registry row. A completed run is reused only after registry, configuration, lineage and artifact checks.
#
# Read `screen_decision.json`, `clean_gap_comparison.csv`, `ieee_oof_predictions.csv`, `source_audit.json` and `comparison_ieee_v2/` in `experiments/t3_gender_dropout_030/gender`. Each IEEE snapshot includes an evaluation manifest with hashes, full probabilities, per-class metrics and corruption scores. The original fold folders and registry keep the native training-run evidence and historical precision scores. Report both the training fit and validation result; a smaller gap alone is not proof of better generalization.
