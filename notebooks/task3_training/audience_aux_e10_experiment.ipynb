# %% [markdown]
# # Task 3 — Gender Audience-Auxiliary E10 Experiment
#
# This Colab runner trains only Gender E10. It keeps the exact E6 GeM model and all official five-way Gender rows, then adds one training-only three-way catalogue-audience head. It never retrains E1–E9.

# %% [markdown]
# ## 1. Safe Colab setup
#
# Run on a GPU runtime. The repository update stops on local changes. Training data is extracted into Colab-local storage; evidence and the registry stay in Drive.

# %%
from pathlib import Path
import math
import os
import subprocess
import sys
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"


def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command))
    return subprocess.run(command, cwd=cwd, check=True)

# %%
try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("This runner must run in Google Colab.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)

if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    dirty = subprocess.check_output(
        ["git", "status", "--porcelain"], cwd=REPO_DIR, text=True
    ).strip()
    if dirty:
        raise RuntimeError(
            "The Colab clone has local changes. Save them first; no switch or merge was attempted."
        )
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

print(f"Repository ready: {REPO_DIR} ({BRANCH})")
# Out:
# Mounted at /content/drive
# $ git clone --branch task-3-gender-usage-classification --single-branch https://github.com/TrnLin/MLA2.git /content/MLA2
# Repository ready: /content/MLA2 (task-3-gender-usage-classification)

# %%
if not DATA_ZIP.is_file():
    raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_suffixes = {".jpg", ".jpeg"}
image_dirs = (
    teacher_dir / "train/images_train",
    teacher_dir / "test/images_test",
)

with zipfile.ZipFile(DATA_ZIP) as archive:
    names = archive.namelist()
    unsafe_names = [
        name for name in names if Path(name).is_absolute() or ".." in Path(name).parts
    ]
    if unsafe_names:
        raise RuntimeError("The dataset archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/")
        and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    if expected_images == 0:
        raise RuntimeError("The archive has no teacher images in the expected folder.")
    current_images = sum(
        path.suffix.lower() in image_suffixes
        for image_dir in image_dirs
        for path in image_dir.glob("*")
    )
    needs_extract = current_images != expected_images or not all(
        path.is_file() for path in required_files
    )
    if needs_extract:
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes
    for image_dir in image_dirs
    for path in image_dir.glob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found "
        f"{actual_images:,}; missing files: {missing_files}"
    )
print(f"Teacher data ready: {actual_images:,} images")

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)
DRIVE_TASK_DIR.mkdir(parents=True, exist_ok=True)
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print("Output folders are ready.")
# Out:
# Extracting 44,441 teacher images...
# Teacher data ready: 44,441 images
# Output folders are ready.

# %% [markdown]
# ## 2. Exact E6 parents and zero-step audit
#
# The frozen IDs must match the completed E6 folds in Drive. The audit checks the saved error counts, the five-to-three label mapping, and helper-label coverage before any optimizer exists.

# %%
from fashion.train.task3_e10 import write_task3_e10_prerun_evidence
from fashion.train.task3_experiments import (
    GENDER_E10_AUXILIARY_LOSS_WEIGHT,
    GENDER_E10_PEAK_MEMORY_LIMIT_BYTES,
    GENDER_E10_PRIMARY_LOSS_WEIGHT,
    audit_completed_registry_rows,
    check_task3_child_setup,
    latest_completed_gender_e6_parent_run_ids,
    run_task3_child_cv,
)

GENDER_E6_PARENT_RUN_IDS = (
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd",
)

resolved_gender = latest_completed_gender_e6_parent_run_ids(output_root=DRIVE_TASK_DIR)
if resolved_gender != GENDER_E6_PARENT_RUN_IDS:
    raise RuntimeError("Resolved Gender E6 parents differ from the frozen tuple.")

gender_e10_check = check_task3_child_setup(
    "gender_audience_aux",
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    root=REPO_DIR,
    device_name="cuda",
)
if gender_e10_check["optimizer_steps"] != 0:
    raise RuntimeError("Preflight unexpectedly reported an optimizer step.")
if gender_e10_check["parameter_count"] != 390_952:
    raise RuntimeError("E10 parameter count changed.")
if gender_e10_check["auxiliary_output_shape"] != [2, 3]:
    raise RuntimeError("E10 audience-head shape changed.")
if gender_e10_check["training_selection_strategy"] != "all":
    raise RuntimeError("E10 must keep every official fold-training row.")
if gender_e10_check["zero_step_peak_memory_bytes"] >= GENDER_E10_PEAK_MEMORY_LIMIT_BYTES:
    raise RuntimeError("E10 failed the frozen zero-step 2 GiB memory check.")
if not math.isclose(
    gender_e10_check["primary_loss_weight"], GENDER_E10_PRIMARY_LOSS_WEIGHT
) or not math.isclose(
    gender_e10_check["auxiliary_loss_weight"], GENDER_E10_AUXILIARY_LOSS_WEIGHT
):
    raise RuntimeError("E10 loss weights changed.")
print("E10 model contract passed zero-step preflight.")
print("Zero-step peak memory bytes:", gender_e10_check["zero_step_peak_memory_bytes"])
# Out:
# E10 model contract passed zero-step preflight.
# Zero-step peak memory bytes: 478367232

# %%
GENDER_E6_AGGREGATE = (
    DRIVE_TASK_DIR / "experiments/t3_gender_e6_gem_p3/gender/aggregate"
)
GENDER_E6_OOF = GENDER_E6_AGGREGATE / "oof_predictions.csv"
GENDER_E6_METRICS = GENDER_E6_AGGREGATE / "metrics.json"
missing_audit_inputs = [
    str(path) for path in (GENDER_E6_OOF, GENDER_E6_METRICS) if not path.is_file()
]
if missing_audit_inputs:
    raise FileNotFoundError(f"Missing saved E6 evidence: {missing_audit_inputs}")

e10_prerun = write_task3_e10_prerun_evidence(
    splits_path=REPO_DIR / "data/processed/splits.csv",
    parent_prediction_path=GENDER_E6_OOF,
    parent_metrics_path=GENDER_E6_METRICS,
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    output_dir=DRIVE_TASK_DIR / "e10_prerun",
)
if e10_prerun["optimizer_steps"] != 0:
    raise RuntimeError("The E10 audit unexpectedly reported an optimizer step.")
if not e10_prerun["verified"] or not all(e10_prerun["checks"].values()):
    raise RuntimeError("The E10 parent evidence did not verify.")
print("Clean E6 errors:", e10_prerun["clean_errors"])
print("Audience/Unisex E6 errors:", e10_prerun["audience_or_unisex_errors"])
print("Focus share:", e10_prerun["audience_or_unisex_share_of_clean_errors"])
print("E10 audit saved to Drive; optimizer steps: 0")
# Out:
# Clean E6 errors: 3338
# Audience/Unisex E6 errors: 2959
# Focus share: 0.8864589574595566
# E10 audit saved to Drive; optimizer steps: 0

# %% [markdown]
# ## 3. Train Gender E10
#
# This is the only training call. It runs all five official folds from scratch. The three-way head helps training, but saved validation predictions and submission output remain the required five Gender classes.

# %%
gender_e10 = run_task3_child_cv(
    "gender_audience_aux",
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    folds=range(5),
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
)
gender_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, gender_e10["fold_run_ids"]
)
print("Gender E10 complete:", gender_e10["metrics_path"])
print(gender_registry_audit)
# Out:
# [task3] starting five-fold experiment=t3_gender_audience_aux_gem_p3 for target=gender
# [task3] preparing target=gender fold=0: train=26,220 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f0_s2753_2bcd937dd320_20260902T035554Z095899; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.6396 train_macro_f1=0.4224 validation_loss=0.6018 validation_macro_f1=0.4953
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.4745 train_macro_f1=0.5839 validation_loss=0.4807 validation_macro_f1=0.6225
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.4127 train_macro_f1=0.6608 validation_loss=0.4216 validation_macro_f1=0.6448
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.3723 train_macro_f1=0.6973 validation_loss=0.4128 validation_macro_f1=0.5977
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.3327 train_macro_f1=0.7388 validation_loss=0.4393 validation_macro_f1=0.6816
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.2920 train_macro_f1=0.7691 validation_loss=0.3995 validation_macro_f1=0.6375
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.2626 train_macro_f1=0.7961 validation_loss=0.4070 validation_macro_f1=0.6941
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.2257 train_macro_f1=0.8312 validation_loss=0.4043 validation_macro_f1=0.6499
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.1887 train_macro_f1=0.8607 validation_loss=0.4126 validation_macro_f1=0.6992
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.1574 train_macro_f1=0.8859 validation_loss=0.4807 validation_macro_f1=0.6723
# [task3] target=gender fold=0 epoch=11/30 train_loss=0.1317 train_macro_f1=0.9049 validation_loss=0.4070 validation_macro_f1=0.7110
# [task3] target=gender fold=0 epoch=12/30 train_loss=0.1014 train_macro_f1=0.9293 validation_loss=0.4619 validation_macro_f1=0.6858
# [task3] target=gender fold=0 epoch=13/30 train_loss=0.0766 train_macro_f1=0.9529 validation_loss=0.4176 validation_macro_f1=0.7272
# [task3] target=gender fold=0 epoch=14/30 train_loss=0.0554 train_macro_f1=0.9626 validation_loss=0.4457 validation_macro_f1=0.7044
# [task3] target=gender fold=0 epoch=15/30 train_loss=0.0410 train_macro_f1=0.9791 validation_loss=0.4560 validation_macro_f1=0.6988
# [task3] target=gender fold=0 epoch=16/30 train_loss=0.0308 train_macro_f1=0.9852 validation_loss=0.4442 validation_macro_f1=0.7239
# [task3] target=gender fold=0 epoch=17/30 train_loss=0.0247 train_macro_f1=0.9900 validation_loss=0.5305 validation_macro_f1=0.7076
# [task3] target=gender fold=0 epoch=18/30 train_loss=0.0175 train_macro_f1=0.9965 validation_loss=0.5583 validation_macro_f1=0.7073
# [task3] target=gender fold=0 epoch=19/30 train_loss=0.0143 train_macro_f1=0.9964 validation_loss=0.4757 validation_macro_f1=0.7278
# [task3] target=gender fold=0 epoch=20/30 train_loss=0.0114 train_macro_f1=0.9983 validation_loss=0.4881 validation_macro_f1=0.7172
# [task3] target=gender fold=0 epoch=21/30 train_loss=0.0092 train_macro_f1=0.9988 validation_loss=0.5619 validation_macro_f1=0.7069
# [task3] target=gender fold=0 epoch=22/30 train_loss=0.0080 train_macro_f1=0.9991 validation_loss=0.5109 validation_macro_f1=0.7155
# [task3] target=gender fold=0 epoch=23/30 train_loss=0.0071 train_macro_f1=0.9991 validation_loss=0.4993 validation_macro_f1=0.7228
# [task3] target=gender fold=0 epoch=24/30 train_loss=0.0062 train_macro_f1=0.9999 validation_loss=0.5066 validation_macro_f1=0.7212
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.0056 train_macro_f1=0.9999 validation_loss=0.5052 validation_macro_f1=0.7251
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.0054 train_macro_f1=0.9996 validation_loss=0.5009 validation_macro_f1=0.7283
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.0049 train_macro_f1=0.9998 validation_loss=0.5029 validation_macro_f1=0.7200
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.0047 train_macro_f1=0.9998 validation_loss=0.5072 validation_macro_f1=0.7184
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.0046 train_macro_f1=0.9999 validation_loss=0.5093 validation_macro_f1=0.7169
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.0044 train_macro_f1=0.9998 validation_loss=0.5157 validation_macro_f1=0.7129
# [task3] completed target=gender fold=0: t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f0_s2753_2bcd937dd320_20260902T035554Z095899
# [task3] preparing target=gender fold=1: train=26,217 (before selection=26,217), validation=6,556
# [task3] fitting fold-training RGB statistics for target=gender fold=1
# [task3] RGB statistics ready for target=gender fold=1
# [task3] registered t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f1_s2753_2bcd937dd320_20260902T040430Z2d2901; the first optimiser step may now run
# [task3] target=gender fold=1 epoch=1/30 train_loss=0.6426 train_macro_f1=0.4227 validation_loss=0.9846 validation_macro_f1=0.3125
# [task3] target=gender fold=1 epoch=2/30 train_loss=0.4713 train_macro_f1=0.5996 validation_loss=0.5116 validation_macro_f1=0.5772
# [task3] target=gender fold=1 epoch=3/30 train_loss=0.4057 train_macro_f1=0.6628 validation_loss=0.4357 validation_macro_f1=0.5993
# [task3] target=gender fold=1 epoch=4/30 train_loss=0.3650 train_macro_f1=0.7117 validation_loss=0.7931 validation_macro_f1=0.4817
# [task3] target=gender fold=1 epoch=5/30 train_loss=0.3198 train_macro_f1=0.7462 validation_loss=0.7552 validation_macro_f1=0.5753
# [task3] target=gender fold=1 epoch=6/30 train_loss=0.2919 train_macro_f1=0.7749 validation_loss=0.4260 validation_macro_f1=0.6202
# [task3] target=gender fold=1 epoch=7/30 train_loss=0.2514 train_macro_f1=0.8062 validation_loss=0.4262 validation_macro_f1=0.5540
# [task3] target=gender fold=1 epoch=8/30 train_loss=0.2175 train_macro_f1=0.8343 validation_loss=0.5135 validation_macro_f1=0.5764
# [task3] target=gender fold=1 epoch=9/30 train_loss=0.1810 train_macro_f1=0.8590 validation_loss=0.3931 validation_macro_f1=0.6805
# [task3] target=gender fold=1 epoch=10/30 train_loss=0.1515 train_macro_f1=0.8883 validation_loss=0.5744 validation_macro_f1=0.6619
# [task3] target=gender fold=1 epoch=11/30 train_loss=0.1267 train_macro_f1=0.9085 validation_loss=0.6451 validation_macro_f1=0.6415
# [task3] target=gender fold=1 epoch=12/30 train_loss=0.0904 train_macro_f1=0.9356 validation_loss=0.4074 validation_macro_f1=0.7316
# [task3] target=gender fold=1 epoch=13/30 train_loss=0.0718 train_macro_f1=0.9519 validation_loss=0.5173 validation_macro_f1=0.6944
# [task3] target=gender fold=1 epoch=14/30 train_loss=0.0553 train_macro_f1=0.9662 validation_loss=0.4465 validation_macro_f1=0.6658
# [task3] target=gender fold=1 epoch=15/30 train_loss=0.0388 train_macro_f1=0.9807 validation_loss=0.5317 validation_macro_f1=0.7054
# [task3] target=gender fold=1 epoch=16/30 train_loss=0.0289 train_macro_f1=0.9859 validation_loss=0.5048 validation_macro_f1=0.7103
# [task3] target=gender fold=1 epoch=17/30 train_loss=0.0231 train_macro_f1=0.9906 validation_loss=0.4554 validation_macro_f1=0.6908
# [task3] target=gender fold=1 epoch=18/30 train_loss=0.0160 train_macro_f1=0.9939 validation_loss=0.7621 validation_macro_f1=0.6429
# [task3] target=gender fold=1 epoch=19/30 train_loss=0.0128 train_macro_f1=0.9977 validation_loss=0.4797 validation_macro_f1=0.7247
# [task3] target=gender fold=1 epoch=20/30 train_loss=0.0103 train_macro_f1=0.9983 validation_loss=0.4635 validation_macro_f1=0.7466
# [task3] target=gender fold=1 epoch=21/30 train_loss=0.0097 train_macro_f1=0.9980 validation_loss=0.4476 validation_macro_f1=0.7524
# [task3] target=gender fold=1 epoch=22/30 train_loss=0.0074 train_macro_f1=0.9993 validation_loss=0.4663 validation_macro_f1=0.7392
# [task3] target=gender fold=1 epoch=23/30 train_loss=0.0066 train_macro_f1=0.9989 validation_loss=0.4674 validation_macro_f1=0.7377
# [task3] target=gender fold=1 epoch=24/30 train_loss=0.0056 train_macro_f1=0.9999 validation_loss=0.4603 validation_macro_f1=0.7411
# [task3] target=gender fold=1 epoch=25/30 train_loss=0.0054 train_macro_f1=0.9995 validation_loss=0.4640 validation_macro_f1=0.7344
# [task3] target=gender fold=1 epoch=26/30 train_loss=0.0052 train_macro_f1=0.9994 validation_loss=0.4635 validation_macro_f1=0.7421
# [task3] target=gender fold=1 epoch=27/30 train_loss=0.0046 train_macro_f1=0.9998 validation_loss=0.4744 validation_macro_f1=0.7379
# [task3] target=gender fold=1 epoch=28/30 train_loss=0.0044 train_macro_f1=0.9997 validation_loss=0.4821 validation_macro_f1=0.7335
# [task3] target=gender fold=1 epoch=29/30 train_loss=0.0043 train_macro_f1=0.9999 validation_loss=0.4772 validation_macro_f1=0.7355
# [task3] target=gender fold=1 epoch=30/30 train_loss=0.0042 train_macro_f1=0.9999 validation_loss=0.4706 validation_macro_f1=0.7362
# [task3] completed target=gender fold=1: t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f1_s2753_2bcd937dd320_20260902T040430Z2d2901
# [task3] preparing target=gender fold=2: train=26,220 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=2
# [task3] RGB statistics ready for target=gender fold=2
# [task3] registered t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f2_s2753_2bcd937dd320_20260902T041309Z09a3c7; the first optimiser step may now run
# [task3] target=gender fold=2 epoch=1/30 train_loss=0.6422 train_macro_f1=0.4269 validation_loss=0.5241 validation_macro_f1=0.5501
# [task3] target=gender fold=2 epoch=2/30 train_loss=0.4749 train_macro_f1=0.5919 validation_loss=0.6043 validation_macro_f1=0.5460
# [task3] target=gender fold=2 epoch=3/30 train_loss=0.4225 train_macro_f1=0.6521 validation_loss=0.4913 validation_macro_f1=0.4902
# [task3] target=gender fold=2 epoch=4/30 train_loss=0.3688 train_macro_f1=0.7063 validation_loss=0.4566 validation_macro_f1=0.6308
# [task3] target=gender fold=2 epoch=5/30 train_loss=0.3302 train_macro_f1=0.7376 validation_loss=0.3899 validation_macro_f1=0.6902
# [task3] target=gender fold=2 epoch=6/30 train_loss=0.3004 train_macro_f1=0.7649 validation_loss=0.3837 validation_macro_f1=0.6959
# [task3] target=gender fold=2 epoch=7/30 train_loss=0.2592 train_macro_f1=0.7980 validation_loss=0.4730 validation_macro_f1=0.6058
# [task3] target=gender fold=2 epoch=8/30 train_loss=0.2246 train_macro_f1=0.8292 validation_loss=0.6727 validation_macro_f1=0.5810
# [task3] target=gender fold=2 epoch=9/30 train_loss=0.1951 train_macro_f1=0.8566 validation_loss=0.3579 validation_macro_f1=0.7013
# [task3] target=gender fold=2 epoch=10/30 train_loss=0.1607 train_macro_f1=0.8865 validation_loss=0.4162 validation_macro_f1=0.7092
# [task3] target=gender fold=2 epoch=11/30 train_loss=0.1247 train_macro_f1=0.9147 validation_loss=0.4724 validation_macro_f1=0.6890
# [task3] target=gender fold=2 epoch=12/30 train_loss=0.0974 train_macro_f1=0.9321 validation_loss=0.4456 validation_macro_f1=0.7025
# [task3] target=gender fold=2 epoch=13/30 train_loss=0.0762 train_macro_f1=0.9494 validation_loss=0.4477 validation_macro_f1=0.7030
# [task3] target=gender fold=2 epoch=14/30 train_loss=0.0563 train_macro_f1=0.9667 validation_loss=0.4332 validation_macro_f1=0.7118
# [task3] target=gender fold=2 epoch=15/30 train_loss=0.0451 train_macro_f1=0.9717 validation_loss=0.4100 validation_macro_f1=0.7102
# [task3] target=gender fold=2 epoch=16/30 train_loss=0.0295 train_macro_f1=0.9847 validation_loss=0.4180 validation_macro_f1=0.7036
# [task3] target=gender fold=2 epoch=17/30 train_loss=0.0236 train_macro_f1=0.9894 validation_loss=0.5055 validation_macro_f1=0.7175
# [task3] target=gender fold=2 epoch=18/30 train_loss=0.0166 train_macro_f1=0.9944 validation_loss=0.6698 validation_macro_f1=0.6112
# [task3] target=gender fold=2 epoch=19/30 train_loss=0.0138 train_macro_f1=0.9954 validation_loss=0.5143 validation_macro_f1=0.7116
# [task3] target=gender fold=2 epoch=20/30 train_loss=0.0115 train_macro_f1=0.9977 validation_loss=0.4665 validation_macro_f1=0.7331
# [task3] target=gender fold=2 epoch=21/30 train_loss=0.0094 train_macro_f1=0.9981 validation_loss=0.4711 validation_macro_f1=0.7115
# [task3] target=gender fold=2 epoch=22/30 train_loss=0.0086 train_macro_f1=0.9985 validation_loss=0.4881 validation_macro_f1=0.7169
# [task3] target=gender fold=2 epoch=23/30 train_loss=0.0072 train_macro_f1=0.9987 validation_loss=0.4608 validation_macro_f1=0.7166
# [task3] target=gender fold=2 epoch=24/30 train_loss=0.0062 train_macro_f1=0.9995 validation_loss=0.4836 validation_macro_f1=0.7219
# [task3] target=gender fold=2 epoch=25/30 train_loss=0.0056 train_macro_f1=0.9997 validation_loss=0.4790 validation_macro_f1=0.7123
# [task3] target=gender fold=2 epoch=26/30 train_loss=0.0053 train_macro_f1=0.9997 validation_loss=0.4973 validation_macro_f1=0.7146
# [task3] target=gender fold=2 epoch=27/30 train_loss=0.0049 train_macro_f1=0.9999 validation_loss=0.4881 validation_macro_f1=0.7174
# [task3] target=gender fold=2 epoch=28/30 train_loss=0.0047 train_macro_f1=0.9999 validation_loss=0.4900 validation_macro_f1=0.7086
# [task3] target=gender fold=2 epoch=29/30 train_loss=0.0045 train_macro_f1=0.9999 validation_loss=0.4845 validation_macro_f1=0.7126
# [task3] target=gender fold=2 epoch=30/30 train_loss=0.0045 train_macro_f1=0.9999 validation_loss=0.4906 validation_macro_f1=0.7139
# [task3] completed target=gender fold=2: t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f2_s2753_2bcd937dd320_20260902T041309Z09a3c7
# [task3] preparing target=gender fold=3: train=26,219 (before selection=26,219), validation=6,554
# [task3] fitting fold-training RGB statistics for target=gender fold=3
# [task3] RGB statistics ready for target=gender fold=3
# [task3] registered t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f3_s2753_2bcd937dd320_20260902T042147Zd77574; the first optimiser step may now run
# [task3] target=gender fold=3 epoch=1/30 train_loss=0.6377 train_macro_f1=0.4150 validation_loss=0.5215 validation_macro_f1=0.5326
# [task3] target=gender fold=3 epoch=2/30 train_loss=0.4702 train_macro_f1=0.5845 validation_loss=0.4416 validation_macro_f1=0.6157
# [task3] target=gender fold=3 epoch=3/30 train_loss=0.4087 train_macro_f1=0.6525 validation_loss=0.4504 validation_macro_f1=0.6734
# [task3] target=gender fold=3 epoch=4/30 train_loss=0.3674 train_macro_f1=0.6829 validation_loss=0.4359 validation_macro_f1=0.6630
# [task3] target=gender fold=3 epoch=5/30 train_loss=0.3253 train_macro_f1=0.7364 validation_loss=0.4711 validation_macro_f1=0.5467
# [task3] target=gender fold=3 epoch=6/30 train_loss=0.2897 train_macro_f1=0.7660 validation_loss=0.4328 validation_macro_f1=0.6654
# [task3] target=gender fold=3 epoch=7/30 train_loss=0.2539 train_macro_f1=0.7944 validation_loss=0.3829 validation_macro_f1=0.7365
# [task3] target=gender fold=3 epoch=8/30 train_loss=0.2143 train_macro_f1=0.8297 validation_loss=0.6797 validation_macro_f1=0.6433
# [task3] target=gender fold=3 epoch=9/30 train_loss=0.1909 train_macro_f1=0.8575 validation_loss=0.4463 validation_macro_f1=0.7107
# [task3] target=gender fold=3 epoch=10/30 train_loss=0.1502 train_macro_f1=0.8882 validation_loss=0.3906 validation_macro_f1=0.7468
# [task3] target=gender fold=3 epoch=11/30 train_loss=0.1152 train_macro_f1=0.9170 validation_loss=0.4449 validation_macro_f1=0.7092
# [task3] target=gender fold=3 epoch=12/30 train_loss=0.0939 train_macro_f1=0.9347 validation_loss=0.5365 validation_macro_f1=0.6395
# [task3] target=gender fold=3 epoch=13/30 train_loss=0.0685 train_macro_f1=0.9518 validation_loss=0.5037 validation_macro_f1=0.7187
# [task3] target=gender fold=3 epoch=14/30 train_loss=0.0493 train_macro_f1=0.9691 validation_loss=0.4285 validation_macro_f1=0.7163
# [task3] target=gender fold=3 epoch=15/30 train_loss=0.0372 train_macro_f1=0.9777 validation_loss=0.5173 validation_macro_f1=0.6914
# [task3] target=gender fold=3 epoch=16/30 train_loss=0.0266 train_macro_f1=0.9856 validation_loss=0.4481 validation_macro_f1=0.7261
# [task3] target=gender fold=3 epoch=17/30 train_loss=0.0198 train_macro_f1=0.9914 validation_loss=0.4781 validation_macro_f1=0.7544
# [task3] target=gender fold=3 epoch=18/30 train_loss=0.0143 train_macro_f1=0.9956 validation_loss=0.4531 validation_macro_f1=0.7548
# [task3] target=gender fold=3 epoch=19/30 train_loss=0.0120 train_macro_f1=0.9973 validation_loss=0.4628 validation_macro_f1=0.7650
# [task3] target=gender fold=3 epoch=20/30 train_loss=0.0092 train_macro_f1=0.9981 validation_loss=0.4759 validation_macro_f1=0.7181
# [task3] target=gender fold=3 epoch=21/30 train_loss=0.0075 train_macro_f1=0.9989 validation_loss=0.4782 validation_macro_f1=0.7362
# [task3] target=gender fold=3 epoch=22/30 train_loss=0.0065 train_macro_f1=0.9995 validation_loss=0.4916 validation_macro_f1=0.7637
# [task3] target=gender fold=3 epoch=23/30 train_loss=0.0056 train_macro_f1=0.9996 validation_loss=0.4871 validation_macro_f1=0.7585
# [task3] target=gender fold=3 epoch=24/30 train_loss=0.0052 train_macro_f1=0.9998 validation_loss=0.5182 validation_macro_f1=0.7522
# [task3] target=gender fold=3 epoch=25/30 train_loss=0.0047 train_macro_f1=1.0000 validation_loss=0.5159 validation_macro_f1=0.7448
# [task3] target=gender fold=3 epoch=26/30 train_loss=0.0044 train_macro_f1=0.9998 validation_loss=0.5027 validation_macro_f1=0.7521
# [task3] target=gender fold=3 epoch=27/30 train_loss=0.0041 train_macro_f1=1.0000 validation_loss=0.5019 validation_macro_f1=0.7573
# [task3] target=gender fold=3 epoch=28/30 train_loss=0.0040 train_macro_f1=1.0000 validation_loss=0.5085 validation_macro_f1=0.7532
# [task3] target=gender fold=3 epoch=29/30 train_loss=0.0039 train_macro_f1=1.0000 validation_loss=0.5098 validation_macro_f1=0.7556
# [task3] target=gender fold=3 epoch=30/30 train_loss=0.0037 train_macro_f1=1.0000 validation_loss=0.5096 validation_macro_f1=0.7556
# [task3] completed target=gender fold=3: t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f3_s2753_2bcd937dd320_20260902T042147Zd77574
# [task3] preparing target=gender fold=4: train=26,216 (before selection=26,216), validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f4_s2753_2bcd937dd320_20260902T043025Zafdd44; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.6395 train_macro_f1=0.4244 validation_loss=0.5180 validation_macro_f1=0.5661
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.4623 train_macro_f1=0.5986 validation_loss=0.4735 validation_macro_f1=0.6140
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.4049 train_macro_f1=0.6601 validation_loss=0.4261 validation_macro_f1=0.6634
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.3579 train_macro_f1=0.7039 validation_loss=0.6274 validation_macro_f1=0.5994
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.3206 train_macro_f1=0.7428 validation_loss=0.3866 validation_macro_f1=0.6967
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.2822 train_macro_f1=0.7747 validation_loss=0.7402 validation_macro_f1=0.6458
# [task3] target=gender fold=4 epoch=7/30 train_loss=0.2434 train_macro_f1=0.8062 validation_loss=0.5154 validation_macro_f1=0.6580
# [task3] target=gender fold=4 epoch=8/30 train_loss=0.2083 train_macro_f1=0.8392 validation_loss=0.3941 validation_macro_f1=0.6886
# [task3] target=gender fold=4 epoch=9/30 train_loss=0.1751 train_macro_f1=0.8621 validation_loss=0.4975 validation_macro_f1=0.6834
# [task3] target=gender fold=4 epoch=10/30 train_loss=0.1468 train_macro_f1=0.8852 validation_loss=0.5196 validation_macro_f1=0.6592
# [task3] target=gender fold=4 epoch=11/30 train_loss=0.1165 train_macro_f1=0.9076 validation_loss=0.4327 validation_macro_f1=0.6698
# [task3] target=gender fold=4 epoch=12/30 train_loss=0.0880 train_macro_f1=0.9362 validation_loss=0.4356 validation_macro_f1=0.6856
# [task3] target=gender fold=4 epoch=13/30 train_loss=0.0668 train_macro_f1=0.9539 validation_loss=0.4492 validation_macro_f1=0.7346
# [task3] target=gender fold=4 epoch=14/30 train_loss=0.0493 train_macro_f1=0.9655 validation_loss=0.4123 validation_macro_f1=0.7167
# [task3] target=gender fold=4 epoch=15/30 train_loss=0.0340 train_macro_f1=0.9817 validation_loss=0.4515 validation_macro_f1=0.7124
# [task3] target=gender fold=4 epoch=16/30 train_loss=0.0265 train_macro_f1=0.9860 validation_loss=0.8646 validation_macro_f1=0.6408
# [task3] target=gender fold=4 epoch=17/30 train_loss=0.0179 train_macro_f1=0.9935 validation_loss=0.4915 validation_macro_f1=0.7204
# [task3] target=gender fold=4 epoch=18/30 train_loss=0.0154 train_macro_f1=0.9953 validation_loss=0.5783 validation_macro_f1=0.7028
# [task3] target=gender fold=4 epoch=19/30 train_loss=0.0124 train_macro_f1=0.9974 validation_loss=0.4839 validation_macro_f1=0.7125
# [task3] target=gender fold=4 epoch=20/30 train_loss=0.0113 train_macro_f1=0.9977 validation_loss=0.5123 validation_macro_f1=0.7190
# [task3] target=gender fold=4 epoch=21/30 train_loss=0.0083 train_macro_f1=0.9992 validation_loss=0.4927 validation_macro_f1=0.7135
# [task3] target=gender fold=4 epoch=22/30 train_loss=0.0066 train_macro_f1=0.9999 validation_loss=0.4807 validation_macro_f1=0.7165
# [task3] target=gender fold=4 epoch=23/30 train_loss=0.0064 train_macro_f1=0.9996 validation_loss=0.5549 validation_macro_f1=0.7170
# [task3] target=gender fold=4 epoch=24/30 train_loss=0.0055 train_macro_f1=0.9999 validation_loss=0.5253 validation_macro_f1=0.7215
# [task3] target=gender fold=4 epoch=25/30 train_loss=0.0053 train_macro_f1=0.9998 validation_loss=0.5265 validation_macro_f1=0.7058
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.0048 train_macro_f1=0.9998 validation_loss=0.5154 validation_macro_f1=0.7156
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.0046 train_macro_f1=0.9998 validation_loss=0.5018 validation_macro_f1=0.7197
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.0043 train_macro_f1=0.9999 validation_loss=0.4984 validation_macro_f1=0.7153
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.0041 train_macro_f1=0.9999 validation_loss=0.5082 validation_macro_f1=0.7126
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.0041 train_macro_f1=0.9999 validation_loss=0.5067 validation_macro_f1=0.7155
# [task3] completed target=gender fold=4: t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f4_s2753_2bcd937dd320_20260902T043025Zafdd44
# [task3] completed pooled five-fold OOF experiment=t3_gender_audience_aux_gem_p3 target=gender
# Gender E10 complete: /content/drive/MyDrive/MLA2/task3/experiments/t3_gender_e10_audience_aux/gender/aggregate/metrics.json
# {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv', 'run_ids': ['t3_gender_e10_audience_aux_gender_smallcnngem3aux3_f0_s2753_2bcd937dd320_20260902T035554Z095899', 't3_gender_e10_audience_aux_gender_smallcnngem3aux3_f1_s2753_2bcd937dd320_20260902T040430Z2d2901', 't3_gender_e10_audience_aux_gender_smallcnngem3aux3_f2_s2753_2bcd937dd320_20260902T041309Z09a3c7', 't3_gender_e10_audience_aux_gender_smallcnngem3aux3_f3_s2753_2bcd937dd320_20260902T042147Zd77574', 't3_gender_e10_audience_aux_gender_smallcnngem3aux3_f4_s2753_2bcd937dd320_20260902T043025Zafdd44'], 'completed_rows': 5, 'ready': True}

# %% [markdown]
# ## 4. Stop and return to the main notebook
#
# Do not run another seed or add another change here. Return the saved E10 aggregate to Notebook 04 and apply the frozen five-way, audience-error, fold, and robustness gates. The separate Usage label audit remains deferred.
