# %% [markdown]
# # Task 3 — Usage MixUp + SAM: folds 0 and 4
#
# This follows the main EDA's saved family folds and the approved expanded v2 dataset.
# Each fold starts with **fresh random model weights**. No Gender weights or earlier Usage checkpoint is loaded.
#
# This is one small trial for the rare-class problem. It still predicts all **nine Usage classes**.
#
# | Setting | Fixed value |
# |---|---|
# | Data | Teacher images + 687 admitted Usage images |
# | Model | SmallCNN, trained from scratch |
# | Validation folds | **0 and 4 only** |
# | Training rows | The other four saved development folds |
# | Epochs / checkpoint | 30 / final epoch |
# | MixUp | alpha 0.2, every training batch |
# | SAM | rho 0.05 over AdamW |
# | Class weights | Recomputed from each training fold, beta 0.999, cap 5 |
# | Other controls | E8 translation, batch 128, seed 2753, existing cosine schedule |
#
# The completed v2 E8 runs are score references only. Success means better predictions on the
# same teacher validation images. A smaller training gap alone is not enough.

# %% [markdown]
# ## 1. Load the separate training bundle
#
# In **VS Code**, select a fresh **Colab GPU kernel**. Keep these files in `MyDrive/MLA2/data/`:
#
# - `usage_mixup_sam_training.zip`
# - Your existing `task3-data.zip`
#
# Choose **Run All**. Results go to `MyDrive/MLA2/task3_usage_mixup_sam/`.

# %%
from pathlib import Path
import hashlib
import json
import os
import shutil
import sys
import tempfile
import zipfile

from google.colab import drive

DRIVE_MOUNT = Path("/content/drive")
drive.mount(str(DRIVE_MOUNT), force_remount=False)
DRIVE_PROJECT = DRIVE_MOUNT / "MyDrive/MLA2"
BUNDLE_ZIP = DRIVE_PROJECT / "data/usage_mixup_sam_training.zip"
TEACHER_ZIP = DRIVE_PROJECT / "data/task3-data.zip"
DRIVE_TASK_DIR = DRIVE_PROJECT / "task3_usage_mixup_sam"


def sha256_file(path):
    with Path(path).open("rb") as handle:
        return hashlib.file_digest(handle, "sha256").hexdigest()


def safe_members(archive, prefix=None):
    members = archive.infolist()
    names = [member.filename for member in members]
    if len(names) != len(set(names)):
        raise ValueError("Archive contains duplicate file names.")
    for member in members:
        name = member.filename
        if Path(name).is_absolute() or ".." in Path(name).parts or "\\" in name:
            raise ValueError(f"Unsafe archive path: {name}")
        if (member.external_attr >> 16) & 0o170000 == 0o120000:
            raise ValueError(f"Archive symlink is not allowed: {name}")
    return [m for m in members if prefix is None or m.filename.startswith(prefix)]


if not BUNDLE_ZIP.is_file():
    raise FileNotFoundError(f"Upload the new training ZIP here first: {BUNDLE_ZIP}")
bundle_digest = sha256_file(BUNDLE_ZIP)
LOCAL_BUNDLE = Path("/content") / f"usage-mixup-sam-{bundle_digest[:12]}.zip"
if not LOCAL_BUNDLE.is_file() or sha256_file(LOCAL_BUNDLE) != bundle_digest:
    partial = LOCAL_BUNDLE.with_suffix(".zip.partial")
    shutil.copyfile(BUNDLE_ZIP, partial)
    if sha256_file(partial) != bundle_digest:
        raise RuntimeError("Training ZIP copy is incomplete. Run this cell again.")
    partial.replace(LOCAL_BUNDLE)
REPO_DIR = Path("/content") / f"MLA2-usage-mixup-sam-{bundle_digest[:12]}"
with zipfile.ZipFile(LOCAL_BUNDLE) as archive:
    members = safe_members(archive)
    manifest = json.loads(archive.read("training_bundle_manifest.json"))
    if manifest["dataset"]["name"] != "teacher_plus_rare_usage_v2_20260906":
        raise ValueError("This notebook requires the new v2 training bundle.")
    if manifest["recipe"]["name"] != "usage_expanded_v2_mixup_sam":
        raise ValueError("This notebook needs the Usage MixUp + SAM bundle.")
    expected = manifest["files"]
    actual = {m.filename for m in members if not m.is_dir()}
    if actual != set(expected) | {"training_bundle_manifest.json"}:
        raise ValueError("The training archive inventory differs from its manifest.")
    for name, digest in expected.items():
        if hashlib.sha256(archive.read(name)).hexdigest() != digest:
            raise ValueError(f"Training archive file changed: {name}")
    if not REPO_DIR.exists():
        with tempfile.TemporaryDirectory(prefix="usage-sam-unpack-", dir="/content") as temporary:
            staging = Path(temporary) / "project"
            staging.mkdir()
            archive.extractall(staging)
            for name, digest in expected.items():
                if sha256_file(staging / name) != digest:
                    raise RuntimeError(f"Extracted bundle file differs: {name}")
            staging.rename(REPO_DIR)
for name, digest in expected.items():
    if not (REPO_DIR / name).is_file() or sha256_file(REPO_DIR / name) != digest:
        raise RuntimeError(f"Local bundle file differs: {name}. Use a fresh runtime.")

# The verified archive stays intact. Current code comes from GitHub.
BUNDLE_ROOT = REPO_DIR
import subprocess
import tempfile

REPOSITORY = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
with tempfile.TemporaryDirectory(prefix="usage-current-code-", dir="/content") as temporary:
    checkout = Path(temporary) / "project"
    subprocess.run(["git", "clone", "--quiet", "--depth=1", "--branch", BRANCH,
                    REPOSITORY, str(checkout)], check=True)
    CODE_COMMIT = subprocess.check_output(
        ["git", "-C", str(checkout), "rev-parse", "HEAD"], text=True).strip()
    REPO_DIR = Path(str(BUNDLE_ROOT) + "-code-" + CODE_COMMIT[:12])
    if REPO_DIR.exists():
        subprocess.run(["git", "-C", str(REPO_DIR), "diff", "--quiet", "HEAD", "--", "src"],
                       check=True)
    else:
        checkout.rename(REPO_DIR)
print("Current code commit:", CODE_COMMIT)

if "fashion.config" in sys.modules:
    loaded_root = Path(sys.modules["fashion.config"].ROOT)
    if loaded_root != REPO_DIR:
        raise RuntimeError("Another notebook is loaded. Restart the session, then Run All.")
os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
if str(REPO_DIR / "src") not in sys.path:
    sys.path.insert(0, str(REPO_DIR / "src"))
from fashion.train.task3_bundle_inputs import install_bundle_inputs
print("Reused data/reference files:", install_bundle_inputs(BUNDLE_ROOT, REPO_DIR))
LOCAL_REGISTRY = REPO_DIR / "screen_registry/results/runs.csv"
REFERENCE_ROOT = REPO_DIR / "reference/usage_mixup_sam"
print("Fresh Usage MixUp + SAM code and data ready:", REPO_DIR)
print("Bundle SHA-256:", bundle_digest)
# Out:
# Mounted at /content/drive
# Fresh Usage MixUp + SAM code and data ready: /content/MLA2-usage-mixup-sam-0e2b8549195d
# Bundle SHA-256: 0e2b8549195d381ba583176c729c26e50fd9cbc691f4a89863802e6d2679de40

# %% [markdown]
# ## 2. Put teacher images on local disk
#
# Training reads local images, while saved results go to Drive.

# %%
if not TEACHER_ZIP.is_file():
    raise FileNotFoundError(f"Existing teacher archive is missing: {TEACHER_ZIP}")
LOCAL_TEACHER_ZIP = Path("/content/task3-data.zip")
if (
    not LOCAL_TEACHER_ZIP.is_file()
    or LOCAL_TEACHER_ZIP.stat().st_size != TEACHER_ZIP.stat().st_size
):
    partial = LOCAL_TEACHER_ZIP.with_suffix(".zip.partial")
    shutil.copyfile(TEACHER_ZIP, partial)
    if partial.stat().st_size != TEACHER_ZIP.stat().st_size:
        raise RuntimeError("Teacher ZIP copy is incomplete. Run this cell again.")
    partial.replace(LOCAL_TEACHER_ZIP)
with zipfile.ZipFile(LOCAL_TEACHER_ZIP) as archive:
    members = safe_members(archive, prefix="data/raw/teacher/")
    if not members:
        raise ValueError("Teacher archive must contain data/raw/teacher/.")
    for member in members:
        destination = REPO_DIR / member.filename
        if member.is_dir():
            destination.mkdir(parents=True, exist_ok=True)
        elif not destination.is_file() or destination.stat().st_size != member.file_size:
            archive.extract(member, REPO_DIR)
print("Teacher images are on local disk.")
# Out:
# Teacher images are on local disk.

# %% [markdown]
# ## 3. Check the two saved folds
#
# No new split is made. All split files, image hashes and source groups are checked before fitting.

# %%
import pandas as pd
import torch
from IPython.display import Image as DisplayImage, display
from fashion.train.task3_usage_expanded_v2 import validate_dataset
from fashion.train.task3_usage_mixup_sam import (
    FOLDS,
    run_usage_mixup_sam,
    save_learning_curves,
    screen_spec,
    usage_registry_path,
)

if not torch.cuda.is_available():
    raise RuntimeError("Choose a GPU runtime, then Run All.")
splits, contract = validate_dataset(root=REPO_DIR, check_images=False)
BASELINE_DIR = REFERENCE_ROOT / "baseline"
BASELINE_REGISTRY = REFERENCE_ROOT / "baseline_runs.csv"
DRIVE_REGISTRY = usage_registry_path(DRIVE_TASK_DIR)
assert FOLDS == (0, 4)
print("GPU:", torch.cuda.get_device_name(0))
print("Fresh model weights. Training only folds:", FOLDS)
print("Dataset:", contract["name"])
print("Recipe:", screen_spec().name)
print("Results:", DRIVE_TASK_DIR)
counts = pd.DataFrame(contract["folds"])
display(counts.loc[counts.fold.isin(FOLDS), [
    "fold", "training_rows", "validation_rows",
    "teacher_validation_rows", "new_added_validation_rows",
]])
# Out:
# GPU: NVIDIA A100-SXM4-40GB
# Fresh model weights. Training only folds: (0, 4)
# Dataset: teacher_plus_rare_usage_v2_20260906
# Recipe: usage_expanded_v2_mixup_sam
# Results: /content/drive/MyDrive/MLA2/task3_usage_mixup_sam
#    fold  training_rows  validation_rows  teacher_validation_rows  \
# 0     0          26751             6708                     6553
# 4     4          26771             6688                     6557
#
#    new_added_validation_rows
# 0                        131
# 4                        106

# %% [markdown]
# ## 4. Train two fresh models
#
# Both folds start from random weights and stop at epoch 30. The runner rejects any other fold list.
# SAM uses the same mixed batch for its two gradient passes and makes one AdamW update per batch.
# BatchNorm keeps one update to its running statistics.
#
# A completed fold is reused only after its saved files and training records pass verification.
# An interrupted fold starts a fresh run; it does not load partial model weights.

# %%
result = run_usage_mixup_sam(
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    baseline_directory=BASELINE_DIR,
    baseline_registry_path=BASELINE_REGISTRY,
    registry_mirrors=(LOCAL_REGISTRY,),
    folds=(0, 4),
)
print("Saved teacher comparison:", result["comparison_path"])
# Out:
# Usage MixUp + SAM: fresh weights, fold 0, 30 epochs
# [task3] preparing target=usage fold=0: train=26,751 (before selection=26,751), validation=6,708
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_expanded_v2_mixup_sam_usage_smallcnn_f0_s2753_dd6018a005e9_20260906T154107Z42a2aa; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=1.1646 train_macro_f1=n/a (mixed inputs) validation_loss=1.0030 validation_macro_f1=0.3463
# [task3] target=usage fold=0 epoch=2/30 train_loss=0.9480 train_macro_f1=n/a (mixed inputs) validation_loss=0.9266 validation_macro_f1=0.3539
# [task3] target=usage fold=0 epoch=3/30 train_loss=0.8323 train_macro_f1=n/a (mixed inputs) validation_loss=0.7813 validation_macro_f1=0.4466
# [task3] target=usage fold=0 epoch=4/30 train_loss=0.7918 train_macro_f1=n/a (mixed inputs) validation_loss=0.7404 validation_macro_f1=0.4797
# [task3] target=usage fold=0 epoch=5/30 train_loss=0.7513 train_macro_f1=n/a (mixed inputs) validation_loss=0.7196 validation_macro_f1=0.6327
# [task3] target=usage fold=0 epoch=6/30 train_loss=0.7160 train_macro_f1=n/a (mixed inputs) validation_loss=0.6583 validation_macro_f1=0.6029
# [task3] target=usage fold=0 epoch=7/30 train_loss=0.7017 train_macro_f1=n/a (mixed inputs) validation_loss=0.5927 validation_macro_f1=0.6477
# [task3] target=usage fold=0 epoch=8/30 train_loss=0.6854 train_macro_f1=n/a (mixed inputs) validation_loss=0.6067 validation_macro_f1=0.6654
# [task3] target=usage fold=0 epoch=9/30 train_loss=0.6568 train_macro_f1=n/a (mixed inputs) validation_loss=0.6078 validation_macro_f1=0.6035
# [task3] target=usage fold=0 epoch=10/30 train_loss=0.6332 train_macro_f1=n/a (mixed inputs) validation_loss=0.5340 validation_macro_f1=0.6457
# [task3] target=usage fold=0 epoch=11/30 train_loss=0.6335 train_macro_f1=n/a (mixed inputs) validation_loss=0.5380 validation_macro_f1=0.7143
# [task3] target=usage fold=0 epoch=12/30 train_loss=0.5731 train_macro_f1=n/a (mixed inputs) validation_loss=0.5567 validation_macro_f1=0.6745
# [task3] target=usage fold=0 epoch=13/30 train_loss=0.6050 train_macro_f1=n/a (mixed inputs) validation_loss=0.6204 validation_macro_f1=0.6787
# [task3] target=usage fold=0 epoch=14/30 train_loss=0.5841 train_macro_f1=n/a (mixed inputs) validation_loss=0.4994 validation_macro_f1=0.7421
# [task3] target=usage fold=0 epoch=15/30 train_loss=0.5480 train_macro_f1=n/a (mixed inputs) validation_loss=0.5451 validation_macro_f1=0.6797
# [task3] target=usage fold=0 epoch=16/30 train_loss=0.5424 train_macro_f1=n/a (mixed inputs) validation_loss=0.5022 validation_macro_f1=0.6991
# [task3] target=usage fold=0 epoch=17/30 train_loss=0.5391 train_macro_f1=n/a (mixed inputs) validation_loss=0.5229 validation_macro_f1=0.6480
# [task3] target=usage fold=0 epoch=18/30 train_loss=0.5163 train_macro_f1=n/a (mixed inputs) validation_loss=0.4557 validation_macro_f1=0.7299
# [task3] target=usage fold=0 epoch=19/30 train_loss=0.5274 train_macro_f1=n/a (mixed inputs) validation_loss=0.4696 validation_macro_f1=0.7064
# [task3] target=usage fold=0 epoch=20/30 train_loss=0.5321 train_macro_f1=n/a (mixed inputs) validation_loss=0.4431 validation_macro_f1=0.7047
# [task3] target=usage fold=0 epoch=21/30 train_loss=0.4877 train_macro_f1=n/a (mixed inputs) validation_loss=0.4403 validation_macro_f1=0.7035
# [task3] target=usage fold=0 epoch=22/30 train_loss=0.5381 train_macro_f1=n/a (mixed inputs) validation_loss=0.4377 validation_macro_f1=0.7519
# [task3] target=usage fold=0 epoch=23/30 train_loss=0.5166 train_macro_f1=n/a (mixed inputs) validation_loss=0.4233 validation_macro_f1=0.7449
# [task3] target=usage fold=0 epoch=24/30 train_loss=0.4731 train_macro_f1=n/a (mixed inputs) validation_loss=0.4252 validation_macro_f1=0.7221
# [task3] target=usage fold=0 epoch=25/30 train_loss=0.4842 train_macro_f1=n/a (mixed inputs) validation_loss=0.4149 validation_macro_f1=0.7453
# [task3] target=usage fold=0 epoch=26/30 train_loss=0.4752 train_macro_f1=n/a (mixed inputs) validation_loss=0.4174 validation_macro_f1=0.7574
# [task3] target=usage fold=0 epoch=27/30 train_loss=0.4569 train_macro_f1=n/a (mixed inputs) validation_loss=0.4126 validation_macro_f1=0.7598
# [task3] target=usage fold=0 epoch=28/30 train_loss=0.4665 train_macro_f1=n/a (mixed inputs) validation_loss=0.4077 validation_macro_f1=0.7497
# [task3] target=usage fold=0 epoch=29/30 train_loss=0.4642 train_macro_f1=n/a (mixed inputs) validation_loss=0.4079 validation_macro_f1=0.7564
# [task3] target=usage fold=0 epoch=30/30 train_loss=0.4405 train_macro_f1=n/a (mixed inputs) validation_loss=0.4077 validation_macro_f1=0.7543
# [task3] completed target=usage fold=0: t3_usage_expanded_v2_mixup_sam_usage_smallcnn_f0_s2753_dd6018a005e9_20260906T154107Z42a2aa
# Usage MixUp + SAM: fresh weights, fold 4, 30 epochs
# [task3] preparing target=usage fold=4: train=26,771 (before selection=26,771), validation=6,688
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_expanded_v2_mixup_sam_usage_smallcnn_f4_s2753_dd6018a005e9_20260906T155155Z92ec97; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=1.1582 train_macro_f1=n/a (mixed inputs) validation_loss=1.0175 validation_macro_f1=0.3343
# [task3] target=usage fold=4 epoch=2/30 train_loss=0.9162 train_macro_f1=n/a (mixed inputs) validation_loss=1.0359 validation_macro_f1=0.4568
# [task3] target=usage fold=4 epoch=3/30 train_loss=0.8148 train_macro_f1=n/a (mixed inputs) validation_loss=0.7300 validation_macro_f1=0.5379
# [task3] target=usage fold=4 epoch=4/30 train_loss=0.7625 train_macro_f1=n/a (mixed inputs) validation_loss=0.7057 validation_macro_f1=0.5771
# [task3] target=usage fold=4 epoch=5/30 train_loss=0.7373 train_macro_f1=n/a (mixed inputs) validation_loss=0.6801 validation_macro_f1=0.5587
# [task3] target=usage fold=4 epoch=6/30 train_loss=0.6981 train_macro_f1=n/a (mixed inputs) validation_loss=0.6478 validation_macro_f1=0.5792
# [task3] target=usage fold=4 epoch=7/30 train_loss=0.6775 train_macro_f1=n/a (mixed inputs) validation_loss=0.6991 validation_macro_f1=0.6258
# [task3] target=usage fold=4 epoch=8/30 train_loss=0.6663 train_macro_f1=n/a (mixed inputs) validation_loss=0.6848 validation_macro_f1=0.6137
# [task3] target=usage fold=4 epoch=9/30 train_loss=0.6386 train_macro_f1=n/a (mixed inputs) validation_loss=0.6376 validation_macro_f1=0.6148
# [task3] target=usage fold=4 epoch=10/30 train_loss=0.6365 train_macro_f1=n/a (mixed inputs) validation_loss=0.6656 validation_macro_f1=0.6432
# [task3] target=usage fold=4 epoch=11/30 train_loss=0.6097 train_macro_f1=n/a (mixed inputs) validation_loss=0.6703 validation_macro_f1=0.6344
# [task3] target=usage fold=4 epoch=12/30 train_loss=0.5682 train_macro_f1=n/a (mixed inputs) validation_loss=0.5816 validation_macro_f1=0.6701
# [task3] target=usage fold=4 epoch=13/30 train_loss=0.5843 train_macro_f1=n/a (mixed inputs) validation_loss=0.5705 validation_macro_f1=0.6989
# [task3] target=usage fold=4 epoch=14/30 train_loss=0.5687 train_macro_f1=n/a (mixed inputs) validation_loss=0.5593 validation_macro_f1=0.6693
# [task3] target=usage fold=4 epoch=15/30 train_loss=0.5556 train_macro_f1=n/a (mixed inputs) validation_loss=0.5715 validation_macro_f1=0.6624
# [task3] target=usage fold=4 epoch=16/30 train_loss=0.5162 train_macro_f1=n/a (mixed inputs) validation_loss=0.5460 validation_macro_f1=0.6506
# [task3] target=usage fold=4 epoch=17/30 train_loss=0.5250 train_macro_f1=n/a (mixed inputs) validation_loss=0.4861 validation_macro_f1=0.7436
# [task3] target=usage fold=4 epoch=18/30 train_loss=0.5036 train_macro_f1=n/a (mixed inputs) validation_loss=0.6206 validation_macro_f1=0.6260
# [task3] target=usage fold=4 epoch=19/30 train_loss=0.5481 train_macro_f1=n/a (mixed inputs) validation_loss=0.4960 validation_macro_f1=0.6840
# [task3] target=usage fold=4 epoch=20/30 train_loss=0.5061 train_macro_f1=n/a (mixed inputs) validation_loss=0.4593 validation_macro_f1=0.7369
# [task3] target=usage fold=4 epoch=21/30 train_loss=0.4792 train_macro_f1=n/a (mixed inputs) validation_loss=0.4555 validation_macro_f1=0.7129
# [task3] target=usage fold=4 epoch=22/30 train_loss=0.5164 train_macro_f1=n/a (mixed inputs) validation_loss=0.4600 validation_macro_f1=0.7027
# [task3] target=usage fold=4 epoch=23/30 train_loss=0.5124 train_macro_f1=n/a (mixed inputs) validation_loss=0.4616 validation_macro_f1=0.7467
# [task3] target=usage fold=4 epoch=24/30 train_loss=0.4420 train_macro_f1=n/a (mixed inputs) validation_loss=0.4425 validation_macro_f1=0.7392
# [task3] target=usage fold=4 epoch=25/30 train_loss=0.4798 train_macro_f1=n/a (mixed inputs) validation_loss=0.4344 validation_macro_f1=0.7339
# [task3] target=usage fold=4 epoch=26/30 train_loss=0.4832 train_macro_f1=n/a (mixed inputs) validation_loss=0.4406 validation_macro_f1=0.7346
# [task3] target=usage fold=4 epoch=27/30 train_loss=0.4563 train_macro_f1=n/a (mixed inputs) validation_loss=0.4357 validation_macro_f1=0.7511
# [task3] target=usage fold=4 epoch=28/30 train_loss=0.4674 train_macro_f1=n/a (mixed inputs) validation_loss=0.4301 validation_macro_f1=0.7434
# [task3] target=usage fold=4 epoch=29/30 train_loss=0.4518 train_macro_f1=n/a (mixed inputs) validation_loss=0.4328 validation_macro_f1=0.7504
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.4475 train_macro_f1=n/a (mixed inputs) validation_loss=0.4305 validation_macro_f1=0.7474
# [task3] completed target=usage fold=4: t3_usage_expanded_v2_mixup_sam_usage_smallcnn_f4_s2753_dd6018a005e9_20260906T155155Z92ec97
# Saved teacher comparison: /content/drive/MyDrive/MLA2/task3_usage_mixup_sam/experiments/t3_usage_expanded_v2_mixup_sam/usage/aggregate_folds_0_4/teacher_comparison.json

# %% [markdown]
# ## 5. Compare the same teacher images
#
# The primary score is macro-F1 on teacher validation images from folds 0 and 4.
# Rare-class recall shows the share found correctly. External-source scores are separate diagnostics.
#
# This trial changes MixUp and SAM together. It cannot tell us their separate effects.
# This is a development screen, and earlier holdout/test checks already exist.
# It does not start the other three folds or pick a final model.

# %%
summary = result["comparison"]
teacher = summary["sources"]["teacher"]
baseline = summary["baseline_sources"]["teacher"]
display(pd.DataFrame([
    {"Model": "Expanded v2 E8", "Teacher macro-F1": baseline["metrics"]["macro_f1"]},
    {"Model": "Fresh MixUp + SAM", "Teacher macro-F1": teacher["metrics"]["macro_f1"]},
]))
print("Same teacher validation images:", teacher["rows"])
print("Teacher macro-F1 change:", summary["teacher_macro_f1_change"])
display(pd.DataFrame(summary["fold_comparison"]))
display(pd.DataFrame(summary["teacher_per_class"]))
display(pd.DataFrame([
    {"Source": name, "Images": scope["rows"],
     "Macro-F1": scope["metrics"]["macro_f1"] if scope["metrics"] else None}
    for name, scope in summary["sources"].items()
]))
print("Result files:", Path(result["comparison_path"]).parent)
print("Run log:", result["registry_path"])
# Out:
#                Model  Teacher macro-F1
# 0     Expanded v2 E8          0.400984
# 1  Fresh MixUp + SAM          0.389790
# Same teacher validation images: 13110
# Teacher macro-F1 change: -0.011193628065483296
#    fold  baseline_teacher_f1  candidate_teacher_f1  teacher_f1_change  \
# 0     0             0.402356              0.395662          -0.006694
# 1     4             0.399614              0.382780          -0.016834
#
#    clean_teacher_train_f1  clean_teacher_gap
# 0                0.659887           0.264225
# 1                0.549982           0.167202
#      class_name  support  baseline_f1  candidate_f1  baseline_recall  \
# 0        Casual    10065     0.931530      0.929061         0.944163
# 1        Ethnic      873     0.853227      0.854935         0.855670
# 2        Formal      779     0.796519      0.774457         0.763800
# 3          Home        1     0.000000      0.000000         0.000000
# 4            NA       22     0.181818      0.233766         0.227273
# 5         Party        6     0.000000      0.000000         0.000000
# 6  Smart Casual       18     0.000000      0.000000         0.000000
# 7        Sports     1338     0.685761      0.661840         0.626308
# 8        Travel        8     0.160000      0.054054         0.250000
#
#    candidate_recall
# 0          0.949230
# 1          0.823597
# 2          0.731707
# 3          0.000000
# 4          0.409091
# 5          0.000000
# 6          0.000000
# 7          0.580717
# 8          0.125000
#            Source  Images  Macro-F1
# 0        combined   13396  0.752694
# 1         teacher   13110  0.389790
# 2  previous_added      49  0.326589
# 3       new_added     237  0.426616
# 4           added     286  0.414860
# Result files: /content/drive/MyDrive/MLA2/task3_usage_mixup_sam/experiments/t3_usage_expanded_v2_mixup_sam/usage/aggregate_folds_0_4
# Run log: /content/drive/MyDrive/MLA2/task3_usage_mixup_sam/experiments/t3_usage_expanded_v2_mixup_sam/usage/results/runs.csv

# %% [markdown]
# ## 6. Check learning curves
#
# These curves show **combined** validation scores and class-weighted losses.
# Mixed training images have no ordinary training F1. Use the clean teacher training/validation
# table above for the final gap. The curves do not select a different checkpoint.

# %%
curve_path = save_learning_curves(
    result,
    path=DRIVE_TASK_DIR / "results/figures/task3/usage_mixup_sam_learning_curves.png",
)
display(DisplayImage(filename=str(curve_path)))
print("Saved curves:", curve_path)
# Out:
# Saved curves: /content/drive/MyDrive/MLA2/task3_usage_mixup_sam/results/figures/task3/usage_mixup_sam_learning_curves.png
