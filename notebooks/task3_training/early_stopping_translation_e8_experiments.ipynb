# %% [markdown]
# # Task 3 — Early Stopping and Translation E8 Experiments
#
# This notebook trains only the two frozen E8 children. **Run All starts ten new fits:** five Gender E8G folds first, then five Usage E8U folds. It never retrains E1–E7.

# %% [markdown]
# ## 1. Mount Drive and load the submitted branch
#
# Drive supplies the teacher data, completed parent folds, persistent registry, and E8 artifacts.

# %%
from pathlib import Path
import json
import os
import subprocess
import sys
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"


def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

# %%
try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)

if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    dirty = subprocess.check_output(
        ["git", "status", "--porcelain"], cwd=REPO_DIR, text=True
    ).strip().splitlines()
    if dirty:
        print("Local repository changes found:")
        for change in dirty:
            print(f"  {change}")
        print("Trying a safe fast-forward update. Git will stop before overwriting a local file.")
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=REPO_DIR, text=True).strip()
print(f"Repository ready: {REPO_DIR}")
print(f"Branch: {BRANCH}")
print(f"Commit: {commit}")
# Out:
# Mounted at /content/drive
# $ git clone --branch task-3-gender-usage-classification --single-branch https://github.com/TrnLin/MLA2.git /content/MLA2
# Repository ready: /content/MLA2
# Branch: task-3-gender-usage-classification
# Commit: 4e4a6d85b033e38eee7f01a8609d7f8b0766543e

# %% [markdown]
# ## 2. Copy the teacher data onto the runtime disk
#
# The ZIP keeps the repository's required `data/raw/teacher` structure.

# %%
if not DATA_ZIP.is_file():
    raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_suffixes = {".jpg", ".jpeg"}

with zipfile.ZipFile(DATA_ZIP) as archive:
    names = archive.namelist()
    unsafe_names = [
        name for name in names if Path(name).is_absolute() or ".." in Path(name).parts
    ]
    if unsafe_names:
        raise RuntimeError("The dataset archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/")
        and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    if expected_images == 0:
        raise RuntimeError("The archive has no teacher images in the expected folder.")
    current_images = sum(
        path.suffix.lower() in image_suffixes for path in teacher_dir.rglob("*")
    )
    needs_extract = current_images != expected_images or not all(
        path.is_file() for path in required_files
    )
    if needs_extract:
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes for path in teacher_dir.rglob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found "
        f"{actual_images:,}; missing files: {missing_files}"
    )
print(f"Teacher data ready: {actual_images:,} images")
# Out:
# Extracting 44,441 teacher images...
# Teacher data ready: 44,441 images

# %% [markdown]
# ## 3. Resolve the completed parents and verify E8
#
# These checks build each frozen model and verify both single-factor contracts. They create no optimizer and take no training step.

# %%
os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)

for output_dir in (
    DRIVE_TASK_DIR / "experiments",
    DRIVE_TASK_DIR / "logs",
    DRIVE_TASK_DIR / "results",
):
    output_dir.mkdir(parents=True, exist_ok=True)

from fashion.train.task3_experiments import (
    check_task3_child_setup,
    latest_completed_gender_e6_parent_run_ids,
    latest_completed_usage_e2_parent_run_ids,
)

gender_parent_run_ids = latest_completed_gender_e6_parent_run_ids(
    output_root=DRIVE_TASK_DIR
)
usage_parent_run_ids = latest_completed_usage_e2_parent_run_ids(
    output_root=DRIVE_TASK_DIR
)
gender_e8_check = check_task3_child_setup(
    "gender_gem_p3_early_stopping",
    parent_run_ids=gender_parent_run_ids,
    root=REPO_DIR,
    device_name="cuda",
)
usage_e8_check = check_task3_child_setup(
    "usage_translation_2px",
    parent_run_ids=usage_parent_run_ids,
    root=REPO_DIR,
    device_name="cuda",
)

gender_child = gender_e8_check["child"]
if gender_e8_check["model_family"] != "task3_small_cnn_gem_p3":
    raise RuntimeError("Gender E8 must keep the E6 GeM model")
if gender_e8_check["parameter_count"] != 390_181:
    raise RuntimeError("Gender E8 parameter contract changed")
if gender_child["checkpoint_policy"] != "best_validation_macro_f1":
    raise RuntimeError("Gender E8 checkpoint policy changed")
if (
    gender_child["early_stopping_min_epoch"],
    gender_child["early_stopping_patience"],
    gender_child["early_stopping_min_delta"],
) != (15, 10, 0.001):
    raise RuntimeError("Gender E8 early-stopping contract changed")

usage_child = usage_e8_check["child"]
if usage_e8_check["model_family"] != "task3_small_cnn":
    raise RuntimeError("Usage E8 must keep the accepted E2 SmallCNN")
if usage_e8_check["parameter_count"] != 391_209:
    raise RuntimeError("Usage E8 parameter contract changed")
if usage_child["training_augmentation"] != "translation_uniform_2px_p05":
    raise RuntimeError("Usage E8 translation contract changed")
if usage_child["class_weight_beta"] != 0.999 or usage_child["class_weight_cap"] != 5.0:
    raise RuntimeError("Usage E8 must keep the accepted E2 class weights")

print("GPU:", gender_e8_check["environment"]["gpu"])
print("Gender E6 parents:", gender_parent_run_ids)
print("Usage E2 parents: ", usage_parent_run_ids)
print("Optimizer steps during checks:", gender_e8_check["optimizer_steps"], usage_e8_check["optimizer_steps"])
# Out:
# GPU: NVIDIA L4
# Gender E6 parents: ('t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f', 't3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5', 't3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677', 't3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a', 't3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd')
# Usage E2 parents:  ('t3_usage_e2_class_balanced_ce_usage_smallcnn_f0_s2753_5461e048c3b3_20260830T115815Z356f6d', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f1_s2753_5461e048c3b3_20260830T120645Z6d08cd', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f2_s2753_5461e048c3b3_20260830T121514Zd58aa0', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f3_s2753_5461e048c3b3_20260830T122347Z2cb06e', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f4_s2753_5461e048c3b3_20260830T123218Z94db47')
# Optimizer steps during checks: 0 0

# %% [markdown]
# ## 4. Train Gender E8G: best-checkpoint early stopping
#
# This keeps E6 GeM unchanged. It changes only checkpoint selection and the stopping rule.

# %%
from fashion.train.task3_experiments import (
    audit_completed_registry_rows,
    run_task3_child_cv,
)

gender_e8_result = run_task3_child_cv(
    "gender_gem_p3_early_stopping",
    parent_run_ids=gender_parent_run_ids,
    folds=range(5),
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[REPO_DIR / "results/runs.csv"],
    device_name="cuda",
)
gender_e8_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, gender_e8_result["fold_run_ids"]
)
{
    "metrics_path": gender_e8_result["metrics_path"],
    "macro_f1": gender_e8_result["metrics"]["macro_f1"],
    "registry_audit": gender_e8_registry_audit,
}
# Out:
# [task3] starting five-fold experiment=t3_gender_gem_p3_early_stopping for target=gender
# [task3] preparing target=gender fold=0: train=26,220, validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_e8_early_stopping_gender_smallcnngem3_f0_s2753_ff453782ef53_20260831T164841Z983ec7; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.5536 train_macro_f1=0.4868 validation_loss=0.5575 validation_macro_f1=0.3516
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.0039 train_macro_f1=0.9999 validation_loss=0.4473 validation_macro_f1=0.7188
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.0038 train_macro_f1=0.9998 validation_loss=0.4433 validation_macro_f1=0.7185
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.0034 train_macro_f1=0.9999 validation_loss=0.4486 validation_macro_f1=0.7180
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.0033 train_macro_f1=0.9998 validation_loss=0.4498 validation_macro_f1=0.7205
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.0032 train_macro_f1=0.9999 validation_loss=0.4538 validation_macro_f1=0.7153
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.0031 train_macro_f1=0.9998 validation_loss=0.4555 validation_macro_f1=0.7196
# [task3] completed target=gender fold=0: t3_gender_e8_early_stopping_gender_smallcnngem3_f0_s2753_ff453782ef53_20260831T164841Z983ec7
# [task3] preparing target=gender fold=1: train=26,217, validation=6,556
# [task3] fitting fold-training RGB statistics for target=gender fold=1
# [task3] RGB statistics ready for target=gender fold=1
# [task3] registered t3_gender_e8_early_stopping_gender_smallcnngem3_f1_s2753_ff453782ef53_20260831T165721Z3a256d; the first optimiser step may now run
# [task3] target=gender fold=1 epoch=1/30 train_loss=0.5584 train_macro_f1=0.4929 validation_loss=0.5762 validation_macro_f1=0.5247
# [task3] target=gender fold=1 epoch=2/30 train_loss=0.4055 train_macro_f1=0.6440 validation_loss=0.4208 validation_macro_f1=0.6423
# [task3] target=gender fold=1 epoch=3/30 train_loss=0.3498 train_macro_f1=0.6929 validation_loss=0.4034 validation_macro_f1=0.5919
# [task3] target=gender fold=1 epoch=4/30 train_loss=0.3117 train_macro_f1=0.7403 validation_loss=0.4259 validation_macro_f1=0.6541
# [task3] target=gender fold=1 epoch=5/30 train_loss=0.2707 train_macro_f1=0.7798 validation_loss=0.5702 validation_macro_f1=0.6099
# [task3] target=gender fold=1 epoch=6/30 train_loss=0.2451 train_macro_f1=0.8021 validation_loss=0.3867 validation_macro_f1=0.6297
# [task3] target=gender fold=1 epoch=7/30 train_loss=0.2115 train_macro_f1=0.8313 validation_loss=0.4853 validation_macro_f1=0.5132
# [task3] target=gender fold=1 epoch=8/30 train_loss=0.1782 train_macro_f1=0.8640 validation_loss=0.4827 validation_macro_f1=0.5757
# [task3] target=gender fold=1 epoch=9/30 train_loss=0.1445 train_macro_f1=0.8965 validation_loss=0.3856 validation_macro_f1=0.7124
# [task3] target=gender fold=1 epoch=10/30 train_loss=0.1194 train_macro_f1=0.9221 validation_loss=0.4261 validation_macro_f1=0.6946
# [task3] target=gender fold=1 epoch=11/30 train_loss=0.0943 train_macro_f1=0.9375 validation_loss=0.5229 validation_macro_f1=0.6370
# [task3] target=gender fold=1 epoch=12/30 train_loss=0.0677 train_macro_f1=0.9678 validation_loss=0.3785 validation_macro_f1=0.7208
# [task3] target=gender fold=1 epoch=13/30 train_loss=0.0517 train_macro_f1=0.9757 validation_loss=0.4911 validation_macro_f1=0.6860
# [task3] target=gender fold=1 epoch=14/30 train_loss=0.0382 train_macro_f1=0.9841 validation_loss=0.4120 validation_macro_f1=0.7007
# [task3] target=gender fold=1 epoch=15/30 train_loss=0.0272 train_macro_f1=0.9931 validation_loss=0.4747 validation_macro_f1=0.6917
# [task3] target=gender fold=1 epoch=16/30 train_loss=0.0190 train_macro_f1=0.9973 validation_loss=0.4285 validation_macro_f1=0.7184
# [task3] target=gender fold=1 epoch=17/30 train_loss=0.0157 train_macro_f1=0.9980 validation_loss=0.4203 validation_macro_f1=0.7144
# [task3] target=gender fold=1 epoch=18/30 train_loss=0.0105 train_macro_f1=0.9993 validation_loss=0.5717 validation_macro_f1=0.6809
# [task3] target=gender fold=1 epoch=19/30 train_loss=0.0081 train_macro_f1=0.9998 validation_loss=0.4462 validation_macro_f1=0.7141
# [task3] target=gender fold=1 epoch=20/30 train_loss=0.0069 train_macro_f1=0.9997 validation_loss=0.4292 validation_macro_f1=0.7299
# [task3] target=gender fold=1 epoch=21/30 train_loss=0.0064 train_macro_f1=0.9997 validation_loss=0.3921 validation_macro_f1=0.7476
# [task3] target=gender fold=1 epoch=22/30 train_loss=0.0048 train_macro_f1=0.9999 validation_loss=0.3962 validation_macro_f1=0.7349
# [task3] target=gender fold=1 epoch=23/30 train_loss=0.0044 train_macro_f1=0.9999 validation_loss=0.4191 validation_macro_f1=0.7463
# [task3] target=gender fold=1 epoch=24/30 train_loss=0.0039 train_macro_f1=0.9999 validation_loss=0.4107 validation_macro_f1=0.7407
# [task3] target=gender fold=1 epoch=25/30 train_loss=0.0036 train_macro_f1=0.9999 validation_loss=0.4111 validation_macro_f1=0.7422
# [task3] target=gender fold=1 epoch=26/30 train_loss=0.0036 train_macro_f1=0.9998 validation_loss=0.4093 validation_macro_f1=0.7364
# [task3] target=gender fold=1 epoch=27/30 train_loss=0.0032 train_macro_f1=0.9998 validation_loss=0.4201 validation_macro_f1=0.7379
# [task3] target=gender fold=1 epoch=28/30 train_loss=0.0030 train_macro_f1=0.9999 validation_loss=0.4261 validation_macro_f1=0.7436
# [task3] target=gender fold=1 epoch=29/30 train_loss=0.0029 train_macro_f1=0.9999 validation_loss=0.4230 validation_macro_f1=0.7402
# [task3] target=gender fold=1 epoch=30/30 train_loss=0.0029 train_macro_f1=0.9999 validation_loss=0.4178 validation_macro_f1=0.7426
# [task3] completed target=gender fold=1: t3_gender_e8_early_stopping_gender_smallcnngem3_f1_s2753_ff453782ef53_20260831T165721Z3a256d
# [task3] preparing target=gender fold=2: train=26,220, validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=2
# [task3] RGB statistics ready for target=gender fold=2
# [task3] registered t3_gender_e8_early_stopping_gender_smallcnngem3_f2_s2753_ff453782ef53_20260831T170603Zdaa448; the first optimiser step may now run
# [task3] target=gender fold=2 epoch=1/30 train_loss=0.5582 train_macro_f1=0.4679 validation_loss=0.4615 validation_macro_f1=0.6014
# [task3] target=gender fold=2 epoch=2/30 train_loss=0.4125 train_macro_f1=0.6317 validation_loss=0.4972 validation_macro_f1=0.5841
# [task3] target=gender fold=2 epoch=26/30 train_loss=0.0038 train_macro_f1=0.9998 validation_loss=0.4240 validation_macro_f1=0.7331
# [task3] target=gender fold=2 epoch=27/30 train_loss=0.0034 train_macro_f1=0.9999 validation_loss=0.4174 validation_macro_f1=0.7287
# [task3] target=gender fold=2 epoch=28/30 train_loss=0.0033 train_macro_f1=0.9999 validation_loss=0.4230 validation_macro_f1=0.7315
# [task3] target=gender fold=2 epoch=29/30 train_loss=0.0032 train_macro_f1=0.9999 validation_loss=0.4164 validation_macro_f1=0.7317
# [task3] target=gender fold=2 epoch=30/30 train_loss=0.0032 train_macro_f1=1.0000 validation_loss=0.4204 validation_macro_f1=0.7287
# [task3] early stopping target=gender fold=2 at epoch=30; selected_epoch=20 selected_validation_macro_f1=0.7352
# [task3] completed target=gender fold=2: t3_gender_e8_early_stopping_gender_smallcnngem3_f2_s2753_ff453782ef53_20260831T170603Zdaa448
# [task3] preparing target=gender fold=3: train=26,219, validation=6,554
# [task3] fitting fold-training RGB statistics for target=gender fold=3
# [task3] RGB statistics ready for target=gender fold=3
# [task3] registered t3_gender_e8_early_stopping_gender_smallcnngem3_f3_s2753_ff453782ef53_20260831T171445Z9426a0; the first optimiser step may now run
# [task3] target=gender fold=3 epoch=1/30 train_loss=0.5569 train_macro_f1=0.4701 validation_loss=0.4817 validation_macro_f1=0.5967
# [task3] target=gender fold=3 epoch=2/30 train_loss=0.4122 train_macro_f1=0.6260 validation_loss=0.4109 validation_macro_f1=0.6183
# [task3] target=gender fold=3 epoch=3/30 train_loss=0.3592 train_macro_f1=0.6840 validation_loss=0.3721 validation_macro_f1=0.6725
# [task3] target=gender fold=3 epoch=4/30 train_loss=0.3209 train_macro_f1=0.7203 validation_loss=0.4003 validation_macro_f1=0.6545
# [task3] target=gender fold=3 epoch=5/30 train_loss=0.2826 train_macro_f1=0.7618 validation_loss=0.3578 validation_macro_f1=0.6386
# [task3] target=gender fold=3 epoch=6/30 train_loss=0.2522 train_macro_f1=0.7957 validation_loss=0.3624 validation_macro_f1=0.6838
# [task3] target=gender fold=3 epoch=7/30 train_loss=0.2194 train_macro_f1=0.8236 validation_loss=0.3877 validation_macro_f1=0.7047
# [task3] target=gender fold=3 epoch=8/30 train_loss=0.1856 train_macro_f1=0.8569 validation_loss=0.4409 validation_macro_f1=0.7007
# [task3] target=gender fold=3 epoch=9/30 train_loss=0.1650 train_macro_f1=0.8823 validation_loss=0.3833 validation_macro_f1=0.6481
# [task3] target=gender fold=3 epoch=10/30 train_loss=0.1287 train_macro_f1=0.9097 validation_loss=0.3292 validation_macro_f1=0.7400
# [task3] target=gender fold=3 epoch=11/30 train_loss=0.1003 train_macro_f1=0.9352 validation_loss=0.3609 validation_macro_f1=0.7443
# [task3] target=gender fold=3 epoch=12/30 train_loss=0.0825 train_macro_f1=0.9528 validation_loss=0.3597 validation_macro_f1=0.7283
# [task3] target=gender fold=3 epoch=13/30 train_loss=0.0595 train_macro_f1=0.9684 validation_loss=0.4078 validation_macro_f1=0.7276
# [task3] target=gender fold=3 epoch=14/30 train_loss=0.0430 train_macro_f1=0.9814 validation_loss=0.3818 validation_macro_f1=0.7204
# [task3] target=gender fold=3 epoch=15/30 train_loss=0.0296 train_macro_f1=0.9917 validation_loss=0.4178 validation_macro_f1=0.7316
# [task3] target=gender fold=3 epoch=16/30 train_loss=0.0211 train_macro_f1=0.9956 validation_loss=0.5422 validation_macro_f1=0.7090
# [task3] target=gender fold=3 epoch=17/30 train_loss=0.0169 train_macro_f1=0.9976 validation_loss=0.3943 validation_macro_f1=0.7241
# [task3] target=gender fold=3 epoch=18/30 train_loss=0.0118 train_macro_f1=0.9992 validation_loss=0.4122 validation_macro_f1=0.7294
# [task3] target=gender fold=3 epoch=19/30 train_loss=0.0087 train_macro_f1=0.9998 validation_loss=0.3989 validation_macro_f1=0.7529
# [task3] target=gender fold=3 epoch=20/30 train_loss=0.0072 train_macro_f1=0.9998 validation_loss=0.4215 validation_macro_f1=0.7323
# [task3] target=gender fold=3 epoch=21/30 train_loss=0.0060 train_macro_f1=1.0000 validation_loss=0.3986 validation_macro_f1=0.7530
# [task3] target=gender fold=3 epoch=22/30 train_loss=0.0052 train_macro_f1=1.0000 validation_loss=0.4349 validation_macro_f1=0.7367
# [task3] target=gender fold=3 epoch=23/30 train_loss=0.0045 train_macro_f1=1.0000 validation_loss=0.4068 validation_macro_f1=0.7560
# [task3] target=gender fold=3 epoch=24/30 train_loss=0.0041 train_macro_f1=1.0000 validation_loss=0.4467 validation_macro_f1=0.7477
# [task3] target=gender fold=3 epoch=25/30 train_loss=0.0038 train_macro_f1=1.0000 validation_loss=0.4340 validation_macro_f1=0.7433
# [task3] target=gender fold=3 epoch=26/30 train_loss=0.0035 train_macro_f1=1.0000 validation_loss=0.4206 validation_macro_f1=0.7494
# [task3] target=gender fold=3 epoch=27/30 train_loss=0.0033 train_macro_f1=1.0000 validation_loss=0.4209 validation_macro_f1=0.7586
# [task3] target=gender fold=3 epoch=28/30 train_loss=0.0032 train_macro_f1=1.0000 validation_loss=0.4285 validation_macro_f1=0.7481
# [task3] target=gender fold=3 epoch=29/30 train_loss=0.0031 train_macro_f1=1.0000 validation_loss=0.4257 validation_macro_f1=0.7562
# [task3] target=gender fold=3 epoch=30/30 train_loss=0.0030 train_macro_f1=1.0000 validation_loss=0.4292 validation_macro_f1=0.7495
# [task3] completed target=gender fold=3: t3_gender_e8_early_stopping_gender_smallcnngem3_f3_s2753_ff453782ef53_20260831T171445Z9426a0
# [task3] preparing target=gender fold=4: train=26,216, validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_e8_early_stopping_gender_smallcnngem3_f4_s2753_ff453782ef53_20260831T172328Z9bb1b2; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.5592 train_macro_f1=0.4581 validation_loss=0.5157 validation_macro_f1=0.5397
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.4056 train_macro_f1=0.6289 validation_loss=0.4297 validation_macro_f1=0.6270
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.3511 train_macro_f1=0.6938 validation_loss=0.3701 validation_macro_f1=0.6649
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.0034 train_macro_f1=0.9998 validation_loss=0.4435 validation_macro_f1=0.7227
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.0032 train_macro_f1=0.9998 validation_loss=0.4345 validation_macro_f1=0.7255
# [task3] early stopping target=gender fold=4 at epoch=27; selected_epoch=17 selected_validation_macro_f1=0.7400
# [task3] completed target=gender fold=4: t3_gender_e8_early_stopping_gender_smallcnngem3_f4_s2753_ff453782ef53_20260831T172328Z9bb1b2
# [task3] completed pooled five-fold OOF experiment=t3_gender_gem_p3_early_stopping target=gender
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_gender_e8_early_stopping/gender/aggregate/metrics.json',
#  'macro_f1': 0.7411986031235207,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_gender_e8_early_stopping_gender_smallcnngem3_f0_s2753_ff453782ef53_20260831T164841Z983ec7',
#    't3_gender_e8_early_stopping_gender_smallcnngem3_f1_s2753_ff453782ef53_20260831T165721Z3a256d',
#    't3_gender_e8_early_stopping_gender_smallcnngem3_f2_s2753_ff453782ef53_20260831T170603Zdaa448',
#    't3_gender_e8_early_stopping_gender_smallcnngem3_f3_s2753_ff453782ef53_20260831T171445Z9426a0',
#    't3_gender_e8_early_stopping_gender_smallcnngem3_f4_s2753_ff453782ef53_20260831T172328Z9bb1b2'],
#   'completed_rows': 5,
#   'ready': True}}

# %% [markdown]
# ## 5. Train Usage E8U: two-pixel translation
#
# This keeps accepted E2 unchanged except for the frozen training-only translation.

# %%
usage_e8_result = run_task3_child_cv(
    "usage_translation_2px",
    parent_run_ids=usage_parent_run_ids,
    folds=range(5),
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[REPO_DIR / "results/runs.csv"],
    device_name="cuda",
)
usage_e8_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, usage_e8_result["fold_run_ids"]
)
{
    "metrics_path": usage_e8_result["metrics_path"],
    "macro_f1": usage_e8_result["metrics"]["macro_f1"],
    "macro_f1_without_home": usage_e8_result["metrics"]["macro_f1_without_home"],
    "registry_audit": usage_e8_registry_audit,
}
# Out:
# [task3] starting five-fold experiment=t3_usage_translation_2px_smallcnn for target=usage
# [task3] preparing target=usage fold=0: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_e8_translation_usage_smallcnn_f0_s2753_be3cf562b9ab_20260831T173123Zd848db; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=1.2437 train_macro_f1=0.1550 validation_loss=1.1730 validation_macro_f1=0.1835
# [task3] target=usage fold=0 epoch=2/30 train_loss=1.1132 train_macro_f1=0.2447 validation_loss=1.0069 validation_macro_f1=0.2584
# [task3] target=usage fold=0 epoch=3/30 train_loss=0.9688 train_macro_f1=0.2851 validation_loss=0.8756 validation_macro_f1=0.2999
# [task3] target=usage fold=0 epoch=4/30 train_loss=0.8774 train_macro_f1=0.3019 validation_loss=0.9118 validation_macro_f1=0.2993
# [task3] target=usage fold=1 epoch=16/30 train_loss=0.4083 train_macro_f1=0.5945 validation_loss=0.7631 validation_macro_f1=0.3300
# [task3] target=usage fold=1 epoch=17/30 train_loss=0.3856 train_macro_f1=0.6387 validation_loss=0.8064 validation_macro_f1=0.3647
# [task3] target=usage fold=1 epoch=18/30 train_loss=0.3456 train_macro_f1=0.6668 validation_loss=0.9323 validation_macro_f1=0.3577
# [task3] target=usage fold=1 epoch=19/30 train_loss=0.3484 train_macro_f1=0.6446 validation_loss=0.8336 validation_macro_f1=0.3645
# [task3] target=usage fold=1 epoch=20/30 train_loss=0.3362 train_macro_f1=0.6815 validation_loss=0.8225 validation_macro_f1=0.3676
# [task3] target=usage fold=1 epoch=21/30 train_loss=0.3072 train_macro_f1=0.7191 validation_loss=0.7801 validation_macro_f1=0.4012
# [task3] target=usage fold=1 epoch=22/30 train_loss=0.3007 train_macro_f1=0.7181 validation_loss=0.7663 validation_macro_f1=0.3902
# [task3] target=usage fold=1 epoch=23/30 train_loss=0.2924 train_macro_f1=0.7409 validation_loss=0.7878 validation_macro_f1=0.3874
# [task3] target=usage fold=1 epoch=24/30 train_loss=0.2937 train_macro_f1=0.7377 validation_loss=0.8212 validation_macro_f1=0.3997
# [task3] target=usage fold=1 epoch=25/30 train_loss=0.2708 train_macro_f1=0.7907 validation_loss=0.8197 validation_macro_f1=0.4033
# [task3] target=usage fold=1 epoch=26/30 train_loss=0.2616 train_macro_f1=0.7932 validation_loss=0.8177 validation_macro_f1=0.4090
# [task3] target=usage fold=1 epoch=27/30 train_loss=0.2613 train_macro_f1=0.7826 validation_loss=0.8445 validation_macro_f1=0.3896
# [task3] target=usage fold=1 epoch=28/30 train_loss=0.2546 train_macro_f1=0.8028 validation_loss=0.8003 validation_macro_f1=0.4073
# [task3] target=usage fold=1 epoch=29/30 train_loss=0.2594 train_macro_f1=0.7892 validation_loss=0.8024 validation_macro_f1=0.4018
# [task3] target=usage fold=1 epoch=30/30 train_loss=0.2530 train_macro_f1=0.7841 validation_loss=0.8291 validation_macro_f1=0.3868
# [task3] completed target=usage fold=1: t3_usage_e8_translation_usage_smallcnn_f1_s2753_be3cf562b9ab_20260831T174039Zabd68d
# [task3] preparing target=usage fold=2: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=2
# [task3] RGB statistics ready for target=usage fold=2
# [task3] registered t3_usage_e8_translation_usage_smallcnn_f2_s2753_be3cf562b9ab_20260831T174953Z528158; the first optimiser step may now run
# [task3] target=usage fold=2 epoch=1/30 train_loss=1.2067 train_macro_f1=0.1506 validation_loss=1.0724 validation_macro_f1=0.1388
# [task3] target=usage fold=2 epoch=2/30 train_loss=1.1262 train_macro_f1=0.2432 validation_loss=1.0625 validation_macro_f1=0.1754
# [task3] target=usage fold=2 epoch=3/30 train_loss=0.9407 train_macro_f1=0.2917 validation_loss=1.0000 validation_macro_f1=0.2713
# [task3] target=usage fold=2 epoch=4/30 train_loss=0.8799 train_macro_f1=0.3110 validation_loss=1.1808 validation_macro_f1=0.2209
# [task3] target=usage fold=2 epoch=5/30 train_loss=0.8362 train_macro_f1=0.3087 validation_loss=0.9069 validation_macro_f1=0.3259
# [task3] target=usage fold=2 epoch=28/30 train_loss=0.2605 train_macro_f1=0.7732 validation_loss=0.8340 validation_macro_f1=0.4485
# [task3] target=usage fold=2 epoch=29/30 train_loss=0.2578 train_macro_f1=0.7972 validation_loss=0.8048 validation_macro_f1=0.4489
# [task3] target=usage fold=2 epoch=30/30 train_loss=0.2559 train_macro_f1=0.7911 validation_loss=0.7978 validation_macro_f1=0.4420
# [task3] completed target=usage fold=2: t3_usage_e8_translation_usage_smallcnn_f2_s2753_be3cf562b9ab_20260831T174953Z528158
# [task3] preparing target=usage fold=3: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=3
# [task3] RGB statistics ready for target=usage fold=3
# [task3] registered t3_usage_e8_translation_usage_smallcnn_f3_s2753_be3cf562b9ab_20260831T175907Z3587b1; the first optimiser step may now run
# [task3] target=usage fold=3 epoch=1/30 train_loss=1.2936 train_macro_f1=0.1593 validation_loss=1.1570 validation_macro_f1=0.1923
# [task3] target=usage fold=3 epoch=2/30 train_loss=1.0355 train_macro_f1=0.2512 validation_loss=1.1339 validation_macro_f1=0.1918
# [task3] target=usage fold=3 epoch=3/30 train_loss=0.9468 train_macro_f1=0.2799 validation_loss=1.1508 validation_macro_f1=0.2400
# [task3] target=usage fold=3 epoch=4/30 train_loss=0.8995 train_macro_f1=0.2996 validation_loss=0.9538 validation_macro_f1=0.2848
# [task3] target=usage fold=3 epoch=5/30 train_loss=0.8292 train_macro_f1=0.3196 validation_loss=0.9485 validation_macro_f1=0.3124
# [task3] target=usage fold=3 epoch=6/30 train_loss=0.7393 train_macro_f1=0.3535 validation_loss=0.9496 validation_macro_f1=0.3124
# [task3] target=usage fold=3 epoch=7/30 train_loss=0.7115 train_macro_f1=0.3464 validation_loss=1.0690 validation_macro_f1=0.3076
# [task3] target=usage fold=3 epoch=8/30 train_loss=0.6941 train_macro_f1=0.3614 validation_loss=0.8905 validation_macro_f1=0.3215
# [task3] target=usage fold=3 epoch=9/30 train_loss=0.6280 train_macro_f1=0.4934 validation_loss=0.8958 validation_macro_f1=0.3252
# [task3] target=usage fold=3 epoch=10/30 train_loss=0.5584 train_macro_f1=0.5170 validation_loss=0.9586 validation_macro_f1=0.2756
# [task3] target=usage fold=3 epoch=11/30 train_loss=0.5303 train_macro_f1=0.5266 validation_loss=0.9725 validation_macro_f1=0.3269
# [task3] target=usage fold=3 epoch=12/30 train_loss=0.4968 train_macro_f1=0.5345 validation_loss=0.8515 validation_macro_f1=0.3388
# [task3] target=usage fold=3 epoch=13/30 train_loss=0.4739 train_macro_f1=0.5637 validation_loss=0.8923 validation_macro_f1=0.3374
# [task3] target=usage fold=3 epoch=14/30 train_loss=0.4512 train_macro_f1=0.5839 validation_loss=1.0051 validation_macro_f1=0.3130
# [task3] target=usage fold=3 epoch=15/30 train_loss=0.4264 train_macro_f1=0.5818 validation_loss=0.9195 validation_macro_f1=0.3332
# [task3] target=usage fold=3 epoch=16/30 train_loss=0.4008 train_macro_f1=0.5956 validation_loss=0.8884 validation_macro_f1=0.3568
# [task3] target=usage fold=3 epoch=17/30 train_loss=0.3870 train_macro_f1=0.6004 validation_loss=1.0161 validation_macro_f1=0.3911
# [task3] target=usage fold=3 epoch=18/30 train_loss=0.3610 train_macro_f1=0.6639 validation_loss=0.8129 validation_macro_f1=0.3829
# [task3] target=usage fold=3 epoch=19/30 train_loss=0.3564 train_macro_f1=0.6417 validation_loss=0.8680 validation_macro_f1=0.4006
# [task3] target=usage fold=3 epoch=20/30 train_loss=0.3269 train_macro_f1=0.6524 validation_loss=0.8991 validation_macro_f1=0.3917
# [task3] target=usage fold=3 epoch=21/30 train_loss=0.3183 train_macro_f1=0.6791 validation_loss=0.8295 validation_macro_f1=0.3841
# [task3] target=usage fold=3 epoch=22/30 train_loss=0.3009 train_macro_f1=0.7072 validation_loss=0.8872 validation_macro_f1=0.3977
# [task3] target=usage fold=3 epoch=23/30 train_loss=0.2954 train_macro_f1=0.7072 validation_loss=0.9143 validation_macro_f1=0.4136
# [task3] target=usage fold=3 epoch=24/30 train_loss=0.2825 train_macro_f1=0.7452 validation_loss=0.8838 validation_macro_f1=0.3797
# [task3] target=usage fold=3 epoch=25/30 train_loss=0.2718 train_macro_f1=0.7474 validation_loss=0.8691 validation_macro_f1=0.4297
# [task3] target=usage fold=3 epoch=26/30 train_loss=0.2752 train_macro_f1=0.7369 validation_loss=0.8979 validation_macro_f1=0.4387
# [task3] target=usage fold=3 epoch=27/30 train_loss=0.2677 train_macro_f1=0.7515 validation_loss=0.8818 validation_macro_f1=0.4308
# [task3] target=usage fold=3 epoch=28/30 train_loss=0.2600 train_macro_f1=0.7526 validation_loss=0.8714 validation_macro_f1=0.4376
# [task3] target=usage fold=3 epoch=29/30 train_loss=0.2597 train_macro_f1=0.7661 validation_loss=0.8681 validation_macro_f1=0.4127
# [task3] target=usage fold=3 epoch=30/30 train_loss=0.2564 train_macro_f1=0.7835 validation_loss=0.8726 validation_macro_f1=0.4137
# [task3] completed target=usage fold=3: t3_usage_e8_translation_usage_smallcnn_f3_s2753_be3cf562b9ab_20260831T175907Z3587b1
# [task3] preparing target=usage fold=4: train=26,215, validation=6,557
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_e8_translation_usage_smallcnn_f4_s2753_be3cf562b9ab_20260831T180832Z708926; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=1.1667 train_macro_f1=0.1496 validation_loss=1.1132 validation_macro_f1=0.2416
# [task3] target=usage fold=4 epoch=2/30 train_loss=0.9596 train_macro_f1=0.2546 validation_loss=1.1450 validation_macro_f1=0.1968
# [task3] target=usage fold=4 epoch=3/30 train_loss=0.8703 train_macro_f1=0.2965 validation_loss=1.5028 validation_macro_f1=0.1897
# [task3] target=usage fold=4 epoch=4/30 train_loss=0.8244 train_macro_f1=0.3104 validation_loss=1.2616 validation_macro_f1=0.2161
# [task3] target=usage fold=4 epoch=5/30 train_loss=0.7646 train_macro_f1=0.3288 validation_loss=0.9492 validation_macro_f1=0.2979
# [task3] target=usage fold=4 epoch=6/30 train_loss=0.7420 train_macro_f1=0.3402 validation_loss=0.9324 validation_macro_f1=0.3151
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.2584 train_macro_f1=0.6862 validation_loss=0.7397 validation_macro_f1=0.3912
# [task3] completed target=usage fold=4: t3_usage_e8_translation_usage_smallcnn_f4_s2753_be3cf562b9ab_20260831T180832Z708926
# [task3] completed pooled five-fold OOF experiment=t3_usage_translation_2px_smallcnn target=usage
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_usage_e8_translation/usage/aggregate/metrics.json',
#  'macro_f1': 0.41939320264210234,
#  'macro_f1_without_home': 0.47181735297236516,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_usage_e8_translation_usage_smallcnn_f0_s2753_be3cf562b9ab_20260831T173123Zd848db',
#    't3_usage_e8_translation_usage_smallcnn_f1_s2753_be3cf562b9ab_20260831T174039Zabd68d',
#    't3_usage_e8_translation_usage_smallcnn_f2_s2753_be3cf562b9ab_20260831T174953Z528158',
#    't3_usage_e8_translation_usage_smallcnn_f3_s2753_be3cf562b9ab_20260831T175907Z3587b1',
#    't3_usage_e8_translation_usage_smallcnn_f4_s2753_be3cf562b9ab_20260831T180832Z708926'],
#   'completed_rows': 5,
#   'ready': True}}

# %% [markdown]
# ## 6. Confirm the saved E8 artifacts
#
# This is a factual training summary only. The frozen gates are applied in the main Task 3 notebook.

# %%
import pandas as pd

parent_metric_paths = {
    "gender": DRIVE_TASK_DIR / "experiments/t3_gender_e6_gem_p3/gender/aggregate/metrics.json",
    "usage": DRIVE_TASK_DIR / "experiments/t3_usage_e2_class_balanced_ce/usage/aggregate/metrics.json",
}
children = {"gender": gender_e8_result, "usage": usage_e8_result}
comparison = []
for target, child in children.items():
    parent = json.loads(parent_metric_paths[target].read_text(encoding="utf-8"))
    fold_metrics = []
    for run_id in child["fold_run_ids"]:
        run_dir = Path(child["metrics_path"]).parent.parent / run_id
        fold_metrics.append(json.loads((run_dir / "metrics.json").read_text(encoding="utf-8")))
    comparison.append(
        {
            "target": target,
            "parent_macro_f1": parent["macro_f1"],
            "e8_macro_f1": child["metrics"]["macro_f1"],
            "macro_f1_change": child["metrics"]["macro_f1"] - parent["macro_f1"],
            "selected_epochs": [metrics["selected_epoch"] for metrics in fold_metrics],
            "epochs_completed": [metrics["epochs_completed"] for metrics in fold_metrics],
            "maximum_peak_memory_gib": max(
                metrics["peak_memory_bytes"] for metrics in fold_metrics
            ) / (1024 ** 3),
            "e8_metrics_path": child["metrics_path"],
        }
    )
pd.DataFrame(comparison)
# Out:
#    target  parent_macro_f1  e8_macro_f1  macro_f1_change  \
# 0  gender         0.733521     0.741199         0.007678
# 1   usage         0.408171     0.419393         0.011223
#
#         selected_epochs      epochs_completed  maximum_peak_memory_gib  \
# 0  [22, 21, 20, 27, 17]  [30, 30, 30, 30, 27]                 0.443352
# 1  [30, 30, 30, 30, 30]  [30, 30, 30, 30, 30]                 0.419200
#
#                                      e8_metrics_path
# 0  /content/drive/MyDrive/MLA2/task3/experiments/...
# 1  /content/drive/MyDrive/MLA2/task3/experiments/...
