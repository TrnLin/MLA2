# %% [markdown]
# # Task 3 — Stronger MixUp screen
#
# Test whether **MixUp alpha 0.4** reduces the remaining clean gap beyond the completed **04af alpha 0.2** models. Run All trains **folds 0 and 4 only**, for **30 epochs**, from scratch. The only training change is MixUp strength.
#
# Use a **fresh Colab L4** matching the previous runs. Push this notebook and its source files first. The completed 04af runs, their earlier parents and 04w precision evidence must be on Drive.
#
# A zero gap is not the goal at the cost of a model that learns too little. This screen requires a smaller clean gap while protecting validation F1 and Unisex recall.

# %% [markdown]
# ## 1. Colab GPU and repository

# %%
import os
import shutil
import subprocess
import sys
import time
import zipfile
from pathlib import Path

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
LOCAL_DATA_ZIP = Path("/content/task3-data.zip")
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"


def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)


try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab GPU runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)
if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=REPO_DIR, text=True).strip()
print("Repository ready:", REPO_DIR)
print("Commit:", commit)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# $ git fetch origin task-3-gender-usage-classification
# $ git switch task-3-gender-usage-classification
# $ git merge --ff-only origin/task-3-gender-usage-classification
# Repository ready: /content/MLA2
# Commit: 1233e4c99b5a318f9602073e0fb4de4d3e747dee

# %% [markdown]
# ## 2. Teacher data and canonical split

# %%
def copy_teacher_zip_to_local_disk():
    if LOCAL_DATA_ZIP.is_file():
        try:
            with zipfile.ZipFile(LOCAL_DATA_ZIP) as existing:
                existing.infolist()
            return
        except zipfile.BadZipFile:
            LOCAL_DATA_ZIP.unlink()
    partial = LOCAL_DATA_ZIP.with_suffix(".zip.partial")
    for attempt in range(1, 4):
        partial.unlink(missing_ok=True)
        try:
            expected_bytes = DATA_ZIP.stat().st_size
            with DATA_ZIP.open("rb") as source, partial.open("wb") as target:
                shutil.copyfileobj(source, target, length=8 * 1024**2)
            if partial.stat().st_size != expected_bytes:
                raise OSError("The local ZIP copy is incomplete.")
            partial.replace(LOCAL_DATA_ZIP)
            return
        except OSError as error:
            partial.unlink(missing_ok=True)
            if attempt == 3:
                raise RuntimeError("Drive disconnected three times. Remount and retry.") from error
            drive.mount(str(DRIVE_MOUNT), force_remount=True)
            time.sleep(2)


copy_teacher_zip_to_local_disk()
teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_dirs = (teacher_dir / "train/images_train", teacher_dir / "test/images_test")
image_suffixes = {".jpg", ".jpeg"}
with zipfile.ZipFile(LOCAL_DATA_ZIP) as archive:
    names = archive.namelist()
    if any(Path(name).is_absolute() or ".." in Path(name).parts for name in names):
        raise RuntimeError("The teacher archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/") and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    current_images = sum(
        path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
    )
    if current_images != expected_images or not all(path.is_file() for path in required_files):
        archive.extractall(REPO_DIR)

actual_images = sum(
    path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
)
if actual_images != expected_images or not all(path.is_file() for path in required_files):
    raise RuntimeError(f"Teacher data is incomplete: {actual_images:,}/{expected_images:,} images")

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
if str(REPO_DIR / "src") not in sys.path:
    sys.path.insert(0, str(REPO_DIR / "src"))
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print(f"Teacher data ready: {actual_images:,} images")
# Out:
# Teacher data ready: 44,441 images

# %% [markdown]
# ## 3. Freeze alpha 0.4 and check the parents
#
# 04af reduced the mean clean training–validation gap to **0.129133**, with pooled validation F1 **0.808909**. Unisex, Boys and Girls explain about **87%** of the remaining summed class gaps. Unisex recall fell slightly, so this trial must not lose more.
#
# Increase only **alpha: 0.2 → 0.4**. For every training batch, draw `lambda ~ Beta(0.4, 0.4)`, then randomly permute that batch to choose partners. Stronger blending gives the second image more influence on average. It may reduce memorization, but it may also hide small product clues. This is one fixed trial, not a sweep.
#
# After the existing augmentation and normalization:
#
# - Image: `lambda * image + (1 - lambda) * partner_image`.
# - Loss: `lambda * CE(logits, label) + (1 - lambda) * CE(logits, partner_label)`.
#
# Self-pairs and same-label pairs remain allowed. Keep the same dedicated PCG64 seed `2753 XOR 0x4D495855`, persisting across epochs. Each original training row appears once per epoch. Only the current training batch supplies partners; validation and held-out images never enter mixing.
#
# Keep the name-truth labels, full images, widths `[32, 64, 128, 256]`, **390,181 parameters**, GeM p=3, dropout **0.30**, translation ±2 px at probability 0.50, mild darkening at probability 0.25, grayscale at probability **0.10**, clean fold-training RGB normalization, AdamW weight decay **0.0001**, learning-rate schedule, batch **128**, seed **2753**, **30 epochs** and the **final-epoch checkpoint**. No class or sample weights apply. Each model starts from random weights; saved parents are only comparison evidence.
#
# Online training F1 stays blank because the labels are mixed. The gap comes from **clean, unmixed training and validation images in evaluation mode**. Corruption evaluations are unmixed too. Scoring uses the same name-truth labels and IEEE FP32 for every model; keep the original teacher-label diagnostic.
#
# The 04af code hashes are checked against its recorded commit `68fef49ab1d55d671531113a71a3e71400a0e3fc`. New source audits separately bind this trial's code and alpha 0.4 contracts. This preserves the completed parent's evidence after the implementation changes.
#
# This is a development trial chosen after seeing earlier results, not an independent blind test. [MixUp paper](https://arxiv.org/abs/1710.09412).

# %%
from fashion.data.gender_name_truth import build_gender_name_truth_variant
from fashion.train.task3_gender_stronger_mixup import (
    check_gender_stronger_mixup_sources,
    run_gender_stronger_mixup_screen,
)

G2_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_v2_g2_translation/gender"
E6_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_e6_gem_p3/gender"
DROPOUT_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_dropout_030/gender"
DARKENING_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_dropout_030_mild_darkening/gender"
GRAYSCALE_DIR = (
    DRIVE_TASK_DIR / "experiments/t3_gender_dropout_030_mild_darkening_grayscale_010/gender"
)
NAME_TRUTH_DIR = (
    DRIVE_TASK_DIR / "experiments/t3_gender_name_truth_dropout_030_grayscale_010/gender"
)
MIXUP_DIR = DRIVE_TASK_DIR / "experiments/t3_gender_name_truth_mixup_alpha020/gender"
PRECISION_DIR = DRIVE_TASK_DIR / "diagnostics/gender_precision/20260905T085822668071Z"

summary = build_gender_name_truth_variant(REPO_DIR)
print("Changed gender labels:", summary["changed_labels"])
print("Unclear names kept:", summary["no_cue_rows"] + summary["multiple_cue_rows"])
print("Fold label changes:", summary["folds"])
sources, classes, spec, evidence = check_gender_stronger_mixup_sources(
    g2_directory=G2_DIR,
    e6_directory=E6_DIR,
    dropout_directory=DROPOUT_DIR,
    darkening_directory=DARKENING_DIR,
    grayscale_directory=GRAYSCALE_DIR,
    name_truth_directory=NAME_TRUTH_DIR,
    mixup_directory=MIXUP_DIR,
    source_registry_path=DRIVE_REGISTRY,
    precision_directory=PRECISION_DIR,
    root=REPO_DIR,
)
assert spec.classifier_dropout == 0.30
assert spec.to_dict()["grayscale_probability"] == 0.10
print("Verified source runs:", {name: len(runs) for name, runs in sources.items()})
print(
    "Direct alpha 0.2 parents:",
    {fold: run["run_id"] for fold, run in sources["MixUp20"].items()},
)
print("Frozen recipe:", spec.to_dict())
print("Output:", DRIVE_TASK_DIR / spec.artifact_dir / "gender")
print("MixUp policy:", spec.to_dict()["mixup_policy"])
print("Additional improvement rules:", spec.to_dict()["improvement_rules"])
# Out:
# Changed gender labels: 350
# Unclear names kept: 1320
# Fold label changes: [{'fold': 0, 'validation_rows': 6553, 'changed_validation_labels': 73, 'changed_training_labels': 277}, {'fold': 1, 'validation_rows': 6556, 'changed_validation_labels': 85, 'changed_training_labels': 265}, {'fold': 2, 'validation_rows': 6553, 'changed_validation_labels': 58, 'changed_training_labels': 292}, {'fold': 3, 'validation_rows': 6554, 'changed_validation_labels': 50, 'changed_training_labels': 300}, {'fold': 4, 'validation_rows': 6557, 'changed_validation_labels': 84, 'changed_training_labels': 266}]
# Verified source runs: {'G2': 5, 'E6': 5, 'Drop30': 2, 'Drop30Dark': 2, 'Gray10': 2, 'NameTruth': 2, 'MixUp20': 2}
# Direct alpha 0.2 parents: {0: 't3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f0_s2753_4566a61e0e2d_20260906T070013Z8f7ca5', 4: 't3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f4_s2753_4566a61e0e2d_20260906T071118Z37920b'}
# Frozen recipe: {'name': 'gender_name_truth_mixup_alpha040', 'target': 'gender', 'experiment_id': 't3_gender_name_truth_mixup_alpha040', 'hypothesis_id': 't3_gender_name_truth_mixup_alpha040', 'artifact_dir': 'experiments/t3_gender_name_truth_mixup_alpha040', 'run_prefix': 't3_gender_name_truth_mixup_alpha040', 'changed_factor': 'mixup_alpha_020_to_040', 'parent_artifact_dir': 'experiments/t3_gender_name_truth_mixup_alpha020', 'parent_run_ids': ['t3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f0_s2753_4566a61e0e2d_20260906T070013Z8f7ca5', 't3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f4_s2753_4566a61e0e2d_20260906T071118Z37920b'], 'model_family': 'task3_small_cnn_gem_p3', 'run_model_token': 'smallcnngem3', 'training_augmentation': 'translation_2px_p05_mild_darkening_p025_grayscale_p010', 'input_view': 'full', 'sample_weight_strategy': 'none', 'loss_name': 'cross_entropy', 'class_weight_beta': None, 'class_weight_cap': None, 'classifier_dropout': 0.3, 'label_smoothing': 0.0, 'focal_gamma': 0.0, 'checkpoint_policy': 'final_epoch', 'early_stopping_min_epoch': 0, 'early_stopping_patience': 0, 'early_stopping_min_delta': 0.0, 'training_selection_strategy': 'all', 'auxiliary_target': 'none', 'primary_loss_weight': 1.0, 'auxiliary_loss_weight': 0.0, 'parent_folds': [0, 4], 'execution_policy': 'g2_training_defaults_ieee_comparison_under_3gb_v1', 'screen_rule_version': 'gname_mixup040_f1floor074_gap005_refine002_v2', 'darkening_rng': 'persistent_worker_initial_seed_xor_0x474431', 'grayscale_probability': 0.1, 'grayscale_rng': 'persistent_worker_initial_seed_xor_0x47524159', 'gender_label_variant': {'canonical_split_sha256': 'd76a49c6dc7999b4f286e94838a92c603d68c4f66179fde081028948f6a187db', 'labels_sha256': '168f7513743fc28b37380ec6b43d0da05243d70e51dbe6d13d311f56a439764a', 'rule_version': 'single_explicit_gender_cue_v1', 'summary_sha256': 'f6e656d93d0af949d8cb0621e28b420fd671405fcf04a9347bcaab03a7cc14fe', 'variant_id': 'gender_name_truth_v1'}, 'independent_blind_test': False, 'mixup_policy': {'version': 'gender_mixup_alpha040_v1', 'alpha': 0.4, 'probability': 1.0, 'lambda': 'one Beta(alpha, alpha) draw per batch', 'partners': 'random permutation within the current training batch; self-pairs allowed', 'placement': 'after existing image augmentation and RGB normalization', 'loss': 'lambda * CE(logits, y) + (1-lambda) * CE(logits, partner_y)', 'rng': 'dedicated numpy PCG64; seed XOR 0x4D495855; persists across epochs', 'evaluation': 'unmixed images, plain unweighted cross-entropy', 'online_train_f1': 'not_applicable_mixed_inputs'}, 'improvement_rules': {'comparison': 'completed MixUp alpha 0.2 on identical name-truth labels', 'minimum_mean_clean_gap_reduction': 0.02, 'each_fold_gap_must_shrink': True, 'minimum_pooled_validation_f1': 0.74, 'relative_f1_comparisons_are_diagnostic_only': True, 'minimum_unisex_recall_delta': 0.0, 'retain_non_f1_g2_e6_gates': True}}
# Output: /content/drive/MyDrive/MLA2/task3/experiments/t3_gender_name_truth_mixup_alpha040/gender
# MixUp policy: {'version': 'gender_mixup_alpha040_v1', 'alpha': 0.4, 'probability': 1.0, 'lambda': 'one Beta(alpha, alpha) draw per batch', 'partners': 'random permutation within the current training batch; self-pairs allowed', 'placement': 'after existing image augmentation and RGB normalization', 'loss': 'lambda * CE(logits, y) + (1-lambda) * CE(logits, partner_y)', 'rng': 'dedicated numpy PCG64; seed XOR 0x4D495855; persists across epochs', 'evaluation': 'unmixed images, plain unweighted cross-entropy', 'online_train_f1': 'not_applicable_mixed_inputs'}
# Additional improvement rules: {'comparison': 'completed MixUp alpha 0.2 on identical name-truth labels', 'minimum_mean_clean_gap_reduction': 0.02, 'each_fold_gap_must_shrink': True, 'minimum_pooled_validation_f1': 0.74, 'relative_f1_comparisons_are_diagnostic_only': True, 'minimum_unisex_recall_delta': 0.0, 'retain_non_f1_g2_e6_gates': True}

# %% [markdown]
# ## 4. Preserve the old guards and require further improvement
#
# Keep the **14 non-F1 G2/E6 checks**, with the same labels and IEEE evaluation:
#
# - Relative pooled, fold and class F1 changes and the paired whole-family bootstrap interval are diagnostic only. Keep 10,000 draws within folds, seed 2753; save the five replaced G2 F1 checks separately as `diagnostic_checks`.
# - The mean clean gap must fall by at least 0.050 versus G2, and both folds' gaps must shrink.
# - NLL may rise by at most 0.020 and ECE by at most 0.010 versus G2.
# - Keep corruption guards versus matched E6: translation-induced F1 change improves by at least 0.030; each other standard corruption worsens by at most 0.020.
# - Exactly 390,181 parameters and peak allocated GPU memory strictly below 3,000,000,000 bytes. Report training time and latency. A memory failure stops before another fold begins.
#
# Add **5 checks**, using completed 04af alpha 0.2 for the gap and recall comparisons:
#
# - Mean clean gap must shrink by **at least 0.020**: approximately **0.129133 → at most 0.109133**.
# - Each fold's clean gap must shrink.
# - Pooled validation macro-F1 must be **at least 0.74 (74%)**. A drop from the parent's 80.89% is allowed.
# - **Unisex recall must not fall** versus 04af (approximately **0.510608**).
#
# Use exact freshly matched parent scores, not these rounded numbers. **All 19 checks must pass.** These targets are chosen before this new fit; they do not rewrite the result of 04af. Read confidence quality and raw corruption scores as well. The 74% floor allows a validation F1 drop in exchange for a smaller clean gap.

# %%
result = run_gender_stronger_mixup_screen(
    g2_directory=G2_DIR,
    e6_directory=E6_DIR,
    dropout_directory=DROPOUT_DIR,
    darkening_directory=DARKENING_DIR,
    grayscale_directory=GRAYSCALE_DIR,
    name_truth_directory=NAME_TRUTH_DIR,
    mixup_directory=MIXUP_DIR,
    source_registry_path=DRIVE_REGISTRY,
    precision_directory=PRECISION_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=(LOCAL_REGISTRY,),
    root=REPO_DIR,
)
print("Screen:", result["status"])
print("Label basis:", result.get("comparison_label_basis"))
for row in result.get("folds", []):
    print(
        "Fold",
        row["fold"],
        "train F1:",
        row["candidate_train_f1"],
        "validation F1:",
        row["candidate_validation_f1"],
        "gap:",
        row["candidate_gap"],
    )
for gate in result.get("checks", []):
    if gate["status"] != "pass":
        print(gate)
if "reason" in result:
    print(result["reason"])
if "incremental_comparison" in result:
    incremental = result["incremental_comparison"]
    print("Direct alpha 0.2 parents:", result["direct_parent_run_ids"])
    print("F1 change versus alpha 0.2 on the same labels:", incremental["validation_delta"])
    print("Paired 95% interval:", incremental["validation_interval"])
    print("Class F1 changes:", incremental["class_f1_delta"])
    print("Induced corruption changes:", incremental["mean_induced_change_delta"])
if "incremental_comparison" in result:
    for row in result["incremental_comparison"]["folds"]:
        print("Direct-parent gap change, fold", row["fold"], ":", row["delta_gap"])
# Out:
# IEEE evaluation: t3_gender_v2_g2_translation_gender_smallcnngem3_f0_s2753_cb072542dbdc_20260904T135102Z6698e6
# IEEE evaluation: t3_gender_v2_g2_translation_gender_smallcnngem3_f4_s2753_cb072542dbdc_20260904T140011Z2211b1
# IEEE evaluation: t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f
# IEEE evaluation: t3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd
# IEEE evaluation: t3_gender_dropout_030_mild_darkening_grayscale_010_gender_smallcnngem3_f0_s2753_eb37119b7e68_20260905T144455Ze47ef6
# IEEE evaluation: t3_gender_dropout_030_mild_darkening_grayscale_010_gender_smallcnngem3_f4_s2753_eb37119b7e68_20260905T145521Z7d0a34
# IEEE evaluation: t3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f0_s2753_4566a61e0e2d_20260906T070013Z8f7ca5
# IEEE evaluation: t3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f4_s2753_4566a61e0e2d_20260906T071118Z37920b
# [task3] preparing target=gender fold=0: train=26,220 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_name_truth_mixup_alpha040_gender_smallcnngem3_f0_s2753_ab0d78c7d178_20260906T081236Zdcdaf6; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.7667 train_macro_f1=n/a (mixed inputs) validation_loss=0.5578 validation_macro_f1=0.5172
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.6630 train_macro_f1=n/a (mixed inputs) validation_loss=0.4907 validation_macro_f1=0.6365
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.6410 train_macro_f1=n/a (mixed inputs) validation_loss=0.4558 validation_macro_f1=0.6433
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.6265 train_macro_f1=n/a (mixed inputs) validation_loss=0.4352 validation_macro_f1=0.6875
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.6187 train_macro_f1=n/a (mixed inputs) validation_loss=0.4567 validation_macro_f1=0.7030
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.5803 train_macro_f1=n/a (mixed inputs) validation_loss=0.3984 validation_macro_f1=0.7240
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.5623 train_macro_f1=n/a (mixed inputs) validation_loss=0.3714 validation_macro_f1=0.7323
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.5674 train_macro_f1=n/a (mixed inputs) validation_loss=0.4448 validation_macro_f1=0.6982
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.5633 train_macro_f1=n/a (mixed inputs) validation_loss=0.3836 validation_macro_f1=0.7317
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.5373 train_macro_f1=n/a (mixed inputs) validation_loss=0.3859 validation_macro_f1=0.7446
# [task3] target=gender fold=0 epoch=11/30 train_loss=0.5380 train_macro_f1=n/a (mixed inputs) validation_loss=0.4036 validation_macro_f1=0.7360
# [task3] target=gender fold=0 epoch=12/30 train_loss=0.5236 train_macro_f1=n/a (mixed inputs) validation_loss=0.3564 validation_macro_f1=0.7433
# [task3] target=gender fold=0 epoch=13/30 train_loss=0.5256 train_macro_f1=n/a (mixed inputs) validation_loss=0.3314 validation_macro_f1=0.7581
# [task3] target=gender fold=0 epoch=14/30 train_loss=0.5013 train_macro_f1=n/a (mixed inputs) validation_loss=0.3252 validation_macro_f1=0.7494
# [task3] target=gender fold=0 epoch=15/30 train_loss=0.5203 train_macro_f1=n/a (mixed inputs) validation_loss=0.3384 validation_macro_f1=0.7504
# [task3] target=gender fold=0 epoch=16/30 train_loss=0.5125 train_macro_f1=n/a (mixed inputs) validation_loss=0.3087 validation_macro_f1=0.7923
# [task3] target=gender fold=0 epoch=17/30 train_loss=0.4973 train_macro_f1=n/a (mixed inputs) validation_loss=0.3570 validation_macro_f1=0.7735
# [task3] target=gender fold=0 epoch=18/30 train_loss=0.4870 train_macro_f1=n/a (mixed inputs) validation_loss=0.3127 validation_macro_f1=0.7761
# [task3] target=gender fold=0 epoch=19/30 train_loss=0.4686 train_macro_f1=n/a (mixed inputs) validation_loss=0.3058 validation_macro_f1=0.7739
# [task3] target=gender fold=0 epoch=20/30 train_loss=0.5013 train_macro_f1=n/a (mixed inputs) validation_loss=0.3029 validation_macro_f1=0.7690
# [task3] target=gender fold=0 epoch=21/30 train_loss=0.4918 train_macro_f1=n/a (mixed inputs) validation_loss=0.3049 validation_macro_f1=0.7831
# [task3] target=gender fold=0 epoch=22/30 train_loss=0.4573 train_macro_f1=n/a (mixed inputs) validation_loss=0.3024 validation_macro_f1=0.7882
# [task3] target=gender fold=0 epoch=23/30 train_loss=0.4933 train_macro_f1=n/a (mixed inputs) validation_loss=0.3070 validation_macro_f1=0.7895
# [task3] target=gender fold=0 epoch=24/30 train_loss=0.4585 train_macro_f1=n/a (mixed inputs) validation_loss=0.2979 validation_macro_f1=0.7840
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.4615 train_macro_f1=n/a (mixed inputs) validation_loss=0.2901 validation_macro_f1=0.7994
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.5006 train_macro_f1=n/a (mixed inputs) validation_loss=0.2923 validation_macro_f1=0.7905
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.4598 train_macro_f1=n/a (mixed inputs) validation_loss=0.2878 validation_macro_f1=0.7898
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.4599 train_macro_f1=n/a (mixed inputs) validation_loss=0.2865 validation_macro_f1=0.7896
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.4531 train_macro_f1=n/a (mixed inputs) validation_loss=0.2882 validation_macro_f1=0.7941
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.4473 train_macro_f1=n/a (mixed inputs) validation_loss=0.2869 validation_macro_f1=0.7967
# [task3] completed target=gender fold=0: t3_gender_name_truth_mixup_alpha040_gender_smallcnngem3_f0_s2753_ab0d78c7d178_20260906T081236Zdcdaf6
# IEEE evaluation: t3_gender_name_truth_mixup_alpha040_gender_smallcnngem3_f0_s2753_ab0d78c7d178_20260906T081236Zdcdaf6
# [task3] preparing target=gender fold=4: train=26,216 (before selection=26,216), validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_name_truth_mixup_alpha040_gender_smallcnngem3_f4_s2753_ab0d78c7d178_20260906T082412Z418937; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.7665 train_macro_f1=n/a (mixed inputs) validation_loss=0.5568 validation_macro_f1=0.6226
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.6661 train_macro_f1=n/a (mixed inputs) validation_loss=0.4767 validation_macro_f1=0.6441
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.6276 train_macro_f1=n/a (mixed inputs) validation_loss=0.4193 validation_macro_f1=0.6937
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.6286 train_macro_f1=n/a (mixed inputs) validation_loss=0.4146 validation_macro_f1=0.6920
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.6149 train_macro_f1=n/a (mixed inputs) validation_loss=0.4016 validation_macro_f1=0.7045
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.5827 train_macro_f1=n/a (mixed inputs) validation_loss=0.5913 validation_macro_f1=0.6494
# [task3] target=gender fold=4 epoch=7/30 train_loss=0.5581 train_macro_f1=n/a (mixed inputs) validation_loss=0.3825 validation_macro_f1=0.7436
# [task3] target=gender fold=4 epoch=8/30 train_loss=0.5626 train_macro_f1=n/a (mixed inputs) validation_loss=0.3634 validation_macro_f1=0.7429
# [task3] target=gender fold=4 epoch=9/30 train_loss=0.5661 train_macro_f1=n/a (mixed inputs) validation_loss=0.3763 validation_macro_f1=0.7565
# [task3] target=gender fold=4 epoch=10/30 train_loss=0.5371 train_macro_f1=n/a (mixed inputs) validation_loss=0.3701 validation_macro_f1=0.7583
# [task3] target=gender fold=4 epoch=11/30 train_loss=0.5348 train_macro_f1=n/a (mixed inputs) validation_loss=0.3943 validation_macro_f1=0.7416
# [task3] target=gender fold=4 epoch=12/30 train_loss=0.5154 train_macro_f1=n/a (mixed inputs) validation_loss=0.3335 validation_macro_f1=0.7797
# [task3] target=gender fold=4 epoch=13/30 train_loss=0.5210 train_macro_f1=n/a (mixed inputs) validation_loss=0.4303 validation_macro_f1=0.7417
# [task3] target=gender fold=4 epoch=14/30 train_loss=0.5073 train_macro_f1=n/a (mixed inputs) validation_loss=0.3461 validation_macro_f1=0.7609
# [task3] target=gender fold=4 epoch=15/30 train_loss=0.5182 train_macro_f1=n/a (mixed inputs) validation_loss=0.3230 validation_macro_f1=0.7878
# [task3] target=gender fold=4 epoch=16/30 train_loss=0.5092 train_macro_f1=n/a (mixed inputs) validation_loss=0.3083 validation_macro_f1=0.7870
# [task3] target=gender fold=4 epoch=17/30 train_loss=0.4957 train_macro_f1=n/a (mixed inputs) validation_loss=0.3105 validation_macro_f1=0.7693
# [task3] target=gender fold=4 epoch=18/30 train_loss=0.4863 train_macro_f1=n/a (mixed inputs) validation_loss=0.3016 validation_macro_f1=0.7873
# [task3] target=gender fold=4 epoch=19/30 train_loss=0.4692 train_macro_f1=n/a (mixed inputs) validation_loss=0.3073 validation_macro_f1=0.7739
# [task3] target=gender fold=4 epoch=20/30 train_loss=0.4978 train_macro_f1=n/a (mixed inputs) validation_loss=0.3009 validation_macro_f1=0.7980
# [task3] target=gender fold=4 epoch=21/30 train_loss=0.4908 train_macro_f1=n/a (mixed inputs) validation_loss=0.2928 validation_macro_f1=0.8034
# [task3] target=gender fold=4 epoch=22/30 train_loss=0.4605 train_macro_f1=n/a (mixed inputs) validation_loss=0.2941 validation_macro_f1=0.8010
# [task3] target=gender fold=4 epoch=23/30 train_loss=0.4640 train_macro_f1=n/a (mixed inputs) validation_loss=0.2993 validation_macro_f1=0.7885
# [task3] target=gender fold=4 epoch=24/30 train_loss=0.4551 train_macro_f1=n/a (mixed inputs) validation_loss=0.2870 validation_macro_f1=0.8051
# [task3] target=gender fold=4 epoch=25/30 train_loss=0.4609 train_macro_f1=n/a (mixed inputs) validation_loss=0.2896 validation_macro_f1=0.8079
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.4864 train_macro_f1=n/a (mixed inputs) validation_loss=0.2883 validation_macro_f1=0.8096
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.4593 train_macro_f1=n/a (mixed inputs) validation_loss=0.2824 validation_macro_f1=0.8144
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.4577 train_macro_f1=n/a (mixed inputs) validation_loss=0.2851 validation_macro_f1=0.8049
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.4501 train_macro_f1=n/a (mixed inputs) validation_loss=0.2845 validation_macro_f1=0.8056
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.4559 train_macro_f1=n/a (mixed inputs) validation_loss=0.2797 validation_macro_f1=0.8019
# [task3] completed target=gender fold=4: t3_gender_name_truth_mixup_alpha040_gender_smallcnngem3_f4_s2753_ab0d78c7d178_20260906T082412Z418937
# IEEE evaluation: t3_gender_name_truth_mixup_alpha040_gender_smallcnngem3_f4_s2753_ab0d78c7d178_20260906T082412Z418937
# Screen: fail
# Label basis: {'canonical_split_sha256': 'd76a49c6dc7999b4f286e94838a92c603d68c4f66179fde081028948f6a187db', 'labels_sha256': '168f7513743fc28b37380ec6b43d0da05243d70e51dbe6d13d311f56a439764a', 'rule_version': 'single_explicit_gender_cue_v1', 'summary_sha256': 'f6e656d93d0af949d8cb0621e28b420fd671405fcf04a9347bcaab03a7cc14fe', 'variant_id': 'gender_name_truth_v1'}
# Fold 0 train F1: 0.9202062862768454 validation F1: 0.7953270561919413 gap: 0.12487923008490409
# Fold 4 train F1: 0.9209246516806747 validation F1: 0.8018859194719461 gap: 0.11903873220872863
# {'gate': 'vs_mixup20.fold_0.gap_reduction', 'value': -0.0004487098892267394, 'rule': '> 0', 'status': 'fail'}
# {'gate': 'vs_mixup20.mean_gap_reduction', 'value': 0.007173691967269247, 'rule': '>= 0.02', 'status': 'fail'}
# Direct alpha 0.2 parents: {'0': 't3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f0_s2753_4566a61e0e2d_20260906T070013Z8f7ca5', '4': 't3_gender_name_truth_mixup_alpha020_gender_smallcnngem3_f4_s2753_4566a61e0e2d_20260906T071118Z37920b'}
# F1 change versus alpha 0.2 on the same labels: -0.010204077544869405
# Paired 95% interval: {'point': -0.010204077544869405, 'lower_95': -0.020515214106747053, 'upper_95': -0.0003357170181873015, 'repetitions': 10000, 'seed': 2753, 'method': 'paired_whole_family_percentile_stratified_by_canonical_fold', 'families_by_fold': {'0': 4564, '4': 4570}, 'classes': ['Boys', 'Girls', 'Men', 'Unisex', 'Women'], 'selection_bias_removed': False}
# Class F1 changes: {'Boys': -0.01878324887174443, 'Girls': -0.03031068451629193, 'Men': -0.0024756804276050426, 'Unisex': 0.0029883961653055513, 'Women': -0.0024391700740113986}
# Induced corruption changes: {'brightness_085': np.float64(0.0058105909698425474), 'brightness_115': np.float64(0.012864188953481702), 'grayscale': np.float64(0.006957260011632403), 'jpeg_75': np.float64(0.0029178970944374986), 'translation_003': np.float64(0.0052964068605868)}
# Direct-parent gap change, fold 0 : 0.0004487098892267394
# Direct-parent gap change, fold 4 : -0.014796093823765233

# %% [markdown]
# ## 5. Stop and review
#
# Stop after folds 0 and 4. Do not auto-run more strengths, folds 1–3, refits or held-out evaluation. Every fit is recorded through the shared registry before its first optimizer step. Reuse requires matching labels, source runs, configuration, alpha 0.4 training evidence and hashes.
#
# Results go to `MyDrive/MLA2/task3/experiments/t3_gender_name_truth_mixup_alpha040/gender`:
#
# - Each run saves `mixup_training.json` with policy, training-row hash, per-epoch row and batch counts, lambda sum, pair counts and mixing-plan hash. Ordinary online training F1 stays blank in `history.csv`.
# - `screen_decision.json` holds all 19 required checks, the five diagnostic F1 checks, the historical G2/E6 status and the improvement rules.
# - `incremental_comparison.json` compares alpha 0.4 with completed alpha 0.2. Its inherited `dropout_*` fields refer to the alpha 0.2 parents.
# - `clean_gap_comparison.csv`, `ieee_oof_predictions.csv` and the per-model IEEE evaluations hold the scores and predictions.
# - `label_basis_comparison.csv` and `original_label_diagnostic.json` retain the teacher-label sensitivity check.
# - `source_audit.json` and `label_variant/` bind the source runs, code and label evidence.
#
# Keep 04af as the current candidate unless the new result passes these rules. Reject pooled validation macro-F1 below 74% or a drop in Unisex recall. Do not keep increasing the strength merely to chase a zero gap.
