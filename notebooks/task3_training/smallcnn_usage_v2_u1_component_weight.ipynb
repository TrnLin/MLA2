# %% [markdown]
# # Task 3 — SmallCNN Usage Dataset V2 U1: Visual-Component Weighting
#
# **Run All starts only two fits:** Usage folds 0 and 4. It reuses the exact E2 SmallCNN and class-balanced loss, then changes only each row’s visual-component weight. It does not repeat E8 translation or train any Gender screen.

# %% [markdown]
# ## 1. Mount Drive and load the Task 3 branch
#
# Drive stores the teacher ZIP, completed causal parents, registry, and new artifacts.

# %%
from pathlib import Path
import os
import subprocess
import sys
import time
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
LOCAL_DATA_ZIP = Path("/content/task3-data.zip")
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"

def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab GPU runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)
if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=REPO_DIR, text=True).strip()
print("Repository ready:", REPO_DIR)
print("Branch:", BRANCH)
print("Commit:", commit)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# $ git fetch origin task-3-gender-usage-classification
# $ git switch task-3-gender-usage-classification
# $ git merge --ff-only origin/task-3-gender-usage-classification
# Repository ready: /content/MLA2
# Branch: task-3-gender-usage-classification
# Commit: 56d077190108c016ad2537ecb77300b44d8f08bb

# %% [markdown]
# ## 2. Restore teacher images on the Colab disk
#
# Only the official teacher dataset is used. The public high-resolution collection is excluded.

# %%
def copy_teacher_zip_to_local_disk():
    if LOCAL_DATA_ZIP.is_file():
        try:
            with zipfile.ZipFile(LOCAL_DATA_ZIP) as existing:
                existing.infolist()
            print("Using the existing local ZIP copy:", LOCAL_DATA_ZIP)
            return
        except zipfile.BadZipFile:
            LOCAL_DATA_ZIP.unlink()

    partial = LOCAL_DATA_ZIP.with_suffix(".zip.partial")
    for attempt in range(1, 4):
        partial.unlink(missing_ok=True)
        try:
            if not DATA_ZIP.is_file():
                raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")
            expected_bytes = DATA_ZIP.stat().st_size
            print(
                f"Copying {expected_bytes / 1024**3:.2f} GiB from Drive "
                f"(attempt {attempt}/3)...",
                flush=True,
            )
            copied = 0
            next_report = 256 * 1024**2
            with DATA_ZIP.open("rb") as source, partial.open("wb") as target:
                while chunk := source.read(8 * 1024**2):
                    target.write(chunk)
                    copied += len(chunk)
                    if copied >= next_report:
                        print(f"  copied {copied / 1024**2:.0f} MiB", flush=True)
                        next_report += 256 * 1024**2
            if copied != expected_bytes:
                raise OSError(f"ZIP copy is incomplete: {copied} of {expected_bytes} bytes")
            partial.replace(LOCAL_DATA_ZIP)
            return
        except (OSError, FileNotFoundError) as error:
            partial.unlink(missing_ok=True)
            if attempt == 3:
                raise RuntimeError(
                    "Drive disconnected three times. Reconnect Drive, then rerun this cell."
                ) from error
            try:
                drive.flush_and_unmount()
            except Exception as unmount_error:
                print("Drive unmount warning:", unmount_error)
            drive.mount(str(DRIVE_MOUNT), force_remount=True)
            time.sleep(2)

copy_teacher_zip_to_local_disk()

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_dirs = (teacher_dir / "train/images_train", teacher_dir / "test/images_test")
image_suffixes = {".jpg", ".jpeg"}

with zipfile.ZipFile(LOCAL_DATA_ZIP) as archive:
    names = archive.namelist()
    if any(Path(name).is_absolute() or ".." in Path(name).parts for name in names):
        raise RuntimeError("The teacher archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/") and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    current_images = sum(
        path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
    )
    if current_images != expected_images or not all(path.is_file() for path in required_files):
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found {actual_images:,}; "
        f"missing files: {missing_files}"
    )

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print(f"Teacher data ready: {actual_images:,} images")
print("Drive output root:", DRIVE_TASK_DIR)
# Out:
# Using the existing local ZIP copy: /content/task3-data.zip
# Teacher data is already extracted; skipping.
# Teacher data ready: 44,441 images
# Drive output root: /content/drive/MyDrive/MLA2/task3

# %% [markdown]
# ## 3. Verify the frozen screen without training
#
# The check resolves the exact five-fold causal parent, verifies the GPU and teacher files, and takes zero optimizer steps.

# %%
USAGE_E2_PARENT_RUN_IDS = (
    "t3_usage_e2_class_balanced_ce_usage_smallcnn_f0_s2753_5461e048c3b3_20260830T115815Z356f6d",
    "t3_usage_e2_class_balanced_ce_usage_smallcnn_f1_s2753_5461e048c3b3_20260830T120645Z6d08cd",
    "t3_usage_e2_class_balanced_ce_usage_smallcnn_f2_s2753_5461e048c3b3_20260830T121514Zd58aa0",
    "t3_usage_e2_class_balanced_ce_usage_smallcnn_f3_s2753_5461e048c3b3_20260830T122347Z2cb06e",
    "t3_usage_e2_class_balanced_ce_usage_smallcnn_f4_s2753_5461e048c3b3_20260830T123218Z94db47",
)

from fashion.train.task3_dataset_v2 import check_task3_dataset_v2_setup
from fashion.train.task3_experiments import latest_completed_usage_e2_parent_run_ids

resolved_parents = latest_completed_usage_e2_parent_run_ids(output_root=DRIVE_TASK_DIR)
if resolved_parents != USAGE_E2_PARENT_RUN_IDS:
    raise RuntimeError("The resolved causal parents differ from the frozen tuple.")

preflight = check_task3_dataset_v2_setup(
    "usage_v2_component_weight",
    parent_run_ids=USAGE_E2_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    root=REPO_DIR,
    device_name="cuda",
)
if preflight["input_view"] != "full" or preflight["training_augmentation"] != "none":
    raise RuntimeError("U1 must keep E2's clean full RGB input.")
if preflight["sample_weight_strategy"] != "accepted_visual_component_v1":
    raise RuntimeError("U1 must change only visual-component weighting.")
child = preflight["child"]
if child["class_weight_beta"] != 0.999 or child["class_weight_cap"] != 5.0:
    raise RuntimeError("U1 must keep E2's accepted class weights.")
component = preflight["visual_component_contract"]
if component["components"] != 32009 or component["fold_crossings"] != 0:
    raise RuntimeError("The frozen accepted visual-component map changed.")
print("GPU:", preflight["environment"]["gpu"])
print("Screen folds:", preflight["screen_folds"])
print("Model:", preflight["child"]["model_family"])
print("Parameters:", f'{preflight["parameter_count"]:,}')
print("Optimizer steps during check:", preflight["optimizer_steps"])
# Out:
# GPU: NVIDIA L4
# Screen folds: [0, 4]
# Model: task3_small_cnn
# Parameters: 391,209
# Optimizer steps during check: 0

# %% [markdown]
# ## 4. Frozen hypothesis
#
# Usage E2 improved class separation, but repeated exact or accepted near-duplicate pictures can still receive excess loss mass. U1 tests whether giving each visual component total weight one changes that trade-off without inventing rare examples.
#
# Each real row appears once per epoch. Its component weight multiplies E2’s fold-only effective-number class weight (`beta=0.999`, cap 5), and the combined loss is normalised by the applied weight sum. There is no weighted sampler and no extra weight for Home, Party, Travel, or NA. Validation keeps the full RGB canvas because the EDA showed that foreground masking and cropping hurt Usage.

# %% [markdown]
# ## 5. Train the two-fold screen
#
# Artifacts are written directly to Drive after every epoch. A completed matching fold is reused after a disconnect.

# %%
from fashion.train.task3_dataset_v2 import run_task3_dataset_v2_screen
from fashion.train.task3_experiments import audit_completed_registry_rows

result = run_task3_dataset_v2_screen(
    "usage_v2_component_weight",
    parent_run_ids=USAGE_E2_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
    reuse_completed=True,
)
registry_audit = audit_completed_registry_rows(DRIVE_REGISTRY, result["fold_run_ids"])
{
    "metrics_path": result["metrics_path"],
    "folds": result["metrics"]["validation_folds"],
    "macro_f1": result["metrics"]["macro_f1"],
    "macro_f1_without_home": result["metrics"]["macro_f1_without_home"],
    "mean_train_validation_gap": result["metrics"]["mean_final_train_validation_gap"],
    "registry_audit": registry_audit,
}
# Out:
# [task3] preparing target=usage fold=0: train=26,219 (before selection=26,219), validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_v2_u1_component_weight_usage_smallcnn_f0_s2753_1d1b2051d464_20260904T143317Zeb944e; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=1.2409 train_macro_f1=0.1560 validation_loss=1.1079 validation_macro_f1=0.1931
# [task3] target=usage fold=0 epoch=2/30 train_loss=1.1056 train_macro_f1=0.2484 validation_loss=0.9634 validation_macro_f1=0.2578
# [task3] target=usage fold=0 epoch=3/30 train_loss=0.9402 train_macro_f1=0.2992 validation_loss=0.9408 validation_macro_f1=0.2724
# [task3] target=usage fold=0 epoch=4/30 train_loss=0.8340 train_macro_f1=0.3185 validation_loss=0.8598 validation_macro_f1=0.3008
# [task3] target=usage fold=0 epoch=5/30 train_loss=0.7905 train_macro_f1=0.3265 validation_loss=0.9781 validation_macro_f1=0.2092
# [task3] target=usage fold=0 epoch=6/30 train_loss=0.7305 train_macro_f1=0.3437 validation_loss=0.9502 validation_macro_f1=0.2603
# [task3] target=usage fold=0 epoch=7/30 train_loss=0.6214 train_macro_f1=0.4656 validation_loss=0.9261 validation_macro_f1=0.3107
# [task3] target=usage fold=0 epoch=8/30 train_loss=0.5997 train_macro_f1=0.4042 validation_loss=1.1924 validation_macro_f1=0.2421
# [task3] target=usage fold=0 epoch=9/30 train_loss=0.5329 train_macro_f1=0.5249 validation_loss=0.8456 validation_macro_f1=0.3334
# [task3] target=usage fold=0 epoch=10/30 train_loss=0.4675 train_macro_f1=0.5362 validation_loss=0.9373 validation_macro_f1=0.3306
# [task3] target=usage fold=0 epoch=11/30 train_loss=0.4354 train_macro_f1=0.5835 validation_loss=0.8026 validation_macro_f1=0.3225
# [task3] target=usage fold=0 epoch=12/30 train_loss=0.3795 train_macro_f1=0.6277 validation_loss=1.0083 validation_macro_f1=0.3385
# [task3] target=usage fold=0 epoch=13/30 train_loss=0.3367 train_macro_f1=0.6852 validation_loss=1.0010 validation_macro_f1=0.3503
# [task3] target=usage fold=0 epoch=14/30 train_loss=0.3083 train_macro_f1=0.7349 validation_loss=1.2948 validation_macro_f1=0.3157
# [task3] target=usage fold=0 epoch=15/30 train_loss=0.2796 train_macro_f1=0.7557 validation_loss=0.8546 validation_macro_f1=0.3820
# [task3] target=usage fold=0 epoch=16/30 train_loss=0.2499 train_macro_f1=0.8136 validation_loss=1.0434 validation_macro_f1=0.3727
# [task3] target=usage fold=0 epoch=17/30 train_loss=0.2351 train_macro_f1=0.8450 validation_loss=1.1192 validation_macro_f1=0.3761
# [task3] target=usage fold=0 epoch=18/30 train_loss=0.2177 train_macro_f1=0.8669 validation_loss=1.0627 validation_macro_f1=0.3766
# [task3] target=usage fold=0 epoch=19/30 train_loss=0.1995 train_macro_f1=0.8810 validation_loss=1.3509 validation_macro_f1=0.3522
# [task3] target=usage fold=0 epoch=20/30 train_loss=0.1857 train_macro_f1=0.9010 validation_loss=1.2853 validation_macro_f1=0.3817
# [task3] target=usage fold=0 epoch=21/30 train_loss=0.1709 train_macro_f1=0.9161 validation_loss=1.1360 validation_macro_f1=0.3876
# [task3] target=usage fold=0 epoch=22/30 train_loss=0.1601 train_macro_f1=0.9284 validation_loss=1.1612 validation_macro_f1=0.4390
# [task3] target=usage fold=0 epoch=23/30 train_loss=0.1512 train_macro_f1=0.9279 validation_loss=1.1672 validation_macro_f1=0.4112
# [task3] target=usage fold=0 epoch=24/30 train_loss=0.1394 train_macro_f1=0.9348 validation_loss=1.1680 validation_macro_f1=0.3960
# [task3] target=usage fold=0 epoch=25/30 train_loss=0.1318 train_macro_f1=0.9484 validation_loss=1.1187 validation_macro_f1=0.4157
# [task3] target=usage fold=0 epoch=26/30 train_loss=0.1251 train_macro_f1=0.9465 validation_loss=1.0942 validation_macro_f1=0.4145
# [task3] target=usage fold=0 epoch=27/30 train_loss=0.1198 train_macro_f1=0.9558 validation_loss=1.1438 validation_macro_f1=0.4067
# [task3] target=usage fold=0 epoch=28/30 train_loss=0.1150 train_macro_f1=0.9538 validation_loss=1.1364 validation_macro_f1=0.4084
# [task3] target=usage fold=0 epoch=29/30 train_loss=0.1124 train_macro_f1=0.9514 validation_loss=1.1492 validation_macro_f1=0.4154
# [task3] target=usage fold=0 epoch=30/30 train_loss=0.1116 train_macro_f1=0.9542 validation_loss=1.1393 validation_macro_f1=0.4274
# [task3] completed target=usage fold=0: t3_usage_v2_u1_component_weight_usage_smallcnn_f0_s2753_1d1b2051d464_20260904T143317Zeb944e
# [task3] preparing target=usage fold=4: train=26,215 (before selection=26,215), validation=6,557
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_v2_u1_component_weight_usage_smallcnn_f4_s2753_1d1b2051d464_20260904T144158Z283ddc; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=1.1548 train_macro_f1=0.1600 validation_loss=1.1744 validation_macro_f1=0.2202
# [task3] target=usage fold=4 epoch=2/30 train_loss=0.9553 train_macro_f1=0.2641 validation_loss=1.4974 validation_macro_f1=0.1634
# [task3] target=usage fold=4 epoch=3/30 train_loss=0.8622 train_macro_f1=0.2998 validation_loss=1.6686 validation_macro_f1=0.1694
# [task3] target=usage fold=4 epoch=4/30 train_loss=0.8002 train_macro_f1=0.3173 validation_loss=1.9088 validation_macro_f1=0.1930
# [task3] target=usage fold=4 epoch=5/30 train_loss=0.7272 train_macro_f1=0.3383 validation_loss=1.0677 validation_macro_f1=0.2465
# [task3] target=usage fold=4 epoch=6/30 train_loss=0.6981 train_macro_f1=0.3496 validation_loss=0.8788 validation_macro_f1=0.3208
# [task3] target=usage fold=4 epoch=7/30 train_loss=0.6176 train_macro_f1=0.3776 validation_loss=1.1756 validation_macro_f1=0.2697
# [task3] target=usage fold=4 epoch=8/30 train_loss=0.5619 train_macro_f1=0.4088 validation_loss=1.5223 validation_macro_f1=0.2262
# [task3] target=usage fold=4 epoch=9/30 train_loss=0.5185 train_macro_f1=0.4223 validation_loss=1.0498 validation_macro_f1=0.3126
# [task3] target=usage fold=4 epoch=10/30 train_loss=0.4475 train_macro_f1=0.5019 validation_loss=0.8158 validation_macro_f1=0.3020
# [task3] target=usage fold=4 epoch=11/30 train_loss=0.3982 train_macro_f1=0.5473 validation_loss=0.8605 validation_macro_f1=0.3291
# [task3] target=usage fold=4 epoch=12/30 train_loss=0.3613 train_macro_f1=0.5792 validation_loss=1.0632 validation_macro_f1=0.3172
# [task3] target=usage fold=4 epoch=13/30 train_loss=0.3123 train_macro_f1=0.6138 validation_loss=1.9739 validation_macro_f1=0.2230
# [task3] target=usage fold=4 epoch=14/30 train_loss=0.2880 train_macro_f1=0.6806 validation_loss=1.1227 validation_macro_f1=0.3027
# [task3] target=usage fold=4 epoch=15/30 train_loss=0.2560 train_macro_f1=0.6985 validation_loss=1.1173 validation_macro_f1=0.3326
# [task3] target=usage fold=4 epoch=16/30 train_loss=0.2343 train_macro_f1=0.7077 validation_loss=1.2014 validation_macro_f1=0.3391
# [task3] target=usage fold=4 epoch=17/30 train_loss=0.2175 train_macro_f1=0.7272 validation_loss=0.9827 validation_macro_f1=0.3799
# [task3] target=usage fold=4 epoch=18/30 train_loss=0.1920 train_macro_f1=0.7802 validation_loss=1.2905 validation_macro_f1=0.3187
# [task3] target=usage fold=4 epoch=19/30 train_loss=0.1746 train_macro_f1=0.7895 validation_loss=0.9542 validation_macro_f1=0.4364
# [task3] target=usage fold=4 epoch=20/30 train_loss=0.1634 train_macro_f1=0.7937 validation_loss=1.7167 validation_macro_f1=0.2865
# [task3] target=usage fold=4 epoch=21/30 train_loss=0.1470 train_macro_f1=0.8144 validation_loss=1.0381 validation_macro_f1=0.3810
# [task3] target=usage fold=4 epoch=22/30 train_loss=0.1349 train_macro_f1=0.8201 validation_loss=1.1536 validation_macro_f1=0.3240
# [task3] target=usage fold=4 epoch=23/30 train_loss=0.1216 train_macro_f1=0.8319 validation_loss=1.1839 validation_macro_f1=0.3621
# [task3] target=usage fold=4 epoch=24/30 train_loss=0.1108 train_macro_f1=0.8409 validation_loss=1.2244 validation_macro_f1=0.3673
# [task3] target=usage fold=4 epoch=25/30 train_loss=0.1027 train_macro_f1=0.8452 validation_loss=1.0947 validation_macro_f1=0.3871
# [task3] target=usage fold=4 epoch=26/30 train_loss=0.0964 train_macro_f1=0.8479 validation_loss=1.0472 validation_macro_f1=0.3905
# [task3] target=usage fold=4 epoch=27/30 train_loss=0.0906 train_macro_f1=0.8532 validation_loss=1.1572 validation_macro_f1=0.3822
# [task3] target=usage fold=4 epoch=28/30 train_loss=0.0865 train_macro_f1=0.8562 validation_loss=1.0796 validation_macro_f1=0.3892
# [task3] target=usage fold=4 epoch=29/30 train_loss=0.0842 train_macro_f1=0.8570 validation_loss=1.0809 validation_macro_f1=0.3900
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.0823 train_macro_f1=0.8553 validation_loss=1.0764 validation_macro_f1=0.3923
# [task3] completed target=usage fold=4: t3_usage_v2_u1_component_weight_usage_smallcnn_f4_s2753_1d1b2051d464_20260904T144158Z283ddc
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_usage_v2_u1_component_weight/usage/aggregate/metrics.json',
#  'folds': [0, 4],
#  'macro_f1': 0.4137951063370886,
#  'macro_f1_without_home': 0.46551949462922476,
#  'mean_train_validation_gap': 0.4987125571026537,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_usage_v2_u1_component_weight_usage_smallcnn_f0_s2753_1d1b2051d464_20260904T143317Zeb944e',
#    't3_usage_v2_u1_component_weight_usage_smallcnn_f4_s2753_1d1b2051d464_20260904T144158Z283ddc'],
#   'completed_rows': 2,
#   'ready': True}}

# %% [markdown]
# ## 6. Confirm the saved evidence
#
# This cell only summarizes the finished folds. It does not promote the model.

# %%
import pandas as pd

display(pd.DataFrame([
    {
        "screen": "usage_v2_component_weight",
        "folds": result["metrics"]["validation_folds"],
        "macro_f1": result["metrics"]["macro_f1"],
        "fold_sd": result["metrics"]["fold_macro_f1_sample_sd"],
        "mean_train_validation_gap": result["metrics"]["mean_final_train_validation_gap"],
        "metrics_path": result["metrics_path"],
    }
]))
print("Stop here. This two-fold result must be analysed before any five-fold promotion.")
# Out:
#                       screen   folds  macro_f1   fold_sd  \
# 0  usage_v2_component_weight  [0, 4]  0.413795  0.024804
#
#    mean_train_validation_gap  \
# 0                   0.498713
#
#                                         metrics_path
# 0  /content/drive/MyDrive/MLA2/task3/experiments/...
# Stop here. This two-fold result must be analysed before any five-fold promotion.
