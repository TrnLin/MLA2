# %% [markdown]
# # Task 3 — TinyConvNeXt and TinyHRNet E7 Experiments
#
# This notebook trains only the two frozen E7 architecture children. **Run All starts ten new fits:** five Usage TinyConvNeXt-18 folds first, then five Gender TinyHRNet-20 folds. It never retrains E1–E6.

# %% [markdown]
# ## 1. Mount Drive and load the submitted branch
#
# Drive supplies the teacher data, accepted parents, persistent registry, and E7 artifacts.

# %%
from pathlib import Path
import json
import os
import subprocess
import sys
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"


def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

# %%
try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)

if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    dirty = subprocess.check_output(
        ["git", "status", "--porcelain"], cwd=REPO_DIR, text=True
    ).strip().splitlines()
    if dirty:
        print("Local repository changes found:")
        for change in dirty:
            print(f"  {change}")
        print("Trying a safe fast-forward update. Git will stop before overwriting a local file.")
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=REPO_DIR, text=True).strip()
print(f"Repository ready: {REPO_DIR}")
print(f"Branch: {BRANCH}")
print(f"Commit: {commit}")
# Out:
# Mounted at /content/drive
# $ git clone --branch task-3-gender-usage-classification --single-branch https://github.com/TrnLin/MLA2.git /content/MLA2
# Repository ready: /content/MLA2
# Branch: task-3-gender-usage-classification
# Commit: a43a80b4690a5187a6416d9e88c9990a4a4f62d0

# %% [markdown]
# ## 2. Copy the teacher data onto the runtime disk
#
# The ZIP keeps the repository’s required `data/raw/teacher` structure.

# %%
if not DATA_ZIP.is_file():
    raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_suffixes = {".jpg", ".jpeg"}

with zipfile.ZipFile(DATA_ZIP) as archive:
    names = archive.namelist()
    unsafe_names = [
        name for name in names if Path(name).is_absolute() or ".." in Path(name).parts
    ]
    if unsafe_names:
        raise RuntimeError("The dataset archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/")
        and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    if expected_images == 0:
        raise RuntimeError("The archive has no teacher images in the expected folder.")
    current_images = sum(
        path.suffix.lower() in image_suffixes for path in teacher_dir.rglob("*")
    )
    needs_extract = current_images != expected_images or not all(
        path.is_file() for path in required_files
    )
    if needs_extract:
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes for path in teacher_dir.rglob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found "
        f"{actual_images:,}; missing files: {missing_files}"
    )
print(f"Teacher data ready: {actual_images:,} images")
# Out:
# Extracting 44,441 teacher images...
# Teacher data ready: 44,441 images

# %% [markdown]
# ## 3. Resolve the accepted parents and verify E7
#
# These checks build each architecture and run a zero-input shape check. They create no optimizer and take no training step.

# %%
os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)

for output_dir in (
    DRIVE_TASK_DIR / "experiments",
    DRIVE_TASK_DIR / "logs",
    DRIVE_TASK_DIR / "results",
):
    output_dir.mkdir(parents=True, exist_ok=True)

from fashion.train.task3_experiments import (
    check_task3_child_setup,
    latest_completed_baseline_parent_run_ids,
    latest_completed_usage_e2_parent_run_ids,
)

usage_parent_run_ids = latest_completed_usage_e2_parent_run_ids(
    output_root=DRIVE_TASK_DIR
)
gender_parent_run_ids = latest_completed_baseline_parent_run_ids(
    "gender", output_root=DRIVE_TASK_DIR
)
usage_e7_check = check_task3_child_setup(
    "usage_tinyconvnext18",
    parent_run_ids=usage_parent_run_ids,
    root=REPO_DIR,
    device_name="cuda",
)
gender_e7_check = check_task3_child_setup(
    "gender_tinyhrnet20",
    parent_run_ids=gender_parent_run_ids,
    root=REPO_DIR,
    device_name="cuda",
)

if usage_e7_check["model_family"] != "task3_tinyconvnext18":
    raise RuntimeError("Usage E7 architecture contract changed")
if usage_e7_check["parameter_count"] != 384_345:
    raise RuntimeError("Usage E7 parameter contract changed")
if usage_e7_check["architecture_macs"] != 95_297_616:
    raise RuntimeError("Usage E7 MAC contract changed")
usage_child = usage_e7_check["child"]
if usage_child["class_weight_beta"] != 0.999 or usage_child["class_weight_cap"] != 5.0:
    raise RuntimeError("Usage E7 must keep the accepted E2 class weights")
if gender_e7_check["model_family"] != "task3_tinyhrnet20":
    raise RuntimeError("Gender E7 architecture contract changed")
if gender_e7_check["parameter_count"] != 374_445:
    raise RuntimeError("Gender E7 parameter contract changed")
if gender_e7_check["architecture_macs"] != 104_064_700:
    raise RuntimeError("Gender E7 MAC contract changed")

print("GPU:", usage_e7_check["environment"]["gpu"])
print("Usage E2 parents: ", usage_parent_run_ids)
print("Gender E1 parents:", gender_parent_run_ids)
print("Usage E7 parameters/MACs:", usage_e7_check["parameter_count"], usage_e7_check["architecture_macs"])
print("Gender E7 parameters/MACs:", gender_e7_check["parameter_count"], gender_e7_check["architecture_macs"])
print("Optimizer steps during checks:", usage_e7_check["optimizer_steps"], gender_e7_check["optimizer_steps"])
# Out:
# GPU: NVIDIA L4
# Usage E2 parents:  ('t3_usage_e2_class_balanced_ce_usage_smallcnn_f0_s2753_5461e048c3b3_20260830T115815Z356f6d', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f1_s2753_5461e048c3b3_20260830T120645Z6d08cd', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f2_s2753_5461e048c3b3_20260830T121514Zd58aa0', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f3_s2753_5461e048c3b3_20260830T122347Z2cb06e', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f4_s2753_5461e048c3b3_20260830T123218Z94db47')
# Gender E1 parents: ('t3_baseline_gender_smallcnn_f0_s2753_e46cd00adf0a_20260830T082833Zf8c1e0', 't3_baseline_gender_smallcnn_f1_s2753_e46cd00adf0a_20260830T083708Z143950', 't3_baseline_gender_smallcnn_f2_s2753_e46cd00adf0a_20260830T084548Z5acbf0', 't3_baseline_gender_smallcnn_f3_s2753_e46cd00adf0a_20260830T085427Z5d34f9', 't3_baseline_gender_smallcnn_f4_s2753_e46cd00adf0a_20260830T090303Z41a843')
# Usage E7 parameters/MACs: 384345 95297616
# Gender E7 parameters/MACs: 374445 104064700
# Optimizer steps during checks: 0 0

# %% [markdown]
# ## 4. Train Usage E7: TinyConvNeXt-18
#
# This changes only the accepted E2 model architecture. It keeps E2 effective-number class weights and all other controls.

# %%
from fashion.train.task3_experiments import (
    audit_completed_registry_rows,
    run_task3_child_cv,
)

usage_e7_result = run_task3_child_cv(
    "usage_tinyconvnext18",
    parent_run_ids=usage_parent_run_ids,
    folds=range(5),
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[REPO_DIR / "results/runs.csv"],
    device_name="cuda",
)
usage_e7_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, usage_e7_result["fold_run_ids"]
)
{
    "metrics_path": usage_e7_result["metrics_path"],
    "macro_f1": usage_e7_result["metrics"]["macro_f1"],
    "macro_f1_without_home": usage_e7_result["metrics"]["macro_f1_without_home"],
    "registry_audit": usage_e7_registry_audit,
}
# Out:
# [task3] starting five-fold experiment=t3_usage_tinyconvnext18 for target=usage
# [task3] preparing target=usage fold=0: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f0_s2753_70abdddddebe_20260831T124841Zc7fa81; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=1.4040 train_macro_f1=0.0984 validation_loss=1.2124 validation_macro_f1=0.1131
# [task3] target=usage fold=0 epoch=2/30 train_loss=1.3023 train_macro_f1=0.1582 validation_loss=1.1563 validation_macro_f1=0.1503
# [task3] target=usage fold=0 epoch=3/30 train_loss=1.2492 train_macro_f1=0.1768 validation_loss=1.1137 validation_macro_f1=0.1789
# [task3] target=usage fold=0 epoch=4/30 train_loss=1.2160 train_macro_f1=0.1849 validation_loss=1.0604 validation_macro_f1=0.1842
# [task3] target=usage fold=0 epoch=5/30 train_loss=1.1823 train_macro_f1=0.2118 validation_loss=1.0685 validation_macro_f1=0.2125
# [task3] target=usage fold=0 epoch=6/30 train_loss=1.1486 train_macro_f1=0.2250 validation_loss=1.0335 validation_macro_f1=0.2124
# [task3] target=usage fold=0 epoch=7/30 train_loss=1.0668 train_macro_f1=0.2397 validation_loss=0.9962 validation_macro_f1=0.2260
# [task3] target=usage fold=0 epoch=8/30 train_loss=1.0614 train_macro_f1=0.2625 validation_loss=1.0349 validation_macro_f1=0.2247
# [task3] target=usage fold=0 epoch=9/30 train_loss=1.0273 train_macro_f1=0.2720 validation_loss=1.0224 validation_macro_f1=0.2054
# [task3] target=usage fold=0 epoch=10/30 train_loss=0.9615 train_macro_f1=0.2605 validation_loss=1.0218 validation_macro_f1=0.2590
# [task3] target=usage fold=0 epoch=11/30 train_loss=0.8988 train_macro_f1=0.2804 validation_loss=1.0645 validation_macro_f1=0.2810
# [task3] target=usage fold=0 epoch=12/30 train_loss=0.8325 train_macro_f1=0.3114 validation_loss=1.0051 validation_macro_f1=0.2814
# [task3] target=usage fold=0 epoch=13/30 train_loss=0.7960 train_macro_f1=0.3081 validation_loss=1.1023 validation_macro_f1=0.2628
# [task3] target=usage fold=0 epoch=14/30 train_loss=0.7801 train_macro_f1=0.3304 validation_loss=1.0516 validation_macro_f1=0.2765
# [task3] target=usage fold=0 epoch=15/30 train_loss=0.7209 train_macro_f1=0.3425 validation_loss=1.0224 validation_macro_f1=0.2786
# [task3] target=usage fold=0 epoch=16/30 train_loss=0.6886 train_macro_f1=0.3576 validation_loss=1.0253 validation_macro_f1=0.2976
# [task3] target=usage fold=0 epoch=17/30 train_loss=0.6656 train_macro_f1=0.3687 validation_loss=1.1009 validation_macro_f1=0.3040
# [task3] target=usage fold=0 epoch=18/30 train_loss=0.6182 train_macro_f1=0.4128 validation_loss=1.1094 validation_macro_f1=0.3117
# [task3] target=usage fold=0 epoch=19/30 train_loss=0.5827 train_macro_f1=0.4282 validation_loss=1.1511 validation_macro_f1=0.3234
# [task3] target=usage fold=0 epoch=20/30 train_loss=0.5446 train_macro_f1=0.4454 validation_loss=1.1846 validation_macro_f1=0.3436
# [task3] target=usage fold=0 epoch=21/30 train_loss=0.5247 train_macro_f1=0.4773 validation_loss=1.1353 validation_macro_f1=0.3323
# [task3] target=usage fold=0 epoch=22/30 train_loss=0.4964 train_macro_f1=0.4836 validation_loss=1.1591 validation_macro_f1=0.3397
# [task3] target=usage fold=0 epoch=23/30 train_loss=0.4795 train_macro_f1=0.5030 validation_loss=1.1946 validation_macro_f1=0.3485
# [task3] target=usage fold=0 epoch=24/30 train_loss=0.4616 train_macro_f1=0.5233 validation_loss=1.1764 validation_macro_f1=0.3396
# [task3] target=usage fold=0 epoch=25/30 train_loss=0.4442 train_macro_f1=0.5389 validation_loss=1.1765 validation_macro_f1=0.3601
# [task3] target=usage fold=0 epoch=26/30 train_loss=0.4382 train_macro_f1=0.5595 validation_loss=1.1760 validation_macro_f1=0.3513
# [task3] target=usage fold=0 epoch=27/30 train_loss=0.4249 train_macro_f1=0.5605 validation_loss=1.1957 validation_macro_f1=0.3501
# [task3] target=usage fold=0 epoch=28/30 train_loss=0.4205 train_macro_f1=0.5778 validation_loss=1.1881 validation_macro_f1=0.3495
# [task3] target=usage fold=0 epoch=29/30 train_loss=0.4174 train_macro_f1=0.5865 validation_loss=1.1806 validation_macro_f1=0.3512
# [task3] target=usage fold=0 epoch=30/30 train_loss=0.4139 train_macro_f1=0.5860 validation_loss=1.1870 validation_macro_f1=0.3498
# [task3] completed target=usage fold=0: t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f0_s2753_70abdddddebe_20260831T124841Zc7fa81
# [task3] preparing target=usage fold=1: train=26,216, validation=6,556
# [task3] fitting fold-training RGB statistics for target=usage fold=1
# [task3] RGB statistics ready for target=usage fold=1
# [task3] registered t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f1_s2753_70abdddddebe_20260831T130419Zdab5ca; the first optimiser step may now run
# [task3] target=usage fold=1 epoch=1/30 train_loss=1.4655 train_macro_f1=0.1035 validation_loss=1.2670 validation_macro_f1=0.1519
# [task3] target=usage fold=1 epoch=2/30 train_loss=1.2801 train_macro_f1=0.1474 validation_loss=1.2136 validation_macro_f1=0.1477
# [task3] target=usage fold=1 epoch=3/30 train_loss=1.2211 train_macro_f1=0.1537 validation_loss=1.2126 validation_macro_f1=0.1665
# [task3] target=usage fold=1 epoch=4/30 train_loss=1.2207 train_macro_f1=0.1606 validation_loss=1.2298 validation_macro_f1=0.1610
# [task3] target=usage fold=1 epoch=5/30 train_loss=1.2252 train_macro_f1=0.1608 validation_loss=1.1830 validation_macro_f1=0.1734
# [task3] target=usage fold=1 epoch=6/30 train_loss=1.1715 train_macro_f1=0.1747 validation_loss=1.1629 validation_macro_f1=0.1942
# [task3] target=usage fold=1 epoch=7/30 train_loss=1.1593 train_macro_f1=0.1969 validation_loss=1.1892 validation_macro_f1=0.1695
# [task3] target=usage fold=1 epoch=8/30 train_loss=1.1140 train_macro_f1=0.2090 validation_loss=1.1472 validation_macro_f1=0.2423
# [task3] target=usage fold=1 epoch=9/30 train_loss=1.0680 train_macro_f1=0.2272 validation_loss=1.1669 validation_macro_f1=0.1722
# [task3] target=usage fold=1 epoch=10/30 train_loss=1.0270 train_macro_f1=0.2488 validation_loss=1.1130 validation_macro_f1=0.2282
# [task3] target=usage fold=1 epoch=11/30 train_loss=0.9650 train_macro_f1=0.2576 validation_loss=1.0924 validation_macro_f1=0.2475
# [task3] target=usage fold=1 epoch=12/30 train_loss=0.8971 train_macro_f1=0.2815 validation_loss=1.0876 validation_macro_f1=0.2566
# [task3] target=usage fold=1 epoch=13/30 train_loss=0.8601 train_macro_f1=0.3051 validation_loss=1.1192 validation_macro_f1=0.2918
# [task3] target=usage fold=1 epoch=14/30 train_loss=0.7706 train_macro_f1=0.3583 validation_loss=1.1087 validation_macro_f1=0.2848
# [task3] target=usage fold=1 epoch=15/30 train_loss=0.7959 train_macro_f1=0.3365 validation_loss=1.1589 validation_macro_f1=0.3098
# [task3] target=usage fold=1 epoch=16/30 train_loss=0.7020 train_macro_f1=0.4291 validation_loss=1.1007 validation_macro_f1=0.2993
# [task3] target=usage fold=1 epoch=17/30 train_loss=0.6720 train_macro_f1=0.3818 validation_loss=1.0961 validation_macro_f1=0.3271
# [task3] target=usage fold=1 epoch=18/30 train_loss=0.6316 train_macro_f1=0.4440 validation_loss=1.1701 validation_macro_f1=0.3211
# [task3] target=usage fold=1 epoch=19/30 train_loss=0.5943 train_macro_f1=0.3980 validation_loss=1.2234 validation_macro_f1=0.3200
# [task3] target=usage fold=1 epoch=20/30 train_loss=0.5416 train_macro_f1=0.5263 validation_loss=1.2435 validation_macro_f1=0.3301
# [task3] target=usage fold=1 epoch=21/30 train_loss=0.5157 train_macro_f1=0.5745 validation_loss=1.2659 validation_macro_f1=0.3257
# [task3] target=usage fold=1 epoch=22/30 train_loss=0.4933 train_macro_f1=0.5807 validation_loss=1.2998 validation_macro_f1=0.3279
# [task3] target=usage fold=1 epoch=23/30 train_loss=0.4623 train_macro_f1=0.6459 validation_loss=1.3115 validation_macro_f1=0.3318
# [task3] target=usage fold=1 epoch=24/30 train_loss=0.4471 train_macro_f1=0.6416 validation_loss=1.3441 validation_macro_f1=0.3359
# [task3] target=usage fold=1 epoch=25/30 train_loss=0.4331 train_macro_f1=0.6591 validation_loss=1.3698 validation_macro_f1=0.3319
# [task3] target=usage fold=1 epoch=26/30 train_loss=0.4203 train_macro_f1=0.6830 validation_loss=1.3490 validation_macro_f1=0.3304
# [task3] target=usage fold=1 epoch=27/30 train_loss=0.4112 train_macro_f1=0.6777 validation_loss=1.3875 validation_macro_f1=0.3322
# [task3] target=usage fold=1 epoch=28/30 train_loss=0.4054 train_macro_f1=0.6891 validation_loss=1.3915 validation_macro_f1=0.3322
# [task3] target=usage fold=1 epoch=29/30 train_loss=0.4020 train_macro_f1=0.6988 validation_loss=1.3885 validation_macro_f1=0.3332
# [task3] target=usage fold=1 epoch=30/30 train_loss=0.3984 train_macro_f1=0.6939 validation_loss=1.4004 validation_macro_f1=0.3334
# [task3] completed target=usage fold=1: t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f1_s2753_70abdddddebe_20260831T130419Zdab5ca
# [task3] preparing target=usage fold=2: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=2
# [task3] RGB statistics ready for target=usage fold=2
# [task3] registered t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f2_s2753_70abdddddebe_20260831T131953Zcc2b31; the first optimiser step may now run
# [task3] target=usage fold=2 epoch=1/30 train_loss=1.3748 train_macro_f1=0.1004 validation_loss=1.2896 validation_macro_f1=0.0965
# [task3] target=usage fold=2 epoch=2/30 train_loss=1.3582 train_macro_f1=0.1223 validation_loss=1.1211 validation_macro_f1=0.1590
# [task3] target=usage fold=2 epoch=3/30 train_loss=1.2814 train_macro_f1=0.1532 validation_loss=1.1177 validation_macro_f1=0.1760
# [task3] target=usage fold=2 epoch=4/30 train_loss=1.2488 train_macro_f1=0.1661 validation_loss=1.0782 validation_macro_f1=0.1888
# [task3] target=usage fold=2 epoch=5/30 train_loss=1.2094 train_macro_f1=0.1944 validation_loss=1.0453 validation_macro_f1=0.2188
# [task3] target=usage fold=2 epoch=6/30 train_loss=1.1649 train_macro_f1=0.2072 validation_loss=1.0367 validation_macro_f1=0.2082
# [task3] target=usage fold=2 epoch=7/30 train_loss=1.0871 train_macro_f1=0.2269 validation_loss=0.9683 validation_macro_f1=0.2551
# [task3] target=usage fold=2 epoch=8/30 train_loss=1.0529 train_macro_f1=0.2636 validation_loss=0.9704 validation_macro_f1=0.2392
# [task3] target=usage fold=2 epoch=9/30 train_loss=0.9925 train_macro_f1=0.2695 validation_loss=0.9444 validation_macro_f1=0.2489
# [task3] target=usage fold=2 epoch=10/30 train_loss=0.9079 train_macro_f1=0.2873 validation_loss=0.9467 validation_macro_f1=0.2628
# [task3] target=usage fold=2 epoch=11/30 train_loss=0.8811 train_macro_f1=0.2969 validation_loss=0.9530 validation_macro_f1=0.2921
# [task3] target=usage fold=2 epoch=12/30 train_loss=0.7981 train_macro_f1=0.3058 validation_loss=0.9423 validation_macro_f1=0.3019
# [task3] target=usage fold=2 epoch=13/30 train_loss=0.7619 train_macro_f1=0.4044 validation_loss=0.9598 validation_macro_f1=0.2654
# [task3] target=usage fold=2 epoch=14/30 train_loss=0.7096 train_macro_f1=0.3862 validation_loss=0.8987 validation_macro_f1=0.2997
# [task3] target=usage fold=2 epoch=15/30 train_loss=0.6678 train_macro_f1=0.4665 validation_loss=0.9041 validation_macro_f1=0.3147
# [task3] target=usage fold=2 epoch=16/30 train_loss=0.6248 train_macro_f1=0.4130 validation_loss=0.9404 validation_macro_f1=0.3201
# [task3] target=usage fold=2 epoch=17/30 train_loss=0.6252 train_macro_f1=0.4346 validation_loss=0.9070 validation_macro_f1=0.3235
# [task3] target=usage fold=2 epoch=18/30 train_loss=0.5562 train_macro_f1=0.5115 validation_loss=0.9111 validation_macro_f1=0.3300
# [task3] target=usage fold=2 epoch=19/30 train_loss=0.5313 train_macro_f1=0.5392 validation_loss=0.9301 validation_macro_f1=0.3394
# [task3] target=usage fold=2 epoch=20/30 train_loss=0.4943 train_macro_f1=0.5312 validation_loss=0.9609 validation_macro_f1=0.3408
# [task3] target=usage fold=2 epoch=21/30 train_loss=0.4767 train_macro_f1=0.5930 validation_loss=0.9474 validation_macro_f1=0.3240
# [task3] target=usage fold=2 epoch=22/30 train_loss=0.4464 train_macro_f1=0.6008 validation_loss=0.9571 validation_macro_f1=0.3400
# [task3] target=usage fold=2 epoch=23/30 train_loss=0.4208 train_macro_f1=0.6516 validation_loss=0.9700 validation_macro_f1=0.3377
# [task3] target=usage fold=2 epoch=24/30 train_loss=0.4051 train_macro_f1=0.6622 validation_loss=1.0152 validation_macro_f1=0.3516
# [task3] target=usage fold=2 epoch=25/30 train_loss=0.3940 train_macro_f1=0.6957 validation_loss=1.0086 validation_macro_f1=0.3481
# [task3] target=usage fold=2 epoch=26/30 train_loss=0.3820 train_macro_f1=0.7087 validation_loss=1.0327 validation_macro_f1=0.3574
# [task3] target=usage fold=2 epoch=27/30 train_loss=0.3746 train_macro_f1=0.7142 validation_loss=1.0440 validation_macro_f1=0.3595
# [task3] target=usage fold=2 epoch=28/30 train_loss=0.3700 train_macro_f1=0.7250 validation_loss=1.0493 validation_macro_f1=0.3561
# [task3] target=usage fold=2 epoch=29/30 train_loss=0.3660 train_macro_f1=0.7404 validation_loss=1.0500 validation_macro_f1=0.3595
# [task3] target=usage fold=2 epoch=30/30 train_loss=0.3631 train_macro_f1=0.7316 validation_loss=1.0513 validation_macro_f1=0.3562
# [task3] completed target=usage fold=2: t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f2_s2753_70abdddddebe_20260831T131953Zcc2b31
# [task3] preparing target=usage fold=3: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=3
# [task3] RGB statistics ready for target=usage fold=3
# [task3] registered t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f3_s2753_70abdddddebe_20260831T133523Z777285; the first optimiser step may now run
# [task3] target=usage fold=3 epoch=1/30 train_loss=1.4581 train_macro_f1=0.1054 validation_loss=1.2399 validation_macro_f1=0.1467
# [task3] target=usage fold=3 epoch=2/30 train_loss=1.2930 train_macro_f1=0.1574 validation_loss=1.1552 validation_macro_f1=0.1666
# [task3] target=usage fold=3 epoch=3/30 train_loss=1.2433 train_macro_f1=0.1666 validation_loss=1.1476 validation_macro_f1=0.1441
# [task3] target=usage fold=3 epoch=4/30 train_loss=1.2183 train_macro_f1=0.1893 validation_loss=1.1024 validation_macro_f1=0.2007
# [task3] target=usage fold=3 epoch=5/30 train_loss=1.1285 train_macro_f1=0.2161 validation_loss=1.0447 validation_macro_f1=0.2282
# [task3] target=usage fold=3 epoch=27/30 train_loss=0.3445 train_macro_f1=0.7242 validation_loss=1.0879 validation_macro_f1=0.3456
# [task3] target=usage fold=3 epoch=28/30 train_loss=0.3396 train_macro_f1=0.7214 validation_loss=1.0991 validation_macro_f1=0.3412
# [task3] target=usage fold=3 epoch=29/30 train_loss=0.3368 train_macro_f1=0.7353 validation_loss=1.0960 validation_macro_f1=0.3406
# [task3] target=usage fold=3 epoch=30/30 train_loss=0.3344 train_macro_f1=0.7349 validation_loss=1.1021 validation_macro_f1=0.3406
# [task3] completed target=usage fold=3: t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f3_s2753_70abdddddebe_20260831T133523Z777285
# [task3] preparing target=usage fold=4: train=26,215, validation=6,557
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f4_s2753_70abdddddebe_20260831T135054Zd71995; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=1.2885 train_macro_f1=0.1169 validation_loss=1.2112 validation_macro_f1=0.1500
# [task3] target=usage fold=4 epoch=2/30 train_loss=1.1739 train_macro_f1=0.1536 validation_loss=1.1595 validation_macro_f1=0.1592
# [task3] target=usage fold=4 epoch=3/30 train_loss=1.1400 train_macro_f1=0.1745 validation_loss=1.0921 validation_macro_f1=0.1810
# [task3] target=usage fold=4 epoch=4/30 train_loss=1.1016 train_macro_f1=0.1841 validation_loss=1.0618 validation_macro_f1=0.1687
# [task3] target=usage fold=4 epoch=5/30 train_loss=1.0676 train_macro_f1=0.2054 validation_loss=1.0506 validation_macro_f1=0.1947
# [task3] target=usage fold=4 epoch=6/30 train_loss=1.0388 train_macro_f1=0.2167 validation_loss=1.0543 validation_macro_f1=0.2042
# [task3] target=usage fold=4 epoch=7/30 train_loss=1.0143 train_macro_f1=0.2321 validation_loss=0.9892 validation_macro_f1=0.2232
# [task3] target=usage fold=4 epoch=8/30 train_loss=0.9686 train_macro_f1=0.2517 validation_loss=0.9583 validation_macro_f1=0.2194
# [task3] target=usage fold=4 epoch=9/30 train_loss=0.9474 train_macro_f1=0.2757 validation_loss=0.9706 validation_macro_f1=0.2503
# [task3] target=usage fold=4 epoch=10/30 train_loss=0.8971 train_macro_f1=0.2834 validation_loss=0.9121 validation_macro_f1=0.2678
# [task3] target=usage fold=4 epoch=11/30 train_loss=0.8400 train_macro_f1=0.3001 validation_loss=0.8995 validation_macro_f1=0.2968
# [task3] target=usage fold=4 epoch=12/30 train_loss=0.7947 train_macro_f1=0.3112 validation_loss=0.8662 validation_macro_f1=0.2622
# [task3] target=usage fold=4 epoch=13/30 train_loss=0.7434 train_macro_f1=0.3429 validation_loss=0.8505 validation_macro_f1=0.3191
# [task3] target=usage fold=4 epoch=14/30 train_loss=0.6921 train_macro_f1=0.3622 validation_loss=0.8853 validation_macro_f1=0.3318
# [task3] target=usage fold=4 epoch=15/30 train_loss=0.6367 train_macro_f1=0.3755 validation_loss=0.8181 validation_macro_f1=0.3295
# [task3] target=usage fold=4 epoch=16/30 train_loss=0.5903 train_macro_f1=0.4037 validation_loss=0.8406 validation_macro_f1=0.3551
# [task3] target=usage fold=4 epoch=17/30 train_loss=0.5439 train_macro_f1=0.4190 validation_loss=0.8088 validation_macro_f1=0.3154
# [task3] target=usage fold=4 epoch=18/30 train_loss=0.5084 train_macro_f1=0.4300 validation_loss=0.8650 validation_macro_f1=0.3363
# [task3] target=usage fold=4 epoch=19/30 train_loss=0.4766 train_macro_f1=0.4630 validation_loss=0.8638 validation_macro_f1=0.3409
# [task3] target=usage fold=4 epoch=20/30 train_loss=0.4346 train_macro_f1=0.4922 validation_loss=0.9826 validation_macro_f1=0.3461
# [task3] target=usage fold=4 epoch=21/30 train_loss=0.4162 train_macro_f1=0.5190 validation_loss=0.9894 validation_macro_f1=0.3652
# [task3] target=usage fold=4 epoch=22/30 train_loss=0.3840 train_macro_f1=0.5439 validation_loss=0.9708 validation_macro_f1=0.3636
# [task3] target=usage fold=4 epoch=23/30 train_loss=0.3703 train_macro_f1=0.5641 validation_loss=1.0106 validation_macro_f1=0.3509
# [task3] target=usage fold=4 epoch=24/30 train_loss=0.3510 train_macro_f1=0.5906 validation_loss=1.0430 validation_macro_f1=0.3482
# [task3] target=usage fold=4 epoch=25/30 train_loss=0.3390 train_macro_f1=0.6022 validation_loss=1.0460 validation_macro_f1=0.3511
# [task3] target=usage fold=4 epoch=26/30 train_loss=0.3292 train_macro_f1=0.6070 validation_loss=1.0739 validation_macro_f1=0.3451
# [task3] target=usage fold=4 epoch=27/30 train_loss=0.3218 train_macro_f1=0.6320 validation_loss=1.0755 validation_macro_f1=0.3533
# [task3] target=usage fold=4 epoch=28/30 train_loss=0.3166 train_macro_f1=0.6350 validation_loss=1.0844 validation_macro_f1=0.3493
# [task3] target=usage fold=4 epoch=29/30 train_loss=0.3133 train_macro_f1=0.6318 validation_loss=1.0769 validation_macro_f1=0.3575
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.3112 train_macro_f1=0.6411 validation_loss=1.0863 validation_macro_f1=0.3571
# [task3] completed target=usage fold=4: t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f4_s2753_70abdddddebe_20260831T135054Zd71995
# [task3] completed pooled five-fold OOF experiment=t3_usage_tinyconvnext18 target=usage
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_usage_e7_tinyconvnext18/usage/aggregate/metrics.json',
#  'macro_f1': 0.34509413831503766,
#  'macro_f1_without_home': 0.3882309056044173,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f0_s2753_70abdddddebe_20260831T124841Zc7fa81',
#    't3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f1_s2753_70abdddddebe_20260831T130419Zdab5ca',
#    't3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f2_s2753_70abdddddebe_20260831T131953Zcc2b31',
#    't3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f3_s2753_70abdddddebe_20260831T133523Z777285',
#    't3_usage_e7_tinyconvnext18_usage_tinyconvnext18_f4_s2753_70abdddddebe_20260831T135054Zd71995'],
#   'completed_rows': 5,
#   'ready': True}}

# %% [markdown]
# ## 5. Train Gender E7: TinyHRNet-20
#
# This changes only the accepted E1 model architecture. It keeps ordinary cross-entropy and all other E1 controls.

# %%
gender_e7_result = run_task3_child_cv(
    "gender_tinyhrnet20",
    parent_run_ids=gender_parent_run_ids,
    folds=range(5),
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[REPO_DIR / "results/runs.csv"],
    device_name="cuda",
)
gender_e7_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, gender_e7_result["fold_run_ids"]
)
{
    "metrics_path": gender_e7_result["metrics_path"],
    "macro_f1": gender_e7_result["metrics"]["macro_f1"],
    "registry_audit": gender_e7_registry_audit,
}
# Out:
# [task3] starting five-fold experiment=t3_gender_tinyhrnet20 for target=gender
# [task3] preparing target=gender fold=0: train=26,220, validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f0_s2753_0a66578f8433_20260831T140631Z12ad21; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.6339 train_macro_f1=0.4326 validation_loss=1.1365 validation_macro_f1=0.2699
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.4446 train_macro_f1=0.5936 validation_loss=0.5505 validation_macro_f1=0.5400
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.3863 train_macro_f1=0.6545 validation_loss=0.4158 validation_macro_f1=0.6594
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.3457 train_macro_f1=0.7044 validation_loss=0.4319 validation_macro_f1=0.5303
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.3076 train_macro_f1=0.7377 validation_loss=0.4715 validation_macro_f1=0.6044
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.2684 train_macro_f1=0.7765 validation_loss=0.4811 validation_macro_f1=0.6437
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.2343 train_macro_f1=0.8091 validation_loss=0.4539 validation_macro_f1=0.6648
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.1999 train_macro_f1=0.8365 validation_loss=0.5126 validation_macro_f1=0.6122
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.1579 train_macro_f1=0.8807 validation_loss=0.5758 validation_macro_f1=0.5639
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.1242 train_macro_f1=0.9064 validation_loss=0.5248 validation_macro_f1=0.6452
# [task3] target=gender fold=1 epoch=21/30 train_loss=0.0014 train_macro_f1=0.9998 validation_loss=0.7126 validation_macro_f1=0.6998
# [task3] target=gender fold=1 epoch=22/30 train_loss=0.0008 train_macro_f1=0.9998 validation_loss=0.7087 validation_macro_f1=0.7029
# [task3] target=gender fold=1 epoch=23/30 train_loss=0.0007 train_macro_f1=0.9999 validation_loss=0.7020 validation_macro_f1=0.6951
# [task3] target=gender fold=1 epoch=24/30 train_loss=0.0007 train_macro_f1=0.9999 validation_loss=0.7085 validation_macro_f1=0.7110
# [task3] target=gender fold=1 epoch=25/30 train_loss=0.0006 train_macro_f1=0.9999 validation_loss=0.7102 validation_macro_f1=0.7047
# [task3] target=gender fold=1 epoch=26/30 train_loss=0.0006 train_macro_f1=0.9998 validation_loss=0.7175 validation_macro_f1=0.7002
# [task3] target=gender fold=1 epoch=27/30 train_loss=0.0005 train_macro_f1=0.9999 validation_loss=0.7108 validation_macro_f1=0.6978
# [task3] target=gender fold=1 epoch=28/30 train_loss=0.0005 train_macro_f1=0.9999 validation_loss=0.7150 validation_macro_f1=0.7043
# [task3] target=gender fold=1 epoch=29/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.7124 validation_macro_f1=0.6978
# [task3] target=gender fold=1 epoch=30/30 train_loss=0.0005 train_macro_f1=0.9999 validation_loss=0.7109 validation_macro_f1=0.7038
# [task3] completed target=gender fold=1: t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f1_s2753_0a66578f8433_20260831T141543Z4f40ec
# [task3] preparing target=gender fold=2: train=26,220, validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=2
# [task3] RGB statistics ready for target=gender fold=2
# [task3] registered t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f2_s2753_0a66578f8433_20260831T142456Z391826; the first optimiser step may now run
# [task3] target=gender fold=2 epoch=1/30 train_loss=0.6320 train_macro_f1=0.4262 validation_loss=0.6065 validation_macro_f1=0.5800
# [task3] target=gender fold=2 epoch=2/30 train_loss=0.4419 train_macro_f1=0.6209 validation_loss=0.5768 validation_macro_f1=0.3832
# [task3] target=gender fold=2 epoch=3/30 train_loss=0.3895 train_macro_f1=0.6569 validation_loss=0.4324 validation_macro_f1=0.5618
# [task3] target=gender fold=2 epoch=4/30 train_loss=0.3489 train_macro_f1=0.6973 validation_loss=0.5453 validation_macro_f1=0.4848
# [task3] target=gender fold=2 epoch=5/30 train_loss=0.3077 train_macro_f1=0.7311 validation_loss=0.5847 validation_macro_f1=0.5784
# [task3] target=gender fold=2 epoch=6/30 train_loss=0.2754 train_macro_f1=0.7701 validation_loss=0.6086 validation_macro_f1=0.5189
# [task3] target=gender fold=2 epoch=7/30 train_loss=0.2364 train_macro_f1=0.8101 validation_loss=0.5173 validation_macro_f1=0.5770
# [task3] target=gender fold=2 epoch=8/30 train_loss=0.1972 train_macro_f1=0.8434 validation_loss=0.7546 validation_macro_f1=0.5739
# [task3] target=gender fold=2 epoch=30/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.6892 validation_macro_f1=0.6639
# [task3] completed target=gender fold=2: t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f2_s2753_0a66578f8433_20260831T142456Z391826
# [task3] preparing target=gender fold=3: train=26,219, validation=6,554
# [task3] fitting fold-training RGB statistics for target=gender fold=3
# [task3] RGB statistics ready for target=gender fold=3
# [task3] registered t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f3_s2753_0a66578f8433_20260831T143409Z11532f; the first optimiser step may now run
# [task3] target=gender fold=3 epoch=1/30 train_loss=0.6348 train_macro_f1=0.4212 validation_loss=0.5053 validation_macro_f1=0.6132
# [task3] target=gender fold=3 epoch=2/30 train_loss=0.4478 train_macro_f1=0.5848 validation_loss=0.4428 validation_macro_f1=0.5370
# [task3] target=gender fold=3 epoch=3/30 train_loss=0.3972 train_macro_f1=0.6412 validation_loss=0.4914 validation_macro_f1=0.5944
# [task3] target=gender fold=3 epoch=4/30 train_loss=0.3552 train_macro_f1=0.6808 validation_loss=0.4923 validation_macro_f1=0.6469
# [task3] target=gender fold=3 epoch=5/30 train_loss=0.3149 train_macro_f1=0.7286 validation_loss=1.3447 validation_macro_f1=0.3834
# [task3] target=gender fold=3 epoch=6/30 train_loss=0.2838 train_macro_f1=0.7660 validation_loss=0.5475 validation_macro_f1=0.4913
# [task3] target=gender fold=3 epoch=7/30 train_loss=0.2434 train_macro_f1=0.7973 validation_loss=0.4486 validation_macro_f1=0.6945
# [task3] target=gender fold=3 epoch=8/30 train_loss=0.2020 train_macro_f1=0.8460 validation_loss=0.4614 validation_macro_f1=0.6828
# [task3] target=gender fold=3 epoch=9/30 train_loss=0.1626 train_macro_f1=0.8802 validation_loss=0.4628 validation_macro_f1=0.6934
# [task3] target=gender fold=3 epoch=10/30 train_loss=0.1282 train_macro_f1=0.9028 validation_loss=1.2215 validation_macro_f1=0.6001
# [task3] target=gender fold=3 epoch=11/30 train_loss=0.0991 train_macro_f1=0.9351 validation_loss=0.5195 validation_macro_f1=0.6898
# [task3] target=gender fold=3 epoch=12/30 train_loss=0.0758 train_macro_f1=0.9489 validation_loss=0.5172 validation_macro_f1=0.7036
# [task3] target=gender fold=3 epoch=13/30 train_loss=0.0491 train_macro_f1=0.9688 validation_loss=0.6020 validation_macro_f1=0.6564
# [task3] target=gender fold=3 epoch=14/30 train_loss=0.0299 train_macro_f1=0.9827 validation_loss=0.5931 validation_macro_f1=0.6983
# [task3] target=gender fold=3 epoch=15/30 train_loss=0.0189 train_macro_f1=0.9920 validation_loss=0.6048 validation_macro_f1=0.7086
# [task3] target=gender fold=3 epoch=16/30 train_loss=0.0096 train_macro_f1=0.9967 validation_loss=0.6297 validation_macro_f1=0.7104
# [task3] target=gender fold=3 epoch=17/30 train_loss=0.0074 train_macro_f1=0.9986 validation_loss=0.6637 validation_macro_f1=0.6987
# [task3] target=gender fold=3 epoch=18/30 train_loss=0.0024 train_macro_f1=0.9997 validation_loss=0.6598 validation_macro_f1=0.7089
# [task3] target=gender fold=3 epoch=19/30 train_loss=0.0022 train_macro_f1=0.9998 validation_loss=0.6656 validation_macro_f1=0.7155
# [task3] target=gender fold=3 epoch=20/30 train_loss=0.0014 train_macro_f1=0.9999 validation_loss=0.6764 validation_macro_f1=0.7056
# [task3] target=gender fold=3 epoch=21/30 train_loss=0.0011 train_macro_f1=1.0000 validation_loss=0.6739 validation_macro_f1=0.7141
# [task3] target=gender fold=3 epoch=22/30 train_loss=0.0008 train_macro_f1=1.0000 validation_loss=0.6768 validation_macro_f1=0.7120
# [task3] target=gender fold=3 epoch=23/30 train_loss=0.0006 train_macro_f1=1.0000 validation_loss=0.6782 validation_macro_f1=0.7196
# [task3] target=gender fold=3 epoch=24/30 train_loss=0.0006 train_macro_f1=1.0000 validation_loss=0.6863 validation_macro_f1=0.7222
# [task3] target=gender fold=3 epoch=25/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.6840 validation_macro_f1=0.7226
# [task3] target=gender fold=3 epoch=26/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.6873 validation_macro_f1=0.7201
# [task3] target=gender fold=3 epoch=27/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.6946 validation_macro_f1=0.7153
# [task3] target=gender fold=3 epoch=28/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.6864 validation_macro_f1=0.7200
# [task3] target=gender fold=3 epoch=29/30 train_loss=0.0005 train_macro_f1=1.0000 validation_loss=0.6913 validation_macro_f1=0.7175
# [task3] target=gender fold=3 epoch=30/30 train_loss=0.0004 train_macro_f1=1.0000 validation_loss=0.6935 validation_macro_f1=0.7222
# [task3] completed target=gender fold=3: t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f3_s2753_0a66578f8433_20260831T143409Z11532f
# [task3] preparing target=gender fold=4: train=26,216, validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f4_s2753_0a66578f8433_20260831T144320Zbbb2cb; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.6440 train_macro_f1=0.3873 validation_loss=0.5597 validation_macro_f1=0.5018
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.4503 train_macro_f1=0.5901 validation_loss=0.4374 validation_macro_f1=0.6481
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.3910 train_macro_f1=0.6473 validation_loss=0.7767 validation_macro_f1=0.4900
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.3502 train_macro_f1=0.6893 validation_loss=0.4544 validation_macro_f1=0.6035
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.3195 train_macro_f1=0.7237 validation_loss=0.4399 validation_macro_f1=0.5957
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.2787 train_macro_f1=0.7690 validation_loss=0.5922 validation_macro_f1=0.6119
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.0006 train_macro_f1=0.9998 validation_loss=0.6792 validation_macro_f1=0.7001
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.0005 train_macro_f1=0.9999 validation_loss=0.6735 validation_macro_f1=0.7028
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.0006 train_macro_f1=0.9998 validation_loss=0.6716 validation_macro_f1=0.7072
# [task3] completed target=gender fold=4: t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f4_s2753_0a66578f8433_20260831T144320Zbbb2cb
# [task3] completed pooled five-fold OOF experiment=t3_gender_tinyhrnet20 target=gender
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_gender_e7_tinyhrnet20/gender/aggregate/metrics.json',
#  'macro_f1': 0.7025170247569041,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f0_s2753_0a66578f8433_20260831T140631Z12ad21',
#    't3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f1_s2753_0a66578f8433_20260831T141543Z4f40ec',
#    't3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f2_s2753_0a66578f8433_20260831T142456Z391826',
#    't3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f3_s2753_0a66578f8433_20260831T143409Z11532f',
#    't3_gender_e7_tinyhrnet20_gender_tinyhrnet20_f4_s2753_0a66578f8433_20260831T144320Zbbb2cb'],
#   'completed_rows': 5,
#   'ready': True}}

# %% [markdown]
# ## 6. Confirm the saved E7 artifacts
#
# This is a factual training summary only. The frozen gates are applied in the main Task 3 notebook.

# %%
import pandas as pd

parent_metric_paths = {
    "usage": DRIVE_TASK_DIR / "experiments/t3_usage_e2_class_balanced_ce/usage/aggregate/metrics.json",
    "gender": DRIVE_TASK_DIR / "baseline/gender/aggregate/metrics.json",
}
children = {"usage": usage_e7_result, "gender": gender_e7_result}
comparison = []
for target, child in children.items():
    parent = json.loads(parent_metric_paths[target].read_text(encoding="utf-8"))
    comparison.append(
        {
            "target": target,
            "parent_macro_f1": parent["macro_f1"],
            "e7_macro_f1": child["metrics"]["macro_f1"],
            "macro_f1_change": child["metrics"]["macro_f1"] - parent["macro_f1"],
            "model_family": child["metrics"]["model_family"],
            "parameter_count": child["metrics"]["parameter_count"],
            "architecture_macs": child["metrics"]["architecture_macs"],
            "e7_metrics_path": child["metrics_path"],
        }
    )
pd.DataFrame(comparison)
# Out:
#    target  parent_macro_f1  e7_macro_f1  macro_f1_change  \
# 0   usage         0.408171     0.345094        -0.063076
# 1  gender         0.711753     0.702517        -0.009236
#
#            model_family  parameter_count  architecture_macs  \
# 0  task3_tinyconvnext18           384345           95297616
# 1     task3_tinyhrnet20           374445          104064700
#
#                                      e7_metrics_path
# 0  /content/drive/MyDrive/MLA2/task3/experiments/...
# 1  /content/drive/MyDrive/MLA2/task3/experiments/...
