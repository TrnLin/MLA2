# %% [markdown]
# # Task 3 — GeM Gender Dataset V2 G2: Tiny Translation
#
# **Run All starts only two fits:** Gender folds 0 and 4. It reuses the exact unfiltered E6 GeM model and changes only its training augmentation. It never trains G1, G3, or Usage U1.

# %% [markdown]
# ## 1. Mount Drive and load the Task 3 branch
#
# Drive stores the teacher ZIP, completed causal parents, registry, and new artifacts.

# %%
from pathlib import Path
import os
import subprocess
import sys
import time
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "fashion-analysis-and-cleanup"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
LOCAL_DATA_ZIP = Path("/content/task3-data.zip")
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"
LOCAL_REGISTRY = REPO_DIR / "results/runs.csv"

def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab GPU runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)
if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=REPO_DIR, text=True).strip()
print("Repository ready:", REPO_DIR)
print("Branch:", BRANCH)
print("Commit:", commit)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# $ git fetch origin task-3-gender-usage-classification
# $ git switch task-3-gender-usage-classification
# $ git merge --ff-only origin/task-3-gender-usage-classification
# Repository ready: /content/MLA2
# Branch: task-3-gender-usage-classification
# Commit: 56d077190108c016ad2537ecb77300b44d8f08bb

# %% [markdown]
# ## 2. Restore teacher images on the Colab disk
#
# Only the official teacher dataset is used. The public high-resolution collection is excluded.

# %%
def copy_teacher_zip_to_local_disk():
    if LOCAL_DATA_ZIP.is_file():
        try:
            with zipfile.ZipFile(LOCAL_DATA_ZIP) as existing:
                existing.infolist()
            print("Using the existing local ZIP copy:", LOCAL_DATA_ZIP)
            return
        except zipfile.BadZipFile:
            LOCAL_DATA_ZIP.unlink()

    partial = LOCAL_DATA_ZIP.with_suffix(".zip.partial")
    for attempt in range(1, 4):
        partial.unlink(missing_ok=True)
        try:
            if not DATA_ZIP.is_file():
                raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")
            expected_bytes = DATA_ZIP.stat().st_size
            print(
                f"Copying {expected_bytes / 1024**3:.2f} GiB from Drive "
                f"(attempt {attempt}/3)...",
                flush=True,
            )
            copied = 0
            next_report = 256 * 1024**2
            with DATA_ZIP.open("rb") as source, partial.open("wb") as target:
                while chunk := source.read(8 * 1024**2):
                    target.write(chunk)
                    copied += len(chunk)
                    if copied >= next_report:
                        print(f"  copied {copied / 1024**2:.0f} MiB", flush=True)
                        next_report += 256 * 1024**2
            if copied != expected_bytes:
                raise OSError(f"ZIP copy is incomplete: {copied} of {expected_bytes} bytes")
            partial.replace(LOCAL_DATA_ZIP)
            return
        except (OSError, FileNotFoundError) as error:
            partial.unlink(missing_ok=True)
            if attempt == 3:
                raise RuntimeError(
                    "Drive disconnected three times. Reconnect Drive, then rerun this cell."
                ) from error
            try:
                drive.flush_and_unmount()
            except Exception as unmount_error:
                print("Drive unmount warning:", unmount_error)
            drive.mount(str(DRIVE_MOUNT), force_remount=True)
            time.sleep(2)

copy_teacher_zip_to_local_disk()

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_dirs = (teacher_dir / "train/images_train", teacher_dir / "test/images_test")
image_suffixes = {".jpg", ".jpeg"}

with zipfile.ZipFile(LOCAL_DATA_ZIP) as archive:
    names = archive.namelist()
    if any(Path(name).is_absolute() or ".." in Path(name).parts for name in names):
        raise RuntimeError("The teacher archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/") and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    current_images = sum(
        path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
    )
    if current_images != expected_images or not all(path.is_file() for path in required_files):
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(
    path.suffix.lower() in image_suffixes for folder in image_dirs for path in folder.glob("*")
)
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found {actual_images:,}; "
        f"missing files: {missing_files}"
    )

os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)
(DRIVE_TASK_DIR / "results").mkdir(parents=True, exist_ok=True)
print(f"Teacher data ready: {actual_images:,} images")
print("Drive output root:", DRIVE_TASK_DIR)
# Out:
# Using the existing local ZIP copy: /content/task3-data.zip
# Teacher data is already extracted; skipping.
# Teacher data ready: 44,441 images
# Drive output root: /content/drive/MyDrive/MLA2/task3

# %% [markdown]
# ## 3. Verify the frozen screen without training
#
# The check resolves the exact five-fold causal parent, verifies the GPU and teacher files, and takes zero optimizer steps.

# %%
GENDER_E6_PARENT_RUN_IDS = (
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a",
    "t3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd",
)

from fashion.train.task3_dataset_v2 import check_task3_dataset_v2_setup
from fashion.train.task3_experiments import latest_completed_gender_e6_parent_run_ids

resolved_parents = latest_completed_gender_e6_parent_run_ids(output_root=DRIVE_TASK_DIR)
if resolved_parents != GENDER_E6_PARENT_RUN_IDS:
    raise RuntimeError("The resolved causal parents differ from the frozen tuple.")

preflight = check_task3_dataset_v2_setup(
    "gender_v2_translation",
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    root=REPO_DIR,
    device_name="cuda",
)
if preflight["input_view"] != "full":
    raise RuntimeError("G2 must keep the full RGB input.")
if preflight["training_augmentation"] != "translation_uniform_2px_p05":
    raise RuntimeError("G2 must use only the frozen 2-pixel translation.")
if preflight["sample_weight_strategy"] != "none":
    raise RuntimeError("G2 must not add example weighting.")
print("GPU:", preflight["environment"]["gpu"])
print("Screen folds:", preflight["screen_folds"])
print("Model:", preflight["child"]["model_family"])
print("Parameters:", f'{preflight["parameter_count"]:,}')
print("Optimizer steps during check:", preflight["optimizer_steps"])
# Out:
# GPU: NVIDIA L4
# Screen folds: [0, 4]
# Model: task3_small_cnn_gem_p3
# Parameters: 390,181
# Optimizer steps during check: 0

# %% [markdown]
# ## 4. Frozen hypothesis
#
# Gender loses about 0.145–0.155 macro-F1 under a tiny positional shift, and no earlier Gender training run tested translation. G2 tests whether teaching only this missing invariance reduces memorisation without removing useful pixels.
#
# On each training load, translation is applied with probability 0.5. Horizontal and vertical shifts are independent integers from -2 through 2 pixels, with bilinear interpolation and white fill. Validation stays full, deterministic, and unaugmented. Architecture, loss, optimiser, epoch budget, labels, and folds stay unchanged.

# %% [markdown]
# ## 5. Train the two-fold screen
#
# Artifacts are written directly to Drive after every epoch. A completed matching fold is reused after a disconnect.

# %%
from fashion.train.task3_dataset_v2 import run_task3_dataset_v2_screen
from fashion.train.task3_experiments import audit_completed_registry_rows

result = run_task3_dataset_v2_screen(
    "gender_v2_translation",
    parent_run_ids=GENDER_E6_PARENT_RUN_IDS,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[LOCAL_REGISTRY],
    root=REPO_DIR,
    device_name="cuda",
    reuse_completed=True,
)
registry_audit = audit_completed_registry_rows(DRIVE_REGISTRY, result["fold_run_ids"])
{
    "metrics_path": result["metrics_path"],
    "folds": result["metrics"]["validation_folds"],
    "macro_f1": result["metrics"]["macro_f1"],
    
    "mean_train_validation_gap": result["metrics"]["mean_final_train_validation_gap"],
    "registry_audit": registry_audit,
}
# Out:
# [task3] preparing target=gender fold=0: train=26,220 (before selection=26,220), validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_v2_g2_translation_gender_smallcnngem3_f0_s2753_cb072542dbdc_20260904T135102Z6698e6; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.5834 train_macro_f1=0.4582 validation_loss=0.5451 validation_macro_f1=0.3604
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.4419 train_macro_f1=0.6047 validation_loss=0.4440 validation_macro_f1=0.6405
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.3888 train_macro_f1=0.6626 validation_loss=0.3789 validation_macro_f1=0.6781
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.3550 train_macro_f1=0.6912 validation_loss=0.3637 validation_macro_f1=0.6333
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.3291 train_macro_f1=0.7156 validation_loss=0.3684 validation_macro_f1=0.6877
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.3051 train_macro_f1=0.7412 validation_loss=0.3510 validation_macro_f1=0.7184
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.2860 train_macro_f1=0.7509 validation_loss=0.4027 validation_macro_f1=0.6855
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.2699 train_macro_f1=0.7761 validation_loss=0.3285 validation_macro_f1=0.7076
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.2476 train_macro_f1=0.7972 validation_loss=0.3407 validation_macro_f1=0.7071
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.2356 train_macro_f1=0.8066 validation_loss=0.3501 validation_macro_f1=0.7264
# [task3] target=gender fold=0 epoch=11/30 train_loss=0.2211 train_macro_f1=0.8243 validation_loss=0.3288 validation_macro_f1=0.7285
# [task3] target=gender fold=0 epoch=12/30 train_loss=0.2091 train_macro_f1=0.8279 validation_loss=0.3365 validation_macro_f1=0.6981
# [task3] target=gender fold=0 epoch=13/30 train_loss=0.1904 train_macro_f1=0.8574 validation_loss=0.3204 validation_macro_f1=0.7357
# [task3] target=gender fold=0 epoch=14/30 train_loss=0.1735 train_macro_f1=0.8697 validation_loss=0.3183 validation_macro_f1=0.7065
# [task3] target=gender fold=0 epoch=15/30 train_loss=0.1645 train_macro_f1=0.8788 validation_loss=0.3287 validation_macro_f1=0.7066
# [task3] target=gender fold=0 epoch=16/30 train_loss=0.1494 train_macro_f1=0.8905 validation_loss=0.3298 validation_macro_f1=0.7267
# [task3] target=gender fold=0 epoch=17/30 train_loss=0.1372 train_macro_f1=0.8956 validation_loss=0.3182 validation_macro_f1=0.7415
# [task3] target=gender fold=0 epoch=18/30 train_loss=0.1291 train_macro_f1=0.9136 validation_loss=0.3913 validation_macro_f1=0.7122
# [task3] target=gender fold=0 epoch=19/30 train_loss=0.1165 train_macro_f1=0.9238 validation_loss=0.3009 validation_macro_f1=0.7447
# [task3] target=gender fold=0 epoch=20/30 train_loss=0.1102 train_macro_f1=0.9283 validation_loss=0.3247 validation_macro_f1=0.7555
# [task3] target=gender fold=0 epoch=21/30 train_loss=0.0991 train_macro_f1=0.9390 validation_loss=0.3179 validation_macro_f1=0.7431
# [task3] target=gender fold=0 epoch=22/30 train_loss=0.0954 train_macro_f1=0.9445 validation_loss=0.3227 validation_macro_f1=0.7513
# [task3] target=gender fold=0 epoch=23/30 train_loss=0.0892 train_macro_f1=0.9446 validation_loss=0.3028 validation_macro_f1=0.7513
# [task3] target=gender fold=0 epoch=24/30 train_loss=0.0835 train_macro_f1=0.9500 validation_loss=0.3120 validation_macro_f1=0.7547
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.0839 train_macro_f1=0.9499 validation_loss=0.3217 validation_macro_f1=0.7494
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.0776 train_macro_f1=0.9565 validation_loss=0.3041 validation_macro_f1=0.7593
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.0745 train_macro_f1=0.9597 validation_loss=0.3014 validation_macro_f1=0.7637
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.0727 train_macro_f1=0.9597 validation_loss=0.3037 validation_macro_f1=0.7607
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.0734 train_macro_f1=0.9567 validation_loss=0.3012 validation_macro_f1=0.7636
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.0702 train_macro_f1=0.9601 validation_loss=0.3027 validation_macro_f1=0.7605
# [task3] completed target=gender fold=0: t3_gender_v2_g2_translation_gender_smallcnngem3_f0_s2753_cb072542dbdc_20260904T135102Z6698e6
# [task3] preparing target=gender fold=4: train=26,216 (before selection=26,216), validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_v2_g2_translation_gender_smallcnngem3_f4_s2753_cb072542dbdc_20260904T140011Z2211b1; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.5825 train_macro_f1=0.4375 validation_loss=0.5647 validation_macro_f1=0.5127
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.4342 train_macro_f1=0.6074 validation_loss=0.4433 validation_macro_f1=0.6090
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.3834 train_macro_f1=0.6625 validation_loss=0.3783 validation_macro_f1=0.6587
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.3512 train_macro_f1=0.6917 validation_loss=0.3605 validation_macro_f1=0.6979
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.3238 train_macro_f1=0.7250 validation_loss=0.3530 validation_macro_f1=0.6704
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.3021 train_macro_f1=0.7399 validation_loss=0.5056 validation_macro_f1=0.6646
# [task3] target=gender fold=4 epoch=7/30 train_loss=0.2819 train_macro_f1=0.7633 validation_loss=0.3496 validation_macro_f1=0.6947
# [task3] target=gender fold=4 epoch=8/30 train_loss=0.2620 train_macro_f1=0.7881 validation_loss=0.3360 validation_macro_f1=0.7022
# [task3] target=gender fold=4 epoch=9/30 train_loss=0.2491 train_macro_f1=0.7956 validation_loss=0.3368 validation_macro_f1=0.7330
# [task3] target=gender fold=4 epoch=10/30 train_loss=0.2290 train_macro_f1=0.8161 validation_loss=0.4229 validation_macro_f1=0.6895
# [task3] target=gender fold=4 epoch=11/30 train_loss=0.2154 train_macro_f1=0.8250 validation_loss=0.2986 validation_macro_f1=0.7313
# [task3] target=gender fold=4 epoch=12/30 train_loss=0.2025 train_macro_f1=0.8439 validation_loss=0.2991 validation_macro_f1=0.7153
# [task3] target=gender fold=4 epoch=13/30 train_loss=0.1834 train_macro_f1=0.8594 validation_loss=0.3342 validation_macro_f1=0.7151
# [task3] target=gender fold=4 epoch=14/30 train_loss=0.1716 train_macro_f1=0.8705 validation_loss=0.2905 validation_macro_f1=0.7360
# [task3] target=gender fold=4 epoch=15/30 train_loss=0.1569 train_macro_f1=0.8805 validation_loss=0.3030 validation_macro_f1=0.6975
# [task3] target=gender fold=4 epoch=16/30 train_loss=0.1460 train_macro_f1=0.8946 validation_loss=0.3078 validation_macro_f1=0.7194
# [task3] target=gender fold=4 epoch=17/30 train_loss=0.1343 train_macro_f1=0.9041 validation_loss=0.2988 validation_macro_f1=0.7419
# [task3] target=gender fold=4 epoch=18/30 train_loss=0.1252 train_macro_f1=0.9103 validation_loss=0.3017 validation_macro_f1=0.7323
# [task3] target=gender fold=4 epoch=19/30 train_loss=0.1156 train_macro_f1=0.9206 validation_loss=0.3037 validation_macro_f1=0.7313
# [task3] target=gender fold=4 epoch=20/30 train_loss=0.1097 train_macro_f1=0.9310 validation_loss=0.3131 validation_macro_f1=0.7273
# [task3] target=gender fold=4 epoch=21/30 train_loss=0.0985 train_macro_f1=0.9364 validation_loss=0.3111 validation_macro_f1=0.7136
# [task3] target=gender fold=4 epoch=22/30 train_loss=0.0903 train_macro_f1=0.9471 validation_loss=0.2871 validation_macro_f1=0.7449
# [task3] target=gender fold=4 epoch=23/30 train_loss=0.0867 train_macro_f1=0.9471 validation_loss=0.2935 validation_macro_f1=0.7180
# [task3] target=gender fold=4 epoch=24/30 train_loss=0.0807 train_macro_f1=0.9541 validation_loss=0.2908 validation_macro_f1=0.7285
# [task3] target=gender fold=4 epoch=25/30 train_loss=0.0794 train_macro_f1=0.9508 validation_loss=0.2894 validation_macro_f1=0.7426
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.0751 train_macro_f1=0.9586 validation_loss=0.3061 validation_macro_f1=0.7345
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.0721 train_macro_f1=0.9575 validation_loss=0.2900 validation_macro_f1=0.7336
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.0716 train_macro_f1=0.9615 validation_loss=0.2867 validation_macro_f1=0.7321
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.0688 train_macro_f1=0.9647 validation_loss=0.2865 validation_macro_f1=0.7387
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.0687 train_macro_f1=0.9636 validation_loss=0.2862 validation_macro_f1=0.7305
# [task3] completed target=gender fold=4: t3_gender_v2_g2_translation_gender_smallcnngem3_f4_s2753_cb072542dbdc_20260904T140011Z2211b1
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_gender_v2_g2_translation/gender/aggregate/metrics.json',
#  'folds': [0, 4],
#  'macro_f1': 0.7457260919007412,
#  'mean_train_validation_gap': 0.24838545670179668,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_gender_v2_g2_translation_gender_smallcnngem3_f0_s2753_cb072542dbdc_20260904T135102Z6698e6',
#    't3_gender_v2_g2_translation_gender_smallcnngem3_f4_s2753_cb072542dbdc_20260904T140011Z2211b1'],
#   'completed_rows': 2,
#   'ready': True}}

# %% [markdown]
# ## 6. Confirm the saved evidence
#
# This cell only summarizes the finished folds. It does not promote the model.

# %%
import pandas as pd

display(pd.DataFrame([
    {
        "screen": "gender_v2_translation",
        "folds": result["metrics"]["validation_folds"],
        "macro_f1": result["metrics"]["macro_f1"],
        "fold_sd": result["metrics"]["fold_macro_f1_sample_sd"],
        "mean_train_validation_gap": result["metrics"]["mean_final_train_validation_gap"],
        "metrics_path": result["metrics_path"],
    }
]))
print("Stop here. This two-fold result must be analysed before any five-fold promotion.")
# Out:
#                   screen   folds  macro_f1   fold_sd  \
# 0  gender_v2_translation  [0, 4]  0.745726  0.021239
#
#    mean_train_validation_gap  \
# 0                   0.248385
#
#                                         metrics_path
# 0  /content/drive/MyDrive/MLA2/task3/experiments/...
# Stop here. This two-fold result must be analysed before any five-fold promotion.
