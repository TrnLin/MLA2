# %% [markdown]
# # Task 3 — GeM and Focal-Loss E6 Experiments
#
# This notebook trains only the two frozen E6 children. **Run All starts ten new fits:** five Gender GeM folds, then five Usage focal-loss folds. It never retrains E1, E2, E4, or E5.

# %% [markdown]
# ## 1. Mount Drive and load the submitted branch
#
# Drive supplies the teacher data, accepted parents, persistent registry, and E6 artifacts.

# %%
from pathlib import Path
import json
import os
import subprocess
import sys
import zipfile

REPO_URL = "https://github.com/TrnLin/MLA2.git"
BRANCH = "task-3-gender-usage-classification"
REPO_DIR = Path("/content/MLA2")
DRIVE_MOUNT = Path("/content/drive")
DRIVE_PROJECT_DIR = DRIVE_MOUNT / "MyDrive/MLA2"
DATA_ZIP = DRIVE_PROJECT_DIR / "data/task3-data.zip"
DRIVE_TASK_DIR = DRIVE_PROJECT_DIR / "task3"
DRIVE_REGISTRY = DRIVE_TASK_DIR / "results/runs.csv"


def run_checked(command, *, cwd=None):
    command = [str(part) for part in command]
    print("$", " ".join(command), flush=True)
    return subprocess.run(command, cwd=cwd, check=True)

# %%
try:
    from google.colab import drive
except ImportError as exc:
    raise RuntimeError("Connect this notebook to a Google Colab runtime first.") from exc

drive.mount(str(DRIVE_MOUNT), force_remount=False)

if (REPO_DIR / ".git").is_dir():
    remote_url = subprocess.check_output(
        ["git", "remote", "get-url", "origin"], cwd=REPO_DIR, text=True
    ).strip()
    if remote_url != REPO_URL:
        raise RuntimeError(f"{REPO_DIR} belongs to a different repository: {remote_url}")
    run_checked(["git", "fetch", "origin", BRANCH], cwd=REPO_DIR)
    run_checked(["git", "switch", BRANCH], cwd=REPO_DIR)
    dirty = subprocess.check_output(
        ["git", "status", "--porcelain"], cwd=REPO_DIR, text=True
    ).strip().splitlines()
    if dirty:
        print("Local repository changes found:")
        for change in dirty:
            print(f"  {change}")
        print("Trying a safe fast-forward update. Git will stop before overwriting a local file.")
    run_checked(["git", "merge", "--ff-only", f"origin/{BRANCH}"], cwd=REPO_DIR)
elif REPO_DIR.exists():
    raise RuntimeError(f"{REPO_DIR} exists but is not a Git repository.")
else:
    run_checked(["git", "clone", "--branch", BRANCH, "--single-branch", REPO_URL, REPO_DIR])

commit = subprocess.check_output(["git", "rev-parse", "HEAD"], cwd=REPO_DIR, text=True).strip()
print(f"Repository ready: {REPO_DIR}")
print(f"Branch: {BRANCH}")
print(f"Commit: {commit}")
# Out:
# Mounted at /content/drive
# $ git clone --branch task-3-gender-usage-classification --single-branch https://github.com/TrnLin/MLA2.git /content/MLA2
# Repository ready: /content/MLA2
# Branch: task-3-gender-usage-classification
# Commit: 7e3c0b23309a3f8f0160ba6bdb07ee25f1bdf3d4

# %% [markdown]
# ## 2. Copy the teacher data onto the runtime disk
#
# The ZIP keeps the repository’s required `data/raw/teacher` structure.

# %%
if not DATA_ZIP.is_file():
    raise FileNotFoundError(f"Dataset archive not found: {DATA_ZIP}")

teacher_dir = REPO_DIR / "data/raw/teacher"
required_files = (
    teacher_dir / "train/styles_train.csv",
    teacher_dir / "test/styles_prediction.csv",
)
image_suffixes = {".jpg", ".jpeg"}

with zipfile.ZipFile(DATA_ZIP) as archive:
    names = archive.namelist()
    unsafe_names = [name for name in names if Path(name).is_absolute() or ".." in Path(name).parts]
    if unsafe_names:
        raise RuntimeError("The dataset archive contains an unsafe path.")
    expected_images = sum(
        name.startswith("data/raw/teacher/") and Path(name).suffix.lower() in image_suffixes
        for name in names
    )
    if expected_images == 0:
        raise RuntimeError("The archive has no teacher images in the expected folder.")
    current_images = sum(path.suffix.lower() in image_suffixes for path in teacher_dir.rglob("*"))
    needs_extract = current_images != expected_images or not all(path.is_file() for path in required_files)
    if needs_extract:
        print(f"Extracting {expected_images:,} teacher images...", flush=True)
        archive.extractall(REPO_DIR)
    else:
        print("Teacher data is already extracted; skipping.")

actual_images = sum(path.suffix.lower() in image_suffixes for path in teacher_dir.rglob("*"))
missing_files = [str(path) for path in required_files if not path.is_file()]
if actual_images != expected_images or missing_files:
    raise RuntimeError(
        f"Dataset check failed: expected {expected_images:,} images, found {actual_images:,}; "
        f"missing files: {missing_files}"
    )
print(f"Teacher data ready: {actual_images:,} images")
# Out:
# Extracting 44,441 teacher images...
# Teacher data ready: 44,441 images

# %% [markdown]
# ## 3. Resolve the accepted parents and verify E6
#
# The checks create no optimizer and take no training step.

# %%
os.chdir(REPO_DIR)
os.environ["FASHION_PROJECT_ROOT"] = str(REPO_DIR)
source_dir = str(REPO_DIR / "src")
if source_dir not in sys.path:
    sys.path.insert(0, source_dir)

for output_dir in (DRIVE_TASK_DIR / "experiments", DRIVE_TASK_DIR / "logs", DRIVE_TASK_DIR / "results"):
    output_dir.mkdir(parents=True, exist_ok=True)

from fashion.train.task3_experiments import (
    check_task3_child_setup,
    latest_completed_baseline_parent_run_ids,
    latest_completed_usage_e2_parent_run_ids,
)

gender_parent_run_ids = latest_completed_baseline_parent_run_ids(
    "gender", output_root=DRIVE_TASK_DIR
)
usage_parent_run_ids = latest_completed_usage_e2_parent_run_ids(
    output_root=DRIVE_TASK_DIR
)
gender_e6_check = check_task3_child_setup(
    "gender_gem_p3",
    parent_run_ids=gender_parent_run_ids,
    root=REPO_DIR,
    device_name="cuda",
)
usage_e6_check = check_task3_child_setup(
    "usage_focal_gamma1",
    parent_run_ids=usage_parent_run_ids,
    root=REPO_DIR,
    device_name="cuda",
)

if gender_e6_check["model_family"] != "task3_small_cnn_gem_p3":
    raise RuntimeError("Gender E6 pooling contract changed")
if gender_e6_check["parameter_count"] != 390_181:
    raise RuntimeError("Gender E6 must keep the E1 parameter count")
if usage_e6_check["focal_gamma"] != 1.0:
    raise RuntimeError("Usage E6 focal gamma changed")
usage_child = usage_e6_check["child"]
if usage_child["class_weight_beta"] != 0.999 or usage_child["class_weight_cap"] != 5.0:
    raise RuntimeError("Usage E6 must keep the accepted E2 class weights")

print("GPU:", gender_e6_check["environment"]["gpu"])
print("Gender E1 parents:", gender_parent_run_ids)
print("Usage E2 parents: ", usage_parent_run_ids)
print("Gender E6 parameters:", gender_e6_check["parameter_count"])
print("Usage E6 focal gamma:", usage_e6_check["focal_gamma"])
print("Optimizer steps during checks:", gender_e6_check["optimizer_steps"], usage_e6_check["optimizer_steps"])
# Out:
# GPU: NVIDIA L4
# Gender E1 parents: ('t3_baseline_gender_smallcnn_f0_s2753_e46cd00adf0a_20260830T082833Zf8c1e0', 't3_baseline_gender_smallcnn_f1_s2753_e46cd00adf0a_20260830T083708Z143950', 't3_baseline_gender_smallcnn_f2_s2753_e46cd00adf0a_20260830T084548Z5acbf0', 't3_baseline_gender_smallcnn_f3_s2753_e46cd00adf0a_20260830T085427Z5d34f9', 't3_baseline_gender_smallcnn_f4_s2753_e46cd00adf0a_20260830T090303Z41a843')
# Usage E2 parents:  ('t3_usage_e2_class_balanced_ce_usage_smallcnn_f0_s2753_5461e048c3b3_20260830T115815Z356f6d', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f1_s2753_5461e048c3b3_20260830T120645Z6d08cd', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f2_s2753_5461e048c3b3_20260830T121514Zd58aa0', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f3_s2753_5461e048c3b3_20260830T122347Z2cb06e', 't3_usage_e2_class_balanced_ce_usage_smallcnn_f4_s2753_5461e048c3b3_20260830T123218Z94db47')
# Gender E6 parameters: 390181
# Usage E6 focal gamma: 1.0
# Optimizer steps during checks: 0 0

# %% [markdown]
# ## 4. Train Gender E6: SmallCNN with fixed GeM `p=3`
#
# This changes only the accepted E1 model’s global pooling.

# %%
from fashion.train.task3_experiments import (
    audit_completed_registry_rows,
    run_task3_child_cv,
)

gender_e6_result = run_task3_child_cv(
    "gender_gem_p3",
    parent_run_ids=gender_parent_run_ids,
    folds=range(5),
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[REPO_DIR / "results/runs.csv"],
    device_name="cuda",
)
gender_e6_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, gender_e6_result["fold_run_ids"]
)
{
    "metrics_path": gender_e6_result["metrics_path"],
    "macro_f1": gender_e6_result["metrics"]["macro_f1"],
    "registry_audit": gender_e6_registry_audit,
}
# Out:
# [task3] starting five-fold experiment=t3_gender_gem_p3_smallcnn for target=gender
# [task3] preparing target=gender fold=0: train=26,220, validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=0
# [task3] RGB statistics ready for target=gender fold=0
# [task3] registered t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f; the first optimiser step may now run
# [task3] target=gender fold=0 epoch=1/30 train_loss=0.5536 train_macro_f1=0.4868 validation_loss=0.5575 validation_macro_f1=0.3516
# [task3] target=gender fold=0 epoch=2/30 train_loss=0.4116 train_macro_f1=0.6290 validation_loss=0.4352 validation_macro_f1=0.6615
# [task3] target=gender fold=0 epoch=3/30 train_loss=0.3546 train_macro_f1=0.6955 validation_loss=0.3695 validation_macro_f1=0.6626
# [task3] target=gender fold=0 epoch=4/30 train_loss=0.3166 train_macro_f1=0.7310 validation_loss=0.3739 validation_macro_f1=0.6936
# [task3] target=gender fold=0 epoch=5/30 train_loss=0.2818 train_macro_f1=0.7658 validation_loss=0.4514 validation_macro_f1=0.6670
# [task3] target=gender fold=0 epoch=6/30 train_loss=0.2455 train_macro_f1=0.7996 validation_loss=0.3545 validation_macro_f1=0.7117
# [task3] target=gender fold=0 epoch=7/30 train_loss=0.2170 train_macro_f1=0.8215 validation_loss=0.3805 validation_macro_f1=0.6608
# [task3] target=gender fold=0 epoch=8/30 train_loss=0.1866 train_macro_f1=0.8596 validation_loss=0.3796 validation_macro_f1=0.6766
# [task3] target=gender fold=0 epoch=9/30 train_loss=0.1515 train_macro_f1=0.8927 validation_loss=0.3559 validation_macro_f1=0.6793
# [task3] target=gender fold=0 epoch=10/30 train_loss=0.1254 train_macro_f1=0.9177 validation_loss=0.4205 validation_macro_f1=0.6656
# [task3] target=gender fold=0 epoch=11/30 train_loss=0.1016 train_macro_f1=0.9357 validation_loss=0.3668 validation_macro_f1=0.7095
# [task3] target=gender fold=0 epoch=12/30 train_loss=0.0753 train_macro_f1=0.9588 validation_loss=0.4116 validation_macro_f1=0.6763
# [task3] target=gender fold=0 epoch=13/30 train_loss=0.0574 train_macro_f1=0.9722 validation_loss=0.4059 validation_macro_f1=0.7197
# [task3] target=gender fold=0 epoch=14/30 train_loss=0.0386 train_macro_f1=0.9862 validation_loss=0.4247 validation_macro_f1=0.6975
# [task3] target=gender fold=0 epoch=15/30 train_loss=0.0285 train_macro_f1=0.9932 validation_loss=0.4209 validation_macro_f1=0.6914
# [task3] target=gender fold=0 epoch=16/30 train_loss=0.0217 train_macro_f1=0.9959 validation_loss=0.4498 validation_macro_f1=0.7063
# [task3] target=gender fold=0 epoch=17/30 train_loss=0.0178 train_macro_f1=0.9970 validation_loss=0.5119 validation_macro_f1=0.6879
# [task3] target=gender fold=0 epoch=18/30 train_loss=0.0123 train_macro_f1=0.9994 validation_loss=0.4619 validation_macro_f1=0.6926
# [task3] target=gender fold=0 epoch=19/30 train_loss=0.0104 train_macro_f1=0.9994 validation_loss=0.4389 validation_macro_f1=0.7008
# [task3] target=gender fold=0 epoch=20/30 train_loss=0.0079 train_macro_f1=0.9997 validation_loss=0.4239 validation_macro_f1=0.7219
# [task3] target=gender fold=0 epoch=21/30 train_loss=0.0063 train_macro_f1=0.9997 validation_loss=0.4591 validation_macro_f1=0.7056
# [task3] target=gender fold=0 epoch=22/30 train_loss=0.0054 train_macro_f1=0.9998 validation_loss=0.4444 validation_macro_f1=0.7240
# [task3] target=gender fold=0 epoch=23/30 train_loss=0.0050 train_macro_f1=0.9997 validation_loss=0.4481 validation_macro_f1=0.7118
# [task3] target=gender fold=0 epoch=24/30 train_loss=0.0043 train_macro_f1=0.9999 validation_loss=0.4502 validation_macro_f1=0.7244
# [task3] target=gender fold=0 epoch=25/30 train_loss=0.0039 train_macro_f1=0.9999 validation_loss=0.4473 validation_macro_f1=0.7188
# [task3] target=gender fold=0 epoch=26/30 train_loss=0.0038 train_macro_f1=0.9998 validation_loss=0.4433 validation_macro_f1=0.7185
# [task3] target=gender fold=0 epoch=27/30 train_loss=0.0034 train_macro_f1=0.9999 validation_loss=0.4486 validation_macro_f1=0.7180
# [task3] target=gender fold=0 epoch=28/30 train_loss=0.0033 train_macro_f1=0.9998 validation_loss=0.4498 validation_macro_f1=0.7205
# [task3] target=gender fold=0 epoch=29/30 train_loss=0.0032 train_macro_f1=0.9999 validation_loss=0.4538 validation_macro_f1=0.7153
# [task3] target=gender fold=0 epoch=30/30 train_loss=0.0031 train_macro_f1=0.9998 validation_loss=0.4555 validation_macro_f1=0.7196
# [task3] completed target=gender fold=0: t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f
# [task3] preparing target=gender fold=1: train=26,217, validation=6,556
# [task3] fitting fold-training RGB statistics for target=gender fold=1
# [task3] RGB statistics ready for target=gender fold=1
# [task3] registered t3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5; the first optimiser step may now run
# [task3] target=gender fold=1 epoch=1/30 train_loss=0.5584 train_macro_f1=0.4929 validation_loss=0.5762 validation_macro_f1=0.5247
# [task3] target=gender fold=1 epoch=2/30 train_loss=0.4055 train_macro_f1=0.6440 validation_loss=0.4208 validation_macro_f1=0.6423
# [task3] target=gender fold=1 epoch=3/30 train_loss=0.3498 train_macro_f1=0.6929 validation_loss=0.4034 validation_macro_f1=0.5919
# [task3] target=gender fold=1 epoch=4/30 train_loss=0.3117 train_macro_f1=0.7403 validation_loss=0.4259 validation_macro_f1=0.6541
# [task3] target=gender fold=1 epoch=5/30 train_loss=0.2707 train_macro_f1=0.7798 validation_loss=0.5702 validation_macro_f1=0.6099
# [task3] target=gender fold=1 epoch=6/30 train_loss=0.2451 train_macro_f1=0.8021 validation_loss=0.3867 validation_macro_f1=0.6297
# [task3] target=gender fold=1 epoch=7/30 train_loss=0.2115 train_macro_f1=0.8313 validation_loss=0.4853 validation_macro_f1=0.5132
# [task3] target=gender fold=1 epoch=8/30 train_loss=0.1782 train_macro_f1=0.8640 validation_loss=0.4827 validation_macro_f1=0.5757
# [task3] target=gender fold=1 epoch=9/30 train_loss=0.1445 train_macro_f1=0.8965 validation_loss=0.3856 validation_macro_f1=0.7124
# [task3] target=gender fold=1 epoch=10/30 train_loss=0.1194 train_macro_f1=0.9221 validation_loss=0.4261 validation_macro_f1=0.6946
# [task3] target=gender fold=1 epoch=11/30 train_loss=0.0943 train_macro_f1=0.9375 validation_loss=0.5229 validation_macro_f1=0.6370
# [task3] target=gender fold=1 epoch=12/30 train_loss=0.0677 train_macro_f1=0.9678 validation_loss=0.3785 validation_macro_f1=0.7208
# [task3] target=gender fold=1 epoch=13/30 train_loss=0.0517 train_macro_f1=0.9757 validation_loss=0.4911 validation_macro_f1=0.6860
# [task3] target=gender fold=1 epoch=14/30 train_loss=0.0382 train_macro_f1=0.9841 validation_loss=0.4120 validation_macro_f1=0.7007
# [task3] target=gender fold=1 epoch=15/30 train_loss=0.0272 train_macro_f1=0.9931 validation_loss=0.4747 validation_macro_f1=0.6917
# [task3] target=gender fold=1 epoch=16/30 train_loss=0.0190 train_macro_f1=0.9973 validation_loss=0.4285 validation_macro_f1=0.7184
# [task3] target=gender fold=1 epoch=17/30 train_loss=0.0157 train_macro_f1=0.9980 validation_loss=0.4203 validation_macro_f1=0.7144
# [task3] target=gender fold=1 epoch=18/30 train_loss=0.0105 train_macro_f1=0.9993 validation_loss=0.5717 validation_macro_f1=0.6809
# [task3] target=gender fold=1 epoch=19/30 train_loss=0.0081 train_macro_f1=0.9998 validation_loss=0.4462 validation_macro_f1=0.7141
# [task3] target=gender fold=1 epoch=20/30 train_loss=0.0069 train_macro_f1=0.9997 validation_loss=0.4292 validation_macro_f1=0.7299
# [task3] target=gender fold=1 epoch=21/30 train_loss=0.0064 train_macro_f1=0.9997 validation_loss=0.3921 validation_macro_f1=0.7476
# [task3] target=gender fold=1 epoch=22/30 train_loss=0.0048 train_macro_f1=0.9999 validation_loss=0.3962 validation_macro_f1=0.7349
# [task3] target=gender fold=1 epoch=23/30 train_loss=0.0044 train_macro_f1=0.9999 validation_loss=0.4191 validation_macro_f1=0.7463
# [task3] target=gender fold=1 epoch=24/30 train_loss=0.0039 train_macro_f1=0.9999 validation_loss=0.4107 validation_macro_f1=0.7407
# [task3] target=gender fold=1 epoch=25/30 train_loss=0.0036 train_macro_f1=0.9999 validation_loss=0.4111 validation_macro_f1=0.7422
# [task3] target=gender fold=1 epoch=26/30 train_loss=0.0036 train_macro_f1=0.9998 validation_loss=0.4093 validation_macro_f1=0.7364
# [task3] target=gender fold=1 epoch=27/30 train_loss=0.0032 train_macro_f1=0.9998 validation_loss=0.4201 validation_macro_f1=0.7379
# [task3] target=gender fold=1 epoch=28/30 train_loss=0.0030 train_macro_f1=0.9999 validation_loss=0.4261 validation_macro_f1=0.7436
# [task3] target=gender fold=1 epoch=29/30 train_loss=0.0029 train_macro_f1=0.9999 validation_loss=0.4230 validation_macro_f1=0.7402
# [task3] target=gender fold=1 epoch=30/30 train_loss=0.0029 train_macro_f1=0.9999 validation_loss=0.4178 validation_macro_f1=0.7426
# [task3] completed target=gender fold=1: t3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5
# [task3] preparing target=gender fold=2: train=26,220, validation=6,553
# [task3] fitting fold-training RGB statistics for target=gender fold=2
# [task3] RGB statistics ready for target=gender fold=2
# [task3] registered t3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677; the first optimiser step may now run
# [task3] target=gender fold=2 epoch=1/30 train_loss=0.5582 train_macro_f1=0.4679 validation_loss=0.4615 validation_macro_f1=0.6014
# [task3] target=gender fold=2 epoch=2/30 train_loss=0.4125 train_macro_f1=0.6317 validation_loss=0.4972 validation_macro_f1=0.5841
# [task3] target=gender fold=2 epoch=3/30 train_loss=0.3635 train_macro_f1=0.6862 validation_loss=0.4542 validation_macro_f1=0.4747
# [task3] target=gender fold=2 epoch=4/30 train_loss=0.3148 train_macro_f1=0.7391 validation_loss=0.3560 validation_macro_f1=0.6786
# [task3] target=gender fold=2 epoch=5/30 train_loss=0.2802 train_macro_f1=0.7700 validation_loss=0.3669 validation_macro_f1=0.6842
# [task3] target=gender fold=2 epoch=6/30 train_loss=0.2522 train_macro_f1=0.7963 validation_loss=0.4097 validation_macro_f1=0.6827
# [task3] target=gender fold=2 epoch=7/30 train_loss=0.2164 train_macro_f1=0.8277 validation_loss=0.6833 validation_macro_f1=0.5464
# [task3] target=gender fold=2 epoch=8/30 train_loss=0.1833 train_macro_f1=0.8617 validation_loss=0.3916 validation_macro_f1=0.6980
# [task3] target=gender fold=2 epoch=9/30 train_loss=0.1573 train_macro_f1=0.8842 validation_loss=0.3633 validation_macro_f1=0.7090
# [task3] target=gender fold=2 epoch=10/30 train_loss=0.1279 train_macro_f1=0.9145 validation_loss=0.3423 validation_macro_f1=0.7218
# [task3] target=gender fold=2 epoch=11/30 train_loss=0.1000 train_macro_f1=0.9384 validation_loss=0.5230 validation_macro_f1=0.6858
# [task3] target=gender fold=2 epoch=12/30 train_loss=0.0756 train_macro_f1=0.9587 validation_loss=0.3353 validation_macro_f1=0.7199
# [task3] target=gender fold=2 epoch=13/30 train_loss=0.0557 train_macro_f1=0.9775 validation_loss=0.7756 validation_macro_f1=0.6285
# [task3] target=gender fold=2 epoch=14/30 train_loss=0.0425 train_macro_f1=0.9855 validation_loss=0.3982 validation_macro_f1=0.7176
# [task3] target=gender fold=2 epoch=15/30 train_loss=0.0307 train_macro_f1=0.9922 validation_loss=0.4077 validation_macro_f1=0.6805
# [task3] target=gender fold=2 epoch=16/30 train_loss=0.0215 train_macro_f1=0.9966 validation_loss=0.3917 validation_macro_f1=0.7042
# [task3] target=gender fold=2 epoch=17/30 train_loss=0.0162 train_macro_f1=0.9983 validation_loss=0.4132 validation_macro_f1=0.7211
# [task3] target=gender fold=2 epoch=18/30 train_loss=0.0112 train_macro_f1=0.9996 validation_loss=0.4161 validation_macro_f1=0.7136
# [task3] target=gender fold=2 epoch=19/30 train_loss=0.0093 train_macro_f1=0.9998 validation_loss=0.4795 validation_macro_f1=0.7058
# [task3] target=gender fold=2 epoch=20/30 train_loss=0.0081 train_macro_f1=0.9998 validation_loss=0.4063 validation_macro_f1=0.7352
# [task3] target=gender fold=2 epoch=21/30 train_loss=0.0066 train_macro_f1=0.9997 validation_loss=0.4228 validation_macro_f1=0.7331
# [task3] target=gender fold=2 epoch=22/30 train_loss=0.0059 train_macro_f1=0.9994 validation_loss=0.4090 validation_macro_f1=0.7276
# [task3] target=gender fold=2 epoch=23/30 train_loss=0.0050 train_macro_f1=0.9999 validation_loss=0.4038 validation_macro_f1=0.7312
# [task3] target=gender fold=2 epoch=24/30 train_loss=0.0043 train_macro_f1=0.9999 validation_loss=0.4158 validation_macro_f1=0.7249
# [task3] target=gender fold=2 epoch=25/30 train_loss=0.0039 train_macro_f1=0.9999 validation_loss=0.4106 validation_macro_f1=0.7360
# [task3] target=gender fold=2 epoch=26/30 train_loss=0.0038 train_macro_f1=0.9998 validation_loss=0.4240 validation_macro_f1=0.7331
# [task3] target=gender fold=2 epoch=27/30 train_loss=0.0034 train_macro_f1=0.9999 validation_loss=0.4174 validation_macro_f1=0.7287
# [task3] target=gender fold=2 epoch=28/30 train_loss=0.0033 train_macro_f1=0.9999 validation_loss=0.4230 validation_macro_f1=0.7315
# [task3] target=gender fold=2 epoch=29/30 train_loss=0.0032 train_macro_f1=0.9999 validation_loss=0.4164 validation_macro_f1=0.7317
# [task3] target=gender fold=2 epoch=30/30 train_loss=0.0032 train_macro_f1=1.0000 validation_loss=0.4204 validation_macro_f1=0.7287
# [task3] completed target=gender fold=2: t3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677
# [task3] preparing target=gender fold=3: train=26,219, validation=6,554
# [task3] fitting fold-training RGB statistics for target=gender fold=3
# [task3] RGB statistics ready for target=gender fold=3
# [task3] registered t3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a; the first optimiser step may now run
# [task3] target=gender fold=3 epoch=1/30 train_loss=0.5569 train_macro_f1=0.4701 validation_loss=0.4817 validation_macro_f1=0.5967
# [task3] target=gender fold=3 epoch=2/30 train_loss=0.4122 train_macro_f1=0.6260 validation_loss=0.4109 validation_macro_f1=0.6183
# [task3] target=gender fold=3 epoch=3/30 train_loss=0.3592 train_macro_f1=0.6840 validation_loss=0.3721 validation_macro_f1=0.6725
# [task3] target=gender fold=3 epoch=4/30 train_loss=0.3209 train_macro_f1=0.7203 validation_loss=0.4003 validation_macro_f1=0.6545
# [task3] target=gender fold=3 epoch=5/30 train_loss=0.2826 train_macro_f1=0.7618 validation_loss=0.3578 validation_macro_f1=0.6386
# [task3] target=gender fold=3 epoch=6/30 train_loss=0.2522 train_macro_f1=0.7957 validation_loss=0.3624 validation_macro_f1=0.6838
# [task3] target=gender fold=3 epoch=7/30 train_loss=0.2194 train_macro_f1=0.8236 validation_loss=0.3877 validation_macro_f1=0.7047
# [task3] target=gender fold=3 epoch=8/30 train_loss=0.1856 train_macro_f1=0.8569 validation_loss=0.4409 validation_macro_f1=0.7007
# [task3] target=gender fold=3 epoch=9/30 train_loss=0.1650 train_macro_f1=0.8823 validation_loss=0.3833 validation_macro_f1=0.6481
# [task3] target=gender fold=3 epoch=10/30 train_loss=0.1287 train_macro_f1=0.9097 validation_loss=0.3292 validation_macro_f1=0.7400
# [task3] target=gender fold=3 epoch=11/30 train_loss=0.1003 train_macro_f1=0.9352 validation_loss=0.3609 validation_macro_f1=0.7443
# [task3] target=gender fold=3 epoch=12/30 train_loss=0.0825 train_macro_f1=0.9528 validation_loss=0.3597 validation_macro_f1=0.7283
# [task3] target=gender fold=3 epoch=13/30 train_loss=0.0595 train_macro_f1=0.9684 validation_loss=0.4078 validation_macro_f1=0.7276
# [task3] target=gender fold=3 epoch=14/30 train_loss=0.0430 train_macro_f1=0.9814 validation_loss=0.3818 validation_macro_f1=0.7204
# [task3] target=gender fold=3 epoch=15/30 train_loss=0.0296 train_macro_f1=0.9917 validation_loss=0.4178 validation_macro_f1=0.7316
# [task3] target=gender fold=3 epoch=16/30 train_loss=0.0211 train_macro_f1=0.9956 validation_loss=0.5422 validation_macro_f1=0.7090
# [task3] target=gender fold=3 epoch=17/30 train_loss=0.0169 train_macro_f1=0.9976 validation_loss=0.3943 validation_macro_f1=0.7241
# [task3] target=gender fold=3 epoch=18/30 train_loss=0.0118 train_macro_f1=0.9992 validation_loss=0.4122 validation_macro_f1=0.7294
# [task3] target=gender fold=3 epoch=19/30 train_loss=0.0087 train_macro_f1=0.9998 validation_loss=0.3989 validation_macro_f1=0.7529
# [task3] target=gender fold=3 epoch=20/30 train_loss=0.0072 train_macro_f1=0.9998 validation_loss=0.4215 validation_macro_f1=0.7323
# [task3] target=gender fold=3 epoch=21/30 train_loss=0.0060 train_macro_f1=1.0000 validation_loss=0.3986 validation_macro_f1=0.7530
# [task3] target=gender fold=3 epoch=22/30 train_loss=0.0052 train_macro_f1=1.0000 validation_loss=0.4349 validation_macro_f1=0.7367
# [task3] target=gender fold=3 epoch=23/30 train_loss=0.0045 train_macro_f1=1.0000 validation_loss=0.4068 validation_macro_f1=0.7560
# [task3] target=gender fold=3 epoch=24/30 train_loss=0.0041 train_macro_f1=1.0000 validation_loss=0.4467 validation_macro_f1=0.7477
# [task3] target=gender fold=3 epoch=25/30 train_loss=0.0038 train_macro_f1=1.0000 validation_loss=0.4340 validation_macro_f1=0.7433
# [task3] target=gender fold=3 epoch=26/30 train_loss=0.0035 train_macro_f1=1.0000 validation_loss=0.4206 validation_macro_f1=0.7494
# [task3] target=gender fold=3 epoch=27/30 train_loss=0.0033 train_macro_f1=1.0000 validation_loss=0.4209 validation_macro_f1=0.7586
# [task3] target=gender fold=3 epoch=28/30 train_loss=0.0032 train_macro_f1=1.0000 validation_loss=0.4285 validation_macro_f1=0.7481
# [task3] target=gender fold=3 epoch=29/30 train_loss=0.0031 train_macro_f1=1.0000 validation_loss=0.4257 validation_macro_f1=0.7562
# [task3] target=gender fold=3 epoch=30/30 train_loss=0.0030 train_macro_f1=1.0000 validation_loss=0.4292 validation_macro_f1=0.7495
# [task3] completed target=gender fold=3: t3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a
# [task3] preparing target=gender fold=4: train=26,216, validation=6,557
# [task3] fitting fold-training RGB statistics for target=gender fold=4
# [task3] RGB statistics ready for target=gender fold=4
# [task3] registered t3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd; the first optimiser step may now run
# [task3] target=gender fold=4 epoch=1/30 train_loss=0.5592 train_macro_f1=0.4581 validation_loss=0.5157 validation_macro_f1=0.5397
# [task3] target=gender fold=4 epoch=2/30 train_loss=0.4056 train_macro_f1=0.6289 validation_loss=0.4297 validation_macro_f1=0.6270
# [task3] target=gender fold=4 epoch=3/30 train_loss=0.3511 train_macro_f1=0.6938 validation_loss=0.3701 validation_macro_f1=0.6649
# [task3] target=gender fold=4 epoch=4/30 train_loss=0.3097 train_macro_f1=0.7352 validation_loss=0.4077 validation_macro_f1=0.6813
# [task3] target=gender fold=4 epoch=5/30 train_loss=0.2765 train_macro_f1=0.7758 validation_loss=0.3447 validation_macro_f1=0.6942
# [task3] target=gender fold=4 epoch=6/30 train_loss=0.2427 train_macro_f1=0.8043 validation_loss=0.4754 validation_macro_f1=0.7088
# [task3] target=gender fold=4 epoch=7/30 train_loss=0.2076 train_macro_f1=0.8405 validation_loss=0.5279 validation_macro_f1=0.6548
# [task3] target=gender fold=4 epoch=8/30 train_loss=0.1769 train_macro_f1=0.8734 validation_loss=0.3606 validation_macro_f1=0.6281
# [task3] target=gender fold=4 epoch=9/30 train_loss=0.1489 train_macro_f1=0.8926 validation_loss=0.3563 validation_macro_f1=0.7318
# [task3] target=gender fold=4 epoch=10/30 train_loss=0.1173 train_macro_f1=0.9265 validation_loss=0.5888 validation_macro_f1=0.6580
# [task3] target=gender fold=4 epoch=11/30 train_loss=0.0951 train_macro_f1=0.9427 validation_loss=0.3650 validation_macro_f1=0.7381
# [task3] target=gender fold=4 epoch=12/30 train_loss=0.0702 train_macro_f1=0.9642 validation_loss=0.3750 validation_macro_f1=0.7115
# [task3] target=gender fold=4 epoch=13/30 train_loss=0.0504 train_macro_f1=0.9802 validation_loss=0.3916 validation_macro_f1=0.7315
# [task3] target=gender fold=4 epoch=14/30 train_loss=0.0386 train_macro_f1=0.9856 validation_loss=0.4171 validation_macro_f1=0.7039
# [task3] target=gender fold=4 epoch=15/30 train_loss=0.0255 train_macro_f1=0.9935 validation_loss=0.3757 validation_macro_f1=0.7281
# [task3] target=gender fold=4 epoch=16/30 train_loss=0.0197 train_macro_f1=0.9962 validation_loss=0.4948 validation_macro_f1=0.7117
# [task3] target=gender fold=4 epoch=17/30 train_loss=0.0132 train_macro_f1=0.9987 validation_loss=0.4089 validation_macro_f1=0.7400
# [task3] target=gender fold=4 epoch=18/30 train_loss=0.0110 train_macro_f1=0.9992 validation_loss=0.4402 validation_macro_f1=0.7243
# [task3] target=gender fold=4 epoch=19/30 train_loss=0.0083 train_macro_f1=0.9996 validation_loss=0.4184 validation_macro_f1=0.7109
# [task3] target=gender fold=4 epoch=20/30 train_loss=0.0078 train_macro_f1=0.9994 validation_loss=0.4732 validation_macro_f1=0.7192
# [task3] target=gender fold=4 epoch=21/30 train_loss=0.0060 train_macro_f1=0.9998 validation_loss=0.4164 validation_macro_f1=0.7283
# [task3] target=gender fold=4 epoch=22/30 train_loss=0.0048 train_macro_f1=0.9999 validation_loss=0.4259 validation_macro_f1=0.7277
# [task3] target=gender fold=4 epoch=23/30 train_loss=0.0046 train_macro_f1=0.9998 validation_loss=0.5701 validation_macro_f1=0.7058
# [task3] target=gender fold=4 epoch=24/30 train_loss=0.0039 train_macro_f1=0.9999 validation_loss=0.4669 validation_macro_f1=0.7131
# [task3] target=gender fold=4 epoch=25/30 train_loss=0.0038 train_macro_f1=0.9998 validation_loss=0.4421 validation_macro_f1=0.7285
# [task3] target=gender fold=4 epoch=26/30 train_loss=0.0034 train_macro_f1=0.9998 validation_loss=0.4435 validation_macro_f1=0.7227
# [task3] target=gender fold=4 epoch=27/30 train_loss=0.0032 train_macro_f1=0.9998 validation_loss=0.4345 validation_macro_f1=0.7255
# [task3] target=gender fold=4 epoch=28/30 train_loss=0.0031 train_macro_f1=0.9999 validation_loss=0.4326 validation_macro_f1=0.7270
# [task3] target=gender fold=4 epoch=29/30 train_loss=0.0029 train_macro_f1=0.9999 validation_loss=0.4388 validation_macro_f1=0.7259
# [task3] target=gender fold=4 epoch=30/30 train_loss=0.0029 train_macro_f1=0.9998 validation_loss=0.4398 validation_macro_f1=0.7263
# [task3] completed target=gender fold=4: t3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd
# [task3] completed pooled five-fold OOF experiment=t3_gender_gem_p3_smallcnn target=gender
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_gender_e6_gem_p3/gender/aggregate/metrics.json',
#  'macro_f1': 0.7335205888652532,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_gender_e6_gem_p3_gender_smallcnngem3_f0_s2753_a8c09286451b_20260831T090059Z0bab1f',
#    't3_gender_e6_gem_p3_gender_smallcnngem3_f1_s2753_a8c09286451b_20260831T090940Z6e10b5',
#    't3_gender_e6_gem_p3_gender_smallcnngem3_f2_s2753_a8c09286451b_20260831T091823Zabb677',
#    't3_gender_e6_gem_p3_gender_smallcnngem3_f3_s2753_a8c09286451b_20260831T092710Zee7c6a',
#    't3_gender_e6_gem_p3_gender_smallcnngem3_f4_s2753_a8c09286451b_20260831T093553Z63b5fd'],
#   'completed_rows': 5,
#   'ready': True}}

# %% [markdown]
# ## 5. Train Usage E6: class-balanced focal loss `gamma=1`
#
# This changes only the accepted E2 loss modulation.

# %%
usage_e6_result = run_task3_child_cv(
    "usage_focal_gamma1",
    parent_run_ids=usage_parent_run_ids,
    folds=range(5),
    root=REPO_DIR,
    output_root=DRIVE_TASK_DIR,
    registry_path=DRIVE_REGISTRY,
    registry_mirrors=[REPO_DIR / "results/runs.csv"],
    device_name="cuda",
)
usage_e6_registry_audit = audit_completed_registry_rows(
    DRIVE_REGISTRY, usage_e6_result["fold_run_ids"]
)
{
    "metrics_path": usage_e6_result["metrics_path"],
    "macro_f1": usage_e6_result["metrics"]["macro_f1"],
    "macro_f1_without_home": usage_e6_result["metrics"]["macro_f1_without_home"],
    "registry_audit": usage_e6_registry_audit,
}
# Out:
# [task3] starting five-fold experiment=t3_usage_focal_gamma1_smallcnn for target=usage
# [task3] preparing target=usage fold=0: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=0
# [task3] RGB statistics ready for target=usage fold=0
# [task3] registered t3_usage_e6_focal_gamma1_usage_smallcnn_f0_s2753_d78d360d01b2_20260831T094442Z22542c; the first optimiser step may now run
# [task3] target=usage fold=0 epoch=1/30 train_loss=0.9756 train_macro_f1=0.1700 validation_loss=0.8695 validation_macro_f1=0.1785
# [task3] target=usage fold=0 epoch=2/30 train_loss=0.8482 train_macro_f1=0.2512 validation_loss=0.7869 validation_macro_f1=0.2277
# [task3] target=usage fold=0 epoch=3/30 train_loss=0.7099 train_macro_f1=0.2986 validation_loss=0.7089 validation_macro_f1=0.2717
# [task3] target=usage fold=0 epoch=4/30 train_loss=0.6097 train_macro_f1=0.3152 validation_loss=0.6154 validation_macro_f1=0.3087
# [task3] target=usage fold=0 epoch=5/30 train_loss=0.5566 train_macro_f1=0.3565 validation_loss=0.6264 validation_macro_f1=0.2943
# [task3] target=usage fold=0 epoch=6/30 train_loss=0.5152 train_macro_f1=0.3389 validation_loss=0.8673 validation_macro_f1=0.2775
# [task3] target=usage fold=0 epoch=7/30 train_loss=0.4354 train_macro_f1=0.3863 validation_loss=0.5826 validation_macro_f1=0.3270
# [task3] target=usage fold=0 epoch=8/30 train_loss=0.3911 train_macro_f1=0.3956 validation_loss=0.9326 validation_macro_f1=0.2427
# [task3] target=usage fold=0 epoch=9/30 train_loss=0.3472 train_macro_f1=0.5073 validation_loss=0.6209 validation_macro_f1=0.3427
# [task3] target=usage fold=0 epoch=10/30 train_loss=0.2945 train_macro_f1=0.5223 validation_loss=0.6769 validation_macro_f1=0.3481
# [task3] target=usage fold=0 epoch=11/30 train_loss=0.2642 train_macro_f1=0.5940 validation_loss=0.6455 validation_macro_f1=0.3066
# [task3] target=usage fold=0 epoch=12/30 train_loss=0.2330 train_macro_f1=0.6387 validation_loss=0.8343 validation_macro_f1=0.3436
# [task3] target=usage fold=0 epoch=13/30 train_loss=0.2093 train_macro_f1=0.6865 validation_loss=0.7562 validation_macro_f1=0.3335
# [task3] target=usage fold=0 epoch=14/30 train_loss=0.1922 train_macro_f1=0.7162 validation_loss=0.6291 validation_macro_f1=0.3798
# [task3] target=usage fold=0 epoch=15/30 train_loss=0.1646 train_macro_f1=0.7644 validation_loss=0.6305 validation_macro_f1=0.3601
# [task3] target=usage fold=0 epoch=16/30 train_loss=0.1475 train_macro_f1=0.8019 validation_loss=0.8395 validation_macro_f1=0.3668
# [task3] target=usage fold=0 epoch=17/30 train_loss=0.1377 train_macro_f1=0.8432 validation_loss=0.7469 validation_macro_f1=0.3630
# [task3] target=usage fold=0 epoch=18/30 train_loss=0.1273 train_macro_f1=0.8607 validation_loss=0.8109 validation_macro_f1=0.3625
# [task3] target=usage fold=0 epoch=19/30 train_loss=0.1171 train_macro_f1=0.8596 validation_loss=0.8817 validation_macro_f1=0.3940
# [task3] target=usage fold=0 epoch=20/30 train_loss=0.1063 train_macro_f1=0.8918 validation_loss=0.9383 validation_macro_f1=0.3606
# [task3] target=usage fold=0 epoch=21/30 train_loss=0.0990 train_macro_f1=0.9112 validation_loss=0.9376 validation_macro_f1=0.3819
# [task3] target=usage fold=0 epoch=22/30 train_loss=0.0932 train_macro_f1=0.9125 validation_loss=0.8650 validation_macro_f1=0.3923
# [task3] target=usage fold=0 epoch=23/30 train_loss=0.0874 train_macro_f1=0.9251 validation_loss=0.9787 validation_macro_f1=0.3939
# [task3] target=usage fold=0 epoch=24/30 train_loss=0.0805 train_macro_f1=0.9372 validation_loss=0.9651 validation_macro_f1=0.3916
# [task3] target=usage fold=0 epoch=25/30 train_loss=0.0760 train_macro_f1=0.9435 validation_loss=0.8714 validation_macro_f1=0.4309
# [task3] target=usage fold=0 epoch=26/30 train_loss=0.0724 train_macro_f1=0.9497 validation_loss=0.8598 validation_macro_f1=0.4117
# [task3] target=usage fold=0 epoch=27/30 train_loss=0.0692 train_macro_f1=0.9537 validation_loss=0.9006 validation_macro_f1=0.4116
# [task3] target=usage fold=0 epoch=28/30 train_loss=0.0667 train_macro_f1=0.9537 validation_loss=0.8796 validation_macro_f1=0.4175
# [task3] target=usage fold=0 epoch=29/30 train_loss=0.0652 train_macro_f1=0.9555 validation_loss=0.8947 validation_macro_f1=0.4156
# [task3] target=usage fold=0 epoch=30/30 train_loss=0.0645 train_macro_f1=0.9580 validation_loss=0.8896 validation_macro_f1=0.4173
# [task3] completed target=usage fold=0: t3_usage_e6_focal_gamma1_usage_smallcnn_f0_s2753_d78d360d01b2_20260831T094442Z22542c
# [task3] preparing target=usage fold=1: train=26,216, validation=6,556
# [task3] fitting fold-training RGB statistics for target=usage fold=1
# [task3] RGB statistics ready for target=usage fold=1
# [task3] registered t3_usage_e6_focal_gamma1_usage_smallcnn_f1_s2753_d78d360d01b2_20260831T095326Z8d3f13; the first optimiser step may now run
# [task3] target=usage fold=1 epoch=1/30 train_loss=1.0738 train_macro_f1=0.1738 validation_loss=0.8108 validation_macro_f1=0.2142
# [task3] target=usage fold=1 epoch=2/30 train_loss=0.7729 train_macro_f1=0.2584 validation_loss=0.7503 validation_macro_f1=0.2627
# [task3] target=usage fold=1 epoch=3/30 train_loss=0.7176 train_macro_f1=0.2919 validation_loss=0.7149 validation_macro_f1=0.2522
# [task3] target=usage fold=1 epoch=4/30 train_loss=0.6154 train_macro_f1=0.3262 validation_loss=0.8115 validation_macro_f1=0.2652
# [task3] target=usage fold=1 epoch=5/30 train_loss=0.5698 train_macro_f1=0.3346 validation_loss=1.1305 validation_macro_f1=0.2453
# [task3] target=usage fold=1 epoch=6/30 train_loss=0.5161 train_macro_f1=0.3455 validation_loss=1.0590 validation_macro_f1=0.2029
# [task3] target=usage fold=1 epoch=7/30 train_loss=0.4393 train_macro_f1=0.3897 validation_loss=0.6132 validation_macro_f1=0.3132
# [task3] target=usage fold=1 epoch=8/30 train_loss=0.3821 train_macro_f1=0.3988 validation_loss=0.5563 validation_macro_f1=0.3167
# [task3] target=usage fold=1 epoch=9/30 train_loss=0.3329 train_macro_f1=0.5242 validation_loss=0.7240 validation_macro_f1=0.2992
# [task3] target=usage fold=1 epoch=10/30 train_loss=0.2770 train_macro_f1=0.5685 validation_loss=0.6716 validation_macro_f1=0.3232
# [task3] target=usage fold=1 epoch=11/30 train_loss=0.2477 train_macro_f1=0.6087 validation_loss=0.7086 validation_macro_f1=0.3729
# [task3] target=usage fold=1 epoch=12/30 train_loss=0.2164 train_macro_f1=0.6682 validation_loss=0.6972 validation_macro_f1=0.3380
# [task3] target=usage fold=1 epoch=13/30 train_loss=0.1955 train_macro_f1=0.7213 validation_loss=0.6574 validation_macro_f1=0.3523
# [task3] target=usage fold=1 epoch=14/30 train_loss=0.1697 train_macro_f1=0.7675 validation_loss=0.8474 validation_macro_f1=0.2850
# [task3] target=usage fold=1 epoch=15/30 train_loss=0.1653 train_macro_f1=0.7421 validation_loss=0.6240 validation_macro_f1=0.3681
# [task3] target=usage fold=1 epoch=16/30 train_loss=0.1519 train_macro_f1=0.7934 validation_loss=0.7205 validation_macro_f1=0.3446
# [task3] target=usage fold=1 epoch=17/30 train_loss=0.1320 train_macro_f1=0.8328 validation_loss=0.8949 validation_macro_f1=0.3141
# [task3] target=usage fold=1 epoch=18/30 train_loss=0.1210 train_macro_f1=0.8560 validation_loss=0.8344 validation_macro_f1=0.3674
# [task3] target=usage fold=1 epoch=19/30 train_loss=0.1128 train_macro_f1=0.8628 validation_loss=0.9499 validation_macro_f1=0.3011
# [task3] target=usage fold=1 epoch=20/30 train_loss=0.1008 train_macro_f1=0.9045 validation_loss=0.8221 validation_macro_f1=0.3690
# [task3] target=usage fold=1 epoch=21/30 train_loss=0.0950 train_macro_f1=0.9171 validation_loss=0.8351 validation_macro_f1=0.3694
# [task3] target=usage fold=1 epoch=22/30 train_loss=0.0864 train_macro_f1=0.9141 validation_loss=0.8336 validation_macro_f1=0.3574
# [task3] target=usage fold=1 epoch=23/30 train_loss=0.0811 train_macro_f1=0.9282 validation_loss=0.7457 validation_macro_f1=0.3779
# [task3] target=usage fold=1 epoch=24/30 train_loss=0.0750 train_macro_f1=0.9384 validation_loss=0.8364 validation_macro_f1=0.3927
# [task3] target=usage fold=1 epoch=25/30 train_loss=0.0710 train_macro_f1=0.9473 validation_loss=0.9132 validation_macro_f1=0.3646
# [task3] target=usage fold=1 epoch=26/30 train_loss=0.0670 train_macro_f1=0.9518 validation_loss=0.8094 validation_macro_f1=0.3892
# [task3] target=usage fold=1 epoch=27/30 train_loss=0.0639 train_macro_f1=0.9562 validation_loss=0.8661 validation_macro_f1=0.3821
# [task3] target=usage fold=1 epoch=28/30 train_loss=0.0617 train_macro_f1=0.9595 validation_loss=0.8206 validation_macro_f1=0.3868
# [task3] target=usage fold=1 epoch=29/30 train_loss=0.0600 train_macro_f1=0.9573 validation_loss=0.8415 validation_macro_f1=0.3828
# [task3] target=usage fold=1 epoch=30/30 train_loss=0.0593 train_macro_f1=0.9590 validation_loss=0.8560 validation_macro_f1=0.3882
# [task3] completed target=usage fold=1: t3_usage_e6_focal_gamma1_usage_smallcnn_f1_s2753_d78d360d01b2_20260831T095326Z8d3f13
# [task3] preparing target=usage fold=2: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=2
# [task3] RGB statistics ready for target=usage fold=2
# [task3] registered t3_usage_e6_focal_gamma1_usage_smallcnn_f2_s2753_d78d360d01b2_20260831T100213Z453f7d; the first optimiser step may now run
# [task3] target=usage fold=2 epoch=1/30 train_loss=0.9364 train_macro_f1=0.1747 validation_loss=0.8857 validation_macro_f1=0.1947
# [task3] target=usage fold=2 epoch=2/30 train_loss=0.8461 train_macro_f1=0.2640 validation_loss=0.7472 validation_macro_f1=0.2183
# [task3] target=usage fold=2 epoch=3/30 train_loss=0.6785 train_macro_f1=0.3012 validation_loss=0.8919 validation_macro_f1=0.2323
# [task3] target=usage fold=2 epoch=4/30 train_loss=0.6077 train_macro_f1=0.3283 validation_loss=0.7579 validation_macro_f1=0.2673
# [task3] target=usage fold=2 epoch=5/30 train_loss=0.5839 train_macro_f1=0.3329 validation_loss=0.6286 validation_macro_f1=0.2923
# [task3] target=usage fold=2 epoch=6/30 train_loss=0.4974 train_macro_f1=0.3767 validation_loss=0.5933 validation_macro_f1=0.3168
# [task3] target=usage fold=2 epoch=7/30 train_loss=0.4191 train_macro_f1=0.3745 validation_loss=0.5613 validation_macro_f1=0.3381
# [task3] target=usage fold=2 epoch=8/30 train_loss=0.3737 train_macro_f1=0.4081 validation_loss=0.6981 validation_macro_f1=0.3335
# [task3] target=usage fold=2 epoch=9/30 train_loss=0.3544 train_macro_f1=0.4299 validation_loss=0.6649 validation_macro_f1=0.2809
# [task3] target=usage fold=2 epoch=10/30 train_loss=0.2920 train_macro_f1=0.5203 validation_loss=0.7057 validation_macro_f1=0.3317
# [task3] target=usage fold=2 epoch=11/30 train_loss=0.2600 train_macro_f1=0.6186 validation_loss=0.5773 validation_macro_f1=0.3559
# [task3] target=usage fold=2 epoch=12/30 train_loss=0.2258 train_macro_f1=0.6316 validation_loss=0.8109 validation_macro_f1=0.3245
# [task3] target=usage fold=2 epoch=13/30 train_loss=0.2142 train_macro_f1=0.6410 validation_loss=0.6767 validation_macro_f1=0.3672
# [task3] target=usage fold=2 epoch=14/30 train_loss=0.1815 train_macro_f1=0.7228 validation_loss=0.6933 validation_macro_f1=0.3615
# [task3] target=usage fold=2 epoch=15/30 train_loss=0.1662 train_macro_f1=0.7410 validation_loss=0.7069 validation_macro_f1=0.3598
# [task3] target=usage fold=2 epoch=16/30 train_loss=0.1605 train_macro_f1=0.7630 validation_loss=0.7694 validation_macro_f1=0.3746
# [task3] target=usage fold=2 epoch=17/30 train_loss=0.1396 train_macro_f1=0.8125 validation_loss=0.7260 validation_macro_f1=0.4357
# [task3] target=usage fold=2 epoch=18/30 train_loss=0.1240 train_macro_f1=0.8560 validation_loss=0.7311 validation_macro_f1=0.4158
# [task3] target=usage fold=2 epoch=19/30 train_loss=0.1183 train_macro_f1=0.8628 validation_loss=0.7705 validation_macro_f1=0.3916
# [task3] target=usage fold=2 epoch=20/30 train_loss=0.1079 train_macro_f1=0.8734 validation_loss=0.7114 validation_macro_f1=0.4175
# [task3] target=usage fold=2 epoch=21/30 train_loss=0.0991 train_macro_f1=0.9047 validation_loss=0.7589 validation_macro_f1=0.4157
# [task3] target=usage fold=2 epoch=22/30 train_loss=0.0934 train_macro_f1=0.9097 validation_loss=0.9902 validation_macro_f1=0.3810
# [task3] target=usage fold=2 epoch=23/30 train_loss=0.0881 train_macro_f1=0.9187 validation_loss=0.7987 validation_macro_f1=0.4198
# [task3] target=usage fold=2 epoch=24/30 train_loss=0.0806 train_macro_f1=0.9289 validation_loss=0.7264 validation_macro_f1=0.4256
# [task3] target=usage fold=2 epoch=25/30 train_loss=0.0766 train_macro_f1=0.9406 validation_loss=0.7629 validation_macro_f1=0.4477
# [task3] target=usage fold=2 epoch=26/30 train_loss=0.0730 train_macro_f1=0.9409 validation_loss=0.7627 validation_macro_f1=0.4326
# [task3] target=usage fold=2 epoch=27/30 train_loss=0.0697 train_macro_f1=0.9428 validation_loss=0.8086 validation_macro_f1=0.4432
# [task3] target=usage fold=2 epoch=28/30 train_loss=0.0671 train_macro_f1=0.9489 validation_loss=0.8346 validation_macro_f1=0.4232
# [task3] target=usage fold=2 epoch=29/30 train_loss=0.0661 train_macro_f1=0.9521 validation_loss=0.7800 validation_macro_f1=0.4412
# [task3] target=usage fold=2 epoch=30/30 train_loss=0.0649 train_macro_f1=0.9521 validation_loss=0.7759 validation_macro_f1=0.4422
# [task3] completed target=usage fold=2: t3_usage_e6_focal_gamma1_usage_smallcnn_f2_s2753_d78d360d01b2_20260831T100213Z453f7d
# [task3] preparing target=usage fold=3: train=26,219, validation=6,553
# [task3] fitting fold-training RGB statistics for target=usage fold=3
# [task3] RGB statistics ready for target=usage fold=3
# [task3] registered t3_usage_e6_focal_gamma1_usage_smallcnn_f3_s2753_d78d360d01b2_20260831T101101Z24818e; the first optimiser step may now run
# [task3] target=usage fold=3 epoch=1/30 train_loss=1.0202 train_macro_f1=0.1709 validation_loss=0.9664 validation_macro_f1=0.1772
# [task3] target=usage fold=3 epoch=2/30 train_loss=0.7788 train_macro_f1=0.2573 validation_loss=0.8060 validation_macro_f1=0.1988
# [task3] target=usage fold=3 epoch=3/30 train_loss=0.6740 train_macro_f1=0.2977 validation_loss=0.8380 validation_macro_f1=0.2679
# [task3] target=usage fold=3 epoch=4/30 train_loss=0.6219 train_macro_f1=0.3054 validation_loss=0.7017 validation_macro_f1=0.2553
# [task3] target=usage fold=3 epoch=5/30 train_loss=0.5481 train_macro_f1=0.3356 validation_loss=0.6997 validation_macro_f1=0.2462
# [task3] target=usage fold=3 epoch=6/30 train_loss=0.4548 train_macro_f1=0.3648 validation_loss=0.6985 validation_macro_f1=0.3047
# [task3] target=usage fold=3 epoch=7/30 train_loss=0.4207 train_macro_f1=0.3610 validation_loss=0.7733 validation_macro_f1=0.3299
# [task3] target=usage fold=3 epoch=8/30 train_loss=0.3661 train_macro_f1=0.4087 validation_loss=0.6941 validation_macro_f1=0.3133
# [task3] target=usage fold=3 epoch=9/30 train_loss=0.3215 train_macro_f1=0.5216 validation_loss=0.6348 validation_macro_f1=0.3197
# [task3] target=usage fold=3 epoch=10/30 train_loss=0.2782 train_macro_f1=0.5789 validation_loss=0.8383 validation_macro_f1=0.3026
# [task3] target=usage fold=3 epoch=11/30 train_loss=0.2519 train_macro_f1=0.6057 validation_loss=0.7447 validation_macro_f1=0.3244
# [task3] target=usage fold=3 epoch=12/30 train_loss=0.2216 train_macro_f1=0.6243 validation_loss=0.6095 validation_macro_f1=0.3773
# [task3] target=usage fold=3 epoch=13/30 train_loss=0.1948 train_macro_f1=0.7053 validation_loss=0.7507 validation_macro_f1=0.3516
# [task3] target=usage fold=3 epoch=14/30 train_loss=0.1830 train_macro_f1=0.7105 validation_loss=0.7582 validation_macro_f1=0.3286
# [task3] target=usage fold=3 epoch=15/30 train_loss=0.1706 train_macro_f1=0.7119 validation_loss=0.8683 validation_macro_f1=0.2848
# [task3] target=usage fold=3 epoch=16/30 train_loss=0.1481 train_macro_f1=0.7740 validation_loss=0.7473 validation_macro_f1=0.3781
# [task3] target=usage fold=3 epoch=17/30 train_loss=0.1315 train_macro_f1=0.8208 validation_loss=0.9797 validation_macro_f1=0.3615
# [task3] target=usage fold=3 epoch=18/30 train_loss=0.1186 train_macro_f1=0.8634 validation_loss=0.7357 validation_macro_f1=0.3929
# [task3] target=usage fold=3 epoch=19/30 train_loss=0.1070 train_macro_f1=0.8841 validation_loss=0.8112 validation_macro_f1=0.3998
# [task3] target=usage fold=3 epoch=20/30 train_loss=0.0995 train_macro_f1=0.8994 validation_loss=0.7953 validation_macro_f1=0.3856
# [task3] target=usage fold=3 epoch=21/30 train_loss=0.0931 train_macro_f1=0.9054 validation_loss=0.9362 validation_macro_f1=0.3414
# [task3] target=usage fold=3 epoch=22/30 train_loss=0.0859 train_macro_f1=0.9170 validation_loss=0.9404 validation_macro_f1=0.3699
# [task3] target=usage fold=3 epoch=23/30 train_loss=0.0802 train_macro_f1=0.9258 validation_loss=0.9822 validation_macro_f1=0.3476
# [task3] target=usage fold=3 epoch=24/30 train_loss=0.0748 train_macro_f1=0.9318 validation_loss=0.8569 validation_macro_f1=0.3765
# [task3] target=usage fold=3 epoch=25/30 train_loss=0.0687 train_macro_f1=0.9401 validation_loss=0.8113 validation_macro_f1=0.4051
# [task3] target=usage fold=3 epoch=26/30 train_loss=0.0660 train_macro_f1=0.9412 validation_loss=0.8551 validation_macro_f1=0.3940
# [task3] target=usage fold=3 epoch=27/30 train_loss=0.0620 train_macro_f1=0.9561 validation_loss=0.8580 validation_macro_f1=0.3902
# [task3] target=usage fold=3 epoch=28/30 train_loss=0.0602 train_macro_f1=0.9570 validation_loss=0.8419 validation_macro_f1=0.3944
# [task3] target=usage fold=3 epoch=29/30 train_loss=0.0586 train_macro_f1=0.9545 validation_loss=0.8341 validation_macro_f1=0.3956
# [task3] target=usage fold=3 epoch=30/30 train_loss=0.0579 train_macro_f1=0.9587 validation_loss=0.8565 validation_macro_f1=0.3939
# [task3] completed target=usage fold=3: t3_usage_e6_focal_gamma1_usage_smallcnn_f3_s2753_d78d360d01b2_20260831T101101Z24818e
# [task3] preparing target=usage fold=4: train=26,215, validation=6,557
# [task3] fitting fold-training RGB statistics for target=usage fold=4
# [task3] RGB statistics ready for target=usage fold=4
# [task3] registered t3_usage_e6_focal_gamma1_usage_smallcnn_f4_s2753_d78d360d01b2_20260831T101946Z418c62; the first optimiser step may now run
# [task3] target=usage fold=4 epoch=1/30 train_loss=0.9012 train_macro_f1=0.1671 validation_loss=0.8633 validation_macro_f1=0.2179
# [task3] target=usage fold=4 epoch=2/30 train_loss=0.7097 train_macro_f1=0.2654 validation_loss=1.6064 validation_macro_f1=0.1103
# [task3] target=usage fold=4 epoch=3/30 train_loss=0.6222 train_macro_f1=0.3075 validation_loss=0.9409 validation_macro_f1=0.2556
# [task3] target=usage fold=4 epoch=4/30 train_loss=0.5698 train_macro_f1=0.3250 validation_loss=1.4723 validation_macro_f1=0.1700
# [task3] target=usage fold=4 epoch=5/30 train_loss=0.4926 train_macro_f1=0.3449 validation_loss=0.7640 validation_macro_f1=0.2726
# [task3] target=usage fold=4 epoch=6/30 train_loss=0.4677 train_macro_f1=0.3472 validation_loss=0.6515 validation_macro_f1=0.3158
# [task3] target=usage fold=4 epoch=7/30 train_loss=0.4021 train_macro_f1=0.3877 validation_loss=0.9989 validation_macro_f1=0.2637
# [task3] target=usage fold=4 epoch=8/30 train_loss=0.3699 train_macro_f1=0.3929 validation_loss=0.7918 validation_macro_f1=0.2637
# [task3] target=usage fold=4 epoch=9/30 train_loss=0.3369 train_macro_f1=0.4108 validation_loss=0.7093 validation_macro_f1=0.2961
# [task3] target=usage fold=4 epoch=10/30 train_loss=0.2811 train_macro_f1=0.4695 validation_loss=0.6337 validation_macro_f1=0.2625
# [task3] target=usage fold=4 epoch=11/30 train_loss=0.2470 train_macro_f1=0.5164 validation_loss=0.5728 validation_macro_f1=0.3356
# [task3] target=usage fold=4 epoch=12/30 train_loss=0.2176 train_macro_f1=0.5815 validation_loss=0.8781 validation_macro_f1=0.3181
# [task3] target=usage fold=4 epoch=13/30 train_loss=0.1896 train_macro_f1=0.6133 validation_loss=1.0537 validation_macro_f1=0.2744
# [task3] target=usage fold=4 epoch=14/30 train_loss=0.1778 train_macro_f1=0.6391 validation_loss=0.6829 validation_macro_f1=0.3635
# [task3] target=usage fold=4 epoch=15/30 train_loss=0.1560 train_macro_f1=0.6827 validation_loss=0.7370 validation_macro_f1=0.3177
# [task3] target=usage fold=4 epoch=16/30 train_loss=0.1417 train_macro_f1=0.7079 validation_loss=0.6875 validation_macro_f1=0.3496
# [task3] target=usage fold=4 epoch=17/30 train_loss=0.1311 train_macro_f1=0.7231 validation_loss=0.7467 validation_macro_f1=0.3769
# [task3] target=usage fold=4 epoch=18/30 train_loss=0.1180 train_macro_f1=0.7621 validation_loss=0.8300 validation_macro_f1=0.3339
# [task3] target=usage fold=4 epoch=19/30 train_loss=0.1100 train_macro_f1=0.7726 validation_loss=0.7955 validation_macro_f1=0.3668
# [task3] target=usage fold=4 epoch=20/30 train_loss=0.1005 train_macro_f1=0.8047 validation_loss=0.9262 validation_macro_f1=0.3361
# [task3] target=usage fold=4 epoch=21/30 train_loss=0.0939 train_macro_f1=0.8049 validation_loss=0.7253 validation_macro_f1=0.3936
# [task3] target=usage fold=4 epoch=22/30 train_loss=0.0854 train_macro_f1=0.8222 validation_loss=0.7114 validation_macro_f1=0.3642
# [task3] target=usage fold=4 epoch=23/30 train_loss=0.0794 train_macro_f1=0.8180 validation_loss=0.9119 validation_macro_f1=0.3505
# [task3] target=usage fold=4 epoch=24/30 train_loss=0.0740 train_macro_f1=0.8284 validation_loss=0.7607 validation_macro_f1=0.3985
# [task3] target=usage fold=4 epoch=25/30 train_loss=0.0696 train_macro_f1=0.8347 validation_loss=0.7597 validation_macro_f1=0.3870
# [task3] target=usage fold=4 epoch=26/30 train_loss=0.0656 train_macro_f1=0.8384 validation_loss=0.7080 validation_macro_f1=0.4026
# [task3] target=usage fold=4 epoch=27/30 train_loss=0.0622 train_macro_f1=0.8392 validation_loss=0.7623 validation_macro_f1=0.3862
# [task3] target=usage fold=4 epoch=28/30 train_loss=0.0603 train_macro_f1=0.8453 validation_loss=0.7370 validation_macro_f1=0.4079
# [task3] target=usage fold=4 epoch=29/30 train_loss=0.0588 train_macro_f1=0.8434 validation_loss=0.7536 validation_macro_f1=0.4082
# [task3] target=usage fold=4 epoch=30/30 train_loss=0.0576 train_macro_f1=0.8426 validation_loss=0.7695 validation_macro_f1=0.3866
# [task3] completed target=usage fold=4: t3_usage_e6_focal_gamma1_usage_smallcnn_f4_s2753_d78d360d01b2_20260831T101946Z418c62
# [task3] completed pooled five-fold OOF experiment=t3_usage_focal_gamma1_smallcnn target=usage
# {'metrics_path': '/content/drive/MyDrive/MLA2/task3/experiments/t3_usage_e6_focal_gamma1/usage/aggregate/metrics.json',
#  'macro_f1': 0.4093852071360374,
#  'macro_f1_without_home': 0.460558358028042,
#  'registry_audit': {'registry_path': '/content/drive/MyDrive/MLA2/task3/results/runs.csv',
#   'run_ids': ['t3_usage_e6_focal_gamma1_usage_smallcnn_f0_s2753_d78d360d01b2_20260831T094442Z22542c',
#    't3_usage_e6_focal_gamma1_usage_smallcnn_f1_s2753_d78d360d01b2_20260831T095326Z8d3f13',
#    't3_usage_e6_focal_gamma1_usage_smallcnn_f2_s2753_d78d360d01b2_20260831T100213Z453f7d',
#    't3_usage_e6_focal_gamma1_usage_smallcnn_f3_s2753_d78d360d01b2_20260831T101101Z24818e',
#    't3_usage_e6_focal_gamma1_usage_smallcnn_f4_s2753_d78d360d01b2_20260831T101946Z418c62'],
#   'completed_rows': 5,
#   'ready': True}}

# %% [markdown]
# ## 6. Show the first parent–child comparison
#
# The main Task 3 notebook performs the full frozen-gate analysis.

# %%
import pandas as pd

parent_metric_paths = {
    "gender": DRIVE_TASK_DIR / "baseline/gender/aggregate/metrics.json",
    "usage": DRIVE_TASK_DIR / "experiments/t3_usage_e2_class_balanced_ce/usage/aggregate/metrics.json",
}
children = {"gender": gender_e6_result, "usage": usage_e6_result}
comparison = []
for target, child in children.items():
    parent = json.loads(parent_metric_paths[target].read_text(encoding="utf-8"))
    comparison.append({
        "target": target,
        "parent_macro_f1": parent["macro_f1"],
        "e6_macro_f1": child["metrics"]["macro_f1"],
        "macro_f1_change": child["metrics"]["macro_f1"] - parent["macro_f1"],
        "model_family": child["metrics"]["model_family"],
        "parameter_count": child["metrics"]["parameter_count"],
        "e6_metrics_path": child["metrics_path"],
    })
pd.DataFrame(comparison)
# Out:
#    target  parent_macro_f1  e6_macro_f1  macro_f1_change  \
# 0  gender         0.711753     0.733521         0.021768
# 1   usage         0.408171     0.409385         0.001215
#
#              model_family  parameter_count  \
# 0  task3_small_cnn_gem_p3           390181
# 1         task3_small_cnn           391209
#
#                                      e6_metrics_path
# 0  /content/drive/MyDrive/MLA2/task3/experiments/...
# 1  /content/drive/MyDrive/MLA2/task3/experiments/...
